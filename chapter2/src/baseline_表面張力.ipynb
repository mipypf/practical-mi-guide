# %% [markdown]
# # 表面張力のbaselineモデル（PLS）を構築

# %% [markdown]
# ## ライブラリをインポート

# %%
import japanize_matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from adjustText import adjust_text
from pandas import json_normalize
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tqdm.notebook import tqdm

# %% [markdown]
# ## グラフ表示の際のフォント種類やフォントサイズを設定

# %%
plt.rcParams["font.size"] = 20
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["xtick.labelsize"] = 20
plt.rcParams["ytick.labelsize"] = 20
plt.rcParams["axes.titlesize"] = 20
plt.rcParams["font.family"] = "IPAexGothic"  #'Times New Roman'

# %% [markdown]
# ## ファイルのコンフィグ情報を定義

# %%
class CFG:
    input_dir = "../input"
    output_dir = "../output"
    random_seed = 42
    exp_no = "exp000"
    target = "表面張力"

# %% [markdown]
# ## データを読み込み、データフレームに格納

# %%
train_df = pd.read_csv(f"{CFG.input_dir}/chapter2_demo_data_postprocess.csv")
train_df
# Out:
#     サンプルID                                        サンプル名    サンプル作成日 担当者  \
# 0   DP_001                                       界1_2.0  2024/1/19  高岡
# 1   DP_002                                       界1_1.5  2024/1/19  高岡
# 2   DP_003                                       界1_1.2  2024/1/19  高岡
# 3   DP_004                                       界1_1.0  2024/1/19  高岡
# 4   DP_005                                       界1_0.5  2024/1/19  高岡
# 5   DP_006                            界1_1.5_樹1_4.0_ref  2024/1/30  福原
# 6   DP_007                                界2_1.5_樹1_4.0  2024/1/30  福原
# 7   DP_008                                界3_1.5_樹1_4.0  2024/1/30  福原
# 8   DP_009                                界1_1.5_樹1_6.0  2024/1/30  福原
# 9   DP_010                                界1_1.5_樹1_8.0  2024/1/30  福原
# 10  DP_011                               界1_1.5_樹1_10.0  2024/1/30  福原
# 11  DP_012                                界1_1.5_樹2_4.0  2024/1/30  福原
# 12  DP_013                                界1_1.5_樹2_6.0  2024/1/30  福原
# 13  DP_014                               界1_1.5_樹2_10.0  2024/1/30  福原
# 14  DP_015                      界1_1.5_樹1_8.0_100℃_0.01  2024/2/15  高岡
# 15  DP_016                      界1_1.5_樹1_8.0_100℃_0.05  2024/2/15  高岡
# 16  DP_017                       界1_1.5_樹1_8.0_80℃_0.01  2024/2/15  高岡
# 17  DP_018                      界1_1.5_樹1_8.0_120℃_0.01  2024/2/15  高岡
# 18  DP_019       溶2_40_添1_2_界1_1.5_樹1_8.0_100℃_0.05_ref  2024/2/28  福原
# 19  DP_020           溶3_40_添1_2_界1_1.5_樹1_8.0_100℃_0.05  2024/2/28  福原
# 20  DP_021           溶2_40_添1_5_界1_1.5_樹1_8.0_100℃_0.05  2024/2/28  福原
# 21  DP_022           溶2_40_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/2/28  福原
# 22  DP_023           溶3_40_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 23  DP_024           溶3_40_添2_5_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 24  DP_025           溶3_45_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 25  DP_026           溶5_35_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 26  DP_027  溶3_40_添2_2_界1_1.5_顔1_5_樹1_8.0_100℃_0.05_ref  2024/4/10  高岡
# 27  DP_028    溶3_40_添2_2_界1_1.5_顔1_7.5_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 28  DP_029     溶3_40_添2_2_界1_1.5_顔1_10_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 29  DP_030      溶3_40_添2_2_界1_1.5_顔2_5_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 30  DP_031    溶3_40_添2_2_界1_1.5_顔2_7.5_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 31  DP_032     溶3_40_添2_2_界1_1.5_顔2_10_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 32  DP_033  溶3_40_添2_2_界1_1.5_顔1,2_5,5_樹1_8.0_100℃_0.05  2024/4/10  高岡
#
#             備考   溶媒１  溶媒2  溶媒3  添加剤1  添加剤2  ...  乾燥温度  乾燥時間  擦過回数  擦過圧力  \
# 0   界面活性剤1水準振り  46.9   40    0     2     0  ...    25   NaN    10     5
# 1   界面活性剤1水準振り  47.4   40    0     2     0  ...    25   NaN    10     5
# 2   界面活性剤1水準振り  47.7   40    0     2     0  ...    25   NaN    10     5
# 3   界面活性剤1水準振り  47.9   40    0     2     0  ...    25   NaN    10     5
# 4   界面活性剤1水準振り  48.4   40    0     2     0  ...    25   NaN    10     5
# 5          ref  47.4   40    0     2     0  ...    25   NaN    10     5
# 6   界面活性剤1種類検討  47.4   40    0     2     0  ...    25   NaN    10     5
# 7   界面活性剤1種類検討  47.4   40    0     2     0  ...    25   NaN    10     5
# 8    定着樹脂１水準振り  45.4   40    0     2     0  ...    25   NaN    10     5
# 9    定着樹脂１水準振り  43.4   40    0     2     0  ...    25   NaN    10     5
# 10   定着樹脂１水準振り  41.4   40    0     2     0  ...    25   NaN    10     5
# 11   定着樹脂２水準振り  47.4   40    0     2     0  ...    25   NaN    10     5
# 12   定着樹脂２水準振り  45.4   40    0     2     0  ...    25   NaN    10     5
# 13   定着樹脂２水準振り  41.4   40    0     2     0  ...    25   NaN    10     5
# 14      乾燥条件振り  43.4   40    0     2     0  ...   100  0.01    10     5
# 15      乾燥条件振り  43.4   40    0     2     0  ...   100  0.03    10     5
# 16      乾燥条件振り  43.4   40    0     2     0  ...    80  0.01    10     5
# 17      乾燥条件振り  43.4   40    0     2     0  ...   120  0.01    10     5
# 18         ref  43.4   40    0     2     0  ...   100  0.03    10     5
# 19       溶媒種振り  43.4    0   40     2     0  ...   100  0.03    10     5
# 20      添加剤量振り  40.4   40    0     5     0  ...   100  0.05    10     5
# 21      添加剤種振り  43.4   40    0     0     2  ...   100  0.03    10     5
# 22  添加剤、溶媒同時変更  43.4    0   40     0     2  ...   100  0.03    10     5
# 23      添加剤量振り  40.4    0   40     0     5  ...   100  0.03    10     5
# 24       溶媒量振り  38.4    0   45     0     2  ...   100  0.03    10     5
# 25       溶媒量振り  48.4    0   35     0     2  ...   100  0.03    10     5
# 26         ref  43.4    0   40     0     2  ...   100  0.03    10     5
# 27        顔料振り  40.9    0   40     0     2  ...   100  0.03    10     5
# 28        顔料振り  38.4    0   40     0     2  ...   100  0.03    10     5
# 29       顔料種振り  43.4    0   40     0     2  ...   100  0.03    10     5
# 30       顔料種振り  40.9    0   40     0     2  ...   100  0.03    10     5
# 31       顔料種振り  38.4    0   40     0     2  ...   100  0.03    10     5
# 32        顔料混合  38.4    0   40     0     2  ...   100  0.03    10     5
#
#     耐擦過性(n10  画像濃度    粘度  表面張力  保存後粘度  保存後状態
# 0        2.4  1.06   9.0    35    NaN    NaN
# 1        2.4  1.07   9.0    38    NaN    NaN
# 2        2.4  1.07   9.0    40    NaN    NaN
# 3        2.4  1.08   9.0    41    NaN    NaN
# 4        2.4  1.09   9.0    44    NaN    NaN
# 5        2.7  1.07   9.1    38    NaN    NaN
# 6        2.7  1.05   9.1    37    NaN    NaN
# 7        2.7  1.02   9.1    39    NaN    NaN
# 8        3.1  1.07  10.3    36    NaN    NaN
# 9        3.6  1.07  11.5    34    NaN    NaN
# 10       4.0  1.07  12.7    32    NaN    NaN
# 11       2.0  1.07   9.1    38    NaN    NaN
# 12       2.1  1.07  10.4    36    NaN    NaN
# 13       2.3  1.07  12.8    32    NaN    NaN
# 14       2.6  1.07  11.5    34    NaN    NaN
# 15       5.0  1.07  11.5    34    NaN    NaN
# 16       2.3  1.07  11.5    34    NaN    NaN
# 17       2.9  1.07  11.5    34    NaN    NaN
# 18       5.0  1.07  11.5    34    NaN    NaN
# 19       5.0  1.07   7.5    36    NaN    NaN
# 20       5.0  1.04  11.7    31    NaN    NaN
# 21       5.0  1.09  11.4    34    NaN    NaN
# 22       5.0  1.09   7.4    36    NaN    NaN
# 23       5.0  1.09   7.4    33    NaN    NaN
# 24       5.0  1.09   7.4    31    NaN    NaN
# 25       5.0  1.09   7.4    41    NaN    NaN
# 26       5.0  1.09   7.4    36    9.8     正常
# 27       5.0  1.34   8.7    34   29.9  塊状物発生
# 28       5.0  1.55   9.9    32   45.6    ゲル化
# 29       5.0  1.17   7.7    36   10.1     正常
# 30       5.0  1.43   9.0    34   67.7    ゲル化
# 31       5.0  1.66  10.4    32  112.8    ゲル化
# 32       5.0  1.61  10.2    32   12.6     正常
#
# [33 rows x 30 columns]

# %% [markdown]
# ## referenceサンプルをデータから削除する

# %%
# 備考にrefと書かれているデータを削除
train_df = train_df[train_df["備考"] != "ref"]
# インデックスを振り直す
train_df = train_df.reset_index(drop=True)
train_df
# Out:
#     サンプルID                                        サンプル名    サンプル作成日 担当者  \
# 0   DP_001                                       界1_2.0  2024/1/19  高岡
# 1   DP_002                                       界1_1.5  2024/1/19  高岡
# 2   DP_003                                       界1_1.2  2024/1/19  高岡
# 3   DP_004                                       界1_1.0  2024/1/19  高岡
# 4   DP_005                                       界1_0.5  2024/1/19  高岡
# 5   DP_007                                界2_1.5_樹1_4.0  2024/1/30  福原
# 6   DP_008                                界3_1.5_樹1_4.0  2024/1/30  福原
# 7   DP_009                                界1_1.5_樹1_6.0  2024/1/30  福原
# 8   DP_010                                界1_1.5_樹1_8.0  2024/1/30  福原
# 9   DP_011                               界1_1.5_樹1_10.0  2024/1/30  福原
# 10  DP_012                                界1_1.5_樹2_4.0  2024/1/30  福原
# 11  DP_013                                界1_1.5_樹2_6.0  2024/1/30  福原
# 12  DP_014                               界1_1.5_樹2_10.0  2024/1/30  福原
# 13  DP_015                      界1_1.5_樹1_8.0_100℃_0.01  2024/2/15  高岡
# 14  DP_016                      界1_1.5_樹1_8.0_100℃_0.05  2024/2/15  高岡
# 15  DP_017                       界1_1.5_樹1_8.0_80℃_0.01  2024/2/15  高岡
# 16  DP_018                      界1_1.5_樹1_8.0_120℃_0.01  2024/2/15  高岡
# 17  DP_020           溶3_40_添1_2_界1_1.5_樹1_8.0_100℃_0.05  2024/2/28  福原
# 18  DP_021           溶2_40_添1_5_界1_1.5_樹1_8.0_100℃_0.05  2024/2/28  福原
# 19  DP_022           溶2_40_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/2/28  福原
# 20  DP_023           溶3_40_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 21  DP_024           溶3_40_添2_5_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 22  DP_025           溶3_45_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 23  DP_026           溶5_35_添2_2_界1_1.5_樹1_8.0_100℃_0.05  2024/3/15  福原
# 24  DP_028    溶3_40_添2_2_界1_1.5_顔1_7.5_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 25  DP_029     溶3_40_添2_2_界1_1.5_顔1_10_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 26  DP_030      溶3_40_添2_2_界1_1.5_顔2_5_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 27  DP_031    溶3_40_添2_2_界1_1.5_顔2_7.5_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 28  DP_032     溶3_40_添2_2_界1_1.5_顔2_10_樹1_8.0_100℃_0.05  2024/4/10  高岡
# 29  DP_033  溶3_40_添2_2_界1_1.5_顔1,2_5,5_樹1_8.0_100℃_0.05  2024/4/10  高岡
#
#             備考   溶媒１  溶媒2  溶媒3  添加剤1  添加剤2  ...  乾燥温度  乾燥時間  擦過回数  擦過圧力  \
# 0   界面活性剤1水準振り  46.9   40    0     2     0  ...    25   NaN    10     5
# 1   界面活性剤1水準振り  47.4   40    0     2     0  ...    25   NaN    10     5
# 2   界面活性剤1水準振り  47.7   40    0     2     0  ...    25   NaN    10     5
# 3   界面活性剤1水準振り  47.9   40    0     2     0  ...    25   NaN    10     5
# 4   界面活性剤1水準振り  48.4   40    0     2     0  ...    25   NaN    10     5
# 5   界面活性剤1種類検討  47.4   40    0     2     0  ...    25   NaN    10     5
# 6   界面活性剤1種類検討  47.4   40    0     2     0  ...    25   NaN    10     5
# 7    定着樹脂１水準振り  45.4   40    0     2     0  ...    25   NaN    10     5
# 8    定着樹脂１水準振り  43.4   40    0     2     0  ...    25   NaN    10     5
# 9    定着樹脂１水準振り  41.4   40    0     2     0  ...    25   NaN    10     5
# 10   定着樹脂２水準振り  47.4   40    0     2     0  ...    25   NaN    10     5
# 11   定着樹脂２水準振り  45.4   40    0     2     0  ...    25   NaN    10     5
# 12   定着樹脂２水準振り  41.4   40    0     2     0  ...    25   NaN    10     5
# 13      乾燥条件振り  43.4   40    0     2     0  ...   100  0.01    10     5
# 14      乾燥条件振り  43.4   40    0     2     0  ...   100  0.03    10     5
# 15      乾燥条件振り  43.4   40    0     2     0  ...    80  0.01    10     5
# 16      乾燥条件振り  43.4   40    0     2     0  ...   120  0.01    10     5
# 17       溶媒種振り  43.4    0   40     2     0  ...   100  0.03    10     5
# 18      添加剤量振り  40.4   40    0     5     0  ...   100  0.05    10     5
# 19      添加剤種振り  43.4   40    0     0     2  ...   100  0.03    10     5
# 20  添加剤、溶媒同時変更  43.4    0   40     0     2  ...   100  0.03    10     5
# 21      添加剤量振り  40.4    0   40     0     5  ...   100  0.03    10     5
# 22       溶媒量振り  38.4    0   45     0     2  ...   100  0.03    10     5
# 23       溶媒量振り  48.4    0   35     0     2  ...   100  0.03    10     5
# 24        顔料振り  40.9    0   40     0     2  ...   100  0.03    10     5
# 25        顔料振り  38.4    0   40     0     2  ...   100  0.03    10     5
# 26       顔料種振り  43.4    0   40     0     2  ...   100  0.03    10     5
# 27       顔料種振り  40.9    0   40     0     2  ...   100  0.03    10     5
# 28       顔料種振り  38.4    0   40     0     2  ...   100  0.03    10     5
# 29        顔料混合  38.4    0   40     0     2  ...   100  0.03    10     5
#
#     耐擦過性(n10  画像濃度    粘度  表面張力  保存後粘度  保存後状態
# 0        2.4  1.06   9.0    35    NaN    NaN
# 1        2.4  1.07   9.0    38    NaN    NaN
# 2        2.4  1.07   9.0    40    NaN    NaN
# 3        2.4  1.08   9.0    41    NaN    NaN
# 4        2.4  1.09   9.0    44    NaN    NaN
# 5        2.7  1.05   9.1    37    NaN    NaN
# 6        2.7  1.02   9.1    39    NaN    NaN
# 7        3.1  1.07  10.3    36    NaN    NaN
# 8        3.6  1.07  11.5    34    NaN    NaN
# 9        4.0  1.07  12.7    32    NaN    NaN
# 10       2.0  1.07   9.1    38    NaN    NaN
# 11       2.1  1.07  10.4    36    NaN    NaN
# 12       2.3  1.07  12.8    32    NaN    NaN
# 13       2.6  1.07  11.5    34    NaN    NaN
# 14       5.0  1.07  11.5    34    NaN    NaN
# 15       2.3  1.07  11.5    34    NaN    NaN
# 16       2.9  1.07  11.5    34    NaN    NaN
# 17       5.0  1.07   7.5    36    NaN    NaN
# 18       5.0  1.04  11.7    31    NaN    NaN
# 19       5.0  1.09  11.4    34    NaN    NaN
# 20       5.0  1.09   7.4    36    NaN    NaN
# 21       5.0  1.09   7.4    33    NaN    NaN
# 22       5.0  1.09   7.4    31    NaN    NaN
# 23       5.0  1.09   7.4    41    NaN    NaN
# 24       5.0  1.34   8.7    34   29.9  塊状物発生
# 25       5.0  1.55   9.9    32   45.6    ゲル化
# 26       5.0  1.17   7.7    36   10.1     正常
# 27       5.0  1.43   9.0    34   67.7    ゲル化
# 28       5.0  1.66  10.4    32  112.8    ゲル化
# 29       5.0  1.61  10.2    32   12.6     正常
#
# [30 rows x 30 columns]

# %% [markdown]
# ## データの列名を確認

# %%
# train_dfの列名をリストで取得
columns = train_df.columns
# train_dfの列名を表示
columns
# Out:
# Index(['サンプルID', 'サンプル名', 'サンプル作成日', '担当者', '備考', '溶媒１', '溶媒2', '溶媒3', '添加剤1',
#        '添加剤2', '界面活性剤１', '界面活性剤２', '界面活性剤３', '顔料１', '顔料２', '定着樹脂１', '定着樹脂２',
#        '防腐剤', '塗布量', '乾燥方式', '乾燥温度', '乾燥時間', '擦過回数', '擦過圧力', '耐擦過性(n10',
#        '画像濃度', '粘度', '表面張力', '保存後粘度', '保存後状態'],
#       dtype='object')

# %% [markdown]
# ## データの欠損を確認

# %%
# 欠損のある列を表示
train_df.isnull().sum()
# Out:
# サンプルID       0
# サンプル名        0
# サンプル作成日      0
# 担当者          0
# 備考           0
# 溶媒１          0
# 溶媒2          0
# 溶媒3          0
# 添加剤1         0
# 添加剤2         0
# 界面活性剤１       0
# 界面活性剤２       0
# 界面活性剤３       0
# 顔料１          0
# 顔料２          0
# 定着樹脂１        0
# 定着樹脂２        0
# 防腐剤          0
# 塗布量          0
# 乾燥方式         0
# 乾燥温度         0
# 乾燥時間        13
# 擦過回数         0
# 擦過圧力         0
# 耐擦過性(n10     0
# 画像濃度         0
# 粘度           0
# 表面張力         0
# 保存後粘度       24
# 保存後状態       24
# dtype: int64

# %% [markdown]
# ## 使用する説明変数をリストとして定義

# %%
numeric_parameter_cols = [
    # 'サンプルID', 'サンプル名', 'サンプル作成日', '担当者', '備考',
    "溶媒１",
    "溶媒2",
    "溶媒3",
    "添加剤1",
    "添加剤2",
    "界面活性剤１",
    "界面活性剤２",
    "界面活性剤３",
    "顔料１",
    "顔料２",
    "定着樹脂１",
    "定着樹脂２",
    "防腐剤",
    "塗布量",
    "乾燥方式",
    "乾燥温度",
    # '乾燥時間',
    "擦過回数",
    "擦過圧力",
    # '耐擦過性(n10','画像濃度', '粘度', '表面張力', '保存後粘度'
]

# %% [markdown]
# ## 説明変数と目的変数の定義

# %%
train_X = train_df[numeric_parameter_cols]
objective_cols = [CFG.target]
train_Y = train_df[objective_cols]

# %% [markdown]
# ## PLSRegressionを用いたLeave-one-outによる交差検証

# %%
models = []
coef = []
rmses_train = []
maes_train = []
r2_train = []
rmses_valid = []
maes_valid = []
r2_valid = []
oof = np.zeros(len(train_X))

model = PLSRegression(n_components=2)

folds = len(train_X)
kf = KFold(n_splits=folds)

scaler_x = StandardScaler()
scaler_y = StandardScaler()

for train_index, valid_index in tqdm(kf.split(train_X)):
    X_train = scaler_x.fit_transform(train_X.iloc[train_index])
    X_valid = scaler_x.transform(train_X.iloc[valid_index])
    y_train = scaler_y.fit_transform(train_Y.iloc[train_index].values.reshape(-1, 1))
    y_valid = scaler_y.transform(train_Y.iloc[valid_index].values.reshape(-1, 1))

    model.fit(X_train, y_train)
    y_pred_train = scaler_y.inverse_transform(model.predict(X_train).reshape(-1, 1))
    y_pred_valid = scaler_y.inverse_transform(model.predict(X_valid).reshape(-1, 1))

    y_train = scaler_y.inverse_transform(y_train)
    y_valid = scaler_y.inverse_transform(y_valid)

    tmp_rmses_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
    tmp_maes_train = mean_absolute_error(y_train, y_pred_train)
    tmp_r2_train = r2_score(y_train, y_pred_train)

    tmp_rmses_valid = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
    tmp_maes_valid = mean_absolute_error(y_valid, y_pred_valid)
    tmp_r2_valid = r2_score(y_valid, y_pred_valid)

    print(train_Y.iloc[valid_index].index)
    print("RMSE_train:", tmp_rmses_train)
    print("MAE_train:", tmp_maes_train)
    print("R2_train:", tmp_r2_train)
    # print("RMSE_valid:", tmp_rmses_valid)
    # print("MAE_valid:", tmp_maes_valid)
    # print("R2_valid:", tmp_r2_valid)

    models.append(model)
    coef.append(model.coef_)
    rmses_train.append(np.sqrt(mean_squared_error(y_train, y_pred_train)))
    maes_train.append(mean_absolute_error(y_train, y_pred_train))
    r2_train.append(r2_score(y_train, y_pred_train))
    # rmses_valid.append(np.sqrt(mean_squared_error(y_valid, y_pred_valid)))
    # maes_valid.append(mean_absolute_error(y_valid, y_pred_valid))
    # r2_valid.append(r2_score(y_valid, y_pred_valid))

    oof[valid_index] = y_pred_valid

    plt.figure(figsize=(8, 8))
    plt.title("Predicted vs Actual")
    plt.scatter(y_train, y_pred_train, label="train", color="blue")
    plt.scatter(y_valid, y_pred_valid, label="valid", color="red", marker="*", s=100)
    x_truth = np.arange(y_train.min(), y_train.max() + 1)
    y_truth = x_truth
    plt.plot(x_truth, y_truth, "--", color="gray", label="truth")
    # plt.textでRMSE, MAE, R2を右下に表示
    plt.text(
        0.6, 0.3, f"RMSE_train: {tmp_rmses_train:.2f}", transform=plt.gca().transAxes
    )
    plt.text(
        0.6, 0.2, f"MAE_train: {tmp_maes_train:.2f}", transform=plt.gca().transAxes
    )
    plt.text(0.6, 0.1, f"R2_train: {tmp_r2_train:.2f}", transform=plt.gca().transAxes)
    # plt.txtでvalid_indexに対応するサンプルIDを表示
    for i, txt in enumerate(train_df.iloc[valid_index]["サンプルID"]):
        plt.text(y_valid[i], y_pred_valid[i], txt, fontsize=15)

    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.legend()
# Out:
# 0it [00:00, ?it/s]
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/cross_decomposition/_pls.py:507: FutureWarning: The attribute `coef_` will be transposed in version 1.3 to be consistent with other linear models in scikit-learn. Currently, `coef_` has a shape of (n_features, n_targets) and in the future it will have a shape of (n_targets, n_features).
#   warnings.warn(
# Int64Index([0], dtype='int64')
# RMSE_train: 1.3476625980162749
# MAE_train: 1.0103276740765315
# R2_train: 0.8281867765944486
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([1], dtype='int64')
# RMSE_train: 1.4286993030245656
# MAE_train: 1.0755864706280251
# R2_train: 0.8022311280636772
# Int64Index([2], dtype='int64')
# RMSE_train: 1.42286551922844
# MAE_train: 1.0365964844809377
# R2_train: 0.7933685162177727
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([3], dtype='int64')
# RMSE_train: 1.4050744991912871
# MAE_train: 1.0175767508662235
# R2_train: 0.790626596859836
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([4], dtype='int64')
# RMSE_train: 1.230948414549018
# MAE_train: 0.9355974347033944
# R2_train: 0.80808557328387
# Int64Index([5], dtype='int64')
# RMSE_train: 1.2835126377794954
# MAE_train: 0.9057576386670848
# R2_train: 0.8427392343454405
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([6], dtype='int64')
# RMSE_train: 1.2610550789039547
# MAE_train: 0.9191567250962739
# R2_train: 0.8424724869238192
# Int64Index([7], dtype='int64')
# RMSE_train: 1.4231925006050041
# MAE_train: 1.0789155670847008
# R2_train: 0.8081727401275257
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([8], dtype='int64')
# RMSE_train: 1.423835708354313
# MAE_train: 1.07359309319166
# R2_train: 0.807130527985561
# Int64Index([9], dtype='int64')
# RMSE_train: 1.425247777717396
# MAE_train: 1.0663527355935787
# R2_train: 0.8004264529609668
# Int64Index([10], dtype='int64')
# RMSE_train: 1.4245504934583042
# MAE_train: 1.0717179708402755
# R2_train: 0.8033780650720344
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([11], dtype='int64')
# RMSE_train: 1.4118160825538073
# MAE_train: 1.076721345675564
# R2_train: 0.8112272599712472
# Int64Index([12], dtype='int64')
# RMSE_train: 1.4592567763356166
# MAE_train: 1.1537654455148099
# R2_train: 0.790788444470132
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([13], dtype='int64')
# RMSE_train: 1.4158185658077203
# MAE_train: 1.0654814280965677
# R2_train: 0.809296380125409
# Int64Index([14], dtype='int64')
# RMSE_train: 1.4158185658077203
# MAE_train: 1.0654814280965677
# R2_train: 0.809296380125409
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([15], dtype='int64')
# RMSE_train: 1.4169928774388159
# MAE_train: 1.0717934462508174
# R2_train: 0.8089799012247654
# Int64Index([16], dtype='int64')
# RMSE_train: 1.4153037474264067
# MAE_train: 1.061004043257917
# R2_train: 0.809435041789589
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([17], dtype='int64')
# RMSE_train: 1.439538397135761
# MAE_train: 1.0774794294225607
# R2_train: 0.8037410202553475
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([18], dtype='int64')
# RMSE_train: 1.4069991223058096
# MAE_train: 1.0196543259846336
# R2_train: 0.8001341258256427
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /var/folders/3q/gwgy4r2561v6xx__yjlk15b80000gn/T/ipykernel_58396/3316188719.py:59: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(8, 8))
# Int64Index([19], dtype='int64')
# RMSE_train: 1.4346060953851287
# MAE_train: 1.075697724716703
# R2_train: 0.8042016289888579
# Int64Index([20], dtype='int64')
# RMSE_train: 1.4508083390174435
# MAE_train: 1.1025166525423333
# R2_train: 0.80065602392465
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([21], dtype='int64')
# RMSE_train: 1.428035408610929
# MAE_train: 1.0675678584749444
# R2_train: 0.8035465300280211
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([22], dtype='int64')
# RMSE_train: 1.374744825536792
# MAE_train: 1.0158506589872278
# R2_train: 0.8091926140430858
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([23], dtype='int64')
# RMSE_train: 1.4386022726800882
# MAE_train: 1.0986314531288228
# R2_train: 0.7805152792401482
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([24], dtype='int64')
# RMSE_train: 1.4318219885235624
# MAE_train: 1.0900302614224973
# R2_train: 0.8049608543059663
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([25], dtype='int64')
# RMSE_train: 1.4135766125625961
# MAE_train: 1.0529209493664546
# R2_train: 0.803681632699755
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([26], dtype='int64')
# RMSE_train: 1.4204400154262333
# MAE_train: 1.0661695940611193
# R2_train: 0.8089140187754897
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([27], dtype='int64')
# RMSE_train: 1.4074736523296185
# MAE_train: 1.0563229908747018
# R2_train: 0.8115377906149608
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /Users/takaharawataru/anaconda3/envs/local/lib/python3.10/site-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# Int64Index([28], dtype='int64')
# RMSE_train: 1.4302784840912457
# MAE_train: 1.1099199905045718
# R2_train: 0.7990150944079778
# Int64Index([29], dtype='int64')
# RMSE_train: 1.4096862382840882
# MAE_train: 1.0612340729880616
# R2_train: 0.8047607407438384

# %% [markdown]
# ## Out-Of-Fold(OOF)のプロット

# %%
# oofをActualとPredictedに分けてプロット
plt.figure(figsize=(8, 8))
plt.title("Predicted vs Actual")
plt.scatter(train_Y, oof, label="valid", color="red", marker="*", s=100)
x_truth = np.arange(train_Y.values.min(), train_Y.values.max() + 1)
y_truth = x_truth
plt.plot(x_truth, y_truth, "--", color="gray", label="truth")
plt.xlabel("Actual")
plt.ylabel("Predicted")
# plt.textでRMSE, MAE, R2を右下に表示
plt.text(
    0.6,
    0.3,
    f"RMSE_valid: {np.sqrt(mean_squared_error(train_Y, oof)):.2f}",
    transform=plt.gca().transAxes,
)
plt.text(
    0.6,
    0.2,
    f"MAE_valid: {mean_absolute_error(train_Y, oof):.2f}",
    transform=plt.gca().transAxes,
)
plt.text(
    0.6, 0.1, f"R2_valid: {r2_score(train_Y, oof):.2f}", transform=plt.gca().transAxes
)
plt.legend()

# %% [markdown]
# ## Out-Of-Fold(OOF)のプロット&各水準のIDを表示

# %%
# oofをActualとPredictedに分けてプロット
plt.figure(figsize=(8, 8))
plt.title("Predicted vs Actual")
plt.scatter(train_Y, oof, label="valid", color="red", marker="*", s=100)
x_truth = np.arange(train_Y.values.min(), train_Y.values.max() + 1)
y_truth = x_truth
plt.plot(x_truth, y_truth, "--", color="gray", label="truth")
plt.xlabel("Actual")
plt.ylabel("Predicted")
# plt.textでRMSE, MAE, R2を右下に表示
plt.text(
    0.6,
    0.3,
    f"RMSE_valid: {np.sqrt(mean_squared_error(train_Y, oof)):.2f}",
    transform=plt.gca().transAxes,
)
plt.text(
    0.6,
    0.2,
    f"MAE_valid: {mean_absolute_error(train_Y, oof):.2f}",
    transform=plt.gca().transAxes,
)
plt.text(
    0.6, 0.1, f"R2_valid: {r2_score(train_Y, oof):.2f}", transform=plt.gca().transAxes
)
# plt.txtでvalid_indexに対応するサンプルIDを表示、adjustTextモジュールを使用して、重なりがないように表示
texts = [
    plt.text(train_Y.values[i], oof[i], train_df["サンプルID"][i], fontsize=10)
    for i in range(len(train_Y))
]
adjust_text(texts, arrowprops=dict(arrowstyle="->", color="green"))
plt.legend()
# Out:
# WARNING:root:Looks like you are using an old matplotlib version.
#                In some cases adjust_text might fail, if possible update
#                matplotlib to version >=3.5.0

# %% [markdown]
# ## Leave-one-outにより得られた標準回帰係数の個数をカウント

# %%
len(coef)
# Out:
# 30

# %% [markdown]
# ## Leave-one-outによる各モデルの標準回帰係数の平均を算出

# %%
# 全てのモデルの係数の平均を算出
coef = np.array(coef)
coef = np.mean(coef, axis=0)
coef
# Out:
# array([[ 0.60066116],
#        [-0.10565639],
#        [ 0.07831978],
#        [-0.15964841],
#        [ 0.0242014 ],
#        [-0.29890794],
#        [-0.04820626],
#        [ 0.06445457],
#        [-0.0884048 ],
#        [-0.03164183],
#        [-0.14815554],
#        [-0.22133397],
#        [ 0.        ],
#        [ 0.        ],
#        [-0.11130847],
#        [-0.10880408],
#        [ 0.        ],
#        [ 0.        ]])

# %% [markdown]
# ## 標準回帰係数の平均をデータフレームに格納

# %%
# coefをDataFrameに変換
coef_df = pd.DataFrame(coef, index=numeric_parameter_cols, columns=["coef"])
coef_df
# Out:
#             coef
# 溶媒１     0.600661
# 溶媒2    -0.105656
# 溶媒3     0.078320
# 添加剤1   -0.159648
# 添加剤2    0.024201
# 界面活性剤１ -0.298908
# 界面活性剤２ -0.048206
# 界面活性剤３  0.064455
# 顔料１    -0.088405
# 顔料２    -0.031642
# 定着樹脂１  -0.148156
# 定着樹脂２  -0.221334
# 防腐剤     0.000000
# 塗布量     0.000000
# 乾燥方式   -0.111308
# 乾燥温度   -0.108804
# 擦過回数    0.000000
# 擦過圧力    0.000000

# %% [markdown]
# ## 標準回帰係数の平均のデータフレームを絶対値の降順に並び替え

# %%
# coef_dfをcoefの絶対値の降順にソート
coef_df = coef_df.reindex(coef_df["coef"].abs().sort_values(ascending=False).index)
coef_df
# Out:
#             coef
# 溶媒１     0.600661
# 界面活性剤１ -0.298908
# 定着樹脂２  -0.221334
# 添加剤1   -0.159648
# 定着樹脂１  -0.148156
# 乾燥方式   -0.111308
# 乾燥温度   -0.108804
# 溶媒2    -0.105656
# 顔料１    -0.088405
# 溶媒3     0.078320
# 界面活性剤３  0.064455
# 界面活性剤２ -0.048206
# 顔料２    -0.031642
# 添加剤2    0.024201
# 塗布量     0.000000
# 防腐剤     0.000000
# 擦過回数    0.000000
# 擦過圧力    0.000000

# %% [markdown]
# ## 標準回帰係数の平均をプロットして特徴量重要度として可視化

# %%
# coef_dfをsns.barplotで可視化
plt.figure(figsize=(8, 8))
sns.barplot(data=coef_df, x="coef", y=coef_df.index)
plt.title(f"{CFG.target}の予測モデルの特徴量重要度")
plt.xlabel("Coefficient")
plt.ylabel("Feature")
plt.tight_layout()

# %% [markdown]
# ## テストデータを読み込み、データフレームに格納

# %%
test_df = pd.read_csv(f"{CFG.input_dir}/chapter2_demo_data_postprocess_test.csv")
test_df
# Out:
#    サンプルID サンプル名  サンプル作成日  担当者  備考   溶媒１  溶媒2  溶媒3  添加剤1  添加剤2  ...  乾燥温度  \
# 0  DP_0XX  test      NaN  NaN NaN  42.9    0   40     0     2  ...   100
#
#    乾燥時間  擦過回数  擦過圧力  耐擦過性(n10  画像濃度   粘度  表面張力  保存後粘度  保存後状態
# 0  0.03    10     5       5.0  1.47  8.0  38.0    9.8     正常
#
# [1 rows x 30 columns]

# %% [markdown]
# ## テストデータについてLeave-one-outで得られた全てのモデルで予測して、その平均値をテストデータにおける予測値とする

# %%
# 全てのmodelで予測してその平均をとる
test_X = test_df[numeric_parameter_cols]
preds = []
for model in models:
    pred = scaler_y.inverse_transform(
        model.predict(scaler_x.transform(test_X)).reshape(-1, 1)
    )
    preds.append(pred)
preds = np.array(preds)
preds = preds.mean(axis=0)
preds
# Out:
# array([[37.05291375]])
