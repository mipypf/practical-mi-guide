# %% [markdown]
# <a href="https://colab.research.google.com/github/mipypf/practical-mi-guide/blob/develop/chapter4/src/feature_generation_cif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 無機材料の特徴量をCIFから生成する

# %% [markdown]
# ### 右上の「接続」をクリックし、ランタイムに接続

# %% [markdown]
# ## ライブラリをインストール

# %%
! pip install matminer==0.9.3
# Out:
# Collecting matminer==0.9.3
#   Downloading matminer-0.9.3-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matminer==0.9.3) (2.0.2)
# Requirement already satisfied: requests~=2.31 in /usr/local/lib/python3.11/dist-packages (from matminer==0.9.3) (2.32.3)
# Requirement already satisfied: pandas<3,>=1.5 in /usr/local/lib/python3.11/dist-packages (from matminer==0.9.3) (2.2.2)
# Requirement already satisfied: tqdm~=4.66 in /usr/local/lib/python3.11/dist-packages (from matminer==0.9.3) (4.67.1)
# Collecting pymongo~=4.5 (from matminer==0.9.3)
#   Downloading pymongo-4.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: scikit-learn~=1.3 in /usr/local/lib/python3.11/dist-packages (from matminer==0.9.3) (1.6.1)
# Requirement already satisfied: sympy~=1.11 in /usr/local/lib/python3.11/dist-packages (from matminer==0.9.3) (1.13.1)
# Collecting monty>=2023 (from matminer==0.9.3)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting pymatgen>=2023 (from matminer==0.9.3)
#   Downloading pymatgen-2025.3.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting ruamel.yaml (from monty>=2023->matminer==0.9.3)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer==0.9.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer==0.9.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.5->matminer==0.9.3) (2025.2)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer==0.9.3) (1.4.2)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer==0.9.3) (3.10.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer==0.9.3) (3.4.2)
# Collecting palettable>=3.3.3 (from pymatgen>=2023->matminer==0.9.3)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer==0.9.3) (5.24.1)
# Collecting pybtex>=0.24.0 (from pymatgen>=2023->matminer==0.9.3)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer==0.9.3) (1.14.1)
# Collecting spglib>=2.5 (from pymatgen>=2023->matminer==0.9.3)
#   Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.11/dist-packages (from pymatgen>=2023->matminer==0.9.3) (0.9.0)
# Collecting uncertainties>=3.1.4 (from pymatgen>=2023->matminer==0.9.3)
#   Downloading uncertainties-3.2.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.5->matminer==0.9.3)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer==0.9.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer==0.9.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer==0.9.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->matminer==0.9.3) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn~=1.3->matminer==0.9.3) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy~=1.11->matminer==0.9.3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen>=2023->matminer==0.9.3) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->pymatgen>=2023->matminer==0.9.3) (9.1.2)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.11/dist-packages (from pybtex>=0.24.0->pymatgen>=2023->matminer==0.9.3) (6.0.2)
# Collecting latexcodec>=1.0.4 (from pybtex>=0.24.0->pymatgen>=2023->matminer==0.9.3)
#   Downloading latexcodec-3.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pybtex>=0.24.0->pymatgen>=2023->matminer==0.9.3) (1.17.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->monty>=2023->matminer==0.9.3)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from spglib>=2.5->pymatgen>=2023->matminer==0.9.3) (4.13.1)
# Downloading matminer-0.9.3-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 43.0 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.8 MB/s eta 0:00:00
# Downloading pymatgen-2025.3.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 55.7 MB/s eta 0:00:00
# Downloading pymongo-4.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.2 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 21.8 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 25.6 MB/s eta 0:00:00
# Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 37.1 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 9.7 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 46.8 MB/s eta 0:00:00
# Downloading uncertainties-3.2.2-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 42.2 MB/s eta 0:00:00
# Installing collected packages: uncertainties, spglib, ruamel.yaml.clib, palettable, latexcodec, dnspython, ruamel.yaml, pymongo, pybtex, monty, pymatgen, matminer
# Successfully installed dnspython-2.7.0 latexcodec-3.0.0 matminer-0.9.3 monty-2025.3.3 palettable-3.3.3 pybtex-0.24.0 pymatgen-2025.3.10 pymongo-4.11.3 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 spglib-2.6.0 uncertainties-3.2.2

# %% [markdown]
# ### 「ランタイム」タブから「セッションを再起動する」を選択し、「はい」をクリック

# %% [markdown]
# ## Google Colabの準備

# %%
# Google Colabを利用する場合はTrue、そうでない場合はFalseとする
colab = True

# %%
# Google Colabのファイルをクリックし、material_projects_api_cif_1000.zip、material_projects_api_cif_1000.csvをドラッグ＆ドロップしてアップロード
if colab:
  INPUT_FILE_PATH = "./"
  OUTPUT_FILE_PATH = "./"
else:
  INPUT_FILE_PATH = "../input/"
  OUTPUT_FILE_PATH = "../output/"

# %%
# localで実行の場合はINPUT_FILE_PATH配下にmaterial_projects_api_cif_1000.zipを配置する
import zipfile

# ファイルを解凍する
with zipfile.ZipFile(INPUT_FILE_PATH + "material_projects_api_cif_1000.zip", "r") as zip_ref:
    zip_ref.extractall("./")

# %% [markdown]
# ## ライブラリをインポート

# %%
import gc
import glob
import os

import pandas as pd
from tqdm.notebook import tqdm

tqdm.pandas()

import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from matminer.featurizers.structure import DensityFeatures
from pymatgen.core.structure import Structure

# %% [markdown]
# # データを読み込み、CIFからの特徴量生成の準備を行う

# %%
# material_projects_api_cif_1000.csvを読み込む
df = pd.read_csv(
    INPUT_FILE_PATH + "material_projects_api_cif_1000.csv"
)
df
# Out:
#                formula          id  band_gap  formation_energy  \
# 0         Cs3Nd(MoO4)3   mp-573369    3.7419         -2.414818
# 1            Ba(PdS2)2    mp-28967    0.7792         -1.124079
# 2      Na7Ta3Zn(SiO4)6  mp-2712904    2.5286         -2.912354
# 3             TiZnBiO5  mp-1042447    0.0000         -2.236384
# 4    Na2YNb3Si4(SO12)2  mp-2715697    1.8105         -2.837049
# ..                 ...         ...       ...               ...
# 995           NaHfMg14  mp-1026645    0.0000          0.123330
# 996            CeGa3Ni  mp-1226580    0.0000         -0.499538
# 997            ReRuCl2   mp-631417    0.0000          1.034857
# 998      Li2NiH8(CO5)2   mp-771916    4.1397         -1.559949
# 999              MgTl3   mp-978262    0.0000          0.042863
#
#      energy_above_hull
# 0             0.000000
# 1             0.000000
# 2             0.049678
# 3             0.077777
# 4             0.079832
# ..                 ...
# 995           0.123330
# 996           0.035687
# 997           1.818772
# 998           0.052192
# 999           0.051358
#
# [1000 rows x 5 columns]

# %%
# material_projects_api_cif_1000に格納されているファイルを確認
files = os.listdir(INPUT_FILE_PATH + "material_projects_api_cif_1000")
len(files)
# Out:
# 1000

# %%
# material_projects_api_cif_1000に格納されているファイルの名前をfiles_dfとしてデータフレーム化
files_df = pd.DataFrame(files, columns=["file_name"])
files_df
# Out:
#                             file_name
# 0    cif_mp-2715587_NaNbSi2SnSO12.cif
# 1     cif_mp-1190493_NiH5CN(ClO)2.cif
# 2       cif_mp-2218111_MgTi(WO4)2.cif
# 3            cif_mp-1194227_H3CO3.cif
# 4           cif_mp-759602_Sb4O5F2.cif
# ..                                ...
# 995           cif_mp-20750_Tb3SnC.cif
# 996      cif_mp-1099261_CsMg6GaO8.cif
# 997            cif_mp-10792_DyBO3.cif
# 998             cif_mp-22893_PbI2.cif
# 999        cif_mp-1097393_Mg2CdRh.cif
#
# [1000 rows x 1 columns]

# %%
# files_dfにidを追加
files_df["id"] = files_df["file_name"].str.extract(r"mp-(\d+)")
files_df["id"] = "mp-" + files_df["id"]
files_df
# Out:
#                             file_name          id
# 0    cif_mp-2715587_NaNbSi2SnSO12.cif  mp-2715587
# 1     cif_mp-1190493_NiH5CN(ClO)2.cif  mp-1190493
# 2       cif_mp-2218111_MgTi(WO4)2.cif  mp-2218111
# 3            cif_mp-1194227_H3CO3.cif  mp-1194227
# 4           cif_mp-759602_Sb4O5F2.cif   mp-759602
# ..                                ...         ...
# 995           cif_mp-20750_Tb3SnC.cif    mp-20750
# 996      cif_mp-1099261_CsMg6GaO8.cif  mp-1099261
# 997            cif_mp-10792_DyBO3.cif    mp-10792
# 998             cif_mp-22893_PbI2.cif    mp-22893
# 999        cif_mp-1097393_Mg2CdRh.cif  mp-1097393
#
# [1000 rows x 2 columns]

# %%
# dfとfiles_dfを結合
merged_df = pd.merge(df, files_df, on='id', how='inner')
merged_df
# Out:
#                formula          id  band_gap  formation_energy  \
# 0         Cs3Nd(MoO4)3   mp-573369    3.7419         -2.414818
# 1            Ba(PdS2)2    mp-28967    0.7792         -1.124079
# 2      Na7Ta3Zn(SiO4)6  mp-2712904    2.5286         -2.912354
# 3             TiZnBiO5  mp-1042447    0.0000         -2.236384
# 4    Na2YNb3Si4(SO12)2  mp-2715697    1.8105         -2.837049
# ..                 ...         ...       ...               ...
# 995           NaHfMg14  mp-1026645    0.0000          0.123330
# 996            CeGa3Ni  mp-1226580    0.0000         -0.499538
# 997            ReRuCl2   mp-631417    0.0000          1.034857
# 998      Li2NiH8(CO5)2   mp-771916    4.1397         -1.559949
# 999              MgTl3   mp-978262    0.0000          0.042863
#
#      energy_above_hull                             file_name
# 0             0.000000        cif_mp-573369_Cs3Nd(MoO4)3.cif
# 1             0.000000            cif_mp-28967_Ba(PdS2)2.cif
# 2             0.049678    cif_mp-2712904_Na7Ta3Zn(SiO4)6.cif
# 3             0.077777           cif_mp-1042447_TiZnBiO5.cif
# 4             0.079832  cif_mp-2715697_Na2YNb3Si4(SO12)2.cif
# ..                 ...                                   ...
# 995           0.123330           cif_mp-1026645_NaHfMg14.cif
# 996           0.035687            cif_mp-1226580_CeGa3Ni.cif
# 997           1.818772             cif_mp-631417_ReRuCl2.cif
# 998           0.052192       cif_mp-771916_Li2NiH8(CO5)2.cif
# 999           0.051358               cif_mp-978262_MgTl3.cif
#
# [1000 rows x 6 columns]

# %%
# merged_dfにCIFのファイルパスを追加
merged_df["file_path"] = INPUT_FILE_PATH + "material_projects_api_cif_1000/" + merged_df["file_name"]
merged_df
# Out:
#                formula          id  band_gap  formation_energy  \
# 0         Cs3Nd(MoO4)3   mp-573369    3.7419         -2.414818
# 1            Ba(PdS2)2    mp-28967    0.7792         -1.124079
# 2      Na7Ta3Zn(SiO4)6  mp-2712904    2.5286         -2.912354
# 3             TiZnBiO5  mp-1042447    0.0000         -2.236384
# 4    Na2YNb3Si4(SO12)2  mp-2715697    1.8105         -2.837049
# ..                 ...         ...       ...               ...
# 995           NaHfMg14  mp-1026645    0.0000          0.123330
# 996            CeGa3Ni  mp-1226580    0.0000         -0.499538
# 997            ReRuCl2   mp-631417    0.0000          1.034857
# 998      Li2NiH8(CO5)2   mp-771916    4.1397         -1.559949
# 999              MgTl3   mp-978262    0.0000          0.042863
#
#      energy_above_hull                             file_name  \
# 0             0.000000        cif_mp-573369_Cs3Nd(MoO4)3.cif
# 1             0.000000            cif_mp-28967_Ba(PdS2)2.cif
# 2             0.049678    cif_mp-2712904_Na7Ta3Zn(SiO4)6.cif
# 3             0.077777           cif_mp-1042447_TiZnBiO5.cif
# 4             0.079832  cif_mp-2715697_Na2YNb3Si4(SO12)2.cif
# ..                 ...                                   ...
# 995           0.123330           cif_mp-1026645_NaHfMg14.cif
# 996           0.035687            cif_mp-1226580_CeGa3Ni.cif
# 997           1.818772             cif_mp-631417_ReRuCl2.cif
# 998           0.052192       cif_mp-771916_Li2NiH8(CO5)2.cif
# 999           0.051358               cif_mp-978262_MgTl3.cif
#
#                                              file_path
# 0    ./material_projects_api_cif_1000/cif_mp-573369...
# 1    ./material_projects_api_cif_1000/cif_mp-28967_...
# 2    ./material_projects_api_cif_1000/cif_mp-271290...
# 3    ./material_projects_api_cif_1000/cif_mp-104244...
# 4    ./material_projects_api_cif_1000/cif_mp-271569...
# ..                                                 ...
# 995  ./material_projects_api_cif_1000/cif_mp-102664...
# 996  ./material_projects_api_cif_1000/cif_mp-122658...
# 997  ./material_projects_api_cif_1000/cif_mp-631417...
# 998  ./material_projects_api_cif_1000/cif_mp-771916...
# 999  ./material_projects_api_cif_1000/cif_mp-978262...
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## CIFから特徴量を生成する

# %%
crystal_train = []

for i in range(0,len(files)):
  with open(merged_df['file_path'].values[i], 'r') as f:
    cif_content = f.read()
  crystal_tmp = Structure.from_str(cif_content, fmt = "cif")
  crystal_train.append(crystal_tmp)

merged_df['structure'] = crystal_train

# %%
merged_df
# Out:
#                formula          id  band_gap  formation_energy  \
# 0         Cs3Nd(MoO4)3   mp-573369    3.7419         -2.414818
# 1            Ba(PdS2)2    mp-28967    0.7792         -1.124079
# 2      Na7Ta3Zn(SiO4)6  mp-2712904    2.5286         -2.912354
# 3             TiZnBiO5  mp-1042447    0.0000         -2.236384
# 4    Na2YNb3Si4(SO12)2  mp-2715697    1.8105         -2.837049
# ..                 ...         ...       ...               ...
# 995           NaHfMg14  mp-1026645    0.0000          0.123330
# 996            CeGa3Ni  mp-1226580    0.0000         -0.499538
# 997            ReRuCl2   mp-631417    0.0000          1.034857
# 998      Li2NiH8(CO5)2   mp-771916    4.1397         -1.559949
# 999              MgTl3   mp-978262    0.0000          0.042863
#
#      energy_above_hull                             file_name  \
# 0             0.000000        cif_mp-573369_Cs3Nd(MoO4)3.cif
# 1             0.000000            cif_mp-28967_Ba(PdS2)2.cif
# 2             0.049678    cif_mp-2712904_Na7Ta3Zn(SiO4)6.cif
# 3             0.077777           cif_mp-1042447_TiZnBiO5.cif
# 4             0.079832  cif_mp-2715697_Na2YNb3Si4(SO12)2.cif
# ..                 ...                                   ...
# 995           0.123330           cif_mp-1026645_NaHfMg14.cif
# 996           0.035687            cif_mp-1226580_CeGa3Ni.cif
# 997           1.818772             cif_mp-631417_ReRuCl2.cif
# 998           0.052192       cif_mp-771916_Li2NiH8(CO5)2.cif
# 999           0.051358               cif_mp-978262_MgTl3.cif
#
#                                              file_path  \
# 0    ./material_projects_api_cif_1000/cif_mp-573369...
# 1    ./material_projects_api_cif_1000/cif_mp-28967_...
# 2    ./material_projects_api_cif_1000/cif_mp-271290...
# 3    ./material_projects_api_cif_1000/cif_mp-104244...
# 4    ./material_projects_api_cif_1000/cif_mp-271569...
# ..                                                 ...
# 995  ./material_projects_api_cif_1000/cif_mp-102664...
# 996  ./material_projects_api_cif_1000/cif_mp-122658...
# 997  ./material_projects_api_cif_1000/cif_mp-631417...
# 998  ./material_projects_api_cif_1000/cif_mp-771916...
# 999  ./material_projects_api_cif_1000/cif_mp-978262...
#
#                                              structure
# 0    [[ 1.63145925  0.23570193 10.77716588] Cs, [1....
# 1    [[4.55327196 5.11963834 2.01929037] Ba, [1.798...
# 2    [[5.74553181 0.18487825 5.49029458] Na, [1.846...
# 3    [[4.62933005 3.74678864 6.11501235] Ti, [3.152...
# 4    [[ 4.45385419  7.65516804 11.47379283] Na, [ 4...
# ..                                                 ...
# 995  [[-0.00959284  1.87776076  1.28696084] Na, [-1...
# 996  [[0. 0. 0.] Ce, [ 2.08237107  2.39787734 -5.56...
# 997  [[0. 0. 0.] Re, [2.5076145  1.77315122 4.34331...
# 998  [[ 1.63225055  4.37071098 11.62767295] Li, [4....
# 999  [[3.51089454 2.0270166  1.30084825] Mg, [-1.03...
#
# [1000 rows x 8 columns]

# %%
# 例としてmerged_dfのはじめのCIFを表示
merged_df['structure'][0]
# Out:
# Structure Summary
# Lattice
#     abc : 6.525837 9.536025 26.422264
#  angles : 90.0 90.0 90.0
#  volume : 1644.2718829861558
#       A : np.float64(6.525837) np.float64(0.0) np.float64(3.995922696903683e-16)
#       B : np.float64(1.5335097790382647e-15) np.float64(9.536025) np.float64(5.839131246419569e-16)
#       C : np.float64(0.0) np.float64(0.0) np.float64(26.422264)
#     pbc : True True True
# PeriodicSite: Cs0 (Cs) (1.631, 0.2357, 10.78) [0.25, 0.02472, 0.4079]
# PeriodicSite: Cs1 (Cs) (1.631, 5.004, 2.434) [0.25, 0.5247, 0.09212]
# PeriodicSite: Cs2 (Cs) (4.894, 9.3, 15.65) [0.75, 0.9753, 0.5921]
# PeriodicSite: Cs3 (Cs) (4.894, 4.532, 23.99) [0.75, 0.4753, 0.9079]
# PeriodicSite: Cs4 (Cs) (1.631, 0.9904, 21.67) [0.25, 0.1039, 0.8201]
# PeriodicSite: Cs5 (Cs) (1.631, 5.758, 17.96) [0.25, 0.6039, 0.6799]
# PeriodicSite: Cs6 (Cs) (4.894, 8.546, 4.753) [0.75, 0.8961, 0.1799]
# PeriodicSite: Cs7 (Cs) (4.894, 3.778, 8.458) [0.75, 0.3961, 0.3201]
# PeriodicSite: Cs8 (Cs) (1.631, 1.797, 6.368) [0.25, 0.1884, 0.241]
# PeriodicSite: Cs9 (Cs) (1.631, 6.565, 6.843) [0.25, 0.6884, 0.259]
# PeriodicSite: Cs10 (Cs) (4.894, 7.739, 20.05) [0.75, 0.8116, 0.759]
# PeriodicSite: Cs11 (Cs) (4.894, 2.971, 19.58) [0.75, 0.3116, 0.741]
# PeriodicSite: Nd12 (Nd) (1.631, 3.037, 14.29) [0.25, 0.3185, 0.5408]
# PeriodicSite: Nd13 (Nd) (1.631, 7.805, 25.35) [0.25, 0.8185, 0.9592]
# PeriodicSite: Nd14 (Nd) (4.894, 6.499, 12.13) [0.75, 0.6815, 0.4592]
# PeriodicSite: Nd15 (Nd) (4.894, 1.731, 1.077) [0.75, 0.1815, 0.04075]
# PeriodicSite: Mo16 (Mo) (1.631, 7.178, 13.85) [0.25, 0.7527, 0.5242]
# PeriodicSite: Mo17 (Mo) (1.631, 2.41, 25.78) [0.25, 0.2527, 0.9758]
# PeriodicSite: Mo18 (Mo) (4.894, 2.358, 12.57) [0.75, 0.2473, 0.4758]
# PeriodicSite: Mo19 (Mo) (4.894, 7.126, 0.6393) [0.75, 0.7473, 0.0242]
# PeriodicSite: Mo20 (Mo) (1.631, 4.583, 10.58) [0.25, 0.4806, 0.4006]
# PeriodicSite: Mo21 (Mo) (1.631, 9.351, 2.628) [0.25, 0.9806, 0.09945]
# PeriodicSite: Mo22 (Mo) (4.894, 4.953, 15.84) [0.75, 0.5194, 0.5995]
# PeriodicSite: Mo23 (Mo) (4.894, 0.1849, 23.79) [0.75, 0.01939, 0.9005]
# PeriodicSite: Mo24 (Mo) (1.631, 1.099, 17.82) [0.25, 0.1152, 0.6743]
# PeriodicSite: Mo25 (Mo) (1.631, 5.867, 21.82) [0.25, 0.6152, 0.8257]
# PeriodicSite: Mo26 (Mo) (4.894, 8.437, 8.606) [0.75, 0.8848, 0.3257]
# PeriodicSite: Mo27 (Mo) (4.894, 3.669, 4.606) [0.75, 0.3848, 0.1743]
# PeriodicSite: O28 (O) (1.631, 7.645, 15.55) [0.25, 0.8017, 0.5885]
# PeriodicSite: O29 (O) (1.631, 2.877, 24.08) [0.25, 0.3017, 0.9115]
# PeriodicSite: O30 (O) (4.894, 1.891, 10.87) [0.75, 0.1983, 0.4115]
# PeriodicSite: O31 (O) (4.894, 6.659, 2.338) [0.75, 0.6983, 0.08848]
# PeriodicSite: O32 (O) (3.093, 7.835, 13.0) [0.4739, 0.8217, 0.4921]
# PeriodicSite: O33 (O) (0.1701, 3.067, 0.2076) [0.02606, 0.3217, 0.007856]
# PeriodicSite: O34 (O) (6.356, 1.701, 13.42) [0.9739, 0.1783, 0.5079]
# PeriodicSite: O35 (O) (3.433, 6.469, 26.21) [0.5261, 0.6783, 0.9921]
# PeriodicSite: O36 (O) (3.433, 1.701, 13.42) [0.5261, 0.1783, 0.5079]
# PeriodicSite: O37 (O) (6.356, 6.469, 26.21) [0.9739, 0.6783, 0.9921]
# PeriodicSite: O38 (O) (0.1701, 7.835, 13.0) [0.02606, 0.8217, 0.4921]
# PeriodicSite: O39 (O) (3.093, 3.067, 0.2076) [0.4739, 0.3217, 0.007856]
# PeriodicSite: O40 (O) (1.631, 5.379, 13.71) [0.25, 0.5641, 0.5188]
# PeriodicSite: O41 (O) (1.631, 0.6112, 25.93) [0.25, 0.06409, 0.9812]
# PeriodicSite: O42 (O) (4.894, 4.157, 12.72) [0.75, 0.4359, 0.4812]
# PeriodicSite: O43 (O) (4.894, 8.925, 0.4955) [0.75, 0.9359, 0.01875]
# PeriodicSite: O44 (O) (1.631, 3.853, 8.95) [0.25, 0.404, 0.3387]
# PeriodicSite: O45 (O) (1.631, 8.621, 4.262) [0.25, 0.904, 0.1613]
# PeriodicSite: O46 (O) (4.894, 5.684, 17.47) [0.75, 0.596, 0.6613]
# PeriodicSite: O47 (O) (4.894, 0.9155, 22.16) [0.75, 0.096, 0.8387]
# PeriodicSite: O48 (O) (1.631, 3.26, 11.8) [0.25, 0.3418, 0.4464]
# PeriodicSite: O49 (O) (1.631, 8.028, 1.416) [0.25, 0.8418, 0.05358]
# PeriodicSite: O50 (O) (4.894, 6.276, 14.63) [0.75, 0.6582, 0.5536]
# PeriodicSite: O51 (O) (4.894, 1.508, 25.01) [0.75, 0.1582, 0.9464]
# PeriodicSite: O52 (O) (3.126, 5.586, 10.72) [0.479, 0.5858, 0.4059]
# PeriodicSite: O53 (O) (0.1368, 0.8183, 2.487) [0.02096, 0.08581, 0.09413]
# PeriodicSite: O54 (O) (6.389, 3.95, 15.7) [0.979, 0.4142, 0.5941]
# PeriodicSite: O55 (O) (3.4, 8.718, 23.94) [0.521, 0.9142, 0.9059]
# PeriodicSite: O56 (O) (3.4, 3.95, 15.7) [0.521, 0.4142, 0.5941]
# PeriodicSite: O57 (O) (6.389, 8.718, 23.94) [0.979, 0.9142, 0.9059]
# PeriodicSite: O58 (O) (0.1368, 5.586, 10.72) [0.02096, 0.5858, 0.4059]
# PeriodicSite: O59 (O) (3.126, 0.8183, 2.487) [0.479, 0.08581, 0.09413]
# PeriodicSite: O60 (O) (0.1571, 0.2043, 18.32) [0.02408, 0.02142, 0.6933]
# PeriodicSite: O61 (O) (3.106, 4.972, 21.31) [0.4759, 0.5214, 0.8067]
# PeriodicSite: O62 (O) (3.42, 9.332, 8.103) [0.5241, 0.9786, 0.3067]
# PeriodicSite: O63 (O) (6.369, 4.564, 5.108) [0.9759, 0.4786, 0.1933]
# PeriodicSite: O64 (O) (6.369, 9.332, 8.103) [0.9759, 0.9786, 0.3067]
# PeriodicSite: O65 (O) (3.42, 4.564, 5.108) [0.5241, 0.4786, 0.1933]
# PeriodicSite: O66 (O) (3.106, 0.2043, 18.32) [0.4759, 0.02142, 0.6933]
# PeriodicSite: O67 (O) (0.1571, 4.972, 21.31) [0.02408, 0.5214, 0.8067]
# PeriodicSite: O68 (O) (1.631, 2.662, 18.7) [0.25, 0.2791, 0.7078]
# PeriodicSite: O69 (O) (1.631, 7.43, 20.93) [0.25, 0.7791, 0.7922]
# PeriodicSite: O70 (O) (4.894, 6.874, 7.719) [0.75, 0.7209, 0.2922]
# PeriodicSite: O71 (O) (4.894, 2.106, 5.492) [0.75, 0.2209, 0.2078]
# PeriodicSite: O72 (O) (1.631, 1.405, 16.02) [0.25, 0.1473, 0.6062]
# PeriodicSite: O73 (O) (1.631, 6.173, 23.62) [0.25, 0.6473, 0.8938]
# PeriodicSite: O74 (O) (4.894, 8.131, 10.41) [0.75, 0.8527, 0.3938]
# PeriodicSite: O75 (O) (4.894, 3.363, 2.805) [0.75, 0.3527, 0.1062]

# %%
merged_df = DensityFeatures().featurize_dataframe(merged_df, col_id="structure", ignore_errors=True)
merged_df
# Out:
#                formula          id  band_gap  formation_energy  \
# 0         Cs3Nd(MoO4)3   mp-573369    3.7419         -2.414818
# 1            Ba(PdS2)2    mp-28967    0.7792         -1.124079
# 2      Na7Ta3Zn(SiO4)6  mp-2712904    2.5286         -2.912354
# 3             TiZnBiO5  mp-1042447    0.0000         -2.236384
# 4    Na2YNb3Si4(SO12)2  mp-2715697    1.8105         -2.837049
# ..                 ...         ...       ...               ...
# 995           NaHfMg14  mp-1026645    0.0000          0.123330
# 996            CeGa3Ni  mp-1226580    0.0000         -0.499538
# 997            ReRuCl2   mp-631417    0.0000          1.034857
# 998      Li2NiH8(CO5)2   mp-771916    4.1397         -1.559949
# 999              MgTl3   mp-978262    0.0000          0.042863
#
#      energy_above_hull                             file_name  \
# 0             0.000000        cif_mp-573369_Cs3Nd(MoO4)3.cif
# 1             0.000000            cif_mp-28967_Ba(PdS2)2.cif
# 2             0.049678    cif_mp-2712904_Na7Ta3Zn(SiO4)6.cif
# 3             0.077777           cif_mp-1042447_TiZnBiO5.cif
# 4             0.079832  cif_mp-2715697_Na2YNb3Si4(SO12)2.cif
# ..                 ...                                   ...
# 995           0.123330           cif_mp-1026645_NaHfMg14.cif
# 996           0.035687            cif_mp-1226580_CeGa3Ni.cif
# 997           1.818772             cif_mp-631417_ReRuCl2.cif
# 998           0.052192       cif_mp-771916_Li2NiH8(CO5)2.cif
# 999           0.051358               cif_mp-978262_MgTl3.cif
#
#                                              file_path  \
# 0    ./material_projects_api_cif_1000/cif_mp-573369...
# 1    ./material_projects_api_cif_1000/cif_mp-28967_...
# 2    ./material_projects_api_cif_1000/cif_mp-271290...
# 3    ./material_projects_api_cif_1000/cif_mp-104244...
# 4    ./material_projects_api_cif_1000/cif_mp-271569...
# ..                                                 ...
# 995  ./material_projects_api_cif_1000/cif_mp-102664...
# 996  ./material_projects_api_cif_1000/cif_mp-122658...
# 997  ./material_projects_api_cif_1000/cif_mp-631417...
# 998  ./material_projects_api_cif_1000/cif_mp-771916...
# 999  ./material_projects_api_cif_1000/cif_mp-978262...
#
#                                              structure    density        vpa  \
# 0    [[ 1.63145925  0.23570193 10.77716588] Cs, [1....   4.131559  21.635156
# 1    [[4.55327196 5.11963834 2.01929037] Ba, [1.798...   5.022717  22.595815
# 2    [[5.74553181 0.18487825 5.49029458] Na, [1.846...   4.084346  13.105962
# 3    [[4.62933005 3.74678864 6.11501235] Ti, [3.152...   6.095516  13.697723
# 4    [[ 4.45385419  7.65516804 11.47379283] Na, [ 4...   2.984554  15.054064
# ..                                                 ...        ...        ...
# 995  [[-0.00959284  1.87776076  1.28696084] Na, [-1...   2.417495  23.257461
# 996  [[0. 0. 0.] Ce, [ 2.08237107  2.39787734 -5.56...   7.521893  18.013128
# 997  [[0. 0. 0.] Re, [2.5076145  1.77315122 4.34331...  10.266085  14.484023
# 998  [[ 1.63225055  4.37071098 11.62767295] Li, [4....   2.198468   8.691208
# 999  [[3.51089454 2.0270166  1.30084825] Mg, [-1.03...   9.528302  27.773016
#
#      packing fraction
# 0            0.721428
# 1            0.514463
# 2            0.511377
# 3            0.396792
# 4            0.302596
# ..                ...
# 995          0.639440
# 996          0.715436
# 997          0.481329
# 998          0.241578
# 999          0.903124
#
# [1000 rows x 11 columns]

# %%
merged_df[["formula","structure", "density", "vpa", "packing fraction"]]
# Out:
#                formula                                          structure  \
# 0         Cs3Nd(MoO4)3  [[ 1.63145925  0.23570193 10.77716588] Cs, [1....
# 1            Ba(PdS2)2  [[4.55327196 5.11963834 2.01929037] Ba, [1.798...
# 2      Na7Ta3Zn(SiO4)6  [[5.74553181 0.18487825 5.49029458] Na, [1.846...
# 3             TiZnBiO5  [[4.62933005 3.74678864 6.11501235] Ti, [3.152...
# 4    Na2YNb3Si4(SO12)2  [[ 4.45385419  7.65516804 11.47379283] Na, [ 4...
# ..                 ...                                                ...
# 995           NaHfMg14  [[-0.00959284  1.87776076  1.28696084] Na, [-1...
# 996            CeGa3Ni  [[0. 0. 0.] Ce, [ 2.08237107  2.39787734 -5.56...
# 997            ReRuCl2  [[0. 0. 0.] Re, [2.5076145  1.77315122 4.34331...
# 998      Li2NiH8(CO5)2  [[ 1.63225055  4.37071098 11.62767295] Li, [4....
# 999              MgTl3  [[3.51089454 2.0270166  1.30084825] Mg, [-1.03...
#
#        density        vpa  packing fraction
# 0     4.131559  21.635156          0.721428
# 1     5.022717  22.595815          0.514463
# 2     4.084346  13.105962          0.511377
# 3     6.095516  13.697723          0.396792
# 4     2.984554  15.054064          0.302596
# ..         ...        ...               ...
# 995   2.417495  23.257461          0.639440
# 996   7.521893  18.013128          0.715436
# 997  10.266085  14.484023          0.481329
# 998   2.198468   8.691208          0.241578
# 999   9.528302  27.773016          0.903124
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 実行環境のライブラリverを保存

# %%
# Pythonのverを確認
# !python3 -V
# Out:
# Python 3.11.11

# %%
# !pip freeze > requirements_feature_generation_cif.txt

# %%
from google.colab import files

files.download('requirements_feature_generation_cif.txt')
