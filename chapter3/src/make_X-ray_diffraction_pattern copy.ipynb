# %%
import pandas as pd
import numpy as np
import os
import glob

from tqdm.notebook import tqdm
import gc
tqdm.pandas()

import warnings 
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

from crystal_toolkit.renderables import StructureGraph
from pymatgen.analysis.local_env import MinimumDistanceNN
from pymatgen.core import Structure
from pymatgen.analysis.diffraction.xrd import XRDCalculator

import scipy as sp
import scipy.special

# %%
path = '../input/material_projects_api_cif/'
files = os.listdir(path)
len(files)
# Out:
# 153235

# %%
files
# Out:
# ['cif_mp-10000_Hf2S.cif',
#  'cif_mp-10003_Nb4CoSi.cif',
#  'cif_mp-10004_Mo3P.cif',
#  'cif_mp-10006_TlAgTe2.cif',
#  'cif_mp-10008_Ca7Ge.cif',
#  'cif_mp-10009_GaTe.cif',
#  'cif_mp-1000_BaTe.cif',
#  'cif_mp-1001011_TaO3.cif',
#  'cif_mp-1001012_Sc2ZnS4.cif',
#  'cif_mp-1001015_Y2ZnS4.cif',
#  'cif_mp-1001016_Sc2ZnSe4.cif',
#  'cif_mp-1001017_Zn(InSe2)2.cif',
#  'cif_mp-1001019_Mg(ScSe2)2.cif',
#  'cif_mp-1001021_Y2ZnSe4.cif',
#  'cif_mp-1001022_Cu2PPd2.cif',
#  'cif_mp-1001023_BeC2.cif',
#  'cif_mp-1001024_Y2MgS4.cif',
#  'cif_mp-1001034_Mg(InSe2)2.cif',
#  'cif_mp-1001069_Li48P16S61.cif',
#  'cif_mp-1001079_Li(CN)2.cif',
#  'cif_mp-1001080_H2CO3.cif',
#  'cif_mp-1001082_Si(CO)2.cif',
#  'cif_mp-10010_Al(CoSi)2.cif',
#  'cif_mp-1001112_Na2H3CO6.cif',
#  'cif_mp-1001113_Si.cif',
#  'cif_mp-1001117_Mn3N2.cif',
#  'cif_mp-10013_SnS.cif',
#  'cif_mp-10014_TaS2.cif',
#  'cif_mp-1001571_CaFeO3.cif',
#  'cif_mp-1001581_LiC6.cif',
#  'cif_mp-1001594_C4O3.cif',
#  'cif_mp-10015_SiOs.cif',
#  'cif_mp-1001600_HfB12.cif',
#  'cif_mp-1001602_B12W.cif',
#  'cif_mp-1001603_LuNiC2.cif',
#  'cif_mp-1001604_LuTlS2.cif',
#  'cif_mp-1001605_PrBi.cif',
#  'cif_mp-1001606_LuFeC2.cif',
#  'cif_mp-1001608_C4O3.cif',
#  'cif_mp-1001611_LuTlSe2.cif',
#  'cif_mp-1001612_LuSi.cif',
#  'cif_mp-1001613_LuGa.cif',
#  'cif_mp-1001614_LuCoC2.cif',
#  'cif_mp-1001615_LiZrSe2.cif',
#  'cif_mp-1001780_LuCuS2.cif',
#  'cif_mp-1001783_LiSnS2.cif',
#  'cif_mp-1001784_LiTiS2.cif',
#  'cif_mp-1001785_MoP.cif',
#  'cif_mp-1001786_LiScS2.cif',
#  'cif_mp-1001787_LiRh3.cif',
#  'cif_mp-1001788_ZrB6.cif',
#  'cif_mp-1001789_IrC.cif',
#  'cif_mp-1001790_LiO3.cif',
#  'cif_mp-1001793_KCoCl3.cif',
#  'cif_mp-1001824_IrC.cif',
#  'cif_mp-1001825_LiBe.cif',
#  'cif_mp-1001826_VN.cif',
#  'cif_mp-1001827_IrC.cif',
#  'cif_mp-1001828_WN.cif',
#  'cif_mp-1001831_LiB.cif',
#  'cif_mp-1001833_InBi.cif',
#  'cif_mp-1001834_HfN.cif',
#  'cif_mp-1001835_LiB.cif',
#  'cif_mp-1001836_MnGa.cif',
#  'cif_mp-1001837_MoP.cif',
#  'cif_mp-1001843_HoP.cif',
#  'cif_mp-1001844_HoN.cif',
#  'cif_mp-10018_Ac.cif',
#  'cif_mp-1001913_HoBi.cif',
#  'cif_mp-1001914_Li2SnIr.cif',
#  'cif_mp-1001916_HfN.cif',
#  'cif_mp-1001917_HoAs.cif',
#  'cif_mp-1001918_HfC.cif',
#  'cif_mp-1001925_LaC.cif',
#  'cif_mp-1001_BaN2.cif',
#  'cif_mp-1002063_SnS2.cif',
#  'cif_mp-1002069_NaLiICl.cif',
#  'cif_mp-1002080_CsLiICl.cif',
#  'cif_mp-1002081_KNaICl.cif',
#  'cif_mp-1002083_CsKICl.cif',
#  'cif_mp-10020_ScC.cif',
#  'cif_mp-1002104_LaPt.cif',
#  'cif_mp-1002105_VN.cif',
#  'cif_mp-1002106_HfPd.cif',
#  'cif_mp-1002107_LaRh.cif',
#  'cif_mp-1002109_VCo.cif',
#  'cif_mp-1002114_VH.cif',
#  'cif_mp-1002115_LaPd.cif',
#  'cif_mp-1002117_TcN.cif',
#  'cif_mp-1002122_HfIr.cif',
#  'cif_mp-1002123_KZrS2.cif',
#  'cif_mp-1002124_HfC.cif',
#  'cif_mp-1002133_LaGa.cif',
#  'cif_mp-1002136_LaAu.cif',
#  'cif_mp-1002164_GeC.cif',
#  'cif_mp-1002165_GeC.cif',
#  'cif_mp-1002181_TcN.cif',
#  'cif_mp-1002182_TcN.cif',
#  'cif_mp-1002183_TcB.cif',
#  'cif_mp-1002184_TcB.cif',
#  'cif_mp-1002187_TcB.cif',
#  'cif_mp-1002188_TcB.cif',
#  'cif_mp-1002197_RuN.cif',
#  'cif_mp-10021_Ga.cif',
#  'cif_mp-1002206_SiC.cif',
#  'cif_mp-1002207_ReN.cif',
#  'cif_mp-1002209_ReN.cif',
#  'cif_mp-1002210_EuS.cif',
#  'cif_mp-1002219_TlSb.cif',
#  'cif_mp-1002220_TmSb.cif',
#  'cif_mp-1002221_ErH.cif',
#  'cif_mp-1002222_TlN.cif',
#  'cif_mp-1002223_DyP.cif',
#  'cif_mp-1002224_ErP.cif',
#  'cif_mp-1002226_ErAs.cif',
#  'cif_mp-1002227_RbSb.cif',
#  'cif_mp-1002228_PtC.cif',
#  'cif_mp-1002229_ErN.cif',
#  'cif_mp-1002230_PuBi.cif',
#  'cif_mp-1002252_Ca8H3N4.cif',
#  'cif_mp-1002346_SmH8(NO5)3.cif',
#  'cif_mp-10023_La.cif',
#  'cif_mp-10024_Ce.cif',
#  'cif_mp-1002568_MgMn2O4.cif',
#  'cif_mp-1002569_MgMnO2.cif',
#  'cif_mp-1002570_KMnO2.cif',
#  'cif_mp-1002571_NaMn2O4.cif',
#  'cif_mp-1002572_LiMnO2.cif',
#  'cif_mp-1002573_MnHO2.cif',
#  'cif_mp-1002574_KMnO2.cif',
#  'cif_mp-10025_SiRu2.cif',
#  'cif_mp-10026_ScTe.cif',
#  'cif_mp-10027_TiSe.cif',
#  'cif_mp-10030_RuC.cif',
#  'cif_mp-10032_Ge2Os.cif',
#  'cif_mp-1003311_CaMn2O4.cif',
#  'cif_mp-1003312_KMn4O8.cif',
#  'cif_mp-1003313_Li2Mn3O6.cif',
#  'cif_mp-1003314_KMn2O4.cif',
#  'cif_mp-1003315_LiMn4O8.cif',
#  'cif_mp-1003316_KMn4O8.cif',
#  'cif_mp-1003317_Mn3HO6.cif',
#  'cif_mp-1003318_CaMn16O32.cif',
#  'cif_mp-1003319_CaMn8O16.cif',
#  'cif_mp-1003320_CaMn4O8.cif',
#  'cif_mp-1003322_CaMnO2.cif',
#  'cif_mp-10033_NbS2.cif',
#  'cif_mp-1003402_CaMnO2.cif',
#  'cif_mp-1003403_Mn8HO16.cif',
#  'cif_mp-1003437_KMn2O4.cif',
#  'cif_mp-1003483_CaMn4O8.cif',
#  'cif_mp-1003484_MgMn4O8.cif',
#  'cif_mp-1003485_Mg2Mn3O6.cif',
#  'cif_mp-1003486_CaMnO2.cif',
#  'cif_mp-1003545_MgMn4O8.cif',
#  'cif_mp-1003548_CaMn2O4.cif',
#  'cif_mp-1003549_LiMn16O32.cif',
#  'cif_mp-1003635_NaMn16O32.cif',
#  'cif_mp-1003636_NaMn4O8.cif',
#  'cif_mp-1003637_LiMn3O6.cif',
#  'cif_mp-1003638_NaMn8O16.cif',
#  'cif_mp-1003639_Ca3Mn4O8.cif',
#  'cif_mp-1003641_MgMn2O4.cif',
#  'cif_mp-10036_Ce3AlC.cif',
#  'cif_mp-1003735_MgMn2O4.cif',
#  'cif_mp-1003736_NaMn2O4.cif',
#  'cif_mp-1003764_K3Mn4O8.cif',
#  'cif_mp-1003765_Mn2HO4.cif',
#  'cif_mp-1003766_NaMn2O4.cif',
#  'cif_mp-1003767_NaMn2O4.cif',
#  'cif_mp-1003769_Li3Mn4O8.cif',
#  'cif_mp-1003770_MgMn2O4.cif',
#  'cif_mp-1003771_MgMn6O12.cif',
#  'cif_mp-10037_AlCo3C.cif',
#  'cif_mp-1003854_KMnO2.cif',
#  'cif_mp-1003856_MgMnO2.cif',
#  'cif_mp-10038_Er3AlC.cif',
#  'cif_mp-1003920_Mn2HO4.cif',
#  'cif_mp-1003923_CaMn4O8.cif',
#  'cif_mp-10039_Pr3AlC.cif',
#  'cif_mp-1003_TbGe2.cif',
#  'cif_mp-1004037_CaMnO2.cif',
#  'cif_mp-1004038_CaMn2O4.cif',
#  'cif_mp-10040_AlPt3C.cif',
#  'cif_mp-10041_Tb3AlC.cif',
#  'cif_mp-1004373_LiMnO2.cif',
#  'cif_mp-1004375_MgMn4O8.cif',
#  'cif_mp-1004376_NaMn2O4.cif',
#  'cif_mp-1004377_HfB6.cif',
#  'cif_mp-10044_BAs.cif',
#  'cif_mp-1004524_HPbI3.cif',
#  'cif_mp-1004525_SmB12.cif',
#  'cif_mp-1004526_WS.cif',
#  'cif_mp-1004528_CsB3PbF12.cif',
#  'cif_mp-1004530_CsBPb(IF2)2.cif',
#  'cif_mp-1004532_CCl4.cif',
#  'cif_mp-10045_Ba5As3.cif',
#  'cif_mp-10046_V2AsC.cif',
#  'cif_mp-1004753_PrB12.cif',
#  'cif_mp-1004756_NdB12.cif',
#  'cif_mp-1004758_Mn3(HO3)2.cif',
#  'cif_mp-1004762_LiMn4O8.cif',
#  'cif_mp-10047_Ca5As3.cif',
#  'cif_mp-10048_GaAs.cif',
#  'cif_mp-10049_MnAsRu.cif',
#  'cif_mp-1004_Nb3Si.cif',
#  'cif_mp-10051_TeAs.cif',
#  'cif_mp-10052_TiAs.cif',
#  'cif_mp-10054_ZrAs.cif',
#  'cif_mp-10055_Co2B4Mo.cif',
#  'cif_mp-1005666_Sc3Al3C2O5.cif',
#  'cif_mp-1005689_Sm6GaCo2.cif',
#  'cif_mp-1005690_Sm2Co12P7.cif',
#  'cif_mp-1005693_Sm2InHg.cif',
#  'cif_mp-10056_UCo3B2.cif',
#  'cif_mp-1005719_Sm3Np.cif',
#  'cif_mp-1005727_TmNp3.cif',
#  'cif_mp-1005752_Sm3In.cif',
#  'cif_mp-1005753_Sm2AlGe6.cif',
#  'cif_mp-1005754_SmHSO5.cif',
#  'cif_mp-1005755_SmGe2Pt.cif',
#  'cif_mp-1005760_Tl3Os.cif',
#  'cif_mp-1005761_SmGd3.cif',
#  'cif_mp-1005762_Sm3Au.cif',
#  'cif_mp-1005789_Sm2(Ga3Co)3.cif',
#  'cif_mp-1005792_Sm2CuAs3O.cif',
#  'cif_mp-10057_VCoB3.cif',
#  'cif_mp-1005829_Sm2Mn12P7.cif',
#  'cif_mp-1005831_Tb2Co3Ge5.cif',
#  'cif_mp-1005895_Sm3Gd.cif',
#  'cif_mp-1005955_Tm3Ni7B2.cif',
#  'cif_mp-1005986_Zr9CoMo4.cif',
#  'cif_mp-10059_ZrCo3B2.cif',
#  'cif_mp-1005_FeP.cif',
#  'cif_mp-1006056_PaNi2Ge.cif',
#  'cif_mp-1006057_LaPrIn2.cif',
#  'cif_mp-1006058_UCd2O5.cif',
#  'cif_mp-1006059_Tl3Bi.cif',
#  'cif_mp-1006068_Gd2AgRh.cif',
#  'cif_mp-1006099_Lu(BRh)4.cif',
#  'cif_mp-10060_DyBPd3.cif',
#  'cif_mp-1006112_Na3Co.cif',
#  'cif_mp-1006115_Ho3Pu.cif',
#  'cif_mp-1006118_P2S7.cif',
#  'cif_mp-1006127_Pa3Mo.cif',
#  'cif_mp-1006132_Hf3Pb.cif',
#  'cif_mp-1006146_Eu(MgBi)2.cif',
#  'cif_mp-1006150_Eu3Re.cif',
#  'cif_mp-1006151_Na3Pu.cif',
#  'cif_mp-1006164_PmPu3.cif',
#  'cif_mp-10061_ErBPd3.cif',
#  'cif_mp-1006223_GdB12.cif',
#  'cif_mp-1006226_ZnBi.cif',
#  'cif_mp-1006242_EuInNi5.cif',
#  'cif_mp-1006245_ErNp3.cif',
#  'cif_mp-1006246_CeSm3.cif',
#  'cif_mp-1006256_CeYTl2.cif',
#  'cif_mp-1006258_ErPu3.cif',
#  'cif_mp-1006277_CeGa4Co9.cif',
#  'cif_mp-1006278_AcEuAu2.cif',
#  'cif_mp-1006282_Nd7Co3.cif',
#  'cif_mp-1006283_Er3(In2Co)2.cif',
#  'cif_mp-10062_Ba2NdNb(CuO4)2.cif',
#  'cif_mp-1006321_Ce(CuSb)2.cif',
#  'cif_mp-1006322_Ce(FeB)4.cif',
#  'cif_mp-1006323_CeLu3.cif',
#  'cif_mp-1006324_Ce(YS2)3.cif',
#  'cif_mp-1006328_LiCeSn.cif',
#  'cif_mp-1006330_Ce3Cu.cif',
#  'cif_mp-1006351_CeY3.cif',
#  'cif_mp-1006352_Er2Co3Ge5.cif',
#  'cif_mp-1006367_Ce2HfSe5.cif',
#  'cif_mp-1006368_Ce2SnSe4.cif',
#  'cif_mp-1006371_CePS.cif',
#  'cif_mp-1006372_AgSO4.cif',
#  'cif_mp-1006390_Ce4Si3Rh4.cif',
#  'cif_mp-1006399_CeZnIn.cif',
#  'cif_mp-10063_CdSnSb2.cif',
#  'cif_mp-10064_SiO2.cif',
#  'cif_mp-1006574_Rb(Zr3Te4)4.cif',
#  'cif_mp-1006588_Zn3In2O6.cif',
#  'cif_mp-1006591_Mg(InSe2)2.cif',
#  'cif_mp-1006593_K3Hf2Se11.cif',
#  'cif_mp-1006594_Ta36B4C35.cif',
#  'cif_mp-10065_UFe3B2.cif',
#  'cif_mp-1006611_Sb4S3N6(OF)12.cif',
#  'cif_mp-1006613_Na2Al2(SiO4)3.cif',
#  'cif_mp-1006615_CrCuN6Cl5.cif',
#  'cif_mp-1006616_Pr(NO5)3.cif',
#  'cif_mp-1006617_ZnP2NO9.cif',
#  'cif_mp-1006619_Sn3PO6.cif',
#  'cif_mp-1006815_CsH3.cif',
#  'cif_mp-1006878_BaO2.cif',
#  'cif_mp-1006880_BiB.cif',
#  'cif_mp-1006882_CdC.cif',
#  'cif_mp-1006883_CoNi.cif',
#  'cif_mp-1006884_CoMo.cif',
#  'cif_mp-1006885_KNdS2.cif',
#  'cif_mp-1006886_CeS.cif',
#  'cif_mp-1006887_CdC.cif',
#  'cif_mp-1006888_KYS2.cif',
#  'cif_mp-1006891_KSmSe2.cif',
#  'cif_mp-10068_Ce2MnN3.cif',
#  'cif_mp-10069_Ce(P3Ru)4.cif',
#  'cif_mp-10070_BaAg(PO3)3.cif',
#  'cif_mp-10074_GeSe2.cif',
#  'cif_mp-1007636_KLuS2.cif',
#  'cif_mp-1007637_KNaH2.cif',
#  'cif_mp-1007652_InAs.cif',
#  'cif_mp-1007656_HfPd3.cif',
#  'cif_mp-1007657_HfRu3.cif',
#  'cif_mp-1007660_IrN.cif',
#  'cif_mp-1007661_InSb.cif',
#  'cif_mp-1007663_HoTlTe2.cif',
#  'cif_mp-1007664_InPd3.cif',
#  'cif_mp-1007665_HoTlS2.cif',
#  'cif_mp-1007666_HoAu.cif',
#  'cif_mp-1007685_InAgSe2.cif',
#  'cif_mp-1007690_HgPt3.cif',
#  'cif_mp-1007691_HfPt.cif',
#  'cif_mp-1007692_HfPd.cif',
#  'cif_mp-1007693_HfOs3.cif',
#  'cif_mp-1007694_SnPO4F.cif',
#  'cif_mp-10076_Hf3(NiGe)4.cif',
#  'cif_mp-1007730_HfAl3.cif',
#  'cif_mp-1007755_HfAu.cif',
#  'cif_mp-1007758_HfCd.cif',
#  'cif_mp-1007760_Ge.cif',
#  'cif_mp-1007761_HW.cif',
#  'cif_mp-1007768_ZnHCO4.cif',
#  'cif_mp-1007770_TlAs.cif',
#  'cif_mp-1007776_TlP.cif',
#  'cif_mp-1007778_TlN.cif',
#  'cif_mp-1007786_HfIr.cif',
#  'cif_mp-1007819_CoW.cif',
#  'cif_mp-1007821_GaCo2Ni.cif',
#  'cif_mp-1007823_GaBN2.cif',
#  'cif_mp-1007824_GaN.cif',
#  'cif_mp-1007852_FeCo3.cif',
#  'cif_mp-1007853_Fe3Ni.cif',
#  'cif_mp-1007854_FeNi3.cif',
#  'cif_mp-1007855_FeNi3.cif',
#  'cif_mp-1007857_Ga.cif',
#  'cif_mp-1007862_Fe3Ni.cif',
#  'cif_mp-1007881_FeB.cif',
#  'cif_mp-10078_TbTiGe.cif',
#  'cif_mp-1007900_EuTlS2.cif',
#  'cif_mp-1007906_ErH.cif',
#  'cif_mp-1007907_ErTlTe2.cif',
#  'cif_mp-1007908_DyTlTe2.cif',
#  'cif_mp-1007910_NaEuS2.cif',
#  'cif_mp-1007918_DyAu.cif',
#  'cif_mp-1007922_CuI.cif',
#  'cif_mp-1007923_CrNi3.cif',
#  'cif_mp-1007924_CrCu2Si.cif',
#  'cif_mp-1007961_CrInCu2.cif',
#  'cif_mp-1007974_CrNi3.cif',
#  'cif_mp-1007975_CrNi3.cif',
#  'cif_mp-1007976_Cs.cif',
#  'cif_mp-1007991_CrInNi2.cif',
#  'cif_mp-1007992_CrH.cif',
#  'cif_mp-10079_TbAgGe.cif',
#  'cif_mp-1007_DySb.cif',
#  'cif_mp-10080_PrGeBO5.cif',
#  'cif_mp-1008223_CaSe.cif',
#  'cif_mp-1008224_CrCo2Si.cif',
#  'cif_mp-1008225_CrFe2Sb.cif',
#  'cif_mp-1008226_CrFe2Sn.cif',
#  'cif_mp-1008228_SnPOF7.cif',
#  'cif_mp-1008274_Co3W.cif',
#  'cif_mp-1008275_Cr3Ni.cif',
#  'cif_mp-1008277_CrCo2As.cif',
#  'cif_mp-1008278_Cr3Ni.cif',
#  'cif_mp-1008279_Co3Mo.cif',
#  'cif_mp-1008280_CrCo3.cif',
#  'cif_mp-1008282_Cr3Fe.cif',
#  'cif_mp-1008283_Ba.cif',
#  'cif_mp-1008284_Cr3Ni.cif',
#  'cif_mp-1008285_Cr3Fe.cif',
#  'cif_mp-1008349_Co3Ni.cif',
#  'cif_mp-1008374_C.cif',
#  'cif_mp-1008376_CeH3.cif',
#  'cif_mp-1008394_Cl2.cif',
#  'cif_mp-1008395_C.cif',
#  'cif_mp-1008471_CdTe.cif',
#  'cif_mp-1008472_CdSiP2.cif',
#  'cif_mp-1008483_CdN.cif',
#  'cif_mp-1008487_BW.cif',
#  'cif_mp-1008488_BiPd.cif',
#  'cif_mp-1008489_CdN.cif',
#  'cif_mp-1008490_BiI3.cif',
#  'cif_mp-1008491_BeSiP2.cif',
#  'cif_mp-1008492_BrCl.cif',
#  'cif_mp-1008498_Ca.cif',
#  'cif_mp-1008500_BaO.cif',
#  'cif_mp-1008501_Be.cif',
#  'cif_mp-1008505_BaPd.cif',
#  'cif_mp-1008506_BaGaSiH.cif',
#  'cif_mp-1008511_BaGaCu2.cif',
#  'cif_mp-1008523_BC2N.cif',
#  'cif_mp-1008524_BeSe.cif',
#  'cif_mp-1008525_B2CN.cif',
#  'cif_mp-1008526_B2CN.cif',
#  'cif_mp-1008527_B2CN.cif',
#  'cif_mp-1008528_B2AsP.cif',
#  'cif_mp-1008530_AlVFeCo.cif',
#  'cif_mp-1008554_Al3V.cif',
#  'cif_mp-1008555_AlCu3.cif',
#  'cif_mp-1008556_AlGaN2.cif',
#  'cif_mp-1008557_AlBN2.cif',
#  'cif_mp-1008558_AuN.cif',
#  'cif_mp-1008559_BP.cif',
#  'cif_mp-1008561_TmTlTe2.cif',
#  'cif_mp-1008568_ZrTi2.cif',
#  'cif_mp-1008600_ZrN2.cif',
#  'cif_mp-1008601_ZrAg2.cif',
#  'cif_mp-1008610_AuN.cif',
#  'cif_mp-1008624_YBiPd.cif',
#  'cif_mp-1008625_W2C.cif',
#  'cif_mp-1008626_VTe2.cif',
#  'cif_mp-1008630_WC.cif',
#  'cif_mp-1008631_VCoTe.cif',
#  'cif_mp-1008632_V2C.cif',
#  'cif_mp-1008634_Au.cif',
#  'cif_mp-1008635_WC.cif',
#  'cif_mp-1008642_UC2.cif',
#  'cif_mp-1008650_CeSe.cif',
#  'cif_mp-1008653_AgC.cif',
#  'cif_mp-1008661_AuC.cif',
#  'cif_mp-1008669_U.cif',
#  'cif_mp-1008673_TmCd2.cif',
#  'cif_mp-1008676_TiS2.cif',
#  'cif_mp-1008677_TiO2.cif',
#  'cif_mp-1008680_TiGePt.cif',
#  'cif_mp-1008681_Sc.cif',
#  'cif_mp-1008682_TiS2.cif',
#  'cif_mp-1008688_Ti2Sn.cif',
#  'cif_mp-1008689_Ti2Si.cif',
#  'cif_mp-10086_YSF.cif',
#  'cif_mp-1008702_Ti2In.cif',
#  'cif_mp-1008726_Ti2Ga.cif',
#  'cif_mp-1008727_Ti2Ge.cif',
#  'cif_mp-1008728_Ni.cif',
#  'cif_mp-1008733_Ge.cif',
#  'cif_mp-1008734_ThH2.cif',
#  'cif_mp-1008752_CeTe.cif',
#  'cif_mp-1008753_Ti2Al.cif',
#  'cif_mp-1008754_TbHg2.cif',
#  'cif_mp-1008755_SrB2.cif',
#  'cif_mp-1008762_TaN2.cif',
#  'cif_mp-1008776_SrC2.cif',
#  'cif_mp-1008777_SmHg2.cif',
#  'cif_mp-1008785_RuO2.cif',
#  'cif_mp-1008786_MgTe.cif',
#  'cif_mp-1008798_ReN2.cif',
#  'cif_mp-10087_CeScSi.cif',
#  'cif_mp-1008802_ReC2.cif',
#  'cif_mp-1008805_ReC2.cif',
#  'cif_mp-1008806_ReC2.cif',
#  'cif_mp-1008807_RbCuO.cif',
#  'cif_mp-1008809_PtN2.cif',
#  'cif_mp-1008813_RbAgO.cif',
#  'cif_mp-1008820_PdN2.cif',
#  'cif_mp-1008823_OsN2.cif',
#  'cif_mp-1008826_OsN2.cif',
#  'cif_mp-1008832_HfC.cif',
#  'cif_mp-1008833_NpN2.cif',
#  'cif_mp-1008835_OsC2.cif',
#  'cif_mp-1008858_NdBiPd.cif',
#  'cif_mp-1008860_NbS2.cif',
#  'cif_mp-1008865_NdCd2.cif',
#  'cif_mp-1008866_NaAgO.cif',
#  'cif_mp-1008867_NaCuO.cif',
#  'cif_mp-1008872_MnFeTe.cif',
#  'cif_mp-1008873_MnCoSe.cif',
#  'cif_mp-1008874_MnCoTe.cif',
#  'cif_mp-1008875_Mn2Sb.cif',
#  'cif_mp-1008876_MnCoS.cif',
#  'cif_mp-1008881_MgNiH.cif',
#  'cif_mp-1008901_MgH2.cif',
#  'cif_mp-1008902_LuSb2.cif',
#  'cif_mp-1008903_MgAgSb.cif',
#  'cif_mp-1008910_LuCd2.cif',
#  'cif_mp-1008911_LiMnAs.cif',
#  'cif_mp-1008912_AgC.cif',
#  'cif_mp-1008918_CdN.cif',
#  'cif_mp-1008920_Mn2Ge.cif',
#  'cif_mp-1008921_CdN.cif',
#  'cif_mp-1008922_CuN.cif',
#  'cif_mp-1008923_CuN.cif',
#  'cif_mp-1008924_DySb.cif',
#  'cif_mp-1008925_LiFeP.cif',
#  'cif_mp-1008926_CrTe.cif',
#  'cif_mp-1008927_LiFeAs.cif',
#  'cif_mp-1008928_EuSe.cif',
#  'cif_mp-1008929_FeN.cif',
#  'cif_mp-1008931_ErSb.cif',
#  'cif_mp-1008965_CdN.cif',
#  'cif_mp-1008985_CoN.cif',
#  'cif_mp-1008986_IrN.cif',
#  'cif_mp-1008987_IrN.cif',
#  'cif_mp-1008998_LaS.cif',
#  'cif_mp-1008999_LaSe.cif',
#  'cif_mp-10089_Ba5Sb4.cif',
#  'cif_mp-1008_NiHg.cif',
#  'cif_mp-1009005_IrN.cif',
#  'cif_mp-1009006_LiCdAs.cif',
#  'cif_mp-1009007_LuSb.cif',
#  'cif_mp-1009008_LaTe.cif',
#  'cif_mp-1009009_LiF.cif',
#  'cif_mp-1009014_LiCuO.cif',
#  'cif_mp-1009015_IrN.cif',
#  'cif_mp-1009016_LuAs.cif',
#  'cif_mp-1009017_HoSb.cif',
#  'cif_mp-1009018_InAg.cif',
#  'cif_mp-1009019_FeN.cif',
#  'cif_mp-1009020_KCuO.cif',
#  'cif_mp-1009048_KAgO.cif',
#  'cif_mp-1009049_IrN2.cif',
#  'cif_mp-1009071_IrC2.cif',
#  'cif_mp-1009077_FeH.cif',
#  'cif_mp-1009078_CoN.cif',
#  'cif_mp-1009079_CrTe.cif',
#  'cif_mp-1009080_HoCd2.cif',
#  'cif_mp-1009082_MgSnAs2.cif',
#  'cif_mp-1009083_MgSnP2.cif',
#  'cif_mp-1009084_BeSnAs2.cif',
#  'cif_mp-1009085_BeSiP2.cif',
#  'cif_mp-1009086_BeSnP2.cif',
#  'cif_mp-1009087_BeSiAs2.cif',
#  'cif_mp-1009088_BeGeAs2.cif',
#  'cif_mp-1009113_HoHg2.cif',
#  'cif_mp-1009127_MgO.cif',
#  'cif_mp-1009128_MnN.cif',
#  'cif_mp-1009129_MgO.cif',
#  'cif_mp-1009130_MnN.cif',
#  'cif_mp-1009131_MnAs.cif',
#  'cif_mp-1009132_HoBiPd.cif',
#  'cif_mp-1009133_MnCo.cif',
#  'cif_mp-1009134_MnFe.cif',
#  'cif_mp-1009135_MnP.cif',
#  'cif_mp-10091_KV(CuSe2)2.cif',
#  'cif_mp-1009206_MnSn.cif',
#  'cif_mp-1009207_MnSb.cif',
#  'cif_mp-1009213_MnSb.cif',
#  'cif_mp-1009217_MnSb.cif',
#  'cif_mp-1009218_MoC.cif',
#  'cif_mp-1009219_HfN2.cif',
#  'cif_mp-1009220_NaH.cif',
#  'cif_mp-1009221_nan.cif',
#  'cif_mp-1009222_MnTe.cif',
#  'cif_mp-1009223_NaAs.cif',
#  'cif_mp-1009230_NdAs.cif',
#  'cif_mp-1009237_NdN.cif',
#  'cif_mp-1009238_Hf2Tl.cif',
#  'cif_mp-1009264_NbCo.cif',
#  'cif_mp-10092_KCu4Se3.cif',
#  'cif_mp-1009458_NbC.cif',
#  'cif_mp-1009459_NbC.cif',
#  'cif_mp-1009460_Hf.cif',
#  'cif_mp-1009471_NbN.cif',
#  'cif_mp-1009483_NiN.cif',
#  'cif_mp-1009485_CrN.cif',
#  'cif_mp-1009488_NiN.cif',
#  'cif_mp-1009489_RbTe.cif',
#  'cif_mp-1009490_O2.cif',
#  'cif_mp-1009491_RbTe.cif',
#  'cif_mp-1009493_NpN.cif',
#  'cif_mp-1009494_NpN.cif',
#  'cif_mp-1009495_OsN.cif',
#  'cif_mp-1009496_OsN.cif',
#  'cif_mp-10094_Tm5(ReO6)2.cif',
#  'cif_mp-1009504_EuZnGe.cif',
#  'cif_mp-1009533_PdC.cif',
#  'cif_mp-1009537_OsC.cif',
#  'cif_mp-1009538_PdC.cif',
#  'cif_mp-1009539_OsC.cif',
#  'cif_mp-1009540_OsC.cif',
#  'cif_mp-1009541_CsRbN.cif',
#  'cif_mp-1009543_DyBiPd.cif',
#  'cif_mp-1009544_CsRbP.cif',
#  'cif_mp-1009545_PaN.cif',
#  'cif_mp-1009547_CsRbAs.cif',
#  'cif_mp-1009548_PdN.cif',
#  'cif_mp-1009551_PbS.cif',
#  'cif_mp-1009555_CrO2.cif',
#  'cif_mp-1009581_CrSe2.cif',
#  'cif_mp-1009582_NiC.cif',
#  'cif_mp-1009583_PrAs.cif',
#  'cif_mp-1009592_CrFeTe.cif',
#  'cif_mp-1009593_CrCoTe.cif',
#  'cif_mp-1009594_Pr.cif',
#  'cif_mp-1009596_PdN.cif',
#  'cif_mp-1009601_PdN.cif',
#  'cif_mp-1009639_PrN.cif',
#  'cif_mp-1009640_PrN.cif',
#  'cif_mp-1009641_CoTe2.cif',
#  'cif_mp-1009646_ReN.cif',
#  'cif_mp-1009648_PtC.cif',
#  'cif_mp-1009649_PrN.cif',
#  'cif_mp-1009650_RbSb.cif',
#  'cif_mp-1009651_CaHg2.cif',
#  'cif_mp-1009652_RhC.cif',
#  'cif_mp-1009653_CaC2.cif',
#  'cif_mp-1009654_CaGe2.cif',
#  'cif_mp-1009655_CaC2.cif',
#  'cif_mp-1009657_CaN2.cif',
#  'cif_mp-1009663_ReC.cif',
#  'cif_mp-1009694_ReN.cif',
#  'cif_mp-1009695_CaB2.cif',
#  'cif_mp-1009696_RhC.cif',
#  'cif_mp-10096_Na3Sr3GaP4.cif',
#  'cif_mp-1009720_RhN.cif',
#  'cif_mp-1009730_Ca2Sn.cif',
#  'cif_mp-1009731_ReC.cif',
#  'cif_mp-1009732_RhN.cif',
#  'cif_mp-1009733_Ca2Si.cif',
#  'cif_mp-1009734_RhN.cif',
#  'cif_mp-1009735_ReC.cif',
#  'cif_mp-1009746_ScP.cif',
#  'cif_mp-1009747_ScSn.cif',
#  'cif_mp-1009748_ScC.cif',
#  'cif_mp-1009750_ScN.cif',
#  'cif_mp-1009751_ScC.cif',
#  'cif_mp-1009752_ScSi.cif',
#  'cif_mp-1009753_ScGe.cif',
#  'cif_mp-1009755_Ca2Ge.cif',
#  'cif_mp-1009756_Ca2Pb.cif',
#  'cif_mp-1009757_Se.cif',
#  'cif_mp-1009766_AgN.cif',
#  'cif_mp-1009767_AgN.cif',
#  'cif_mp-1009769_RuN.cif',
#  'cif_mp-1009770_RuN.cif',
#  'cif_mp-1009787_RuC.cif',
#  'cif_mp-1009792_RuC.cif',
#  'cif_mp-10097_Na3Sr3GaAs4.cif',
#  'cif_mp-1009813_SiSn.cif',
#  'cif_mp-1009814_SmAs.cif',
#  'cif_mp-1009817_TaC.cif',
#  'cif_mp-1009818_CN2.cif',
#  'cif_mp-1009819_SrO.cif',
#  'cif_mp-1009820_SnC.cif',
#  'cif_mp-1009822_SnC.cif',
#  'cif_mp-1009823_BeB2.cif',
#  'cif_mp-1009826_TaCo.cif',
#  'cif_mp-1009827_BaSi2.cif',
#  'cif_mp-1009828_BaSiC.cif',
#  'cif_mp-1009829_Be2Si.cif',
#  'cif_mp-1009830_Be2Zn.cif',
#  'cif_mp-1009831_TaN.cif',
#  'cif_mp-1009832_TaC.cif',
#  'cif_mp-1009833_TaN.cif',
#  'cif_mp-1009834_Al2Ru.cif',
#  'cif_mp-1009835_TaC.cif',
#  'cif_mp-1009836_ZrN.cif',
#  'cif_mp-1009837_TcC.cif',
#  'cif_mp-1009838_ZrN.cif',
#  'cif_mp-1009839_TbAl.cif',
#  'cif_mp-1009848_TcC.cif',
#  'cif_mp-1009878_ZrC.cif',
#  'cif_mp-1009885_ZrN.cif',
#  'cif_mp-1009894_ZrC.cif',
#  'cif_mp-10098_YGeAu.cif',
#  'cif_mp-1009_SrSi6.cif',
#  'cif_mp-100_Hf.cif',
#  'cif_mp-1010048_Br.cif',
#  'cif_mp-1010071_CrCo.cif',
#  'cif_mp-1010136_Cu.cif',
#  'cif_mp-1010161_DyAs.cif',
#  'cif_mp-10101_CsAgC2.cif',
#  'cif_mp-10102_KAgC2.cif',
#  'cif_mp-10105_UTeAs.cif',
#  'cif_mp-10106_Ca2As.cif',
#  'cif_mp-10108_NpP.cif',
#  'cif_mp-1010953_MgNi.cif',
#  'cif_mp-10109_NpS.cif',
#  'cif_mp-1010_MnB4.cif',
#  'cif_mp-1011031_PrBi.cif',
#  'cif_mp-10110_SiRh.cif',
#  'cif_mp-1011260_EuFeO3.cif',
#  'cif_mp-10112_LaB2Ir3.cif',
#  'cif_mp-1011374_CeSe2.cif',
#  'cif_mp-1011375_CeSe2.cif',
#  'cif_mp-1011376_CeSe2.cif',
#  'cif_mp-1011377_CeSe2.cif',
#  'cif_mp-10113_ScBIr3.cif',
#  'cif_mp-10114_ScB4Ir3.cif',
#  'cif_mp-10115_ThB2Ir3.cif',
#  'cif_mp-1011695_Cs2Se.cif',
#  'cif_mp-1011696_Cs2Se.cif',
#  'cif_mp-1011697_Cs2Se.cif',
#  'cif_mp-10116_UB2Ir3.cif',
#  'cif_mp-1011709_Cs2Se.cif',
#  'cif_mp-1011710_Mn2AlO4.cif',
#  'cif_mp-1011730_Cs2Se.cif',
#  'cif_mp-10117_Mg3(Ni10B3)2.cif',
#  'cif_mp-1011834_Na2CoP2O7.cif',
#  'cif_mp-1011858_Na2CoP2O7.cif',
#  'cif_mp-1011860_Na2CoP2O7.cif',
#  'cif_mp-10118_Mn3B4.cif',
#  'cif_mp-10120_NdBPd3.cif',
#  'cif_mp-1012103_V2NiO6.cif',
#  'cif_mp-1012110_Cs.cif',
#  'cif_mp-10123_Ni21(B3Sb)2.cif',
#  'cif_mp-1012435_PbS.cif',
#  'cif_mp-10124_Tb(Ni2B)6.cif',
#  'cif_mp-1012551_BaBrCl.cif',
#  'cif_mp-10125_SbIr.cif',
#  'cif_mp-1012640_CrFeCoNi.cif',
#  'cif_mp-1012668_LiMo2P2O9.cif',
#  'cif_mp-1012670_Na3Ti2(GeO4)3.cif',
#  'cif_mp-1012678_NaMo3P3O13.cif',
#  'cif_mp-1012686_Na3V2(GeO4)3.cif',
#  'cif_mp-10126_V5SiB2.cif',
#  'cif_mp-1012740_H6RuCI3N.cif',
#  'cif_mp-1012742_NaMn3P3O13.cif',
#  'cif_mp-1012789_LiCr3P3O13.cif',
#  'cif_mp-1012791_NaV3P3O13.cif',
#  'cif_mp-1012835_SmCu(WO4)2.cif',
#  'cif_mp-1012865_LiTi3P3O13.cif',
#  'cif_mp-1012879_Li3Cr2(GeO4)3.cif',
#  'cif_mp-10128_ThGe2.cif',
#  'cif_mp-10129_TmNi4B.cif',
#  'cif_mp-10130_U2(Ni7B2)3.cif',
#  'cif_mp-10131_Zn3(Ni10B3)2.cif',
#  'cif_mp-10132_UB2Os3.cif',
#  'cif_mp-10133_Sc3BPb.cif',
#  'cif_mp-10134_TmBPd3.cif',
#  'cif_mp-1013524_Ca3N2.cif',
#  'cif_mp-1013525_VS2.cif',
#  'cif_mp-1013526_VS2.cif',
#  'cif_mp-1013527_BeGeP2.cif',
#  'cif_mp-1013528_Ba3N2.cif',
#  'cif_mp-1013529_Sr3N2.cif',
#  'cif_mp-1013530_Sr3BiP.cif',
#  'cif_mp-1013531_Sr3BiN.cif',
#  'cif_mp-1013532_Sr3AsP.cif',
#  'cif_mp-1013533_Ba3PN.cif',
#  'cif_mp-1013534_Sr3SbN.cif',
#  'cif_mp-1013535_Sr3SbP.cif',
#  'cif_mp-1013536_Sr3PN.cif',
#  'cif_mp-1013537_Sr3AsN.cif',
#  'cif_mp-1013540_Ca3PN.cif',
#  'cif_mp-1013541_Sr3SbAs.cif',
#  'cif_mp-1013542_Ca3BiN.cif',
#  'cif_mp-1013543_Ca3AsN.cif',
#  'cif_mp-1013544_Ca3SbAs.cif',
#  'cif_mp-1013545_Ca3BiAs.cif',
#  'cif_mp-1013546_Ca3Sb2.cif',
#  'cif_mp-1013547_Ca3P2.cif',
#  'cif_mp-1013548_Ca3SbN.cif',
#  'cif_mp-1013549_Ba3BiN.cif',
#  'cif_mp-1013550_Ca3SbP.cif',
#  'cif_mp-1013551_Ba3P2.cif',
#  'cif_mp-1013552_Sr3P2.cif',
#  'cif_mp-1013553_Sr3AsP.cif',
#  'cif_mp-1013554_Sr3PN.cif',
#  'cif_mp-1013555_Sr3AsN.cif',
#  'cif_mp-1013557_Ba3SbN.cif',
#  'cif_mp-1013558_Ca3BiP.cif',
#  'cif_mp-1013559_Sr3As2.cif',
#  'cif_mp-1013560_Ba3As2.cif',
#  'cif_mp-1013561_Sr3SbAs.cif',
#  'cif_mp-1013562_Ba3SbAs.cif',
#  'cif_mp-1013563_Ba3BiAs.cif',
#  'cif_mp-1013564_Sr3BiAs.cif',
#  'cif_mp-1013565_Na2CoP2O7.cif',
#  'cif_mp-1013577_Na2CoP2O7.cif',
#  'cif_mp-1013582_Ba3Sb2.cif',
#  'cif_mp-1013583_Sr3Sb2.cif',
#  'cif_mp-1013584_Ba3BiSb.cif',
#  'cif_mp-1013585_Sr3BiSb.cif',
#  'cif_mp-1013586_Ba3AsP.cif',
#  'cif_mp-1013587_Sr3Bi2.cif',
#  'cif_mp-1013588_Sr3SbP.cif',
#  'cif_mp-1013599_Na2CoP2O7.cif',
#  'cif_mp-1013642_Ca3AsP.cif',
#  'cif_mp-1013643_Sr3BiP.cif',
#  'cif_mp-1013691_Ba3BiP.cif',
#  'cif_mp-10136_Ti2ReB2.cif',
#  'cif_mp-1013702_Ca3BiP.cif',
#  'cif_mp-1013703_Ca3BiAs.cif',
#  'cif_mp-1013704_Ca3BiSb.cif',
#  'cif_mp-1013705_Sr3BiAs.cif',
#  'cif_mp-1013706_Sr3BiSb.cif',
#  'cif_mp-1013707_Ba3PN.cif',
#  'cif_mp-1013708_Ba3SbN.cif',
#  'cif_mp-1013709_Ba3AsN.cif',
#  'cif_mp-1013710_Ba3BiN.cif',
#  'cif_mp-1013711_Ba3AsP.cif',
#  'cif_mp-1013712_Ba3SbP.cif',
#  'cif_mp-1013713_Ba3BiP.cif',
#  'cif_mp-1013714_Ba3SbAs.cif',
#  'cif_mp-1013716_Ba3BiAs.cif',
#  'cif_mp-1013719_Ba3BiSb.cif',
#  'cif_mp-1013726_Cd4SF6.cif',
#  'cif_mp-1013730_Cd5(S2Cl)2.cif',
#  'cif_mp-1013733_Ca3BiSb.cif',
#  'cif_mp-1013734_Ba3AsN.cif',
#  'cif_mp-1013735_Ca3Bi2.cif',
#  'cif_mp-1013736_Ba3Bi2.cif',
#  'cif_mp-1013737_Ba3SbP.cif',
#  'cif_mp-1013738_Ca3SbAs.cif',
#  'cif_mp-1013749_Li3Ti2(GeO4)3.cif',
#  'cif_mp-1013750_Sn4SF6.cif',
#  'cif_mp-1013760_Sn5(S2Cl)2.cif',
#  'cif_mp-1013762_LiTi2P2O9.cif',
#  'cif_mp-1013794_Na3Co2(GeO4)3.cif',
#  'cif_mp-1013795_Li3Ge3(MoO6)2.cif',
#  'cif_mp-1013796_Li3Ni2(GeO4)3.cif',
#  'cif_mp-1013797_Na3Ge3(MoO6)2.cif',
#  'cif_mp-10137_UB2Ru3.cif',
#  'cif_mp-1013807_Li3Co2(GeO4)3.cif',
#  'cif_mp-1013808_Na3Ni2(GeO4)3.cif',
#  'cif_mp-1013830_NaCo3P3O13.cif',
#  'cif_mp-1013842_Na3Mn2(GeO4)3.cif',
#  'cif_mp-1013843_NaMo2P2O9.cif',
#  'cif_mp-1013849_Li3Fe2(GeO4)3.cif',
#  'cif_mp-1013850_LiV2P2O9.cif',
#  'cif_mp-1013864_Na3Fe2(GeO4)3.cif',
#  'cif_mp-1013874_NaTi3P3O13.cif',
#  'cif_mp-1013878_LiV3P3O13.cif',
#  'cif_mp-1013898_LiMo3P3O13.cif',
#  'cif_mp-1013899_LiFe3P3O13.cif',
#  'cif_mp-10138_Y(BRu)4.cif',
#  'cif_mp-1013900_TiSCl.cif',
#  'cif_mp-1013910_LiFe2P2O9.cif',
#  'cif_mp-1013911_Na2CoP2O7.cif',
#  'cif_mp-1013912_LiCo3P3O13.cif',
#  'cif_mp-1013916_Li3V2(GeO4)3.cif',
#  'cif_mp-1013917_LiMn3P3O13.cif',
#  'cif_mp-1013922_LiCr2P2O9.cif',
#  'cif_mp-1013939_TiSF.cif',
#  'cif_mp-1013953_LiCo2P2O9.cif',
#  'cif_mp-1013987_LiNi2P2O9.cif',
#  'cif_mp-10139_Sc3SnB.cif',
#  'cif_mp-1014005_Mn2SiRh.cif',
#  'cif_mp-1014013_P.cif',
#  'cif_mp-10140_Sc3TlB.cif',
#  'cif_mp-1014111_Ni.cif',
#  'cif_mp-1014138_ZrB.cif',
#  'cif_mp-1014160_ZrN.cif',
#  'cif_mp-1014168_CsPbBr3.cif',
#  'cif_mp-10141_SmB2.cif',
#  'cif_mp-1014204_Sn5(S2Cl)2.cif',
#  'cif_mp-1014212_Si.cif',
#  'cif_mp-1014214_C3N.cif',
#  'cif_mp-1014219_HfZn.cif',
#  'cif_mp-1014226_Zr3ZnN.cif',
#  'cif_mp-1014227_Ti2ZnN.cif',
#  'cif_mp-1014229_Ti2Zn.cif',
#  'cif_mp-1014230_TiZn.cif',
#  'cif_mp-1014231_Hf2Zn.cif',
#  'cif_mp-1014244_ZrZnN2.cif',
#  'cif_mp-1014246_ZrB.cif',
#  'cif_mp-1014251_HfZnN2.cif',
#  'cif_mp-1014252_Hf3ZnN.cif',
#  'cif_mp-1014257_Ti3ZnN.cif',
#  'cif_mp-1014261_IrO2.cif',
#  'cif_mp-1014264_CrN2.cif',
#  'cif_mp-1014265_Zr2N.cif',
#  'cif_mp-1014281_C3N.cif',
#  'cif_mp-1014286_C3N.cif',
#  'cif_mp-1014287_C3N.cif',
#  'cif_mp-1014296_C3N.cif',
#  'cif_mp-1014297_C3N.cif',
#  'cif_mp-1014298_C3N.cif',
#  'cif_mp-10142_Ta3B4.cif',
#  'cif_mp-1014303_Cr3N2.cif',
#  'cif_mp-1014307_ZrC.cif',
#  'cif_mp-1014311_C3N.cif',
#  'cif_mp-1014316_C3N.cif',
#  'cif_mp-1014318_Cr3N2.cif',
#  'cif_mp-1014324_C3N.cif',
#  'cif_mp-1014332_C3N.cif',
#  'cif_mp-1014333_C3N.cif',
#  'cif_mp-1014339_CrN2.cif',
#  'cif_mp-1014342_CrN2.cif',
#  'cif_mp-1014345_Cr3N4.cif',
#  'cif_mp-1014347_Cr3N4.cif',
#  'cif_mp-1014358_Cr3N4.cif',
#  'cif_mp-1014365_Cr3N4.cif',
#  'cif_mp-1014366_CrN2.cif',
#  'cif_mp-1014369_Cr3N4.cif',
#  'cif_mp-1014373_CrN2.cif',
#  'cif_mp-1014379_Cr3N4.cif',
#  'cif_mp-10143_TiB.cif',
#  'cif_mp-1014444_Cr3N2.cif',
#  'cif_mp-1014454_Cr3N2.cif',
#  'cif_mp-1014460_Cr3N4.cif',
#  'cif_mp-1014462_Li2YAl.cif',
#  'cif_mp-1014478_CrN2.cif',
#  'cif_mp-10144_B2W.cif',
#  'cif_mp-1014509_Cr3N2.cif',
#  'cif_mp-1014558_Cr3N4.cif',
#  'cif_mp-1014565_CrN2.cif',
#  'cif_mp-1014873_NaLi2As.cif',
#  'cif_mp-10148_InSb.cif',
#  'cif_mp-1014910_CrN2.cif',
#  'cif_mp-1014993_CrN2.cif',
#  'cif_mp-1014995_CrN2.cif',
#  'cif_mp-10149_InSb.cif',
#  'cif_mp-1014_ZrMn2.cif',
#  'cif_mp-1015026_CrN2.cif',
#  'cif_mp-1015061_NaLi2Sn.cif',
#  'cif_mp-1015065_Cr3N4.cif',
#  'cif_mp-1015076_CrN2.cif',
#  'cif_mp-10152_La(SiIr)2.cif',
#  'cif_mp-10154_MnSbIr.cif',
#  'cif_mp-1015567_CrN2.cif',
#  'cif_mp-1015582_CrN2.cif',
#  'cif_mp-10155_P2Ir.cif',
#  'cif_mp-1015612_CrN2.cif',
#  'cif_mp-1015780_CrN2.cif',
#  'cif_mp-10157_K.cif',
#  'cif_mp-1015811_AlCo2Si.cif',
#  'cif_mp-1015814_LiMg2Al.cif',
#  'cif_mp-1015908_CrN2.cif',
#  'cif_mp-10159_K3Sb.cif',
#  'cif_mp-1015_ZrMn2.cif',
#  'cif_mp-1016048_CrN2.cif',
#  'cif_mp-1016058_CrN2.cif',
#  'cif_mp-1016059_CrN2.cif',
#  'cif_mp-1016063_CrN2.cif',
#  'cif_mp-1016069_CrN2.cif',
#  'cif_mp-1016070_CrN2.cif',
#  'cif_mp-1016071_Cr3N4.cif',
#  'cif_mp-1016073_CrN2.cif',
#  'cif_mp-1016076_CrN2.cif',
#  'cif_mp-1016078_CrN2.cif',
#  'cif_mp-1016081_CrN2.cif',
#  'cif_mp-1016092_Re2O7.cif',
#  'cif_mp-1016095_LiMn2O4.cif',
#  'cif_mp-1016106_HfZn16.cif',
#  'cif_mp-1016107_Hf6Zn6N.cif',
#  'cif_mp-1016108_TiZnN2.cif',
#  'cif_mp-1016109_ZrZn16.cif',
#  'cif_mp-1016111_MnHO2.cif',
#  'cif_mp-1016119_NaMnO2.cif',
#  'cif_mp-1016120_KMnO2.cif',
#  'cif_mp-1016136_MnHO2.cif',
#  'cif_mp-1016144_MgMn3O6.cif',
#  'cif_mp-1016145_CaMn3O6.cif',
#  'cif_mp-1016146_MgMn4O8.cif',
#  'cif_mp-1016152_NaMnO2.cif',
#  'cif_mp-1016153_KMn8O16.cif',
#  'cif_mp-1016154_MgMnO2.cif',
#  'cif_mp-1016155_NaMn4O8.cif',
#  'cif_mp-1016165_LiMn8O16.cif',
#  'cif_mp-1016190_KMn3O6.cif',
#  'cif_mp-1016197_MgSiAs2.cif',
#  'cif_mp-10161_KZnSb.cif',
#  'cif_mp-1016200_MgGeAs2.cif',
#  'cif_mp-1016212_Sn3H6CNO7.cif',
#  'cif_mp-1016213_Sn3H8C2NO7.cif',
#  'cif_mp-1016214_Bi2H18C3(IN)9.cif',
#  'cif_mp-1016216_Mg3Si.cif',
#  'cif_mp-1016217_Mg3Zr.cif',
#  'cif_mp-1016218_BaMg3.cif',
#  'cif_mp-1016219_NaMg3.cif',
#  'cif_mp-1016220_Mg3Nb.cif',
#  'cif_mp-1016221_Mg3Ga.cif',
#  'cif_mp-1016222_LiMg3.cif',
#  'cif_mp-1016223_Mg3Mo.cif',
#  'cif_mp-1016224_Mg3Cu.cif',
#  'cif_mp-1016225_Mg3Cr.cif',
#  'cif_mp-1016226_RbMg3.cif',
#  'cif_mp-1016227_LaMg3.cif',
#  'cif_mp-1016228_Mg3Co.cif',
#  'cif_mp-1016229_Mg3Ni.cif',
#  'cif_mp-1016231_CsMg3.cif',
#  'cif_mp-1016233_Mg3Al.cif',
#  'cif_mp-1016234_Mg3Bi.cif',
#  'cif_mp-1016235_CaMg3.cif',
#  'cif_mp-1016236_Mg3Sb.cif',
#  'cif_mp-1016237_Mg3Cd.cif',
#  'cif_mp-1016238_Mg3Sn.cif',
#  'cif_mp-1016239_HfMg3.cif',
#  'cif_mp-1016240_Mg3C.cif',
#  'cif_mp-1016241_Mg3Mn.cif',
#  'cif_mp-1016242_Mg3Ti.cif',
#  'cif_mp-1016243_Mg3Zn.cif',
#  'cif_mp-1016250_Mg3B.cif',
#  'cif_mp-1016252_Mg7Ga.cif',
#  'cif_mp-1016253_Mg7Cd.cif',
#  'cif_mp-1016254_CeMg3.cif',
#  'cif_mp-1016256_HfMg7.cif',
#  'cif_mp-1016257_Mg3W.cif',
#  'cif_mp-1016260_Mg3Fe.cif',
#  'cif_mp-1016262_Mg7B.cif',
#  'cif_mp-1016263_Mg3V.cif',
#  'cif_mp-1016264_CsMg7.cif',
#  'cif_mp-1016265_Mg7Ti.cif',
#  'cif_mp-1016266_SrMg6Mo.cif',
#  'cif_mp-1016267_CsMg6Cd.cif',
#  'cif_mp-1016268_SrMg7.cif',
#  'cif_mp-1016269_Mg7W.cif',
#  'cif_mp-1016270_Mg7Sb.cif',
#  'cif_mp-1016271_Mg7Al.cif',
#  'cif_mp-1016272_Mg7C.cif',
#  ...]

# %%
# reference from https://qiita.com/ojiya/items/1b154c3698cff91c8a2b

# %%
struct = Structure.from_file("../input/material_projects_api_cif_1000/cif_mp-1401213_MgTi2O4.cif")

# %%
xrd_cond = XRDCalculator()
xrd_calcd = xrd_cond.get_pattern(struct)
print(type(xrd_calcd))
# Out:
# <class 'pymatgen.analysis.diffraction.core.DiffractionPattern'>

# %%
dict_xrd_calcd = xrd_calcd.as_dict()
print(dict_xrd_calcd.keys())
# Out:
# dict_keys(['@module', '@class', '@version', 'x', 'y', 'hkls', 'd_hkls'])

# %%
calcd_x = xrd_calcd.x
calcd_y = xrd_calcd.y
calcd_hkls = xrd_calcd.hkls
calcd_d = xrd_calcd.d_hkls

# %%
print(calcd_x[0], calcd_y[0], calcd_hkls[0], calcd_d[0])
# Out:
# 11.926123983588784 49.65770548093947 [{'hkl': (0, 0, 1), 'multiplicity': 2}] 7.420734999755016

# %%
calcd_x
# Out:
# array([11.92612398, 12.00207681, 15.34846614, 18.41814661, 23.98393594,
#        24.13840715, 24.85731996, 24.96945063, 28.80773317, 28.90560473,
#        30.98128798, 31.69001606, 32.11172124, 35.74530458, 35.79917348,
#        36.17570673, 36.31881975, 36.38856176, 36.55739785, 36.87434219,
#        36.92678786, 37.33492311, 38.77874238, 40.09588541, 40.21796123,
#        40.48843519, 40.68204666, 41.87823542, 43.18307692, 43.32094675,
#        44.78758149, 44.9215221 , 45.17867525, 45.26739732, 47.2340778 ,
#        47.80774688, 47.91391385, 48.40249533, 48.71754153, 49.1078056 ,
#        49.44022363, 49.71754307, 49.80004943, 50.43851841, 50.99194942,
#        51.23468057, 52.87546708, 53.01096637, 53.11206407, 53.30607434,
#        54.05164067, 54.24589298, 54.80765299, 55.03852244, 56.54748852,
#        56.67948552, 57.33888092, 57.38550265, 58.20764567, 58.3187245 ,
#        59.64361729, 59.67086476, 59.82591329, 59.88951891, 61.48385596,
#        61.91303753, 62.58891011, 63.03143429, 63.2100329 , 63.5798334 ,
#        63.94225401, 64.23011491, 64.57420124, 64.57927804, 64.78328953,
#        64.98161597, 65.09615046, 65.31106305, 65.32839084, 66.19590771,
#        66.43728587, 66.44576253, 66.78038194, 66.85734546, 67.00125322,
#        67.10384133, 67.16660862, 67.64672755, 67.91884978, 68.06165578,
#        68.29909543, 68.62003617, 68.73834803, 69.33298585, 69.40028233,
#        69.71841612, 69.76876483, 71.27492314, 71.57390799, 71.6078862 ,
#        71.65765646, 72.74576046, 72.83391691, 73.17965607, 73.89167596,
#        74.02273961, 74.56224408, 74.70920057, 75.65566172, 75.73024641,
#        75.81754205, 75.86017855, 75.96365434, 76.22375618, 76.4448771 ,
#        76.56600111, 76.77105848, 77.11851403, 77.12669456, 77.1816838 ,
#        77.28808935, 77.61075933, 77.63340892, 77.69930138, 78.21472737,
#        78.29513552, 78.47392819, 78.54591612, 78.77073554, 79.60601563,
#        79.62955327, 79.79302072, 80.1093832 , 80.17674693, 80.43208598,
#        80.86292707, 81.11790877, 81.54989156, 81.67525495, 81.80449199,
#        82.09216703, 83.20706287, 83.63296218, 83.71216933, 83.7799857 ,
#        84.0782329 , 84.31562353, 84.61114744, 84.63456092, 84.86413276,
#        84.903747  , 85.07720279, 85.18821867, 86.06031172, 86.24967717,
#        86.56761341, 86.88302736, 87.58437337, 87.65371614, 87.89006891,
#        88.08857208, 88.14227477, 88.26829603])

# %%
def voigt(xval,params):
    norm,center,lw,gw = params
    z = (xval - center + 1j*lw)/(gw * np.sqrt(2.0))
    w = scipy.special.wofz(z)
    model_y = norm * (w.real)/(gw * np.sqrt(2.0*np.pi))
    return model_y

# %%
# x = np.arange(10,90,0.02)

# calcd_pattern = np.zeros(len(x))

# N = len(calcd_x)
# for i in range(N):
#     norm = calcd_y[i]
#     center = calcd_x[i]
#     lw = 0.05
#     gw = 0.05
#     params = [norm, center, lw, gw]
#     calcd_pattern += voigt(x, params)

# figure = plt.figure(figsize=(5,3))
# ax = figure.add_subplot(111)

# ax.plot(x, calcd_pattern,color='red')

# ax.set_xlim(10, 60)
# ax.set_ylim(0, 500)

# ax.set_xlabel(r'2$\theta$')
# ax.set_ylabel('Intensity (a.u.)')

# %%
# # 上記のfigureを保存
# plt.savefig('../input/material_projects_maked_xrd_pattern/cif_mp-1401213_MgTi2O4_xrd_pattern.png')

# %%
# # x, calcd_patternをcsvで保存、xは2theta、calcd_patternはIntensity
# df = pd.DataFrame({'2theta':x, 'Intensity':calcd_pattern})
# df.to_csv('../input/material_projects_maked_xrd_pattern/cif_mp-1401213_MgTi2O4_xrd_pattern.csv', index=False)

# %%
# df

# %%
# # Set to use 'Agg' backend which does not display to the screen
# plt.switch_backend('Agg')

# for file in tqdm(files):
#     struct = Structure.from_file(f"{path}/{file}")
#     xrd_cond = XRDCalculator()
#     xrd_calcd = xrd_cond.get_pattern(struct)
    
#     calcd_x = xrd_calcd.x
#     calcd_y = xrd_calcd.y
#     calcd_hkls = xrd_calcd.hkls
#     calcd_d = xrd_calcd.d_hkls
    
#     calcd_pattern = np.zeros(len(x))
    
#     N = len(calcd_x)
#     for i in range(N):
#         norm = calcd_y[i]
#         center = calcd_x[i]
#         lw = 0.05
#         gw = 0.05
#         params = [norm, center, lw, gw]
#         calcd_pattern += voigt(x, params)
    
#     figure = plt.figure(figsize=(5,3))
#     ax = figure.add_subplot(111)
    
#     ax.plot(x, calcd_pattern,color='red')
    
#     ax.set_xlim(10, 60)
#     ax.set_ylim(0, 500)
    
#     ax.set_xlabel(r'2$\theta$ (deg)')
#     ax.set_ylabel('Intensity (a.u.)')
    
    # 上記のfigureを保存
    # plt.tightlayout()
    # plt.savefig(f'../input/material_projects_maked_xrd_pattern_full/{file}_xrd_pattern.png',bbox_inches='tight')
    
#     # x, calcd_patternをcsvで保存、xは2theta、calcd_patternはIntensity
#     df = pd.DataFrame({'2theta':x, 'Intensity':calcd_pattern})
#     df.to_csv(f'../input/material_projects_maked_xrd_pattern_full/{file}_xrd_pattern.csv', index=False)
    
#     del struct, xrd_cond, xrd_calcd, calcd_x, calcd_y, calcd_hkls, calcd_d, calcd_pattern, df
#     gc.collect()

# %%
# filesのCIFファイルについて、_cell_length_a、_cell_length_b、_cell_length_cが等しく、_cell_angle_alpha、_cell_angle_beta、_cell_angle_gammaが90度であるものを抽出

def check_cubic(struct):
    if struct.lattice.a == struct.lattice.b == struct.lattice.c and struct.lattice.alpha == struct.lattice.beta == struct.lattice.gamma == 90:
        return True
    else:
        return False
    
cubic_files = []

for file in tqdm(files):
    struct = Structure.from_file(f"{path}/{file}")
    if check_cubic(struct):
        cubic_files.append(file)
    del struct
    gc.collect()

len(cubic_files)
# Out:
#   0%|          | 0/153235 [00:00<?, ?it/s]
# 4575

# %%
cubic_files
# Out:
# ['cif_mp-1001571_CaFeO3.cif',
#  'cif_mp-10015_SiOs.cif',
#  'cif_mp-1001788_ZrB6.cif',
#  'cif_mp-1001834_HfN.cif',
#  'cif_mp-1001843_HoP.cif',
#  'cif_mp-1001844_HoN.cif',
#  'cif_mp-1001913_HoBi.cif',
#  'cif_mp-1001917_HoAs.cif',
#  'cif_mp-1001918_HfC.cif',
#  'cif_mp-1002105_VN.cif',
#  'cif_mp-1002106_HfPd.cif',
#  'cif_mp-1002109_VCo.cif',
#  'cif_mp-1002117_TcN.cif',
#  'cif_mp-1002122_HfIr.cif',
#  'cif_mp-1002183_TcB.cif',
#  'cif_mp-1002207_ReN.cif',
#  'cif_mp-1002210_EuS.cif',
#  'cif_mp-1002220_TmSb.cif',
#  'cif_mp-1002223_DyP.cif',
#  'cif_mp-1002224_ErP.cif',
#  'cif_mp-1002226_ErAs.cif',
#  'cif_mp-1002228_PtC.cif',
#  'cif_mp-1002229_ErN.cif',
#  'cif_mp-1002230_PuBi.cif',
#  'cif_mp-10037_AlCo3C.cif',
#  'cif_mp-10038_Er3AlC.cif',
#  'cif_mp-10039_Pr3AlC.cif',
#  'cif_mp-10040_AlPt3C.cif',
#  'cif_mp-10041_Tb3AlC.cif',
#  'cif_mp-1004377_HfB6.cif',
#  'cif_mp-1004524_HPbI3.cif',
#  'cif_mp-1004_Nb3Si.cif',
#  'cif_mp-1005719_Sm3Np.cif',
#  'cif_mp-1005727_TmNp3.cif',
#  'cif_mp-10060_DyBPd3.cif',
#  'cif_mp-1006115_Ho3Pu.cif',
#  'cif_mp-10061_ErBPd3.cif',
#  'cif_mp-1006245_ErNp3.cif',
#  'cif_mp-1006246_CeSm3.cif',
#  'cif_mp-1006330_Ce3Cu.cif',
#  'cif_mp-1006615_CrCuN6Cl5.cif',
#  'cif_mp-1006883_CoNi.cif',
#  'cif_mp-1006884_CoMo.cif',
#  'cif_mp-1006886_CeS.cif',
#  'cif_mp-1007656_HfPd3.cif',
#  'cif_mp-1007657_HfRu3.cif',
#  'cif_mp-1007690_HgPt3.cif',
#  'cif_mp-1007693_HfOs3.cif',
#  'cif_mp-1007730_HfAl3.cif',
#  'cif_mp-1007819_CoW.cif',
#  'cif_mp-1007974_CrNi3.cif',
#  'cif_mp-1008278_Cr3Ni.cif',
#  'cif_mp-1008285_Cr3Fe.cif',
#  'cif_mp-1008489_CdN.cif',
#  'cif_mp-1008554_Al3V.cif',
#  'cif_mp-1008555_AlCu3.cif',
#  'cif_mp-1008630_WC.cif',
#  'cif_mp-1008650_CeSe.cif',
#  'cif_mp-1008752_CeTe.cif',
#  'cif_mp-1008923_CuN.cif',
#  'cif_mp-1008924_DySb.cif',
#  'cif_mp-1008928_EuSe.cif',
#  'cif_mp-1008931_ErSb.cif',
#  'cif_mp-1008985_CoN.cif',
#  'cif_mp-1008998_LaS.cif',
#  'cif_mp-1008999_LaSe.cif',
#  'cif_mp-1008_NiHg.cif',
#  'cif_mp-1009005_IrN.cif',
#  'cif_mp-1009007_LuSb.cif',
#  'cif_mp-1009008_LaTe.cif',
#  'cif_mp-1009009_LiF.cif',
#  'cif_mp-1009016_LuAs.cif',
#  'cif_mp-1009017_HoSb.cif',
#  'cif_mp-1009018_InAg.cif',
#  'cif_mp-1009019_FeN.cif',
#  'cif_mp-1009127_MgO.cif',
#  'cif_mp-1009128_MnN.cif',
#  'cif_mp-1009133_MnCo.cif',
#  'cif_mp-1009206_MnSn.cif',
#  'cif_mp-1009207_MnSb.cif',
#  'cif_mp-1009220_NaH.cif',
#  'cif_mp-1009237_NdN.cif',
#  'cif_mp-1009264_NbCo.cif',
#  'cif_mp-1009459_NbC.cif',
#  'cif_mp-1009471_NbN.cif',
#  'cif_mp-1009483_NiN.cif',
#  'cif_mp-1009485_CrN.cif',
#  'cif_mp-1009493_NpN.cif',
#  'cif_mp-1009537_OsC.cif',
#  'cif_mp-1009596_PdN.cif',
#  'cif_mp-1009640_PrN.cif',
#  'cif_mp-1009731_ReC.cif',
#  'cif_mp-1009748_ScC.cif',
#  'cif_mp-1009819_SrO.cif',
#  'cif_mp-1009826_TaCo.cif',
#  'cif_mp-1009831_TaN.cif',
#  'cif_mp-1009835_TaC.cif',
#  'cif_mp-1009836_ZrN.cif',
#  'cif_mp-1009839_TbAl.cif',
#  'cif_mp-1009878_ZrC.cif',
#  'cif_mp-1010071_CrCo.cif',
#  'cif_mp-1010161_DyAs.cif',
#  'cif_mp-1011031_PrBi.cif',
#  'cif_mp-10110_SiRh.cif',
#  'cif_mp-10113_ScBIr3.cif',
#  'cif_mp-1011697_Cs2Se.cif',
#  'cif_mp-10120_NdBPd3.cif',
#  'cif_mp-10133_Sc3BPb.cif',
#  'cif_mp-10134_TmBPd3.cif',
#  'cif_mp-1013524_Ca3N2.cif',
#  'cif_mp-1013528_Ba3N2.cif',
#  'cif_mp-1013529_Sr3N2.cif',
#  'cif_mp-1013530_Sr3BiP.cif',
#  'cif_mp-1013531_Sr3BiN.cif',
#  'cif_mp-1013532_Sr3AsP.cif',
#  'cif_mp-1013533_Ba3PN.cif',
#  'cif_mp-1013534_Sr3SbN.cif',
#  'cif_mp-1013535_Sr3SbP.cif',
#  'cif_mp-1013536_Sr3PN.cif',
#  'cif_mp-1013537_Sr3AsN.cif',
#  'cif_mp-1013540_Ca3PN.cif',
#  'cif_mp-1013541_Sr3SbAs.cif',
#  'cif_mp-1013542_Ca3BiN.cif',
#  'cif_mp-1013543_Ca3AsN.cif',
#  'cif_mp-1013544_Ca3SbAs.cif',
#  'cif_mp-1013545_Ca3BiAs.cif',
#  'cif_mp-1013546_Ca3Sb2.cif',
#  'cif_mp-1013547_Ca3P2.cif',
#  'cif_mp-1013548_Ca3SbN.cif',
#  'cif_mp-1013549_Ba3BiN.cif',
#  'cif_mp-1013550_Ca3SbP.cif',
#  'cif_mp-1013551_Ba3P2.cif',
#  'cif_mp-1013552_Sr3P2.cif',
#  'cif_mp-1013553_Sr3AsP.cif',
#  'cif_mp-1013554_Sr3PN.cif',
#  'cif_mp-1013555_Sr3AsN.cif',
#  'cif_mp-1013557_Ba3SbN.cif',
#  'cif_mp-1013558_Ca3BiP.cif',
#  'cif_mp-1013559_Sr3As2.cif',
#  'cif_mp-1013560_Ba3As2.cif',
#  'cif_mp-1013561_Sr3SbAs.cif',
#  'cif_mp-1013562_Ba3SbAs.cif',
#  'cif_mp-1013563_Ba3BiAs.cif',
#  'cif_mp-1013564_Sr3BiAs.cif',
#  'cif_mp-1013582_Ba3Sb2.cif',
#  'cif_mp-1013583_Sr3Sb2.cif',
#  'cif_mp-1013584_Ba3BiSb.cif',
#  'cif_mp-1013585_Sr3BiSb.cif',
#  'cif_mp-1013586_Ba3AsP.cif',
#  'cif_mp-1013587_Sr3Bi2.cif',
#  'cif_mp-1013588_Sr3SbP.cif',
#  'cif_mp-1013642_Ca3AsP.cif',
#  'cif_mp-1013643_Sr3BiP.cif',
#  'cif_mp-1013691_Ba3BiP.cif',
#  'cif_mp-1013702_Ca3BiP.cif',
#  'cif_mp-1013703_Ca3BiAs.cif',
#  'cif_mp-1013704_Ca3BiSb.cif',
#  'cif_mp-1013705_Sr3BiAs.cif',
#  'cif_mp-1013706_Sr3BiSb.cif',
#  'cif_mp-1013707_Ba3PN.cif',
#  'cif_mp-1013708_Ba3SbN.cif',
#  'cif_mp-1013709_Ba3AsN.cif',
#  'cif_mp-1013710_Ba3BiN.cif',
#  'cif_mp-1013711_Ba3AsP.cif',
#  'cif_mp-1013712_Ba3SbP.cif',
#  'cif_mp-1013713_Ba3BiP.cif',
#  'cif_mp-1013714_Ba3SbAs.cif',
#  'cif_mp-1013716_Ba3BiAs.cif',
#  'cif_mp-1013719_Ba3BiSb.cif',
#  'cif_mp-1013733_Ca3BiSb.cif',
#  'cif_mp-1013734_Ba3AsN.cif',
#  'cif_mp-1013735_Ca3Bi2.cif',
#  'cif_mp-1013736_Ba3Bi2.cif',
#  'cif_mp-1013737_Ba3SbP.cif',
#  'cif_mp-1013738_Ca3SbAs.cif',
#  'cif_mp-10139_Sc3SnB.cif',
#  'cif_mp-10140_Sc3TlB.cif',
#  'cif_mp-1014214_C3N.cif',
#  'cif_mp-1014219_HfZn.cif',
#  'cif_mp-1014230_TiZn.cif',
#  'cif_mp-1014297_C3N.cif',
#  'cif_mp-1014316_C3N.cif',
#  'cif_mp-1014460_Cr3N4.cif',
#  'cif_mp-10148_InSb.cif',
#  'cif_mp-1014993_CrN2.cif',
#  'cif_mp-1016227_LaMg3.cif',
#  'cif_mp-1016819_HfZnO3.cif',
#  'cif_mp-1016820_MgSnO3.cif',
#  'cif_mp-1016821_BaSiO3.cif',
#  'cif_mp-1016823_BaGeO3.cif',
#  'cif_mp-1016825_HfMgO3.cif',
#  'cif_mp-1016826_MgIrO3.cif',
#  'cif_mp-1016827_MgGeO3.cif',
#  'cif_mp-1016828_CdIrO3.cif',
#  'cif_mp-1016829_MgRuO3.cif',
#  'cif_mp-1016830_MgTiO3.cif',
#  'cif_mp-1016831_HgIrO3.cif',
#  'cif_mp-1016833_CaRhO3.cif',
#  'cif_mp-1016835_CaRuO3.cif',
#  'cif_mp-1016836_ZnOsO3.cif',
#  'cif_mp-1016837_SnHgO3.cif',
#  'cif_mp-1016840_HgOsO3.cif',
#  'cif_mp-1016841_HfHgO3.cif',
#  'cif_mp-1016842_TiHgO3.cif',
#  'cif_mp-1016843_MgOsO3.cif',
#  'cif_mp-1016845_ZrCdO3.cif',
#  'cif_mp-1016846_TiCdO3.cif',
#  'cif_mp-1016848_SrIrO3.cif',
#  'cif_mp-1016849_CdRuO3.cif',
#  'cif_mp-1016850_BaRhO3.cif',
#  'cif_mp-1016851_HgRuO3.cif',
#  'cif_mp-1016852_BaMnO3.cif',
#  'cif_mp-1016853_CaVO3.cif',
#  'cif_mp-1016854_MnCdO3.cif',
#  'cif_mp-1016871_ZrHgO3.cif',
#  'cif_mp-1016872_CaIrO3.cif',
#  'cif_mp-1016873_CaHfO3.cif',
#  'cif_mp-1016874_SiHgO3.cif',
#  'cif_mp-1016875_CdRhO3.cif',
#  'cif_mp-1016876_ZnSiO3.cif',
#  'cif_mp-1016877_HgRhO3.cif',
#  'cif_mp-1016879_CdSiO3.cif',
#  'cif_mp-1016880_ZnRhO3.cif',
#  'cif_mp-1016881_CdSnO3.cif',
#  'cif_mp-1016882_CdOsO3.cif',
#  'cif_mp-1016883_ZrZnO3.cif',
#  'cif_mp-1016884_CaGeO3.cif',
#  'cif_mp-1016886_MgVO3.cif',
#  'cif_mp-1016900_CaOsO3.cif',
#  'cif_mp-1016902_ZnSnO3.cif',
#  'cif_mp-1016903_CdGeO3.cif',
#  'cif_mp-1016904_VCdO3.cif',
#  'cif_mp-1016926_ZnIrO3.cif',
#  'cif_mp-1016927_TiZnO3.cif',
#  'cif_mp-1016928_MgSiO3.cif',
#  'cif_mp-1016929_MgRhO3.cif',
#  'cif_mp-1016930_ZnGeO3.cif',
#  'cif_mp-1016931_VZnO3.cif',
#  'cif_mp-1016932_MnZnO3.cif',
#  'cif_mp-1016938_VHgO3.cif',
#  'cif_mp-1016999_SrGeO3.cif',
#  'cif_mp-1017000_MgZrO3.cif',
#  'cif_mp-1017439_SrSiO3.cif',
#  'cif_mp-1017441_SrRhO3.cif',
#  'cif_mp-1017446_HfCdO3.cif',
#  'cif_mp-1017447_HgGeO3.cif',
#  'cif_mp-1017465_BaVO3.cif',
#  'cif_mp-1017467_CaMnO3.cif',
#  'cif_mp-1017519_IrC.cif',
#  'cif_mp-1017529_VCo3.cif',
#  'cif_mp-1017542_ZrOs3.cif',
#  'cif_mp-1017543_ZrPd3.cif',
#  'cif_mp-1017544_ZrRu3.cif',
#  'cif_mp-1017553_CdCo3N.cif',
#  'cif_mp-1017555_CsBeF3.cif',
#  'cif_mp-1017557_Dy3AlN.cif',
#  'cif_mp-1017558_Er3AlN.cif',
#  'cif_mp-1017563_GaPt3C.cif',
#  'cif_mp-1017566_GePbO3.cif',
#  'cif_mp-1017577_Ho3AlN.cif',
#  'cif_mp-1017578_HfBRh3.cif',
#  'cif_mp-1017580_KMgH3.cif',
#  'cif_mp-1017581_LaPd3C.cif',
#  'cif_mp-1017582_LaPt3C.cif',
#  'cif_mp-1017591_BaRuO3.cif',
#  'cif_mp-10175_KCdF3.cif',
#  'cif_mp-1017626_LiCaF3.cif',
#  'cif_mp-1017627_Lu3AlN.cif',
#  'cif_mp-1017629_MgNiH3.cif',
#  'cif_mp-1017631_ScBPd3.cif',
#  'cif_mp-1017632_Ni3SnN.cif',
#  'cif_mp-1018029_CuPd.cif',
#  'cif_mp-1018042_UBi.cif',
#  'cif_mp-1018054_HfPt3.cif',
#  'cif_mp-1018061_FeH3.cif',
#  'cif_mp-1018081_CrFe3.cif',
#  'cif_mp-1018101_AlCo3.cif',
#  'cif_mp-10185_Mg3ZnC.cif',
#  'cif_mp-1018627_ScBPt3.cif',
#  'cif_mp-1018628_ScPt3C.cif',
#  'cif_mp-1018629_YPd3C.cif',
#  'cif_mp-1018633_LaBPt3.cif',
#  'cif_mp-1018635_ScPd3C.cif',
#  'cif_mp-1018636_SnPd3C.cif',
#  'cif_mp-1018638_Tb3AlN.cif',
#  'cif_mp-1018639_TiSnO3.cif',
#  'cif_mp-1018641_Tm3AlN.cif',
#  'cif_mp-1018643_YBPd3.cif',
#  'cif_mp-1018644_YBPt3.cif',
#  'cif_mp-1018645_YPt3C.cif',
#  'cif_mp-1018734_IrN.cif',
#  'cif_mp-1018849_OsN.cif',
#  'cif_mp-1019052_ReN.cif',
#  'cif_mp-1019378_Al3GaN4.cif',
#  'cif_mp-1019379_AlB3N4.cif',
#  'cif_mp-1019380_Al3BN4.cif',
#  'cif_mp-1019508_AlGa3N4.cif',
#  'cif_mp-1019541_BaCa3O4.cif',
#  'cif_mp-1019609_Cs2Sr2Li3B3(PO4)6.cif',
#  'cif_mp-1019740_GaB3N4.cif',
#  'cif_mp-1019743_Ga3BN4.cif',
#  'cif_mp-1019788_K4Al3(SiO4)3.cif',
#  'cif_mp-1019799_K8NO3.cif',
#  'cif_mp-1019800_K8N3O.cif',
#  'cif_mp-1019801_K8PO3.cif',
#  'cif_mp-10198_Mn3PdN.cif',
#  'cif_mp-1020020_Li8NO3.cif',
#  'cif_mp-1020029_Li8PO3.cif',
#  'cif_mp-1020032_Li8N3O.cif',
#  'cif_mp-1020147_Na2Mg2P3NO9.cif',
#  'cif_mp-1020578_Sr4S3O.cif',
#  'cif_mp-1020590_Na8N3O.cif',
#  'cif_mp-1020591_Rb8NO3.cif',
#  'cif_mp-1020595_Rb8PO3.cif',
#  'cif_mp-1020625_Rb8N3O.cif',
#  'cif_mp-1020633_RbMgBO3.cif',
#  'cif_mp-1020638_Na8PO3.cif',
#  'cif_mp-1020645_Na8NO3.cif',
#  'cif_mp-1020_TaRh3.cif',
#  'cif_mp-1021489_IrO3.cif',
#  'cif_mp-1021503_SiO2.cif',
#  'cif_mp-1021666_AlSi.cif',
#  'cif_mp-1021667_IClO3.cif',
#  'cif_mp-1021668_In3Sb.cif',
#  'cif_mp-1022721_AlCu.cif',
#  'cif_mp-10229_Nb3Si.cif',
#  'cif_mp-1023127_Ba4Cu3PbO9.cif',
#  'cif_mp-1023920_Mg3NbO4.cif',
#  'cif_mp-1024033_Mg3SnO4.cif',
#  'cif_mp-1024034_SrMg3O4.cif',
#  'cif_mp-1024035_RbMg3O4.cif',
#  'cif_mp-1024036_Mg3SiO4.cif',
#  'cif_mp-1024037_NaMg3O4.cif',
#  'cif_mp-1024038_CeMg3O4.cif',
#  'cif_mp-1024039_Mg3AlO4.cif',
#  'cif_mp-1024040_BaMg3O4.cif',
#  'cif_mp-1024043_CaMg3O4.cif',
#  'cif_mp-1024044_Mg3CrO4.cif',
#  'cif_mp-1024045_Mg3ZnO4.cif',
#  'cif_mp-1024046_YMg3O4.cif',
#  'cif_mp-1024068_Mg3VO4.cif',
#  'cif_mp-10250_BaLiF3.cif',
#  'cif_mp-1025192_Ta4C3.cif',
#  'cif_mp-1025397_GeRu.cif',
#  'cif_mp-1025551_GaPt.cif',
#  'cif_mp-10266_ZnFe3C.cif',
#  'cif_mp-10274_Er3GaC.cif',
#  'cif_mp-10275_Er3InC.cif',
#  'cif_mp-10279_Ho3GaC.cif',
#  'cif_mp-1027_HfRh3.cif',
#  'cif_mp-10280_Nd3GaC.cif',
#  'cif_mp-1029265_Mg2ZnN2.cif',
#  'cif_mp-1029502_Ba(NbN2)2.cif',
#  'cif_mp-1029505_Ba(MoN2)2.cif',
#  'cif_mp-1029517_Li7BiN4.cif',
#  'cif_mp-1029522_Li7SbN4.cif',
#  'cif_mp-1029568_Ba(CrN2)2.cif',
#  'cif_mp-1029616_Ba(TaN2)2.cif',
#  'cif_mp-1029619_Ba(ReN2)2.cif',
#  'cif_mp-1029918_Ba(VN2)2.cif',
#  'cif_mp-1030618_Mg3ZrO4.cif',
#  'cif_mp-1030631_Mg3MnO4.cif',
#  'cif_mp-1030635_LaMg3O4.cif',
#  'cif_mp-1030636_Mg3TiO4.cif',
#  'cif_mp-1031_GdCd.cif',
#  'cif_mp-1033_BeNi.cif',
#  'cif_mp-10351_Tm3GaC.cif',
#  'cif_mp-10356_Ho3InC.cif',
#  'cif_mp-10373_Cr3PdN.cif',
#  'cif_mp-10376_Cr3SnN.cif',
#  'cif_mp-1038814_MgCd.cif',
#  'cif_mp-1038832_Mg3Cd.cif',
#  'cif_mp-1038837_CeMg3.cif',
#  'cif_mp-1038879_Ca3Zn.cif',
#  'cif_mp-1038934_MgAl.cif',
#  'cif_mp-1039073_Mg3Bi.cif',
#  'cif_mp-1039106_SnBi.cif',
#  'cif_mp-1039147_CaZn.cif',
#  'cif_mp-1039148_CaMg.cif',
#  'cif_mp-1039154_MgBi.cif',
#  'cif_mp-1039365_CeMg.cif',
#  'cif_mp-1040464_NaOsO3.cif',
#  'cif_mp-1040467_RbOsO3.cif',
#  'cif_mp-1040469_KMoO3.cif',
#  'cif_mp-1040471_NaMoO3.cif',
#  'cif_mp-1040472_KWO3.cif',
#  'cif_mp-10413_AgB(CN)4.cif',
#  'cif_mp-1044_UIr3.cif',
#  'cif_mp-1053_NdZn.cif',
#  'cif_mp-10554_Ca3TlN.cif',
#  'cif_mp-1056900_IN.cif',
#  'cif_mp-1056920_CsI.cif',
#  'cif_mp-1057125_KS.cif',
#  'cif_mp-1057486_CsS.cif',
#  'cif_mp-1057750_RbS.cif',
#  'cif_mp-1058151_NCl.cif',
#  'cif_mp-1058159_NaS.cif',
#  'cif_mp-1058331_CsSe.cif',
#  'cif_mp-1058798_LiBe.cif',
#  'cif_mp-1059160_BrN.cif',
#  'cif_mp-1059242_ClO.cif',
#  'cif_mp-1059707_CaNi.cif',
#  'cif_mp-1059879_CsN.cif',
#  'cif_mp-1059_NdCd.cif',
#  'cif_mp-10600_La3AlC.cif',
#  'cif_mp-10602_Sm3GaC.cif',
#  'cif_mp-10606_Sm3TlC.cif',
#  'cif_mp-10607_Lu3TlC.cif',
#  'cif_mp-1060962_TlC.cif',
#  'cif_mp-1060967_AgBr.cif',
#  'cif_mp-10609_Lu3SnC.cif',
#  'cif_mp-1061123_TiAl.cif',
#  'cif_mp-1061395_Na2O2.cif',
#  'cif_mp-10627_SrS.cif',
#  'cif_mp-1062_CeMg.cif',
#  'cif_mp-10632_TlS.cif',
#  'cif_mp-1063661_MgNi3.cif',
#  'cif_mp-10637_ThSb.cif',
#  'cif_mp-1064000_Cs3Pt.cif',
#  'cif_mp-1064161_NaN3.cif',
#  'cif_mp-1064282_InC3.cif',
#  'cif_mp-1064459_PBr.cif',
#  'cif_mp-1064508_K3Pd.cif',
#  'cif_mp-10646_ThSe.cif',
#  'cif_mp-10647_TlSe.cif',
#  'cif_mp-1064861_GaC3.cif',
#  'cif_mp-10652_SmTe.cif',
#  'cif_mp-10653_SrTe.cif',
#  'cif_mp-1065428_Rb3Re.cif',
#  'cif_mp-1065540_AlC3.cif',
#  'cif_mp-1065741_NbFe3.cif',
#  'cif_mp-1065783_LaRh3.cif',
#  'cif_mp-10666_Mn3AgN.cif',
#  'cif_mp-1066774_Rb3Os.cif',
#  'cif_mp-1067129_VC3.cif',
#  'cif_mp-1067281_Rb3Pt.cif',
#  'cif_mp-10674_Sm3AlN.cif',
#  'cif_mp-1067833_SnI3.cif',
#  'cif_mp-1068011_SrAlH3.cif',
#  'cif_mp-10680_BaSe.cif',
#  'cif_mp-1068212_Fe2O3.cif',
#  'cif_mp-1068389_SnCCl3.cif',
#  'cif_mp-10683_Ca.cif',
#  'cif_mp-10684_CaTe.cif',
#  'cif_mp-1068577_ZrPbO3.cif',
#  'cif_mp-1068746_TlHPd3.cif',
#  'cif_mp-1068795_NiNF3.cif',
#  'cif_mp-1069129_MnNCl3.cif',
#  'cif_mp-1069166_MnNF3.cif',
#  'cif_mp-1069270_ZnNi3N.cif',
#  'cif_mp-1069273_Gd3AlN.cif',
#  'cif_mp-10692_CoGe.cif',
#  'cif_mp-1069346_PrVO3.cif',
#  'cif_mp-1069526_Ce3InC.cif',
#  'cif_mp-1069538_CsPbI3.cif',
#  'cif_mp-1069774_UBRh3.cif',
#  'cif_mp-10699_LuRh3C.cif',
#  'cif_mp-1070242_Mn3CuN.cif',
#  'cif_mp-1070375_CsSnCl3.cif',
#  'cif_mp-1070440_VPbO3.cif',
#  'cif_mp-10706_ZrRu3C.cif',
#  'cif_mp-1070713_InNi3N.cif',
#  'cif_mp-1070737_K3CO.cif',
#  'cif_mp-10708_PrRh3C.cif',
#  'cif_mp-10712_ScRh3C.cif',
#  'cif_mp-10714_TmRh3C.cif',
#  'cif_mp-10718_Sm3SnC.cif',
#  'cif_mp-10720_ThC2.cif',
#  'cif_mp-1072852_CdB2.cif',
#  'cif_mp-10729_Pd2O.cif',
#  'cif_mp-10732_ThTaN3.cif',
#  'cif_mp-10735_Zr2O.cif',
#  'cif_mp-1073_CaCd.cif',
#  'cif_mp-10748_TaCu3S4.cif',
#  'cif_mp-1074_RbSi.cif',
#  'cif_mp-1075902_EuCuO3.cif',
#  'cif_mp-1075904_EuFeO3.cif',
#  'cif_mp-1075911_RbNbO3.cif',
#  'cif_mp-1075921_LaNiO3.cif',
#  'cif_mp-1075922_Sr7CaTi8O24.cif',
#  'cif_mp-1075933_SmAgO3.cif',
#  'cif_mp-1075973_SmMnO3.cif',
#  'cif_mp-1075975_EuCoO3.cif',
#  'cif_mp-1076000_LaAgO3.cif',
#  'cif_mp-1076070_LaCuO3.cif',
#  'cif_mp-1076128_Ca7Mg(CoO3)8.cif',
#  'cif_mp-1076131_La7SmV8O24.cif',
#  'cif_mp-10762_Cd3As2.cif',
#  'cif_mp-1076317_MgCuO3.cif',
#  'cif_mp-1076360_RbCrO3.cif',
#  'cif_mp-1076368_MgFeO3.cif',
#  'cif_mp-1076382_La7Sm(FeO3)8.cif',
#  'cif_mp-1076445_Sr8MnFe7O24.cif',
#  'cif_mp-1076485_Ca7MgMn8O24.cif',
#  'cif_mp-1076534_RbTaO3.cif',
#  'cif_mp-1076633_KVO3.cif',
#  'cif_mp-1076638_RbVO3.cif',
#  'cif_mp-1076642_NaCrO3.cif',
#  'cif_mp-1076706_SmCuO3.cif',
#  'cif_mp-1076732_KCrO3.cif',
#  'cif_mp-1076782_BaCoO3.cif',
#  'cif_mp-1076800_BaCuO3.cif',
#  'cif_mp-1076927_GdPb3.cif',
#  'cif_mp-1076_KB6.cif',
#  'cif_mp-1077045_Ti2H.cif',
#  'cif_mp-1077622_EuAgO3.cif',
#  'cif_mp-1077660_Sr8Fe7CoO24.cif',
#  'cif_mp-1078464_MnGe.cif',
#  'cif_mp-1078554_KNa3H4.cif',
#  'cif_mp-1078558_NaCl3.cif',
#  'cif_mp-1078597_ZnCd3Se4.cif',
#  'cif_mp-1078643_RbNa3H4.cif',
#  'cif_mp-1078780_ZnCd3S4.cif',
#  'cif_mp-1078915_Ba3CaO4.cif',
#  'cif_mp-1079034_Zn3CdSe4.cif',
#  'cif_mp-1079228_Ga4BiAs3.cif',
#  'cif_mp-1079248_K3NaH4.cif',
#  'cif_mp-1079399_V3Fe.cif',
#  'cif_mp-1079533_CrCd3Te4.cif',
#  'cif_mp-1079594_Ca3ZnSe4.cif',
#  'cif_mp-1079689_Tl3Pt.cif',
#  'cif_mp-1079702_Cr3GaP4.cif',
#  'cif_mp-1079788_Sr4SO3.cif',
#  'cif_mp-1079796_Ti3Pd.cif',
#  'cif_mp-1079882_Ba3SrO4.cif',
#  'cif_mp-1079910_SiTc.cif',
#  'cif_mp-1079914_HfSb.cif',
#  'cif_mp-1079940_Sr3CaO4.cif',
#  'cif_mp-1079947_Pd3N.cif',
#  'cif_mp-1080016_Tl3Ir.cif',
#  'cif_mp-1080187_MnHgO3.cif',
#  'cif_mp-1080300_CeSe2.cif',
#  'cif_mp-1080375_CeSe2.cif',
#  'cif_mp-1080476_FeH3.cif',
#  'cif_mp-1080569_Tl3Au.cif',
#  'cif_mp-1080659_OsC.cif',
#  'cif_mp-1080726_Zn3CrS4.cif',
#  'cif_mp-1080771_NaCl7.cif',
#  'cif_mp-1080799_CuNF3.cif',
#  'cif_mp-1080847_Mg3SbN.cif',
#  'cif_mp-1080852_CeSe2.cif',
#  'cif_mp-1080865_CeSe2.cif',
#  'cif_mp-1082_VIr3.cif',
#  'cif_mp-10844_Te2Ir.cif',
#  'cif_mp-1084771_Be3P2.cif',
#  'cif_mp-1084796_CaZn3Se4.cif',
#  'cif_mp-10848_AsPdS.cif',
#  'cif_mp-10850_SbTePd.cif',
#  'cif_mp-10871_AlAu.cif',
#  'cif_mp-1087545_Zn3CrTe4.cif',
#  'cif_mp-10879_CeAl.cif',
#  'cif_mp-10890_LiAl3.cif',
#  'cif_mp-1089_TiIr3.cif',
#  'cif_mp-10902_PrAl.cif',
#  'cif_mp-10903_AlPt.cif',
#  'cif_mp-10904_AlPt.cif',
#  'cif_mp-10908_AlRe.cif',
#  'cif_mp-1092_HoHg.cif',
#  'cif_mp-1094009_YAgO3.cif',
#  'cif_mp-1094049_SnB6.cif',
#  'cif_mp-1094056_Si7Ge.cif',
#  'cif_mp-1094072_Pr3AlN.cif',
#  'cif_mp-1094082_Ni4O.cif',
#  'cif_mp-1094084_Ni4N3.cif',
#  'cif_mp-1094085_Nd3SnN.cif',
#  'cif_mp-1094090_Ni4N.cif',
#  'cif_mp-1094094_Ni5O4.cif',
#  'cif_mp-1094096_Ni4O3.cif',
#  'cif_mp-1094101_Nd3PbN.cif',
#  'cif_mp-1094118_Mn3InC.cif',
#  'cif_mp-1094669_MgSn.cif',
#  'cif_mp-1094670_LiMg3.cif',
#  'cif_mp-1094705_YSn.cif',
#  'cif_mp-1094724_Mg3Sb.cif',
#  'cif_mp-1094726_MgTi.cif',
#  'cif_mp-1094731_SrMg3.cif',
#  'cif_mp-1094743_MgZr.cif',
#  'cif_mp-1094768_MgZr3.cif',
#  'cif_mp-1094769_Y3Mg.cif',
#  'cif_mp-1094779_MgZn.cif',
#  'cif_mp-1094786_Sr3Mg.cif',
#  'cif_mp-1094791_Mg3Zn.cif',
#  'cif_mp-1094792_Mg3Zr.cif',
#  'cif_mp-1094802_MgSn3.cif',
#  'cif_mp-1094839_MgCd3.cif',
#  'cif_mp-1094849_MgGa.cif',
#  'cif_mp-1094857_Ca3Mg.cif',
#  'cif_mp-1094867_MgZn3.cif',
#  'cif_mp-1094874_ZrSn.cif',
#  'cif_mp-1094889_LiMg.cif',
#  'cif_mp-1094904_Ce3Mg.cif',
#  'cif_mp-1094922_CaMg3.cif',
#  'cif_mp-1094958_HfMg3.cif',
#  'cif_mp-1094967_MgSb.cif',
#  'cif_mp-1094969_MgGa3.cif',
#  'cif_mp-1094980_CaZn3.cif',
#  'cif_mp-1094990_HfMg.cif',
#  'cif_mp-1095028_Zn3CrSe4.cif',
#  'cif_mp-1095030_BC7.cif',
#  'cif_mp-1095176_Rb3NaH4.cif',
#  'cif_mp-1095177_SiNi.cif',
#  'cif_mp-1095224_PtO2.cif',
#  'cif_mp-1095264_OsO2.cif',
#  'cif_mp-1095440_CdS2.cif',
#  'cif_mp-1095493_CdSe2.cif',
#  'cif_mp-1095507_SbIrSe.cif',
#  'cif_mp-1095551_K8AsO3.cif',
#  'cif_mp-1095618_PtN2.cif',
#  'cif_mp-1095638_LiMgIr.cif',
#  'cif_mp-1096764_Ca3SbP.cif',
#  'cif_mp-1096779_Ba4Ce(CuO3)3.cif',
#  'cif_mp-1096797_HgB6.cif',
#  'cif_mp-1096800_LaScO3.cif',
#  'cif_mp-1096825_B6Pb.cif',
#  'cif_mp-1096836_Ba3SnS4.cif',
#  'cif_mp-1096844_BiB6.cif',
#  'cif_mp-1096854_Ca3As2.cif',
#  'cif_mp-1096856_Ca3AsP.cif',
#  'cif_mp-1096862_CdHCl3.cif',
#  'cif_mp-1096919_CrN2.cif',
#  'cif_mp-1096944_CsNbO3.cif',
#  'cif_mp-1097006_KAlH3.cif',
#  'cif_mp-1097026_LaGaO3.cif',
#  'cif_mp-1099244_Mg3WO4.cif',
#  'cif_mp-1099245_Mg3FeO4.cif',
#  'cif_mp-1099246_Mg3BiO4.cif',
#  'cif_mp-1099248_Mg3CO4.cif',
#  'cif_mp-1099249_Mg3CuO4.cif',
#  'cif_mp-1099250_Mg3MoO4.cif',
#  'cif_mp-1099251_Mg3GaO4.cif',
#  'cif_mp-1099252_Mg3SbO4.cif',
#  'cif_mp-1099254_Mg3CoO4.cif',
#  'cif_mp-1099255_Mg3CdO4.cif',
#  'cif_mp-1099256_Mg3BO4.cif',
#  'cif_mp-1099257_KMg3O4.cif',
#  'cif_mp-1099258_HfMg3O4.cif',
#  'cif_mp-1099259_LiMg3O4.cif',
#  'cif_mp-1099583_SmTiO3.cif',
#  'cif_mp-1099588_SmFeO3.cif',
#  'cif_mp-1099591_NaVO3.cif',
#  'cif_mp-1099619_EuMnO3.cif',
#  'cif_mp-1099664_KNa7V8O24.cif',
#  'cif_mp-1099685_BaSr7(FeO3)8.cif',
#  'cif_mp-1099778_BaSr7Ti8O24.cif',
#  'cif_mp-1099824_Ba7Sr(CuO3)8.cif',
#  'cif_mp-1099873_CaCuO3.cif',
#  'cif_mp-1099881_Sr2TiMnO6.cif',
#  'cif_mp-1099923_La7SmMn8O24.cif',
#  'cif_mp-1099934_CaCoO3.cif',
#  'cif_mp-1100771_TiTl3.cif',
#  'cif_mp-1100773_Y3Cd.cif',
#  'cif_mp-1100774_U3N.cif',
#  'cif_mp-1100775_SrEuO3.cif',
#  'cif_mp-1100776_ZnBi3.cif',
#  'cif_mp-1100777_VTeO3.cif',
#  'cif_mp-1100778_ZnCuO3.cif',
#  'cif_mp-1100784_U3In.cif',
#  'cif_mp-1101333_SrNdO3.cif',
#  'cif_mp-1101336_TbCeO4.cif',
#  'cif_mp-1101666_NaFe5O8.cif',
#  'cif_mp-1101717_PrHfO4.cif',
#  'cif_mp-1101754_Ti4H7.cif',
#  'cif_mp-1101765_BiRhSe.cif',
#  'cif_mp-1101820_MgTi3H8.cif',
#  'cif_mp-1101823_Cd(N2O3)2.cif',
#  'cif_mp-1101846_Mg3TiH8.cif',
#  'cif_mp-1101868_AuN2.cif',
#  'cif_mp-1101912_BaSiPt.cif',
#  'cif_mp-1101930_MgO.cif',
#  'cif_mp-1101975_WN2.cif',
#  'cif_mp-1102002_FeTe2.cif',
#  'cif_mp-1102038_MgH2.cif',
#  'cif_mp-1102074_OsN2.cif',
#  'cif_mp-1102114_TaN2.cif',
#  'cif_mp-1102124_Na8BiO3.cif',
#  'cif_mp-1102140_NdSiIr.cif',
#  'cif_mp-1102163_Li8AsO3.cif',
#  'cif_mp-1102170_CrO2.cif',
#  'cif_mp-1102223_K8SbO3.cif',
#  'cif_mp-1102232_HCN.cif',
#  'cif_mp-1102235_IrN2.cif',
#  'cif_mp-1102261_IrS2.cif',
#  'cif_mp-1102284_SbPdS.cif',
#  'cif_mp-1102324_NiTe2.cif',
#  'cif_mp-1102366_SbRhSe.cif',
#  'cif_mp-1102429_HfN2.cif',
#  'cif_mp-1102430_SbTeIr.cif',
#  'cif_mp-1102443_CoSbS.cif',
#  'cif_mp-1102444_UC2.cif',
#  'cif_mp-1102515_ZnSe2.cif',
#  'cif_mp-1102531_PRhSe.cif',
#  'cif_mp-1102539_Na8SbO3.cif',
#  'cif_mp-1102584_Ca4Mg4Fe3.cif',
#  'cif_mp-1102591_TiO2.cif',
#  'cif_mp-1102609_BaSiPd.cif',
#  'cif_mp-1102647_NaC2.cif',
#  'cif_mp-1102668_CrSbPt.cif',
#  'cif_mp-11026_Rb3Hg20.cif',
#  'cif_mp-1102707_FeSbPt.cif',
#  'cif_mp-1102716_Li8SbO3.cif',
#  'cif_mp-1102743_ZnS2.cif',
#  'cif_mp-1102773_K8BiO3.cif',
#  'cif_mp-11027_Cs3Hg20.cif',
#  'cif_mp-1102811_SiC2.cif',
#  'cif_mp-1102836_BiIrS.cif',
#  'cif_mp-1102845_TiS2.cif',
#  'cif_mp-1102850_SbPtS.cif',
#  'cif_mp-1102865_Li8BiO3.cif',
#  'cif_mp-1102981_Rb8SbO3.cif',
#  'cif_mp-1102998_Na8AsO3.cif',
#  'cif_mp-1103017_NiBiSe.cif',
#  'cif_mp-1103058_Rb8AsO3.cif',
#  'cif_mp-1103098_BiRhS.cif',
#  'cif_mp-1103155_LaSiRh.cif',
#  'cif_mp-1103177_FeSe2.cif',
#  'cif_mp-1103210_EuMgNi.cif',
#  'cif_mp-1103228_BiIrSe.cif',
#  'cif_mp-1103235_CuTe2.cif',
#  'cif_mp-1103284_Rb8BiO3.cif',
#  'cif_mp-1103317_SbRhS.cif',
#  'cif_mp-1103420_ReN2.cif',
#  'cif_mp-1103427_PdN2.cif',
#  'cif_mp-1103513_Li3(Mg2Si)4.cif',
#  'cif_mp-1103521_Sr8Rh5.cif',
#  'cif_mp-1103590_MgSe2.cif',
#  'cif_mp-1103943_ErGa3Ru.cif',
#  'cif_mp-1104461_TbGa3Ru.cif',
#  'cif_mp-1104503_YGa3Ru.cif',
#  'cif_mp-1104547_HoGa3Ru.cif',
#  'cif_mp-1104791_Li(Mg2Si)4.cif',
#  'cif_mp-1104_LaMg.cif',
#  'cif_mp-1105018_Al2O3.cif',
#  'cif_mp-1105019_DyGa3Ru.cif',
#  'cif_mp-1105290_Co3Sb4(OF)6.cif',
#  'cif_mp-1105641_InHO2.cif',
#  'cif_mp-1105655_C3N2.cif',
#  'cif_mp-1105932_Li2MgSi.cif',
#  'cif_mp-1106349_SmPd3S4.cif',
#  'cif_mp-1110791_RbAuCl3.cif',
#  'cif_mp-1110854_KAuCl3.cif',
#  'cif_mp-1110999_RbAuBr3.cif',
#  'cif_mp-1111644_RbAuF3.cif',
#  'cif_mp-1111868_KAuF3.cif',
#  'cif_mp-1112174_KAuBr3.cif',
#  'cif_mp-1112985_CsAuF3.cif',
#  'cif_mp-1112987_CsAuBr3.cif',
#  'cif_mp-1120716_CdHg3Te4.cif',
#  'cif_mp-1120717_V3Bi.cif',
#  'cif_mp-1120718_MgZn3S4.cif',
#  'cif_mp-1120722_CuO.cif',
#  'cif_mp-1120765_BaNiO3.cif',
#  'cif_mp-1120777_NaTiF3.cif',
#  'cif_mp-1120_Mo3Ir.cif',
#  'cif_mp-1121_GaCo.cif',
#  'cif_mp-11221_SmAl.cif',
#  'cif_mp-11222_Sm3Al.cif',
#  'cif_mp-11224_Sr8Al7.cif',
#  'cif_mp-11229_YAl.cif',
#  'cif_mp-11231_YAl3.cif',
#  'cif_mp-11237_ScAg.cif',
#  'cif_mp-11240_DyAu.cif',
#  'cif_mp-11245_HoAu.cif',
#  'cif_mp-11248_LiAu3.cif',
#  'cif_mp-11249_LuAu.cif',
#  'cif_mp-11254_NdAu.cif',
#  'cif_mp-11255_PrAu.cif',
#  'cif_mp-11256_ScAu.cif',
#  'cif_mp-11257_SmAu.cif',
#  'cif_mp-11258_TbAu.cif',
#  'cif_mp-11259_TiAu.cif',
#  'cif_mp-11260_Ti3Au.cif',
#  'cif_mp-11261_YAu.cif',
#  'cif_mp-11271_BeMo3.cif',
#  'cif_mp-11274_BePd.cif',
#  'cif_mp-11276_BeRh.cif',
#  'cif_mp-11279_TiBe.cif',
#  'cif_mp-11286_CaHg.cif',
#  'cif_mp-11290_CaSn3.cif',
#  'cif_mp-1129_ScIr.cif',
#  'cif_mp-11309_NbCd3.cif',
#  'cif_mp-11312_V3Cd.cif',
#  'cif_mp-11334_W.cif',
#  'cif_mp-11364_TiCu.cif',
#  'cif_mp-11365_Ti3Cu.cif',
#  'cif_mp-11370_ErIn.cif',
#  'cif_mp-11372_ErSn3.cif',
#  'cif_mp-11374_DyTl.cif',
#  'cif_mp-11375_EuHg.cif',
#  'cif_mp-11388_GaIr.cif',
#  'cif_mp-1139958_LiY(TlCl3)2.cif',
#  'cif_mp-11407_GaPt3.cif',
#  'cif_mp-11418_TbGa3.cif',
#  'cif_mp-11422_GdHg.cif',
#  'cif_mp-11447_UTe.cif',
#  'cif_mp-11452_HfOs.cif',
#  'cif_mp-11455_HfPt.cif',
#  'cif_mp-11457_HfRh.cif',
#  'cif_mp-11460_HfTc.cif',
#  'cif_mp-11467_NdHg.cif',
#  'cif_mp-11469_PrHg.cif',
#  'cif_mp-11471_ScHg.cif',
#  'cif_mp-11473_TlHg.cif',
#  'cif_mp-11474_TlHg3.cif',
#  'cif_mp-1147577_GdCrO3.cif',
#  'cif_mp-11475_TmHg.cif',
#  'cif_mp-1147612_Mg(CuN)3.cif',
#  'cif_mp-1147638_CsVC6.cif',
#  'cif_mp-1147651_SnAu.cif',
#  'cif_mp-1147653_CaCu3O4.cif',
#  'cif_mp-1147655_Ba4Cu3SnO9.cif',
#  'cif_mp-1147674_Li(CuN)3.cif',
#  'cif_mp-1147675_Rh3Cl4.cif',
#  'cif_mp-1147682_CsNbC6.cif',
#  'cif_mp-1147699_Ba4Ti(CuO3)3.cif',
#  'cif_mp-11476_HoIr.cif',
#  'cif_mp-1147701_Cu3NF3.cif',
#  'cif_mp-1147702_Li(CuO)3.cif',
#  'cif_mp-1147710_CsPdCl3.cif',
#  'cif_mp-1147716_CsMoC6.cif',
#  'cif_mp-1147731_In(CuN)3.cif',
#  'cif_mp-1147740_Pt3Cl3F.cif',
#  'cif_mp-1147742_CsCrC6.cif',
#  'cif_mp-1147771_Al(CuN)3.cif',
#  'cif_mp-11477_HoSn3.cif',
#  'cif_mp-11478_GaAg.cif',
#  'cif_mp-11483_TmIr.cif',
#  'cif_mp-11484_ZrIr.cif',
#  'cif_mp-11487_LaPt3.cif',
#  'cif_mp-11488_LaTl.cif',
#  'cif_mp-11495_LuRu.cif',
#  'cif_mp-11496_LuZn.cif',
#  'cif_mp-11498_MgTl.cif',
#  'cif_mp-11503_MnZn.cif',
#  'cif_mp-1150_URh3.cif',
#  'cif_mp-11516_NbRu.cif',
#  'cif_mp-11521_ScNi.cif',
#  'cif_mp-1152_TiRh3.cif',
#  'cif_mp-11536_NpRh3.cif',
#  'cif_mp-11541_ZrOs.cif',
#  'cif_mp-11546_TiPd.cif',
#  'cif_mp-11552_TiPt.cif',
#  'cif_mp-11554_ZrPt.cif',
#  'cif_mp-11555_PuRu.cif',
#  'cif_mp-11561_TbRh.cif',
#  'cif_mp-11563_TiRh.cif',
#  'cif_mp-11564_TmRh.cif',
#  'cif_mp-11566_ScZn.cif',
#  'cif_mp-11568_SmTl.cif',
#  'cif_mp-11569_SmTl3.cif',
#  'cif_mp-11570_TbSn3.cif',
#  'cif_mp-11571_YSn3.cif',
#  'cif_mp-11572_TaTc.cif',
#  'cif_mp-11573_TiTc.cif',
#  'cif_mp-11575_YTl.cif',
#  'cif_mp-1158_LuPd3.cif',
#  'cif_mp-1169_ScCu.cif',
#  'cif_mp-1172909_BeCl2.cif',
#  'cif_mp-1172_MgRh.cif',
#  'cif_mp-11733_Lu3InN.cif',
#  'cif_mp-1174_MgSc.cif',
#  'cif_mp-1176363_Na2Sb3O8.cif',
#  'cif_mp-1176709_LiFeF3.cif',
#  'cif_mp-1177863_Li2Ti3FeO8.cif',
#  'cif_mp-1177906_Li2Ti3CoO8.cif',
#  'cif_mp-1177935_Li2Mn3CoO8.cif',
#  'cif_mp-1177962_Li2Fe3SnO8.cif',
#  'cif_mp-1177997_Li2Fe3BiO8.cif',
#  'cif_mp-1178248_HfZrO4.cif',
#  'cif_mp-1178268_GdAlO3.cif',
#  'cif_mp-1178354_EuZrO3.cif',
#  'cif_mp-1178500_CeHfO4.cif',
#  'cif_mp-1178510_BaPdO3.cif',
#  'cif_mp-1178641_ZnCu3NiSe4.cif',
#  'cif_mp-1178642_ZnCoCu3Se4.cif',
#  'cif_mp-1178643_ZnCrCu3Se4.cif',
#  'cif_mp-1178644_ZnGaCu3Se4.cif',
#  'cif_mp-1178645_ZnInCu3Se4.cif',
#  'cif_mp-1178697_YCu3PbSe4.cif',
#  'cif_mp-1178705_YMgCu3Se4.cif',
#  'cif_mp-1178710_YCu3HgSe4.cif',
#  'cif_mp-1178729_YCdCu3Se4.cif',
#  'cif_mp-1178753_VZnCu3Se4.cif',
#  'cif_mp-1178804_VCu3HgSe4.cif',
#  'cif_mp-1178806_VCdCu3Se4.cif',
#  'cif_mp-1178824_VCu3PbSe4.cif',
#  'cif_mp-1178984_TlZnCu3Se4.cif',
#  'cif_mp-1178991_Ti4(SiO8)3.cif',
#  'cif_mp-1179003_SrYCu3Se4.cif',
#  'cif_mp-1179014_SrVCu3Se4.cif',
#  'cif_mp-1179021_TlCdCu3Se4.cif',
#  'cif_mp-1179028_TlCu3PbSe4.cif',
#  'cif_mp-1179060_SrTlCu3Se4.cif',
#  'cif_mp-1179075_SrScCu3Se4.cif',
#  'cif_mp-1179109_TeC6(I3N)2.cif',
#  'cif_mp-1179118_SrGaCu3Se4.cif',
#  'cif_mp-1179119_SrInCu3Se4.cif',
#  'cif_mp-1179135_ScZnCu3Se4.cif',
#  'cif_mp-1179138_SrCu3NiSe4.cif',
#  'cif_mp-1179142_SrCoCu3Se4.cif',
#  'cif_mp-1179174_SrAlCu3Se4.cif',
#  'cif_mp-1179510_ScCdCu3Se4.cif',
#  'cif_mp-1179516_ScCu3HgSe4.cif',
#  'cif_mp-1179525_ScCu3PbSe4.cif',
#  'cif_mp-1179676_RbZrCu3Se4.cif',
#  'cif_mp-1179694_RbVCu3Se4.cif',
#  'cif_mp-1179697_RbTiCu3Se4.cif',
#  'cif_mp-1179714_RbMnCu3Se4.cif',
#  'cif_mp-1179715_RbHfCu3Se4.cif',
#  'cif_mp-1179749_RbCu3GeSe4.cif',
#  'cif_mp-1179750_RbCoCu3Se4.cif',
#  'cif_mp-1179752_RbCu3SnSe4.cif',
#  'cif_mp-1179753_RbCu3SiSe4.cif',
#  'cif_mp-1179805_RbCr(SO10)2.cif',
#  'cif_mp-1179860_NaCu3SnSe4.cif',
#  'cif_mp-1179864_NaMnCu3Se4.cif',
#  'cif_mp-1179880_NaCu3GeSe4.cif',
#  'cif_mp-1179888_NaCu3PbSe4.cif',
#  'cif_mp-1179889_NaCoCu3Se4.cif',
#  'cif_mp-1179901_NaCu3NiSe4.cif',
#  'cif_mp-1180005_NaCr(SO10)2.cif',
#  'cif_mp-1180089_NaZrCu3Se4.cif',
#  'cif_mp-1180113_NaVCu3Se4.cif',
#  'cif_mp-1180119_NaTiCu3Se4.cif',
#  'cif_mp-1180276_MgVCu3Se4.cif',
#  'cif_mp-1180283_MgGaCu3Se4.cif',
#  'cif_mp-1180284_MgCu3NiSe4.cif',
#  'cif_mp-1180289_MgCrCu3Se4.cif',
#  'cif_mp-1180309_Mn2Al3.cif',
#  'cif_mp-1180322_MgCoCu3Se4.cif',
#  'cif_mp-1180325_MgTlCu3Se4.cif',
#  'cif_mp-1180332_MgAlCu3Se4.cif',
#  'cif_mp-1180537_NiH12(ClO6)2.cif',
#  'cif_mp-1180545_NaAl(SO10)2.cif',
#  'cif_mp-1180619_Li2O2.cif',
#  'cif_mp-1180674_KZrCu3Se4.cif',
#  'cif_mp-1180688_KTiCu3Se4.cif',
#  'cif_mp-1180689_KVCu3Se4.cif',
#  'cif_mp-1180796_KCu3SnSe4.cif',
#  'cif_mp-1180804_KCoCu3Se4.cif',
#  'cif_mp-1180817_KCu3NiSe4.cif',
#  'cif_mp-1180832_KMnCu3Se4.cif',
#  'cif_mp-1180842_KCu3GeSe4.cif',
#  'cif_mp-1180844_KCu3SiSe4.cif',
#  'cif_mp-1180884_KHfCu3Se4.cif',
#  'cif_mp-1180900_KCu3PbSe4.cif',
#  'cif_mp-1180995_InCu3HgSe4.cif',
#  'cif_mp-1181191_KAl(SO10)2.cif',
#  'cif_mp-1181291_Ge7O23.cif',
#  'cif_mp-1181331_GaCu3HgSe4.cif',
#  'cif_mp-1181468_Cu3NiHgSe4.cif',
#  'cif_mp-1181478_Ni2Mo3N.cif',
#  'cif_mp-1181558_CsZrCu3Se4.cif',
#  'cif_mp-1181577_CsTiCu3Se4.cif',
#  'cif_mp-1181585_CsHfCu3Se4.cif',
#  'cif_mp-1181597_CsCu3GeSe4.cif',
#  'cif_mp-1181613_Cu3NiPbSe4.cif',
#  'cif_mp-1181644_NaCo(N2O3)4.cif',
#  'cif_mp-1181705_Cu3SnAu.cif',
#  'cif_mp-1181713_CrCdCu3Se4.cif',
#  'cif_mp-1181716_CrCu3HgSe4.cif',
#  'cif_mp-1181720_CrCu3PbSe4.cif',
#  'cif_mp-1181785_CoCu3HgSe4.cif',
#  'cif_mp-1181852_CaTlCu3Se4.cif',
#  'cif_mp-1181874_CdGaCu3Se4.cif',
#  'cif_mp-1181876_LaAl(NO4)6.cif',
#  'cif_mp-1181879_CdCu3NiSe4.cif',
#  'cif_mp-1181881_CdCoCu3Se4.cif',
#  'cif_mp-1181925_CaScCu3Se4.cif',
#  'cif_mp-1181927_CaYCu3Se4.cif',
#  'cif_mp-1181943_CaVCu3Se4.cif',
#  'cif_mp-1181967_CaCu3NiSe4.cif',
#  'cif_mp-1181975_CaCoCu3Se4.cif',
#  'cif_mp-1181990_CdInCu3Se4.cif',
#  'cif_mp-1182006_CaCrCu3Se4.cif',
#  'cif_mp-1182175_BaInCu3Se4.cif',
#  'cif_mp-1182176_BaAlCu3Se4.cif',
#  'cif_mp-1182182_BaScCu3Se4.cif',
#  'cif_mp-1182227_BaGaCu3Se4.cif',
#  'cif_mp-1182239_BaCu3NiSe4.cif',
#  'cif_mp-1182240_BaTlCu3Se4.cif',
#  'cif_mp-1182242_BaYCu3Se4.cif',
#  'cif_mp-11824_Ca3PN.cif',
#  'cif_mp-1182688_CsTiH24(SO10)2.cif',
#  'cif_mp-1182706_Nb3Al2N.cif',
#  'cif_mp-1182859_AlZnCu3Se4.cif',
#  'cif_mp-1182878_AlCdCu3Se4.cif',
#  'cif_mp-1182880_AlCu3HgSe4.cif',
#  'cif_mp-1182885_AlCu4.cif',
#  'cif_mp-1182890_AlCu3PbSe4.cif',
#  'cif_mp-1182920_AlS2NO20.cif',
#  'cif_mp-1183043_ZrSiO3.cif',
#  'cif_mp-1183044_ZrTlO3.cif',
#  'cif_mp-1183045_ZrTiO3.cif',
#  'cif_mp-1183052_AcBO3.cif',
#  'cif_mp-1183053_AcGaO3.cif',
#  'cif_mp-1183056_Ac3Cl.cif',
#  'cif_mp-1183058_Ac3Zr.cif',
#  'cif_mp-1183064_Ac3Au.cif',
#  'cif_mp-1183075_Ac3Cr.cif',
#  'cif_mp-1183105_Ac3Ce.cif',
#  ...]

# %%
import pickle
with open('cubic_files_list.pkl', 'wb') as f:
    pickle.dump(cubic_files, f)

# %%
# cubic_files_list.pklを読み込み
with open('cubic_files_list.pkl', 'rb') as f:
    cubic_files_ = pickle.load(f)
    
cubic_files_
# Out:
# ['cif_mp-1001571_CaFeO3.cif',
#  'cif_mp-10015_SiOs.cif',
#  'cif_mp-1001788_ZrB6.cif',
#  'cif_mp-1001834_HfN.cif',
#  'cif_mp-1001843_HoP.cif',
#  'cif_mp-1001844_HoN.cif',
#  'cif_mp-1001913_HoBi.cif',
#  'cif_mp-1001917_HoAs.cif',
#  'cif_mp-1001918_HfC.cif',
#  'cif_mp-1002105_VN.cif',
#  'cif_mp-1002106_HfPd.cif',
#  'cif_mp-1002109_VCo.cif',
#  'cif_mp-1002117_TcN.cif',
#  'cif_mp-1002122_HfIr.cif',
#  'cif_mp-1002183_TcB.cif',
#  'cif_mp-1002207_ReN.cif',
#  'cif_mp-1002210_EuS.cif',
#  'cif_mp-1002220_TmSb.cif',
#  'cif_mp-1002223_DyP.cif',
#  'cif_mp-1002224_ErP.cif',
#  'cif_mp-1002226_ErAs.cif',
#  'cif_mp-1002228_PtC.cif',
#  'cif_mp-1002229_ErN.cif',
#  'cif_mp-1002230_PuBi.cif',
#  'cif_mp-10037_AlCo3C.cif',
#  'cif_mp-10038_Er3AlC.cif',
#  'cif_mp-10039_Pr3AlC.cif',
#  'cif_mp-10040_AlPt3C.cif',
#  'cif_mp-10041_Tb3AlC.cif',
#  'cif_mp-1004377_HfB6.cif',
#  'cif_mp-1004524_HPbI3.cif',
#  'cif_mp-1004_Nb3Si.cif',
#  'cif_mp-1005719_Sm3Np.cif',
#  'cif_mp-1005727_TmNp3.cif',
#  'cif_mp-10060_DyBPd3.cif',
#  'cif_mp-1006115_Ho3Pu.cif',
#  'cif_mp-10061_ErBPd3.cif',
#  'cif_mp-1006245_ErNp3.cif',
#  'cif_mp-1006246_CeSm3.cif',
#  'cif_mp-1006330_Ce3Cu.cif',
#  'cif_mp-1006615_CrCuN6Cl5.cif',
#  'cif_mp-1006883_CoNi.cif',
#  'cif_mp-1006884_CoMo.cif',
#  'cif_mp-1006886_CeS.cif',
#  'cif_mp-1007656_HfPd3.cif',
#  'cif_mp-1007657_HfRu3.cif',
#  'cif_mp-1007690_HgPt3.cif',
#  'cif_mp-1007693_HfOs3.cif',
#  'cif_mp-1007730_HfAl3.cif',
#  'cif_mp-1007819_CoW.cif',
#  'cif_mp-1007974_CrNi3.cif',
#  'cif_mp-1008278_Cr3Ni.cif',
#  'cif_mp-1008285_Cr3Fe.cif',
#  'cif_mp-1008489_CdN.cif',
#  'cif_mp-1008554_Al3V.cif',
#  'cif_mp-1008555_AlCu3.cif',
#  'cif_mp-1008630_WC.cif',
#  'cif_mp-1008650_CeSe.cif',
#  'cif_mp-1008752_CeTe.cif',
#  'cif_mp-1008923_CuN.cif',
#  'cif_mp-1008924_DySb.cif',
#  'cif_mp-1008928_EuSe.cif',
#  'cif_mp-1008931_ErSb.cif',
#  'cif_mp-1008985_CoN.cif',
#  'cif_mp-1008998_LaS.cif',
#  'cif_mp-1008999_LaSe.cif',
#  'cif_mp-1008_NiHg.cif',
#  'cif_mp-1009005_IrN.cif',
#  'cif_mp-1009007_LuSb.cif',
#  'cif_mp-1009008_LaTe.cif',
#  'cif_mp-1009009_LiF.cif',
#  'cif_mp-1009016_LuAs.cif',
#  'cif_mp-1009017_HoSb.cif',
#  'cif_mp-1009018_InAg.cif',
#  'cif_mp-1009019_FeN.cif',
#  'cif_mp-1009127_MgO.cif',
#  'cif_mp-1009128_MnN.cif',
#  'cif_mp-1009133_MnCo.cif',
#  'cif_mp-1009206_MnSn.cif',
#  'cif_mp-1009207_MnSb.cif',
#  'cif_mp-1009220_NaH.cif',
#  'cif_mp-1009237_NdN.cif',
#  'cif_mp-1009264_NbCo.cif',
#  'cif_mp-1009459_NbC.cif',
#  'cif_mp-1009471_NbN.cif',
#  'cif_mp-1009483_NiN.cif',
#  'cif_mp-1009485_CrN.cif',
#  'cif_mp-1009493_NpN.cif',
#  'cif_mp-1009537_OsC.cif',
#  'cif_mp-1009596_PdN.cif',
#  'cif_mp-1009640_PrN.cif',
#  'cif_mp-1009731_ReC.cif',
#  'cif_mp-1009748_ScC.cif',
#  'cif_mp-1009819_SrO.cif',
#  'cif_mp-1009826_TaCo.cif',
#  'cif_mp-1009831_TaN.cif',
#  'cif_mp-1009835_TaC.cif',
#  'cif_mp-1009836_ZrN.cif',
#  'cif_mp-1009839_TbAl.cif',
#  'cif_mp-1009878_ZrC.cif',
#  'cif_mp-1010071_CrCo.cif',
#  'cif_mp-1010161_DyAs.cif',
#  'cif_mp-1011031_PrBi.cif',
#  'cif_mp-10110_SiRh.cif',
#  'cif_mp-10113_ScBIr3.cif',
#  'cif_mp-1011697_Cs2Se.cif',
#  'cif_mp-10120_NdBPd3.cif',
#  'cif_mp-10133_Sc3BPb.cif',
#  'cif_mp-10134_TmBPd3.cif',
#  'cif_mp-1013524_Ca3N2.cif',
#  'cif_mp-1013528_Ba3N2.cif',
#  'cif_mp-1013529_Sr3N2.cif',
#  'cif_mp-1013530_Sr3BiP.cif',
#  'cif_mp-1013531_Sr3BiN.cif',
#  'cif_mp-1013532_Sr3AsP.cif',
#  'cif_mp-1013533_Ba3PN.cif',
#  'cif_mp-1013534_Sr3SbN.cif',
#  'cif_mp-1013535_Sr3SbP.cif',
#  'cif_mp-1013536_Sr3PN.cif',
#  'cif_mp-1013537_Sr3AsN.cif',
#  'cif_mp-1013540_Ca3PN.cif',
#  'cif_mp-1013541_Sr3SbAs.cif',
#  'cif_mp-1013542_Ca3BiN.cif',
#  'cif_mp-1013543_Ca3AsN.cif',
#  'cif_mp-1013544_Ca3SbAs.cif',
#  'cif_mp-1013545_Ca3BiAs.cif',
#  'cif_mp-1013546_Ca3Sb2.cif',
#  'cif_mp-1013547_Ca3P2.cif',
#  'cif_mp-1013548_Ca3SbN.cif',
#  'cif_mp-1013549_Ba3BiN.cif',
#  'cif_mp-1013550_Ca3SbP.cif',
#  'cif_mp-1013551_Ba3P2.cif',
#  'cif_mp-1013552_Sr3P2.cif',
#  'cif_mp-1013553_Sr3AsP.cif',
#  'cif_mp-1013554_Sr3PN.cif',
#  'cif_mp-1013555_Sr3AsN.cif',
#  'cif_mp-1013557_Ba3SbN.cif',
#  'cif_mp-1013558_Ca3BiP.cif',
#  'cif_mp-1013559_Sr3As2.cif',
#  'cif_mp-1013560_Ba3As2.cif',
#  'cif_mp-1013561_Sr3SbAs.cif',
#  'cif_mp-1013562_Ba3SbAs.cif',
#  'cif_mp-1013563_Ba3BiAs.cif',
#  'cif_mp-1013564_Sr3BiAs.cif',
#  'cif_mp-1013582_Ba3Sb2.cif',
#  'cif_mp-1013583_Sr3Sb2.cif',
#  'cif_mp-1013584_Ba3BiSb.cif',
#  'cif_mp-1013585_Sr3BiSb.cif',
#  'cif_mp-1013586_Ba3AsP.cif',
#  'cif_mp-1013587_Sr3Bi2.cif',
#  'cif_mp-1013588_Sr3SbP.cif',
#  'cif_mp-1013642_Ca3AsP.cif',
#  'cif_mp-1013643_Sr3BiP.cif',
#  'cif_mp-1013691_Ba3BiP.cif',
#  'cif_mp-1013702_Ca3BiP.cif',
#  'cif_mp-1013703_Ca3BiAs.cif',
#  'cif_mp-1013704_Ca3BiSb.cif',
#  'cif_mp-1013705_Sr3BiAs.cif',
#  'cif_mp-1013706_Sr3BiSb.cif',
#  'cif_mp-1013707_Ba3PN.cif',
#  'cif_mp-1013708_Ba3SbN.cif',
#  'cif_mp-1013709_Ba3AsN.cif',
#  'cif_mp-1013710_Ba3BiN.cif',
#  'cif_mp-1013711_Ba3AsP.cif',
#  'cif_mp-1013712_Ba3SbP.cif',
#  'cif_mp-1013713_Ba3BiP.cif',
#  'cif_mp-1013714_Ba3SbAs.cif',
#  'cif_mp-1013716_Ba3BiAs.cif',
#  'cif_mp-1013719_Ba3BiSb.cif',
#  'cif_mp-1013733_Ca3BiSb.cif',
#  'cif_mp-1013734_Ba3AsN.cif',
#  'cif_mp-1013735_Ca3Bi2.cif',
#  'cif_mp-1013736_Ba3Bi2.cif',
#  'cif_mp-1013737_Ba3SbP.cif',
#  'cif_mp-1013738_Ca3SbAs.cif',
#  'cif_mp-10139_Sc3SnB.cif',
#  'cif_mp-10140_Sc3TlB.cif',
#  'cif_mp-1014214_C3N.cif',
#  'cif_mp-1014219_HfZn.cif',
#  'cif_mp-1014230_TiZn.cif',
#  'cif_mp-1014297_C3N.cif',
#  'cif_mp-1014316_C3N.cif',
#  'cif_mp-1014460_Cr3N4.cif',
#  'cif_mp-10148_InSb.cif',
#  'cif_mp-1014993_CrN2.cif',
#  'cif_mp-1016227_LaMg3.cif',
#  'cif_mp-1016819_HfZnO3.cif',
#  'cif_mp-1016820_MgSnO3.cif',
#  'cif_mp-1016821_BaSiO3.cif',
#  'cif_mp-1016823_BaGeO3.cif',
#  'cif_mp-1016825_HfMgO3.cif',
#  'cif_mp-1016826_MgIrO3.cif',
#  'cif_mp-1016827_MgGeO3.cif',
#  'cif_mp-1016828_CdIrO3.cif',
#  'cif_mp-1016829_MgRuO3.cif',
#  'cif_mp-1016830_MgTiO3.cif',
#  'cif_mp-1016831_HgIrO3.cif',
#  'cif_mp-1016833_CaRhO3.cif',
#  'cif_mp-1016835_CaRuO3.cif',
#  'cif_mp-1016836_ZnOsO3.cif',
#  'cif_mp-1016837_SnHgO3.cif',
#  'cif_mp-1016840_HgOsO3.cif',
#  'cif_mp-1016841_HfHgO3.cif',
#  'cif_mp-1016842_TiHgO3.cif',
#  'cif_mp-1016843_MgOsO3.cif',
#  'cif_mp-1016845_ZrCdO3.cif',
#  'cif_mp-1016846_TiCdO3.cif',
#  'cif_mp-1016848_SrIrO3.cif',
#  'cif_mp-1016849_CdRuO3.cif',
#  'cif_mp-1016850_BaRhO3.cif',
#  'cif_mp-1016851_HgRuO3.cif',
#  'cif_mp-1016852_BaMnO3.cif',
#  'cif_mp-1016853_CaVO3.cif',
#  'cif_mp-1016854_MnCdO3.cif',
#  'cif_mp-1016871_ZrHgO3.cif',
#  'cif_mp-1016872_CaIrO3.cif',
#  'cif_mp-1016873_CaHfO3.cif',
#  'cif_mp-1016874_SiHgO3.cif',
#  'cif_mp-1016875_CdRhO3.cif',
#  'cif_mp-1016876_ZnSiO3.cif',
#  'cif_mp-1016877_HgRhO3.cif',
#  'cif_mp-1016879_CdSiO3.cif',
#  'cif_mp-1016880_ZnRhO3.cif',
#  'cif_mp-1016881_CdSnO3.cif',
#  'cif_mp-1016882_CdOsO3.cif',
#  'cif_mp-1016883_ZrZnO3.cif',
#  'cif_mp-1016884_CaGeO3.cif',
#  'cif_mp-1016886_MgVO3.cif',
#  'cif_mp-1016900_CaOsO3.cif',
#  'cif_mp-1016902_ZnSnO3.cif',
#  'cif_mp-1016903_CdGeO3.cif',
#  'cif_mp-1016904_VCdO3.cif',
#  'cif_mp-1016926_ZnIrO3.cif',
#  'cif_mp-1016927_TiZnO3.cif',
#  'cif_mp-1016928_MgSiO3.cif',
#  'cif_mp-1016929_MgRhO3.cif',
#  'cif_mp-1016930_ZnGeO3.cif',
#  'cif_mp-1016931_VZnO3.cif',
#  'cif_mp-1016932_MnZnO3.cif',
#  'cif_mp-1016938_VHgO3.cif',
#  'cif_mp-1016999_SrGeO3.cif',
#  'cif_mp-1017000_MgZrO3.cif',
#  'cif_mp-1017439_SrSiO3.cif',
#  'cif_mp-1017441_SrRhO3.cif',
#  'cif_mp-1017446_HfCdO3.cif',
#  'cif_mp-1017447_HgGeO3.cif',
#  'cif_mp-1017465_BaVO3.cif',
#  'cif_mp-1017467_CaMnO3.cif',
#  'cif_mp-1017519_IrC.cif',
#  'cif_mp-1017529_VCo3.cif',
#  'cif_mp-1017542_ZrOs3.cif',
#  'cif_mp-1017543_ZrPd3.cif',
#  'cif_mp-1017544_ZrRu3.cif',
#  'cif_mp-1017553_CdCo3N.cif',
#  'cif_mp-1017555_CsBeF3.cif',
#  'cif_mp-1017557_Dy3AlN.cif',
#  'cif_mp-1017558_Er3AlN.cif',
#  'cif_mp-1017563_GaPt3C.cif',
#  'cif_mp-1017566_GePbO3.cif',
#  'cif_mp-1017577_Ho3AlN.cif',
#  'cif_mp-1017578_HfBRh3.cif',
#  'cif_mp-1017580_KMgH3.cif',
#  'cif_mp-1017581_LaPd3C.cif',
#  'cif_mp-1017582_LaPt3C.cif',
#  'cif_mp-1017591_BaRuO3.cif',
#  'cif_mp-10175_KCdF3.cif',
#  'cif_mp-1017626_LiCaF3.cif',
#  'cif_mp-1017627_Lu3AlN.cif',
#  'cif_mp-1017629_MgNiH3.cif',
#  'cif_mp-1017631_ScBPd3.cif',
#  'cif_mp-1017632_Ni3SnN.cif',
#  'cif_mp-1018029_CuPd.cif',
#  'cif_mp-1018042_UBi.cif',
#  'cif_mp-1018054_HfPt3.cif',
#  'cif_mp-1018061_FeH3.cif',
#  'cif_mp-1018081_CrFe3.cif',
#  'cif_mp-1018101_AlCo3.cif',
#  'cif_mp-10185_Mg3ZnC.cif',
#  'cif_mp-1018627_ScBPt3.cif',
#  'cif_mp-1018628_ScPt3C.cif',
#  'cif_mp-1018629_YPd3C.cif',
#  'cif_mp-1018633_LaBPt3.cif',
#  'cif_mp-1018635_ScPd3C.cif',
#  'cif_mp-1018636_SnPd3C.cif',
#  'cif_mp-1018638_Tb3AlN.cif',
#  'cif_mp-1018639_TiSnO3.cif',
#  'cif_mp-1018641_Tm3AlN.cif',
#  'cif_mp-1018643_YBPd3.cif',
#  'cif_mp-1018644_YBPt3.cif',
#  'cif_mp-1018645_YPt3C.cif',
#  'cif_mp-1018734_IrN.cif',
#  'cif_mp-1018849_OsN.cif',
#  'cif_mp-1019052_ReN.cif',
#  'cif_mp-1019378_Al3GaN4.cif',
#  'cif_mp-1019379_AlB3N4.cif',
#  'cif_mp-1019380_Al3BN4.cif',
#  'cif_mp-1019508_AlGa3N4.cif',
#  'cif_mp-1019541_BaCa3O4.cif',
#  'cif_mp-1019609_Cs2Sr2Li3B3(PO4)6.cif',
#  'cif_mp-1019740_GaB3N4.cif',
#  'cif_mp-1019743_Ga3BN4.cif',
#  'cif_mp-1019788_K4Al3(SiO4)3.cif',
#  'cif_mp-1019799_K8NO3.cif',
#  'cif_mp-1019800_K8N3O.cif',
#  'cif_mp-1019801_K8PO3.cif',
#  'cif_mp-10198_Mn3PdN.cif',
#  'cif_mp-1020020_Li8NO3.cif',
#  'cif_mp-1020029_Li8PO3.cif',
#  'cif_mp-1020032_Li8N3O.cif',
#  'cif_mp-1020147_Na2Mg2P3NO9.cif',
#  'cif_mp-1020578_Sr4S3O.cif',
#  'cif_mp-1020590_Na8N3O.cif',
#  'cif_mp-1020591_Rb8NO3.cif',
#  'cif_mp-1020595_Rb8PO3.cif',
#  'cif_mp-1020625_Rb8N3O.cif',
#  'cif_mp-1020633_RbMgBO3.cif',
#  'cif_mp-1020638_Na8PO3.cif',
#  'cif_mp-1020645_Na8NO3.cif',
#  'cif_mp-1020_TaRh3.cif',
#  'cif_mp-1021489_IrO3.cif',
#  'cif_mp-1021503_SiO2.cif',
#  'cif_mp-1021666_AlSi.cif',
#  'cif_mp-1021667_IClO3.cif',
#  'cif_mp-1021668_In3Sb.cif',
#  'cif_mp-1022721_AlCu.cif',
#  'cif_mp-10229_Nb3Si.cif',
#  'cif_mp-1023127_Ba4Cu3PbO9.cif',
#  'cif_mp-1023920_Mg3NbO4.cif',
#  'cif_mp-1024033_Mg3SnO4.cif',
#  'cif_mp-1024034_SrMg3O4.cif',
#  'cif_mp-1024035_RbMg3O4.cif',
#  'cif_mp-1024036_Mg3SiO4.cif',
#  'cif_mp-1024037_NaMg3O4.cif',
#  'cif_mp-1024038_CeMg3O4.cif',
#  'cif_mp-1024039_Mg3AlO4.cif',
#  'cif_mp-1024040_BaMg3O4.cif',
#  'cif_mp-1024043_CaMg3O4.cif',
#  'cif_mp-1024044_Mg3CrO4.cif',
#  'cif_mp-1024045_Mg3ZnO4.cif',
#  'cif_mp-1024046_YMg3O4.cif',
#  'cif_mp-1024068_Mg3VO4.cif',
#  'cif_mp-10250_BaLiF3.cif',
#  'cif_mp-1025192_Ta4C3.cif',
#  'cif_mp-1025397_GeRu.cif',
#  'cif_mp-1025551_GaPt.cif',
#  'cif_mp-10266_ZnFe3C.cif',
#  'cif_mp-10274_Er3GaC.cif',
#  'cif_mp-10275_Er3InC.cif',
#  'cif_mp-10279_Ho3GaC.cif',
#  'cif_mp-1027_HfRh3.cif',
#  'cif_mp-10280_Nd3GaC.cif',
#  'cif_mp-1029265_Mg2ZnN2.cif',
#  'cif_mp-1029502_Ba(NbN2)2.cif',
#  'cif_mp-1029505_Ba(MoN2)2.cif',
#  'cif_mp-1029517_Li7BiN4.cif',
#  'cif_mp-1029522_Li7SbN4.cif',
#  'cif_mp-1029568_Ba(CrN2)2.cif',
#  'cif_mp-1029616_Ba(TaN2)2.cif',
#  'cif_mp-1029619_Ba(ReN2)2.cif',
#  'cif_mp-1029918_Ba(VN2)2.cif',
#  'cif_mp-1030618_Mg3ZrO4.cif',
#  'cif_mp-1030631_Mg3MnO4.cif',
#  'cif_mp-1030635_LaMg3O4.cif',
#  'cif_mp-1030636_Mg3TiO4.cif',
#  'cif_mp-1031_GdCd.cif',
#  'cif_mp-1033_BeNi.cif',
#  'cif_mp-10351_Tm3GaC.cif',
#  'cif_mp-10356_Ho3InC.cif',
#  'cif_mp-10373_Cr3PdN.cif',
#  'cif_mp-10376_Cr3SnN.cif',
#  'cif_mp-1038814_MgCd.cif',
#  'cif_mp-1038832_Mg3Cd.cif',
#  'cif_mp-1038837_CeMg3.cif',
#  'cif_mp-1038879_Ca3Zn.cif',
#  'cif_mp-1038934_MgAl.cif',
#  'cif_mp-1039073_Mg3Bi.cif',
#  'cif_mp-1039106_SnBi.cif',
#  'cif_mp-1039147_CaZn.cif',
#  'cif_mp-1039148_CaMg.cif',
#  'cif_mp-1039154_MgBi.cif',
#  'cif_mp-1039365_CeMg.cif',
#  'cif_mp-1040464_NaOsO3.cif',
#  'cif_mp-1040467_RbOsO3.cif',
#  'cif_mp-1040469_KMoO3.cif',
#  'cif_mp-1040471_NaMoO3.cif',
#  'cif_mp-1040472_KWO3.cif',
#  'cif_mp-10413_AgB(CN)4.cif',
#  'cif_mp-1044_UIr3.cif',
#  'cif_mp-1053_NdZn.cif',
#  'cif_mp-10554_Ca3TlN.cif',
#  'cif_mp-1056900_IN.cif',
#  'cif_mp-1056920_CsI.cif',
#  'cif_mp-1057125_KS.cif',
#  'cif_mp-1057486_CsS.cif',
#  'cif_mp-1057750_RbS.cif',
#  'cif_mp-1058151_NCl.cif',
#  'cif_mp-1058159_NaS.cif',
#  'cif_mp-1058331_CsSe.cif',
#  'cif_mp-1058798_LiBe.cif',
#  'cif_mp-1059160_BrN.cif',
#  'cif_mp-1059242_ClO.cif',
#  'cif_mp-1059707_CaNi.cif',
#  'cif_mp-1059879_CsN.cif',
#  'cif_mp-1059_NdCd.cif',
#  'cif_mp-10600_La3AlC.cif',
#  'cif_mp-10602_Sm3GaC.cif',
#  'cif_mp-10606_Sm3TlC.cif',
#  'cif_mp-10607_Lu3TlC.cif',
#  'cif_mp-1060962_TlC.cif',
#  'cif_mp-1060967_AgBr.cif',
#  'cif_mp-10609_Lu3SnC.cif',
#  'cif_mp-1061123_TiAl.cif',
#  'cif_mp-1061395_Na2O2.cif',
#  'cif_mp-10627_SrS.cif',
#  'cif_mp-1062_CeMg.cif',
#  'cif_mp-10632_TlS.cif',
#  'cif_mp-1063661_MgNi3.cif',
#  'cif_mp-10637_ThSb.cif',
#  'cif_mp-1064000_Cs3Pt.cif',
#  'cif_mp-1064161_NaN3.cif',
#  'cif_mp-1064282_InC3.cif',
#  'cif_mp-1064459_PBr.cif',
#  'cif_mp-1064508_K3Pd.cif',
#  'cif_mp-10646_ThSe.cif',
#  'cif_mp-10647_TlSe.cif',
#  'cif_mp-1064861_GaC3.cif',
#  'cif_mp-10652_SmTe.cif',
#  'cif_mp-10653_SrTe.cif',
#  'cif_mp-1065428_Rb3Re.cif',
#  'cif_mp-1065540_AlC3.cif',
#  'cif_mp-1065741_NbFe3.cif',
#  'cif_mp-1065783_LaRh3.cif',
#  'cif_mp-10666_Mn3AgN.cif',
#  'cif_mp-1066774_Rb3Os.cif',
#  'cif_mp-1067129_VC3.cif',
#  'cif_mp-1067281_Rb3Pt.cif',
#  'cif_mp-10674_Sm3AlN.cif',
#  'cif_mp-1067833_SnI3.cif',
#  'cif_mp-1068011_SrAlH3.cif',
#  'cif_mp-10680_BaSe.cif',
#  'cif_mp-1068212_Fe2O3.cif',
#  'cif_mp-1068389_SnCCl3.cif',
#  'cif_mp-10683_Ca.cif',
#  'cif_mp-10684_CaTe.cif',
#  'cif_mp-1068577_ZrPbO3.cif',
#  'cif_mp-1068746_TlHPd3.cif',
#  'cif_mp-1068795_NiNF3.cif',
#  'cif_mp-1069129_MnNCl3.cif',
#  'cif_mp-1069166_MnNF3.cif',
#  'cif_mp-1069270_ZnNi3N.cif',
#  'cif_mp-1069273_Gd3AlN.cif',
#  'cif_mp-10692_CoGe.cif',
#  'cif_mp-1069346_PrVO3.cif',
#  'cif_mp-1069526_Ce3InC.cif',
#  'cif_mp-1069538_CsPbI3.cif',
#  'cif_mp-1069774_UBRh3.cif',
#  'cif_mp-10699_LuRh3C.cif',
#  'cif_mp-1070242_Mn3CuN.cif',
#  'cif_mp-1070375_CsSnCl3.cif',
#  'cif_mp-1070440_VPbO3.cif',
#  'cif_mp-10706_ZrRu3C.cif',
#  'cif_mp-1070713_InNi3N.cif',
#  'cif_mp-1070737_K3CO.cif',
#  'cif_mp-10708_PrRh3C.cif',
#  'cif_mp-10712_ScRh3C.cif',
#  'cif_mp-10714_TmRh3C.cif',
#  'cif_mp-10718_Sm3SnC.cif',
#  'cif_mp-10720_ThC2.cif',
#  'cif_mp-1072852_CdB2.cif',
#  'cif_mp-10729_Pd2O.cif',
#  'cif_mp-10732_ThTaN3.cif',
#  'cif_mp-10735_Zr2O.cif',
#  'cif_mp-1073_CaCd.cif',
#  'cif_mp-10748_TaCu3S4.cif',
#  'cif_mp-1074_RbSi.cif',
#  'cif_mp-1075902_EuCuO3.cif',
#  'cif_mp-1075904_EuFeO3.cif',
#  'cif_mp-1075911_RbNbO3.cif',
#  'cif_mp-1075921_LaNiO3.cif',
#  'cif_mp-1075922_Sr7CaTi8O24.cif',
#  'cif_mp-1075933_SmAgO3.cif',
#  'cif_mp-1075973_SmMnO3.cif',
#  'cif_mp-1075975_EuCoO3.cif',
#  'cif_mp-1076000_LaAgO3.cif',
#  'cif_mp-1076070_LaCuO3.cif',
#  'cif_mp-1076128_Ca7Mg(CoO3)8.cif',
#  'cif_mp-1076131_La7SmV8O24.cif',
#  'cif_mp-10762_Cd3As2.cif',
#  'cif_mp-1076317_MgCuO3.cif',
#  'cif_mp-1076360_RbCrO3.cif',
#  'cif_mp-1076368_MgFeO3.cif',
#  'cif_mp-1076382_La7Sm(FeO3)8.cif',
#  'cif_mp-1076445_Sr8MnFe7O24.cif',
#  'cif_mp-1076485_Ca7MgMn8O24.cif',
#  'cif_mp-1076534_RbTaO3.cif',
#  'cif_mp-1076633_KVO3.cif',
#  'cif_mp-1076638_RbVO3.cif',
#  'cif_mp-1076642_NaCrO3.cif',
#  'cif_mp-1076706_SmCuO3.cif',
#  'cif_mp-1076732_KCrO3.cif',
#  'cif_mp-1076782_BaCoO3.cif',
#  'cif_mp-1076800_BaCuO3.cif',
#  'cif_mp-1076927_GdPb3.cif',
#  'cif_mp-1076_KB6.cif',
#  'cif_mp-1077045_Ti2H.cif',
#  'cif_mp-1077622_EuAgO3.cif',
#  'cif_mp-1077660_Sr8Fe7CoO24.cif',
#  'cif_mp-1078464_MnGe.cif',
#  'cif_mp-1078554_KNa3H4.cif',
#  'cif_mp-1078558_NaCl3.cif',
#  'cif_mp-1078597_ZnCd3Se4.cif',
#  'cif_mp-1078643_RbNa3H4.cif',
#  'cif_mp-1078780_ZnCd3S4.cif',
#  'cif_mp-1078915_Ba3CaO4.cif',
#  'cif_mp-1079034_Zn3CdSe4.cif',
#  'cif_mp-1079228_Ga4BiAs3.cif',
#  'cif_mp-1079248_K3NaH4.cif',
#  'cif_mp-1079399_V3Fe.cif',
#  'cif_mp-1079533_CrCd3Te4.cif',
#  'cif_mp-1079594_Ca3ZnSe4.cif',
#  'cif_mp-1079689_Tl3Pt.cif',
#  'cif_mp-1079702_Cr3GaP4.cif',
#  'cif_mp-1079788_Sr4SO3.cif',
#  'cif_mp-1079796_Ti3Pd.cif',
#  'cif_mp-1079882_Ba3SrO4.cif',
#  'cif_mp-1079910_SiTc.cif',
#  'cif_mp-1079914_HfSb.cif',
#  'cif_mp-1079940_Sr3CaO4.cif',
#  'cif_mp-1079947_Pd3N.cif',
#  'cif_mp-1080016_Tl3Ir.cif',
#  'cif_mp-1080187_MnHgO3.cif',
#  'cif_mp-1080300_CeSe2.cif',
#  'cif_mp-1080375_CeSe2.cif',
#  'cif_mp-1080476_FeH3.cif',
#  'cif_mp-1080569_Tl3Au.cif',
#  'cif_mp-1080659_OsC.cif',
#  'cif_mp-1080726_Zn3CrS4.cif',
#  'cif_mp-1080771_NaCl7.cif',
#  'cif_mp-1080799_CuNF3.cif',
#  'cif_mp-1080847_Mg3SbN.cif',
#  'cif_mp-1080852_CeSe2.cif',
#  'cif_mp-1080865_CeSe2.cif',
#  'cif_mp-1082_VIr3.cif',
#  'cif_mp-10844_Te2Ir.cif',
#  'cif_mp-1084771_Be3P2.cif',
#  'cif_mp-1084796_CaZn3Se4.cif',
#  'cif_mp-10848_AsPdS.cif',
#  'cif_mp-10850_SbTePd.cif',
#  'cif_mp-10871_AlAu.cif',
#  'cif_mp-1087545_Zn3CrTe4.cif',
#  'cif_mp-10879_CeAl.cif',
#  'cif_mp-10890_LiAl3.cif',
#  'cif_mp-1089_TiIr3.cif',
#  'cif_mp-10902_PrAl.cif',
#  'cif_mp-10903_AlPt.cif',
#  'cif_mp-10904_AlPt.cif',
#  'cif_mp-10908_AlRe.cif',
#  'cif_mp-1092_HoHg.cif',
#  'cif_mp-1094009_YAgO3.cif',
#  'cif_mp-1094049_SnB6.cif',
#  'cif_mp-1094056_Si7Ge.cif',
#  'cif_mp-1094072_Pr3AlN.cif',
#  'cif_mp-1094082_Ni4O.cif',
#  'cif_mp-1094084_Ni4N3.cif',
#  'cif_mp-1094085_Nd3SnN.cif',
#  'cif_mp-1094090_Ni4N.cif',
#  'cif_mp-1094094_Ni5O4.cif',
#  'cif_mp-1094096_Ni4O3.cif',
#  'cif_mp-1094101_Nd3PbN.cif',
#  'cif_mp-1094118_Mn3InC.cif',
#  'cif_mp-1094669_MgSn.cif',
#  'cif_mp-1094670_LiMg3.cif',
#  'cif_mp-1094705_YSn.cif',
#  'cif_mp-1094724_Mg3Sb.cif',
#  'cif_mp-1094726_MgTi.cif',
#  'cif_mp-1094731_SrMg3.cif',
#  'cif_mp-1094743_MgZr.cif',
#  'cif_mp-1094768_MgZr3.cif',
#  'cif_mp-1094769_Y3Mg.cif',
#  'cif_mp-1094779_MgZn.cif',
#  'cif_mp-1094786_Sr3Mg.cif',
#  'cif_mp-1094791_Mg3Zn.cif',
#  'cif_mp-1094792_Mg3Zr.cif',
#  'cif_mp-1094802_MgSn3.cif',
#  'cif_mp-1094839_MgCd3.cif',
#  'cif_mp-1094849_MgGa.cif',
#  'cif_mp-1094857_Ca3Mg.cif',
#  'cif_mp-1094867_MgZn3.cif',
#  'cif_mp-1094874_ZrSn.cif',
#  'cif_mp-1094889_LiMg.cif',
#  'cif_mp-1094904_Ce3Mg.cif',
#  'cif_mp-1094922_CaMg3.cif',
#  'cif_mp-1094958_HfMg3.cif',
#  'cif_mp-1094967_MgSb.cif',
#  'cif_mp-1094969_MgGa3.cif',
#  'cif_mp-1094980_CaZn3.cif',
#  'cif_mp-1094990_HfMg.cif',
#  'cif_mp-1095028_Zn3CrSe4.cif',
#  'cif_mp-1095030_BC7.cif',
#  'cif_mp-1095176_Rb3NaH4.cif',
#  'cif_mp-1095177_SiNi.cif',
#  'cif_mp-1095224_PtO2.cif',
#  'cif_mp-1095264_OsO2.cif',
#  'cif_mp-1095440_CdS2.cif',
#  'cif_mp-1095493_CdSe2.cif',
#  'cif_mp-1095507_SbIrSe.cif',
#  'cif_mp-1095551_K8AsO3.cif',
#  'cif_mp-1095618_PtN2.cif',
#  'cif_mp-1095638_LiMgIr.cif',
#  'cif_mp-1096764_Ca3SbP.cif',
#  'cif_mp-1096779_Ba4Ce(CuO3)3.cif',
#  'cif_mp-1096797_HgB6.cif',
#  'cif_mp-1096800_LaScO3.cif',
#  'cif_mp-1096825_B6Pb.cif',
#  'cif_mp-1096836_Ba3SnS4.cif',
#  'cif_mp-1096844_BiB6.cif',
#  'cif_mp-1096854_Ca3As2.cif',
#  'cif_mp-1096856_Ca3AsP.cif',
#  'cif_mp-1096862_CdHCl3.cif',
#  'cif_mp-1096919_CrN2.cif',
#  'cif_mp-1096944_CsNbO3.cif',
#  'cif_mp-1097006_KAlH3.cif',
#  'cif_mp-1097026_LaGaO3.cif',
#  'cif_mp-1099244_Mg3WO4.cif',
#  'cif_mp-1099245_Mg3FeO4.cif',
#  'cif_mp-1099246_Mg3BiO4.cif',
#  'cif_mp-1099248_Mg3CO4.cif',
#  'cif_mp-1099249_Mg3CuO4.cif',
#  'cif_mp-1099250_Mg3MoO4.cif',
#  'cif_mp-1099251_Mg3GaO4.cif',
#  'cif_mp-1099252_Mg3SbO4.cif',
#  'cif_mp-1099254_Mg3CoO4.cif',
#  'cif_mp-1099255_Mg3CdO4.cif',
#  'cif_mp-1099256_Mg3BO4.cif',
#  'cif_mp-1099257_KMg3O4.cif',
#  'cif_mp-1099258_HfMg3O4.cif',
#  'cif_mp-1099259_LiMg3O4.cif',
#  'cif_mp-1099583_SmTiO3.cif',
#  'cif_mp-1099588_SmFeO3.cif',
#  'cif_mp-1099591_NaVO3.cif',
#  'cif_mp-1099619_EuMnO3.cif',
#  'cif_mp-1099664_KNa7V8O24.cif',
#  'cif_mp-1099685_BaSr7(FeO3)8.cif',
#  'cif_mp-1099778_BaSr7Ti8O24.cif',
#  'cif_mp-1099824_Ba7Sr(CuO3)8.cif',
#  'cif_mp-1099873_CaCuO3.cif',
#  'cif_mp-1099881_Sr2TiMnO6.cif',
#  'cif_mp-1099923_La7SmMn8O24.cif',
#  'cif_mp-1099934_CaCoO3.cif',
#  'cif_mp-1100771_TiTl3.cif',
#  'cif_mp-1100773_Y3Cd.cif',
#  'cif_mp-1100774_U3N.cif',
#  'cif_mp-1100775_SrEuO3.cif',
#  'cif_mp-1100776_ZnBi3.cif',
#  'cif_mp-1100777_VTeO3.cif',
#  'cif_mp-1100778_ZnCuO3.cif',
#  'cif_mp-1100784_U3In.cif',
#  'cif_mp-1101333_SrNdO3.cif',
#  'cif_mp-1101336_TbCeO4.cif',
#  'cif_mp-1101666_NaFe5O8.cif',
#  'cif_mp-1101717_PrHfO4.cif',
#  'cif_mp-1101754_Ti4H7.cif',
#  'cif_mp-1101765_BiRhSe.cif',
#  'cif_mp-1101820_MgTi3H8.cif',
#  'cif_mp-1101823_Cd(N2O3)2.cif',
#  'cif_mp-1101846_Mg3TiH8.cif',
#  'cif_mp-1101868_AuN2.cif',
#  'cif_mp-1101912_BaSiPt.cif',
#  'cif_mp-1101930_MgO.cif',
#  'cif_mp-1101975_WN2.cif',
#  'cif_mp-1102002_FeTe2.cif',
#  'cif_mp-1102038_MgH2.cif',
#  'cif_mp-1102074_OsN2.cif',
#  'cif_mp-1102114_TaN2.cif',
#  'cif_mp-1102124_Na8BiO3.cif',
#  'cif_mp-1102140_NdSiIr.cif',
#  'cif_mp-1102163_Li8AsO3.cif',
#  'cif_mp-1102170_CrO2.cif',
#  'cif_mp-1102223_K8SbO3.cif',
#  'cif_mp-1102232_HCN.cif',
#  'cif_mp-1102235_IrN2.cif',
#  'cif_mp-1102261_IrS2.cif',
#  'cif_mp-1102284_SbPdS.cif',
#  'cif_mp-1102324_NiTe2.cif',
#  'cif_mp-1102366_SbRhSe.cif',
#  'cif_mp-1102429_HfN2.cif',
#  'cif_mp-1102430_SbTeIr.cif',
#  'cif_mp-1102443_CoSbS.cif',
#  'cif_mp-1102444_UC2.cif',
#  'cif_mp-1102515_ZnSe2.cif',
#  'cif_mp-1102531_PRhSe.cif',
#  'cif_mp-1102539_Na8SbO3.cif',
#  'cif_mp-1102584_Ca4Mg4Fe3.cif',
#  'cif_mp-1102591_TiO2.cif',
#  'cif_mp-1102609_BaSiPd.cif',
#  'cif_mp-1102647_NaC2.cif',
#  'cif_mp-1102668_CrSbPt.cif',
#  'cif_mp-11026_Rb3Hg20.cif',
#  'cif_mp-1102707_FeSbPt.cif',
#  'cif_mp-1102716_Li8SbO3.cif',
#  'cif_mp-1102743_ZnS2.cif',
#  'cif_mp-1102773_K8BiO3.cif',
#  'cif_mp-11027_Cs3Hg20.cif',
#  'cif_mp-1102811_SiC2.cif',
#  'cif_mp-1102836_BiIrS.cif',
#  'cif_mp-1102845_TiS2.cif',
#  'cif_mp-1102850_SbPtS.cif',
#  'cif_mp-1102865_Li8BiO3.cif',
#  'cif_mp-1102981_Rb8SbO3.cif',
#  'cif_mp-1102998_Na8AsO3.cif',
#  'cif_mp-1103017_NiBiSe.cif',
#  'cif_mp-1103058_Rb8AsO3.cif',
#  'cif_mp-1103098_BiRhS.cif',
#  'cif_mp-1103155_LaSiRh.cif',
#  'cif_mp-1103177_FeSe2.cif',
#  'cif_mp-1103210_EuMgNi.cif',
#  'cif_mp-1103228_BiIrSe.cif',
#  'cif_mp-1103235_CuTe2.cif',
#  'cif_mp-1103284_Rb8BiO3.cif',
#  'cif_mp-1103317_SbRhS.cif',
#  'cif_mp-1103420_ReN2.cif',
#  'cif_mp-1103427_PdN2.cif',
#  'cif_mp-1103513_Li3(Mg2Si)4.cif',
#  'cif_mp-1103521_Sr8Rh5.cif',
#  'cif_mp-1103590_MgSe2.cif',
#  'cif_mp-1103943_ErGa3Ru.cif',
#  'cif_mp-1104461_TbGa3Ru.cif',
#  'cif_mp-1104503_YGa3Ru.cif',
#  'cif_mp-1104547_HoGa3Ru.cif',
#  'cif_mp-1104791_Li(Mg2Si)4.cif',
#  'cif_mp-1104_LaMg.cif',
#  'cif_mp-1105018_Al2O3.cif',
#  'cif_mp-1105019_DyGa3Ru.cif',
#  'cif_mp-1105290_Co3Sb4(OF)6.cif',
#  'cif_mp-1105641_InHO2.cif',
#  'cif_mp-1105655_C3N2.cif',
#  'cif_mp-1105932_Li2MgSi.cif',
#  'cif_mp-1106349_SmPd3S4.cif',
#  'cif_mp-1110791_RbAuCl3.cif',
#  'cif_mp-1110854_KAuCl3.cif',
#  'cif_mp-1110999_RbAuBr3.cif',
#  'cif_mp-1111644_RbAuF3.cif',
#  'cif_mp-1111868_KAuF3.cif',
#  'cif_mp-1112174_KAuBr3.cif',
#  'cif_mp-1112985_CsAuF3.cif',
#  'cif_mp-1112987_CsAuBr3.cif',
#  'cif_mp-1120716_CdHg3Te4.cif',
#  'cif_mp-1120717_V3Bi.cif',
#  'cif_mp-1120718_MgZn3S4.cif',
#  'cif_mp-1120722_CuO.cif',
#  'cif_mp-1120765_BaNiO3.cif',
#  'cif_mp-1120777_NaTiF3.cif',
#  'cif_mp-1120_Mo3Ir.cif',
#  'cif_mp-1121_GaCo.cif',
#  'cif_mp-11221_SmAl.cif',
#  'cif_mp-11222_Sm3Al.cif',
#  'cif_mp-11224_Sr8Al7.cif',
#  'cif_mp-11229_YAl.cif',
#  'cif_mp-11231_YAl3.cif',
#  'cif_mp-11237_ScAg.cif',
#  'cif_mp-11240_DyAu.cif',
#  'cif_mp-11245_HoAu.cif',
#  'cif_mp-11248_LiAu3.cif',
#  'cif_mp-11249_LuAu.cif',
#  'cif_mp-11254_NdAu.cif',
#  'cif_mp-11255_PrAu.cif',
#  'cif_mp-11256_ScAu.cif',
#  'cif_mp-11257_SmAu.cif',
#  'cif_mp-11258_TbAu.cif',
#  'cif_mp-11259_TiAu.cif',
#  'cif_mp-11260_Ti3Au.cif',
#  'cif_mp-11261_YAu.cif',
#  'cif_mp-11271_BeMo3.cif',
#  'cif_mp-11274_BePd.cif',
#  'cif_mp-11276_BeRh.cif',
#  'cif_mp-11279_TiBe.cif',
#  'cif_mp-11286_CaHg.cif',
#  'cif_mp-11290_CaSn3.cif',
#  'cif_mp-1129_ScIr.cif',
#  'cif_mp-11309_NbCd3.cif',
#  'cif_mp-11312_V3Cd.cif',
#  'cif_mp-11334_W.cif',
#  'cif_mp-11364_TiCu.cif',
#  'cif_mp-11365_Ti3Cu.cif',
#  'cif_mp-11370_ErIn.cif',
#  'cif_mp-11372_ErSn3.cif',
#  'cif_mp-11374_DyTl.cif',
#  'cif_mp-11375_EuHg.cif',
#  'cif_mp-11388_GaIr.cif',
#  'cif_mp-1139958_LiY(TlCl3)2.cif',
#  'cif_mp-11407_GaPt3.cif',
#  'cif_mp-11418_TbGa3.cif',
#  'cif_mp-11422_GdHg.cif',
#  'cif_mp-11447_UTe.cif',
#  'cif_mp-11452_HfOs.cif',
#  'cif_mp-11455_HfPt.cif',
#  'cif_mp-11457_HfRh.cif',
#  'cif_mp-11460_HfTc.cif',
#  'cif_mp-11467_NdHg.cif',
#  'cif_mp-11469_PrHg.cif',
#  'cif_mp-11471_ScHg.cif',
#  'cif_mp-11473_TlHg.cif',
#  'cif_mp-11474_TlHg3.cif',
#  'cif_mp-1147577_GdCrO3.cif',
#  'cif_mp-11475_TmHg.cif',
#  'cif_mp-1147612_Mg(CuN)3.cif',
#  'cif_mp-1147638_CsVC6.cif',
#  'cif_mp-1147651_SnAu.cif',
#  'cif_mp-1147653_CaCu3O4.cif',
#  'cif_mp-1147655_Ba4Cu3SnO9.cif',
#  'cif_mp-1147674_Li(CuN)3.cif',
#  'cif_mp-1147675_Rh3Cl4.cif',
#  'cif_mp-1147682_CsNbC6.cif',
#  'cif_mp-1147699_Ba4Ti(CuO3)3.cif',
#  'cif_mp-11476_HoIr.cif',
#  'cif_mp-1147701_Cu3NF3.cif',
#  'cif_mp-1147702_Li(CuO)3.cif',
#  'cif_mp-1147710_CsPdCl3.cif',
#  'cif_mp-1147716_CsMoC6.cif',
#  'cif_mp-1147731_In(CuN)3.cif',
#  'cif_mp-1147740_Pt3Cl3F.cif',
#  'cif_mp-1147742_CsCrC6.cif',
#  'cif_mp-1147771_Al(CuN)3.cif',
#  'cif_mp-11477_HoSn3.cif',
#  'cif_mp-11478_GaAg.cif',
#  'cif_mp-11483_TmIr.cif',
#  'cif_mp-11484_ZrIr.cif',
#  'cif_mp-11487_LaPt3.cif',
#  'cif_mp-11488_LaTl.cif',
#  'cif_mp-11495_LuRu.cif',
#  'cif_mp-11496_LuZn.cif',
#  'cif_mp-11498_MgTl.cif',
#  'cif_mp-11503_MnZn.cif',
#  'cif_mp-1150_URh3.cif',
#  'cif_mp-11516_NbRu.cif',
#  'cif_mp-11521_ScNi.cif',
#  'cif_mp-1152_TiRh3.cif',
#  'cif_mp-11536_NpRh3.cif',
#  'cif_mp-11541_ZrOs.cif',
#  'cif_mp-11546_TiPd.cif',
#  'cif_mp-11552_TiPt.cif',
#  'cif_mp-11554_ZrPt.cif',
#  'cif_mp-11555_PuRu.cif',
#  'cif_mp-11561_TbRh.cif',
#  'cif_mp-11563_TiRh.cif',
#  'cif_mp-11564_TmRh.cif',
#  'cif_mp-11566_ScZn.cif',
#  'cif_mp-11568_SmTl.cif',
#  'cif_mp-11569_SmTl3.cif',
#  'cif_mp-11570_TbSn3.cif',
#  'cif_mp-11571_YSn3.cif',
#  'cif_mp-11572_TaTc.cif',
#  'cif_mp-11573_TiTc.cif',
#  'cif_mp-11575_YTl.cif',
#  'cif_mp-1158_LuPd3.cif',
#  'cif_mp-1169_ScCu.cif',
#  'cif_mp-1172909_BeCl2.cif',
#  'cif_mp-1172_MgRh.cif',
#  'cif_mp-11733_Lu3InN.cif',
#  'cif_mp-1174_MgSc.cif',
#  'cif_mp-1176363_Na2Sb3O8.cif',
#  'cif_mp-1176709_LiFeF3.cif',
#  'cif_mp-1177863_Li2Ti3FeO8.cif',
#  'cif_mp-1177906_Li2Ti3CoO8.cif',
#  'cif_mp-1177935_Li2Mn3CoO8.cif',
#  'cif_mp-1177962_Li2Fe3SnO8.cif',
#  'cif_mp-1177997_Li2Fe3BiO8.cif',
#  'cif_mp-1178248_HfZrO4.cif',
#  'cif_mp-1178268_GdAlO3.cif',
#  'cif_mp-1178354_EuZrO3.cif',
#  'cif_mp-1178500_CeHfO4.cif',
#  'cif_mp-1178510_BaPdO3.cif',
#  'cif_mp-1178641_ZnCu3NiSe4.cif',
#  'cif_mp-1178642_ZnCoCu3Se4.cif',
#  'cif_mp-1178643_ZnCrCu3Se4.cif',
#  'cif_mp-1178644_ZnGaCu3Se4.cif',
#  'cif_mp-1178645_ZnInCu3Se4.cif',
#  'cif_mp-1178697_YCu3PbSe4.cif',
#  'cif_mp-1178705_YMgCu3Se4.cif',
#  'cif_mp-1178710_YCu3HgSe4.cif',
#  'cif_mp-1178729_YCdCu3Se4.cif',
#  'cif_mp-1178753_VZnCu3Se4.cif',
#  'cif_mp-1178804_VCu3HgSe4.cif',
#  'cif_mp-1178806_VCdCu3Se4.cif',
#  'cif_mp-1178824_VCu3PbSe4.cif',
#  'cif_mp-1178984_TlZnCu3Se4.cif',
#  'cif_mp-1178991_Ti4(SiO8)3.cif',
#  'cif_mp-1179003_SrYCu3Se4.cif',
#  'cif_mp-1179014_SrVCu3Se4.cif',
#  'cif_mp-1179021_TlCdCu3Se4.cif',
#  'cif_mp-1179028_TlCu3PbSe4.cif',
#  'cif_mp-1179060_SrTlCu3Se4.cif',
#  'cif_mp-1179075_SrScCu3Se4.cif',
#  'cif_mp-1179109_TeC6(I3N)2.cif',
#  'cif_mp-1179118_SrGaCu3Se4.cif',
#  'cif_mp-1179119_SrInCu3Se4.cif',
#  'cif_mp-1179135_ScZnCu3Se4.cif',
#  'cif_mp-1179138_SrCu3NiSe4.cif',
#  'cif_mp-1179142_SrCoCu3Se4.cif',
#  'cif_mp-1179174_SrAlCu3Se4.cif',
#  'cif_mp-1179510_ScCdCu3Se4.cif',
#  'cif_mp-1179516_ScCu3HgSe4.cif',
#  'cif_mp-1179525_ScCu3PbSe4.cif',
#  'cif_mp-1179676_RbZrCu3Se4.cif',
#  'cif_mp-1179694_RbVCu3Se4.cif',
#  'cif_mp-1179697_RbTiCu3Se4.cif',
#  'cif_mp-1179714_RbMnCu3Se4.cif',
#  'cif_mp-1179715_RbHfCu3Se4.cif',
#  'cif_mp-1179749_RbCu3GeSe4.cif',
#  'cif_mp-1179750_RbCoCu3Se4.cif',
#  'cif_mp-1179752_RbCu3SnSe4.cif',
#  'cif_mp-1179753_RbCu3SiSe4.cif',
#  'cif_mp-1179805_RbCr(SO10)2.cif',
#  'cif_mp-1179860_NaCu3SnSe4.cif',
#  'cif_mp-1179864_NaMnCu3Se4.cif',
#  'cif_mp-1179880_NaCu3GeSe4.cif',
#  'cif_mp-1179888_NaCu3PbSe4.cif',
#  'cif_mp-1179889_NaCoCu3Se4.cif',
#  'cif_mp-1179901_NaCu3NiSe4.cif',
#  'cif_mp-1180005_NaCr(SO10)2.cif',
#  'cif_mp-1180089_NaZrCu3Se4.cif',
#  'cif_mp-1180113_NaVCu3Se4.cif',
#  'cif_mp-1180119_NaTiCu3Se4.cif',
#  'cif_mp-1180276_MgVCu3Se4.cif',
#  'cif_mp-1180283_MgGaCu3Se4.cif',
#  'cif_mp-1180284_MgCu3NiSe4.cif',
#  'cif_mp-1180289_MgCrCu3Se4.cif',
#  'cif_mp-1180309_Mn2Al3.cif',
#  'cif_mp-1180322_MgCoCu3Se4.cif',
#  'cif_mp-1180325_MgTlCu3Se4.cif',
#  'cif_mp-1180332_MgAlCu3Se4.cif',
#  'cif_mp-1180537_NiH12(ClO6)2.cif',
#  'cif_mp-1180545_NaAl(SO10)2.cif',
#  'cif_mp-1180619_Li2O2.cif',
#  'cif_mp-1180674_KZrCu3Se4.cif',
#  'cif_mp-1180688_KTiCu3Se4.cif',
#  'cif_mp-1180689_KVCu3Se4.cif',
#  'cif_mp-1180796_KCu3SnSe4.cif',
#  'cif_mp-1180804_KCoCu3Se4.cif',
#  'cif_mp-1180817_KCu3NiSe4.cif',
#  'cif_mp-1180832_KMnCu3Se4.cif',
#  'cif_mp-1180842_KCu3GeSe4.cif',
#  'cif_mp-1180844_KCu3SiSe4.cif',
#  'cif_mp-1180884_KHfCu3Se4.cif',
#  'cif_mp-1180900_KCu3PbSe4.cif',
#  'cif_mp-1180995_InCu3HgSe4.cif',
#  'cif_mp-1181191_KAl(SO10)2.cif',
#  'cif_mp-1181291_Ge7O23.cif',
#  'cif_mp-1181331_GaCu3HgSe4.cif',
#  'cif_mp-1181468_Cu3NiHgSe4.cif',
#  'cif_mp-1181478_Ni2Mo3N.cif',
#  'cif_mp-1181558_CsZrCu3Se4.cif',
#  'cif_mp-1181577_CsTiCu3Se4.cif',
#  'cif_mp-1181585_CsHfCu3Se4.cif',
#  'cif_mp-1181597_CsCu3GeSe4.cif',
#  'cif_mp-1181613_Cu3NiPbSe4.cif',
#  'cif_mp-1181644_NaCo(N2O3)4.cif',
#  'cif_mp-1181705_Cu3SnAu.cif',
#  'cif_mp-1181713_CrCdCu3Se4.cif',
#  'cif_mp-1181716_CrCu3HgSe4.cif',
#  'cif_mp-1181720_CrCu3PbSe4.cif',
#  'cif_mp-1181785_CoCu3HgSe4.cif',
#  'cif_mp-1181852_CaTlCu3Se4.cif',
#  'cif_mp-1181874_CdGaCu3Se4.cif',
#  'cif_mp-1181876_LaAl(NO4)6.cif',
#  'cif_mp-1181879_CdCu3NiSe4.cif',
#  'cif_mp-1181881_CdCoCu3Se4.cif',
#  'cif_mp-1181925_CaScCu3Se4.cif',
#  'cif_mp-1181927_CaYCu3Se4.cif',
#  'cif_mp-1181943_CaVCu3Se4.cif',
#  'cif_mp-1181967_CaCu3NiSe4.cif',
#  'cif_mp-1181975_CaCoCu3Se4.cif',
#  'cif_mp-1181990_CdInCu3Se4.cif',
#  'cif_mp-1182006_CaCrCu3Se4.cif',
#  'cif_mp-1182175_BaInCu3Se4.cif',
#  'cif_mp-1182176_BaAlCu3Se4.cif',
#  'cif_mp-1182182_BaScCu3Se4.cif',
#  'cif_mp-1182227_BaGaCu3Se4.cif',
#  'cif_mp-1182239_BaCu3NiSe4.cif',
#  'cif_mp-1182240_BaTlCu3Se4.cif',
#  'cif_mp-1182242_BaYCu3Se4.cif',
#  'cif_mp-11824_Ca3PN.cif',
#  'cif_mp-1182688_CsTiH24(SO10)2.cif',
#  'cif_mp-1182706_Nb3Al2N.cif',
#  'cif_mp-1182859_AlZnCu3Se4.cif',
#  'cif_mp-1182878_AlCdCu3Se4.cif',
#  'cif_mp-1182880_AlCu3HgSe4.cif',
#  'cif_mp-1182885_AlCu4.cif',
#  'cif_mp-1182890_AlCu3PbSe4.cif',
#  'cif_mp-1182920_AlS2NO20.cif',
#  'cif_mp-1183043_ZrSiO3.cif',
#  'cif_mp-1183044_ZrTlO3.cif',
#  'cif_mp-1183045_ZrTiO3.cif',
#  'cif_mp-1183052_AcBO3.cif',
#  'cif_mp-1183053_AcGaO3.cif',
#  'cif_mp-1183056_Ac3Cl.cif',
#  'cif_mp-1183058_Ac3Zr.cif',
#  'cif_mp-1183064_Ac3Au.cif',
#  'cif_mp-1183075_Ac3Cr.cif',
#  'cif_mp-1183105_Ac3Ce.cif',
#  ...]

# %%
# cubicfilesのcif4575個を/workdir/practical-mi-guide/chapter3/input/material_projects_api_cifから/workdir/practical-mi-guide/chapter3/input/material_projects_api_cif_cubicにコピー
import shutil

for file in tqdm(cubic_files_):
    shutil.copy(f"{path}/{file}", f"../input/material_projects_api_cif_cubic/{file}")
# Out:
#   0%|          | 0/4575 [00:00<?, ?it/s]

# %%
path = '../input/material_projects_api_cif_cubic/'
files = os.listdir(path)
len(files)

x = np.arange(5,100,0.01)

# Set to use 'Agg' backend which does not display to the screen
plt.switch_backend('Agg')

for file in tqdm(files):
    struct = Structure.from_file(f"{path}/{file}")
    xrd_cond = XRDCalculator()
    xrd_calcd = xrd_cond.get_pattern(struct)
    
    calcd_x = xrd_calcd.x
    calcd_y = xrd_calcd.y
    calcd_hkls = xrd_calcd.hkls
    calcd_d = xrd_calcd.d_hkls
    
    calcd_pattern = np.zeros(len(x))
    
    N = len(calcd_x)
    for i in range(N):
        norm = calcd_y[i]
        center = calcd_x[i]
        lw = 0.05
        gw = 0.05
        params = [norm, center, lw, gw]
        calcd_pattern += voigt(x, params)
    
    figure = plt.figure(figsize=(5,3))
    ax = figure.add_subplot(111)
    
    ax.plot(x, calcd_pattern,color='red')
    
    ax.set_xlim(5, 100)
    ax.set_ylim(0, 500)
    
    ax.set_xlabel(r'2$\theta$ (deg)')
    ax.set_ylabel('Intensity (a.u.)')
    
    # 上記のfigureを保存
    plt.tight_layout()
    plt.savefig(f'../input/material_projects_maked_xrd_pattern_cubic/{file}_xrd_pattern.png',bbox_inches='tight')
    
    # x, calcd_patternをcsvで保存、xは2theta、calcd_patternはIntensity
    df = pd.DataFrame({'2theta':x, 'Intensity':calcd_pattern})
    df.to_csv(f'../input/material_projects_maked_xrd_pattern_cubic/{file}_xrd_pattern.csv', index=False)
    
    del struct, xrd_cond, xrd_calcd, calcd_x, calcd_y, calcd_hkls, calcd_d, calcd_pattern, df
    gc.collect()
# Out:
#   0%|          | 0/4575 [00:00<?, ?it/s]

# %%
files
# Out:
# ['cif_mp-1001571_CaFeO3.cif',
#  'cif_mp-10015_SiOs.cif',
#  'cif_mp-1001788_ZrB6.cif',
#  'cif_mp-1001834_HfN.cif',
#  'cif_mp-1001843_HoP.cif',
#  'cif_mp-1001844_HoN.cif',
#  'cif_mp-1001913_HoBi.cif',
#  'cif_mp-1001917_HoAs.cif',
#  'cif_mp-1001918_HfC.cif',
#  'cif_mp-1002105_VN.cif',
#  'cif_mp-1002106_HfPd.cif',
#  'cif_mp-1002109_VCo.cif',
#  'cif_mp-1002117_TcN.cif',
#  'cif_mp-1002122_HfIr.cif',
#  'cif_mp-1002183_TcB.cif',
#  'cif_mp-1002207_ReN.cif',
#  'cif_mp-1002210_EuS.cif',
#  'cif_mp-1002220_TmSb.cif',
#  'cif_mp-1002223_DyP.cif',
#  'cif_mp-1002224_ErP.cif',
#  'cif_mp-1002226_ErAs.cif',
#  'cif_mp-1002228_PtC.cif',
#  'cif_mp-1002229_ErN.cif',
#  'cif_mp-1002230_PuBi.cif',
#  'cif_mp-10037_AlCo3C.cif',
#  'cif_mp-10038_Er3AlC.cif',
#  'cif_mp-10039_Pr3AlC.cif',
#  'cif_mp-10040_AlPt3C.cif',
#  'cif_mp-10041_Tb3AlC.cif',
#  'cif_mp-1004377_HfB6.cif',
#  'cif_mp-1004524_HPbI3.cif',
#  'cif_mp-1004_Nb3Si.cif',
#  'cif_mp-1005719_Sm3Np.cif',
#  'cif_mp-1005727_TmNp3.cif',
#  'cif_mp-10060_DyBPd3.cif',
#  'cif_mp-1006115_Ho3Pu.cif',
#  'cif_mp-10061_ErBPd3.cif',
#  'cif_mp-1006245_ErNp3.cif',
#  'cif_mp-1006246_CeSm3.cif',
#  'cif_mp-1006330_Ce3Cu.cif',
#  'cif_mp-1006615_CrCuN6Cl5.cif',
#  'cif_mp-1006883_CoNi.cif',
#  'cif_mp-1006884_CoMo.cif',
#  'cif_mp-1006886_CeS.cif',
#  'cif_mp-1007656_HfPd3.cif',
#  'cif_mp-1007657_HfRu3.cif',
#  'cif_mp-1007690_HgPt3.cif',
#  'cif_mp-1007693_HfOs3.cif',
#  'cif_mp-1007730_HfAl3.cif',
#  'cif_mp-1007819_CoW.cif',
#  'cif_mp-1007974_CrNi3.cif',
#  'cif_mp-1008278_Cr3Ni.cif',
#  'cif_mp-1008285_Cr3Fe.cif',
#  'cif_mp-1008489_CdN.cif',
#  'cif_mp-1008554_Al3V.cif',
#  'cif_mp-1008555_AlCu3.cif',
#  'cif_mp-1008630_WC.cif',
#  'cif_mp-1008650_CeSe.cif',
#  'cif_mp-1008752_CeTe.cif',
#  'cif_mp-1008923_CuN.cif',
#  'cif_mp-1008924_DySb.cif',
#  'cif_mp-1008928_EuSe.cif',
#  'cif_mp-1008931_ErSb.cif',
#  'cif_mp-1008985_CoN.cif',
#  'cif_mp-1008998_LaS.cif',
#  'cif_mp-1008999_LaSe.cif',
#  'cif_mp-1008_NiHg.cif',
#  'cif_mp-1009005_IrN.cif',
#  'cif_mp-1009007_LuSb.cif',
#  'cif_mp-1009008_LaTe.cif',
#  'cif_mp-1009009_LiF.cif',
#  'cif_mp-1009016_LuAs.cif',
#  'cif_mp-1009017_HoSb.cif',
#  'cif_mp-1009018_InAg.cif',
#  'cif_mp-1009019_FeN.cif',
#  'cif_mp-1009127_MgO.cif',
#  'cif_mp-1009128_MnN.cif',
#  'cif_mp-1009133_MnCo.cif',
#  'cif_mp-1009206_MnSn.cif',
#  'cif_mp-1009207_MnSb.cif',
#  'cif_mp-1009220_NaH.cif',
#  'cif_mp-1009237_NdN.cif',
#  'cif_mp-1009264_NbCo.cif',
#  'cif_mp-1009459_NbC.cif',
#  'cif_mp-1009471_NbN.cif',
#  'cif_mp-1009483_NiN.cif',
#  'cif_mp-1009485_CrN.cif',
#  'cif_mp-1009493_NpN.cif',
#  'cif_mp-1009537_OsC.cif',
#  'cif_mp-1009596_PdN.cif',
#  'cif_mp-1009640_PrN.cif',
#  'cif_mp-1009731_ReC.cif',
#  'cif_mp-1009748_ScC.cif',
#  'cif_mp-1009819_SrO.cif',
#  'cif_mp-1009826_TaCo.cif',
#  'cif_mp-1009831_TaN.cif',
#  'cif_mp-1009835_TaC.cif',
#  'cif_mp-1009836_ZrN.cif',
#  'cif_mp-1009839_TbAl.cif',
#  'cif_mp-1009878_ZrC.cif',
#  'cif_mp-1010071_CrCo.cif',
#  'cif_mp-1010161_DyAs.cif',
#  'cif_mp-1011031_PrBi.cif',
#  'cif_mp-10110_SiRh.cif',
#  'cif_mp-10113_ScBIr3.cif',
#  'cif_mp-1011697_Cs2Se.cif',
#  'cif_mp-10120_NdBPd3.cif',
#  'cif_mp-10133_Sc3BPb.cif',
#  'cif_mp-10134_TmBPd3.cif',
#  'cif_mp-1013524_Ca3N2.cif',
#  'cif_mp-1013528_Ba3N2.cif',
#  'cif_mp-1013529_Sr3N2.cif',
#  'cif_mp-1013530_Sr3BiP.cif',
#  'cif_mp-1013531_Sr3BiN.cif',
#  'cif_mp-1013532_Sr3AsP.cif',
#  'cif_mp-1013533_Ba3PN.cif',
#  'cif_mp-1013534_Sr3SbN.cif',
#  'cif_mp-1013535_Sr3SbP.cif',
#  'cif_mp-1013536_Sr3PN.cif',
#  'cif_mp-1013537_Sr3AsN.cif',
#  'cif_mp-1013540_Ca3PN.cif',
#  'cif_mp-1013541_Sr3SbAs.cif',
#  'cif_mp-1013542_Ca3BiN.cif',
#  'cif_mp-1013543_Ca3AsN.cif',
#  'cif_mp-1013544_Ca3SbAs.cif',
#  'cif_mp-1013545_Ca3BiAs.cif',
#  'cif_mp-1013546_Ca3Sb2.cif',
#  'cif_mp-1013547_Ca3P2.cif',
#  'cif_mp-1013548_Ca3SbN.cif',
#  'cif_mp-1013549_Ba3BiN.cif',
#  'cif_mp-1013550_Ca3SbP.cif',
#  'cif_mp-1013551_Ba3P2.cif',
#  'cif_mp-1013552_Sr3P2.cif',
#  'cif_mp-1013553_Sr3AsP.cif',
#  'cif_mp-1013554_Sr3PN.cif',
#  'cif_mp-1013555_Sr3AsN.cif',
#  'cif_mp-1013557_Ba3SbN.cif',
#  'cif_mp-1013558_Ca3BiP.cif',
#  'cif_mp-1013559_Sr3As2.cif',
#  'cif_mp-1013560_Ba3As2.cif',
#  'cif_mp-1013561_Sr3SbAs.cif',
#  'cif_mp-1013562_Ba3SbAs.cif',
#  'cif_mp-1013563_Ba3BiAs.cif',
#  'cif_mp-1013564_Sr3BiAs.cif',
#  'cif_mp-1013582_Ba3Sb2.cif',
#  'cif_mp-1013583_Sr3Sb2.cif',
#  'cif_mp-1013584_Ba3BiSb.cif',
#  'cif_mp-1013585_Sr3BiSb.cif',
#  'cif_mp-1013586_Ba3AsP.cif',
#  'cif_mp-1013587_Sr3Bi2.cif',
#  'cif_mp-1013588_Sr3SbP.cif',
#  'cif_mp-1013642_Ca3AsP.cif',
#  'cif_mp-1013643_Sr3BiP.cif',
#  'cif_mp-1013691_Ba3BiP.cif',
#  'cif_mp-1013702_Ca3BiP.cif',
#  'cif_mp-1013703_Ca3BiAs.cif',
#  'cif_mp-1013704_Ca3BiSb.cif',
#  'cif_mp-1013705_Sr3BiAs.cif',
#  'cif_mp-1013706_Sr3BiSb.cif',
#  'cif_mp-1013707_Ba3PN.cif',
#  'cif_mp-1013708_Ba3SbN.cif',
#  'cif_mp-1013709_Ba3AsN.cif',
#  'cif_mp-1013710_Ba3BiN.cif',
#  'cif_mp-1013711_Ba3AsP.cif',
#  'cif_mp-1013712_Ba3SbP.cif',
#  'cif_mp-1013713_Ba3BiP.cif',
#  'cif_mp-1013714_Ba3SbAs.cif',
#  'cif_mp-1013716_Ba3BiAs.cif',
#  'cif_mp-1013719_Ba3BiSb.cif',
#  'cif_mp-1013733_Ca3BiSb.cif',
#  'cif_mp-1013734_Ba3AsN.cif',
#  'cif_mp-1013735_Ca3Bi2.cif',
#  'cif_mp-1013736_Ba3Bi2.cif',
#  'cif_mp-1013737_Ba3SbP.cif',
#  'cif_mp-1013738_Ca3SbAs.cif',
#  'cif_mp-10139_Sc3SnB.cif',
#  'cif_mp-10140_Sc3TlB.cif',
#  'cif_mp-1014214_C3N.cif',
#  'cif_mp-1014219_HfZn.cif',
#  'cif_mp-1014230_TiZn.cif',
#  'cif_mp-1014297_C3N.cif',
#  'cif_mp-1014316_C3N.cif',
#  'cif_mp-1014460_Cr3N4.cif',
#  'cif_mp-10148_InSb.cif',
#  'cif_mp-1014993_CrN2.cif',
#  'cif_mp-1016227_LaMg3.cif',
#  'cif_mp-1016819_HfZnO3.cif',
#  'cif_mp-1016820_MgSnO3.cif',
#  'cif_mp-1016821_BaSiO3.cif',
#  'cif_mp-1016823_BaGeO3.cif',
#  'cif_mp-1016825_HfMgO3.cif',
#  'cif_mp-1016826_MgIrO3.cif',
#  'cif_mp-1016827_MgGeO3.cif',
#  'cif_mp-1016828_CdIrO3.cif',
#  'cif_mp-1016829_MgRuO3.cif',
#  'cif_mp-1016830_MgTiO3.cif',
#  'cif_mp-1016831_HgIrO3.cif',
#  'cif_mp-1016833_CaRhO3.cif',
#  'cif_mp-1016835_CaRuO3.cif',
#  'cif_mp-1016836_ZnOsO3.cif',
#  'cif_mp-1016837_SnHgO3.cif',
#  'cif_mp-1016840_HgOsO3.cif',
#  'cif_mp-1016841_HfHgO3.cif',
#  'cif_mp-1016842_TiHgO3.cif',
#  'cif_mp-1016843_MgOsO3.cif',
#  'cif_mp-1016845_ZrCdO3.cif',
#  'cif_mp-1016846_TiCdO3.cif',
#  'cif_mp-1016848_SrIrO3.cif',
#  'cif_mp-1016849_CdRuO3.cif',
#  'cif_mp-1016850_BaRhO3.cif',
#  'cif_mp-1016851_HgRuO3.cif',
#  'cif_mp-1016852_BaMnO3.cif',
#  'cif_mp-1016853_CaVO3.cif',
#  'cif_mp-1016854_MnCdO3.cif',
#  'cif_mp-1016871_ZrHgO3.cif',
#  'cif_mp-1016872_CaIrO3.cif',
#  'cif_mp-1016873_CaHfO3.cif',
#  'cif_mp-1016874_SiHgO3.cif',
#  'cif_mp-1016875_CdRhO3.cif',
#  'cif_mp-1016876_ZnSiO3.cif',
#  'cif_mp-1016877_HgRhO3.cif',
#  'cif_mp-1016879_CdSiO3.cif',
#  'cif_mp-1016880_ZnRhO3.cif',
#  'cif_mp-1016881_CdSnO3.cif',
#  'cif_mp-1016882_CdOsO3.cif',
#  'cif_mp-1016883_ZrZnO3.cif',
#  'cif_mp-1016884_CaGeO3.cif',
#  'cif_mp-1016886_MgVO3.cif',
#  'cif_mp-1016900_CaOsO3.cif',
#  'cif_mp-1016902_ZnSnO3.cif',
#  'cif_mp-1016903_CdGeO3.cif',
#  'cif_mp-1016904_VCdO3.cif',
#  'cif_mp-1016926_ZnIrO3.cif',
#  'cif_mp-1016927_TiZnO3.cif',
#  'cif_mp-1016928_MgSiO3.cif',
#  'cif_mp-1016929_MgRhO3.cif',
#  'cif_mp-1016930_ZnGeO3.cif',
#  'cif_mp-1016931_VZnO3.cif',
#  'cif_mp-1016932_MnZnO3.cif',
#  'cif_mp-1016938_VHgO3.cif',
#  'cif_mp-1016999_SrGeO3.cif',
#  'cif_mp-1017000_MgZrO3.cif',
#  'cif_mp-1017439_SrSiO3.cif',
#  'cif_mp-1017441_SrRhO3.cif',
#  'cif_mp-1017446_HfCdO3.cif',
#  'cif_mp-1017447_HgGeO3.cif',
#  'cif_mp-1017465_BaVO3.cif',
#  'cif_mp-1017467_CaMnO3.cif',
#  'cif_mp-1017519_IrC.cif',
#  'cif_mp-1017529_VCo3.cif',
#  'cif_mp-1017542_ZrOs3.cif',
#  'cif_mp-1017543_ZrPd3.cif',
#  'cif_mp-1017544_ZrRu3.cif',
#  'cif_mp-1017553_CdCo3N.cif',
#  'cif_mp-1017555_CsBeF3.cif',
#  'cif_mp-1017557_Dy3AlN.cif',
#  'cif_mp-1017558_Er3AlN.cif',
#  'cif_mp-1017563_GaPt3C.cif',
#  'cif_mp-1017566_GePbO3.cif',
#  'cif_mp-1017577_Ho3AlN.cif',
#  'cif_mp-1017578_HfBRh3.cif',
#  'cif_mp-1017580_KMgH3.cif',
#  'cif_mp-1017581_LaPd3C.cif',
#  'cif_mp-1017582_LaPt3C.cif',
#  'cif_mp-1017591_BaRuO3.cif',
#  'cif_mp-10175_KCdF3.cif',
#  'cif_mp-1017626_LiCaF3.cif',
#  'cif_mp-1017627_Lu3AlN.cif',
#  'cif_mp-1017629_MgNiH3.cif',
#  'cif_mp-1017631_ScBPd3.cif',
#  'cif_mp-1017632_Ni3SnN.cif',
#  'cif_mp-1018029_CuPd.cif',
#  'cif_mp-1018042_UBi.cif',
#  'cif_mp-1018054_HfPt3.cif',
#  'cif_mp-1018061_FeH3.cif',
#  'cif_mp-1018081_CrFe3.cif',
#  'cif_mp-1018101_AlCo3.cif',
#  'cif_mp-10185_Mg3ZnC.cif',
#  'cif_mp-1018627_ScBPt3.cif',
#  'cif_mp-1018628_ScPt3C.cif',
#  'cif_mp-1018629_YPd3C.cif',
#  'cif_mp-1018633_LaBPt3.cif',
#  'cif_mp-1018635_ScPd3C.cif',
#  'cif_mp-1018636_SnPd3C.cif',
#  'cif_mp-1018638_Tb3AlN.cif',
#  'cif_mp-1018639_TiSnO3.cif',
#  'cif_mp-1018641_Tm3AlN.cif',
#  'cif_mp-1018643_YBPd3.cif',
#  'cif_mp-1018644_YBPt3.cif',
#  'cif_mp-1018645_YPt3C.cif',
#  'cif_mp-1018734_IrN.cif',
#  'cif_mp-1018849_OsN.cif',
#  'cif_mp-1019052_ReN.cif',
#  'cif_mp-1019378_Al3GaN4.cif',
#  'cif_mp-1019379_AlB3N4.cif',
#  'cif_mp-1019380_Al3BN4.cif',
#  'cif_mp-1019508_AlGa3N4.cif',
#  'cif_mp-1019541_BaCa3O4.cif',
#  'cif_mp-1019609_Cs2Sr2Li3B3(PO4)6.cif',
#  'cif_mp-1019740_GaB3N4.cif',
#  'cif_mp-1019743_Ga3BN4.cif',
#  'cif_mp-1019788_K4Al3(SiO4)3.cif',
#  'cif_mp-1019799_K8NO3.cif',
#  'cif_mp-1019800_K8N3O.cif',
#  'cif_mp-1019801_K8PO3.cif',
#  'cif_mp-10198_Mn3PdN.cif',
#  'cif_mp-1020020_Li8NO3.cif',
#  'cif_mp-1020029_Li8PO3.cif',
#  'cif_mp-1020032_Li8N3O.cif',
#  'cif_mp-1020147_Na2Mg2P3NO9.cif',
#  'cif_mp-1020578_Sr4S3O.cif',
#  'cif_mp-1020590_Na8N3O.cif',
#  'cif_mp-1020591_Rb8NO3.cif',
#  'cif_mp-1020595_Rb8PO3.cif',
#  'cif_mp-1020625_Rb8N3O.cif',
#  'cif_mp-1020633_RbMgBO3.cif',
#  'cif_mp-1020638_Na8PO3.cif',
#  'cif_mp-1020645_Na8NO3.cif',
#  'cif_mp-1020_TaRh3.cif',
#  'cif_mp-1021489_IrO3.cif',
#  'cif_mp-1021503_SiO2.cif',
#  'cif_mp-1021666_AlSi.cif',
#  'cif_mp-1021667_IClO3.cif',
#  'cif_mp-1021668_In3Sb.cif',
#  'cif_mp-1022721_AlCu.cif',
#  'cif_mp-10229_Nb3Si.cif',
#  'cif_mp-1023127_Ba4Cu3PbO9.cif',
#  'cif_mp-1023920_Mg3NbO4.cif',
#  'cif_mp-1024033_Mg3SnO4.cif',
#  'cif_mp-1024034_SrMg3O4.cif',
#  'cif_mp-1024035_RbMg3O4.cif',
#  'cif_mp-1024036_Mg3SiO4.cif',
#  'cif_mp-1024037_NaMg3O4.cif',
#  'cif_mp-1024038_CeMg3O4.cif',
#  'cif_mp-1024039_Mg3AlO4.cif',
#  'cif_mp-1024040_BaMg3O4.cif',
#  'cif_mp-1024043_CaMg3O4.cif',
#  'cif_mp-1024044_Mg3CrO4.cif',
#  'cif_mp-1024045_Mg3ZnO4.cif',
#  'cif_mp-1024046_YMg3O4.cif',
#  'cif_mp-1024068_Mg3VO4.cif',
#  'cif_mp-10250_BaLiF3.cif',
#  'cif_mp-1025192_Ta4C3.cif',
#  'cif_mp-1025397_GeRu.cif',
#  'cif_mp-1025551_GaPt.cif',
#  'cif_mp-10266_ZnFe3C.cif',
#  'cif_mp-10274_Er3GaC.cif',
#  'cif_mp-10275_Er3InC.cif',
#  'cif_mp-10279_Ho3GaC.cif',
#  'cif_mp-1027_HfRh3.cif',
#  'cif_mp-10280_Nd3GaC.cif',
#  'cif_mp-1029265_Mg2ZnN2.cif',
#  'cif_mp-1029502_Ba(NbN2)2.cif',
#  'cif_mp-1029505_Ba(MoN2)2.cif',
#  'cif_mp-1029517_Li7BiN4.cif',
#  'cif_mp-1029522_Li7SbN4.cif',
#  'cif_mp-1029568_Ba(CrN2)2.cif',
#  'cif_mp-1029616_Ba(TaN2)2.cif',
#  'cif_mp-1029619_Ba(ReN2)2.cif',
#  'cif_mp-1029918_Ba(VN2)2.cif',
#  'cif_mp-1030618_Mg3ZrO4.cif',
#  'cif_mp-1030631_Mg3MnO4.cif',
#  'cif_mp-1030635_LaMg3O4.cif',
#  'cif_mp-1030636_Mg3TiO4.cif',
#  'cif_mp-1031_GdCd.cif',
#  'cif_mp-1033_BeNi.cif',
#  'cif_mp-10351_Tm3GaC.cif',
#  'cif_mp-10356_Ho3InC.cif',
#  'cif_mp-10373_Cr3PdN.cif',
#  'cif_mp-10376_Cr3SnN.cif',
#  'cif_mp-1038814_MgCd.cif',
#  'cif_mp-1038832_Mg3Cd.cif',
#  'cif_mp-1038837_CeMg3.cif',
#  'cif_mp-1038879_Ca3Zn.cif',
#  'cif_mp-1038934_MgAl.cif',
#  'cif_mp-1039073_Mg3Bi.cif',
#  'cif_mp-1039106_SnBi.cif',
#  'cif_mp-1039147_CaZn.cif',
#  'cif_mp-1039148_CaMg.cif',
#  'cif_mp-1039154_MgBi.cif',
#  'cif_mp-1039365_CeMg.cif',
#  'cif_mp-1040464_NaOsO3.cif',
#  'cif_mp-1040467_RbOsO3.cif',
#  'cif_mp-1040469_KMoO3.cif',
#  'cif_mp-1040471_NaMoO3.cif',
#  'cif_mp-1040472_KWO3.cif',
#  'cif_mp-10413_AgB(CN)4.cif',
#  'cif_mp-1044_UIr3.cif',
#  'cif_mp-1053_NdZn.cif',
#  'cif_mp-10554_Ca3TlN.cif',
#  'cif_mp-1056900_IN.cif',
#  'cif_mp-1056920_CsI.cif',
#  'cif_mp-1057125_KS.cif',
#  'cif_mp-1057486_CsS.cif',
#  'cif_mp-1057750_RbS.cif',
#  'cif_mp-1058151_NCl.cif',
#  'cif_mp-1058159_NaS.cif',
#  'cif_mp-1058331_CsSe.cif',
#  'cif_mp-1058798_LiBe.cif',
#  'cif_mp-1059160_BrN.cif',
#  'cif_mp-1059242_ClO.cif',
#  'cif_mp-1059707_CaNi.cif',
#  'cif_mp-1059879_CsN.cif',
#  'cif_mp-1059_NdCd.cif',
#  'cif_mp-10600_La3AlC.cif',
#  'cif_mp-10602_Sm3GaC.cif',
#  'cif_mp-10606_Sm3TlC.cif',
#  'cif_mp-10607_Lu3TlC.cif',
#  'cif_mp-1060962_TlC.cif',
#  'cif_mp-1060967_AgBr.cif',
#  'cif_mp-10609_Lu3SnC.cif',
#  'cif_mp-1061123_TiAl.cif',
#  'cif_mp-1061395_Na2O2.cif',
#  'cif_mp-10627_SrS.cif',
#  'cif_mp-1062_CeMg.cif',
#  'cif_mp-10632_TlS.cif',
#  'cif_mp-1063661_MgNi3.cif',
#  'cif_mp-10637_ThSb.cif',
#  'cif_mp-1064000_Cs3Pt.cif',
#  'cif_mp-1064161_NaN3.cif',
#  'cif_mp-1064282_InC3.cif',
#  'cif_mp-1064459_PBr.cif',
#  'cif_mp-1064508_K3Pd.cif',
#  'cif_mp-10646_ThSe.cif',
#  'cif_mp-10647_TlSe.cif',
#  'cif_mp-1064861_GaC3.cif',
#  'cif_mp-10652_SmTe.cif',
#  'cif_mp-10653_SrTe.cif',
#  'cif_mp-1065428_Rb3Re.cif',
#  'cif_mp-1065540_AlC3.cif',
#  'cif_mp-1065741_NbFe3.cif',
#  'cif_mp-1065783_LaRh3.cif',
#  'cif_mp-10666_Mn3AgN.cif',
#  'cif_mp-1066774_Rb3Os.cif',
#  'cif_mp-1067129_VC3.cif',
#  'cif_mp-1067281_Rb3Pt.cif',
#  'cif_mp-10674_Sm3AlN.cif',
#  'cif_mp-1067833_SnI3.cif',
#  'cif_mp-1068011_SrAlH3.cif',
#  'cif_mp-10680_BaSe.cif',
#  'cif_mp-1068212_Fe2O3.cif',
#  'cif_mp-1068389_SnCCl3.cif',
#  'cif_mp-10683_Ca.cif',
#  'cif_mp-10684_CaTe.cif',
#  'cif_mp-1068577_ZrPbO3.cif',
#  'cif_mp-1068746_TlHPd3.cif',
#  'cif_mp-1068795_NiNF3.cif',
#  'cif_mp-1069129_MnNCl3.cif',
#  'cif_mp-1069166_MnNF3.cif',
#  'cif_mp-1069270_ZnNi3N.cif',
#  'cif_mp-1069273_Gd3AlN.cif',
#  'cif_mp-10692_CoGe.cif',
#  'cif_mp-1069346_PrVO3.cif',
#  'cif_mp-1069526_Ce3InC.cif',
#  'cif_mp-1069538_CsPbI3.cif',
#  'cif_mp-1069774_UBRh3.cif',
#  'cif_mp-10699_LuRh3C.cif',
#  'cif_mp-1070242_Mn3CuN.cif',
#  'cif_mp-1070375_CsSnCl3.cif',
#  'cif_mp-1070440_VPbO3.cif',
#  'cif_mp-10706_ZrRu3C.cif',
#  'cif_mp-1070713_InNi3N.cif',
#  'cif_mp-1070737_K3CO.cif',
#  'cif_mp-10708_PrRh3C.cif',
#  'cif_mp-10712_ScRh3C.cif',
#  'cif_mp-10714_TmRh3C.cif',
#  'cif_mp-10718_Sm3SnC.cif',
#  'cif_mp-10720_ThC2.cif',
#  'cif_mp-1072852_CdB2.cif',
#  'cif_mp-10729_Pd2O.cif',
#  'cif_mp-10732_ThTaN3.cif',
#  'cif_mp-10735_Zr2O.cif',
#  'cif_mp-1073_CaCd.cif',
#  'cif_mp-10748_TaCu3S4.cif',
#  'cif_mp-1074_RbSi.cif',
#  'cif_mp-1075902_EuCuO3.cif',
#  'cif_mp-1075904_EuFeO3.cif',
#  'cif_mp-1075911_RbNbO3.cif',
#  'cif_mp-1075921_LaNiO3.cif',
#  'cif_mp-1075922_Sr7CaTi8O24.cif',
#  'cif_mp-1075933_SmAgO3.cif',
#  'cif_mp-1075973_SmMnO3.cif',
#  'cif_mp-1075975_EuCoO3.cif',
#  'cif_mp-1076000_LaAgO3.cif',
#  'cif_mp-1076070_LaCuO3.cif',
#  'cif_mp-1076128_Ca7Mg(CoO3)8.cif',
#  'cif_mp-1076131_La7SmV8O24.cif',
#  'cif_mp-10762_Cd3As2.cif',
#  'cif_mp-1076317_MgCuO3.cif',
#  'cif_mp-1076360_RbCrO3.cif',
#  'cif_mp-1076368_MgFeO3.cif',
#  'cif_mp-1076382_La7Sm(FeO3)8.cif',
#  'cif_mp-1076445_Sr8MnFe7O24.cif',
#  'cif_mp-1076485_Ca7MgMn8O24.cif',
#  'cif_mp-1076534_RbTaO3.cif',
#  'cif_mp-1076633_KVO3.cif',
#  'cif_mp-1076638_RbVO3.cif',
#  'cif_mp-1076642_NaCrO3.cif',
#  'cif_mp-1076706_SmCuO3.cif',
#  'cif_mp-1076732_KCrO3.cif',
#  'cif_mp-1076782_BaCoO3.cif',
#  'cif_mp-1076800_BaCuO3.cif',
#  'cif_mp-1076927_GdPb3.cif',
#  'cif_mp-1076_KB6.cif',
#  'cif_mp-1077045_Ti2H.cif',
#  'cif_mp-1077622_EuAgO3.cif',
#  'cif_mp-1077660_Sr8Fe7CoO24.cif',
#  'cif_mp-1078464_MnGe.cif',
#  'cif_mp-1078554_KNa3H4.cif',
#  'cif_mp-1078558_NaCl3.cif',
#  'cif_mp-1078597_ZnCd3Se4.cif',
#  'cif_mp-1078643_RbNa3H4.cif',
#  'cif_mp-1078780_ZnCd3S4.cif',
#  'cif_mp-1078915_Ba3CaO4.cif',
#  'cif_mp-1079034_Zn3CdSe4.cif',
#  'cif_mp-1079228_Ga4BiAs3.cif',
#  'cif_mp-1079248_K3NaH4.cif',
#  'cif_mp-1079399_V3Fe.cif',
#  'cif_mp-1079533_CrCd3Te4.cif',
#  'cif_mp-1079594_Ca3ZnSe4.cif',
#  'cif_mp-1079689_Tl3Pt.cif',
#  'cif_mp-1079702_Cr3GaP4.cif',
#  'cif_mp-1079788_Sr4SO3.cif',
#  'cif_mp-1079796_Ti3Pd.cif',
#  'cif_mp-1079882_Ba3SrO4.cif',
#  'cif_mp-1079910_SiTc.cif',
#  'cif_mp-1079914_HfSb.cif',
#  'cif_mp-1079940_Sr3CaO4.cif',
#  'cif_mp-1079947_Pd3N.cif',
#  'cif_mp-1080016_Tl3Ir.cif',
#  'cif_mp-1080187_MnHgO3.cif',
#  'cif_mp-1080300_CeSe2.cif',
#  'cif_mp-1080375_CeSe2.cif',
#  'cif_mp-1080476_FeH3.cif',
#  'cif_mp-1080569_Tl3Au.cif',
#  'cif_mp-1080659_OsC.cif',
#  'cif_mp-1080726_Zn3CrS4.cif',
#  'cif_mp-1080771_NaCl7.cif',
#  'cif_mp-1080799_CuNF3.cif',
#  'cif_mp-1080847_Mg3SbN.cif',
#  'cif_mp-1080852_CeSe2.cif',
#  'cif_mp-1080865_CeSe2.cif',
#  'cif_mp-1082_VIr3.cif',
#  'cif_mp-10844_Te2Ir.cif',
#  'cif_mp-1084771_Be3P2.cif',
#  'cif_mp-1084796_CaZn3Se4.cif',
#  'cif_mp-10848_AsPdS.cif',
#  'cif_mp-10850_SbTePd.cif',
#  'cif_mp-10871_AlAu.cif',
#  'cif_mp-1087545_Zn3CrTe4.cif',
#  'cif_mp-10879_CeAl.cif',
#  'cif_mp-10890_LiAl3.cif',
#  'cif_mp-1089_TiIr3.cif',
#  'cif_mp-10902_PrAl.cif',
#  'cif_mp-10903_AlPt.cif',
#  'cif_mp-10904_AlPt.cif',
#  'cif_mp-10908_AlRe.cif',
#  'cif_mp-1092_HoHg.cif',
#  'cif_mp-1094009_YAgO3.cif',
#  'cif_mp-1094049_SnB6.cif',
#  'cif_mp-1094056_Si7Ge.cif',
#  'cif_mp-1094072_Pr3AlN.cif',
#  'cif_mp-1094082_Ni4O.cif',
#  'cif_mp-1094084_Ni4N3.cif',
#  'cif_mp-1094085_Nd3SnN.cif',
#  'cif_mp-1094090_Ni4N.cif',
#  'cif_mp-1094094_Ni5O4.cif',
#  'cif_mp-1094096_Ni4O3.cif',
#  'cif_mp-1094101_Nd3PbN.cif',
#  'cif_mp-1094118_Mn3InC.cif',
#  'cif_mp-1094669_MgSn.cif',
#  'cif_mp-1094670_LiMg3.cif',
#  'cif_mp-1094705_YSn.cif',
#  'cif_mp-1094724_Mg3Sb.cif',
#  'cif_mp-1094726_MgTi.cif',
#  'cif_mp-1094731_SrMg3.cif',
#  'cif_mp-1094743_MgZr.cif',
#  'cif_mp-1094768_MgZr3.cif',
#  'cif_mp-1094769_Y3Mg.cif',
#  'cif_mp-1094779_MgZn.cif',
#  'cif_mp-1094786_Sr3Mg.cif',
#  'cif_mp-1094791_Mg3Zn.cif',
#  'cif_mp-1094792_Mg3Zr.cif',
#  'cif_mp-1094802_MgSn3.cif',
#  'cif_mp-1094839_MgCd3.cif',
#  'cif_mp-1094849_MgGa.cif',
#  'cif_mp-1094857_Ca3Mg.cif',
#  'cif_mp-1094867_MgZn3.cif',
#  'cif_mp-1094874_ZrSn.cif',
#  'cif_mp-1094889_LiMg.cif',
#  'cif_mp-1094904_Ce3Mg.cif',
#  'cif_mp-1094922_CaMg3.cif',
#  'cif_mp-1094958_HfMg3.cif',
#  'cif_mp-1094967_MgSb.cif',
#  'cif_mp-1094969_MgGa3.cif',
#  'cif_mp-1094980_CaZn3.cif',
#  'cif_mp-1094990_HfMg.cif',
#  'cif_mp-1095028_Zn3CrSe4.cif',
#  'cif_mp-1095030_BC7.cif',
#  'cif_mp-1095176_Rb3NaH4.cif',
#  'cif_mp-1095177_SiNi.cif',
#  'cif_mp-1095224_PtO2.cif',
#  'cif_mp-1095264_OsO2.cif',
#  'cif_mp-1095440_CdS2.cif',
#  'cif_mp-1095493_CdSe2.cif',
#  'cif_mp-1095507_SbIrSe.cif',
#  'cif_mp-1095551_K8AsO3.cif',
#  'cif_mp-1095618_PtN2.cif',
#  'cif_mp-1095638_LiMgIr.cif',
#  'cif_mp-1096764_Ca3SbP.cif',
#  'cif_mp-1096779_Ba4Ce(CuO3)3.cif',
#  'cif_mp-1096797_HgB6.cif',
#  'cif_mp-1096800_LaScO3.cif',
#  'cif_mp-1096825_B6Pb.cif',
#  'cif_mp-1096836_Ba3SnS4.cif',
#  'cif_mp-1096844_BiB6.cif',
#  'cif_mp-1096854_Ca3As2.cif',
#  'cif_mp-1096856_Ca3AsP.cif',
#  'cif_mp-1096862_CdHCl3.cif',
#  'cif_mp-1096919_CrN2.cif',
#  'cif_mp-1096944_CsNbO3.cif',
#  'cif_mp-1097006_KAlH3.cif',
#  'cif_mp-1097026_LaGaO3.cif',
#  'cif_mp-1099244_Mg3WO4.cif',
#  'cif_mp-1099245_Mg3FeO4.cif',
#  'cif_mp-1099246_Mg3BiO4.cif',
#  'cif_mp-1099248_Mg3CO4.cif',
#  'cif_mp-1099249_Mg3CuO4.cif',
#  'cif_mp-1099250_Mg3MoO4.cif',
#  'cif_mp-1099251_Mg3GaO4.cif',
#  'cif_mp-1099252_Mg3SbO4.cif',
#  'cif_mp-1099254_Mg3CoO4.cif',
#  'cif_mp-1099255_Mg3CdO4.cif',
#  'cif_mp-1099256_Mg3BO4.cif',
#  'cif_mp-1099257_KMg3O4.cif',
#  'cif_mp-1099258_HfMg3O4.cif',
#  'cif_mp-1099259_LiMg3O4.cif',
#  'cif_mp-1099583_SmTiO3.cif',
#  'cif_mp-1099588_SmFeO3.cif',
#  'cif_mp-1099591_NaVO3.cif',
#  'cif_mp-1099619_EuMnO3.cif',
#  'cif_mp-1099664_KNa7V8O24.cif',
#  'cif_mp-1099685_BaSr7(FeO3)8.cif',
#  'cif_mp-1099778_BaSr7Ti8O24.cif',
#  'cif_mp-1099824_Ba7Sr(CuO3)8.cif',
#  'cif_mp-1099873_CaCuO3.cif',
#  'cif_mp-1099881_Sr2TiMnO6.cif',
#  'cif_mp-1099923_La7SmMn8O24.cif',
#  'cif_mp-1099934_CaCoO3.cif',
#  'cif_mp-1100771_TiTl3.cif',
#  'cif_mp-1100773_Y3Cd.cif',
#  'cif_mp-1100774_U3N.cif',
#  'cif_mp-1100775_SrEuO3.cif',
#  'cif_mp-1100776_ZnBi3.cif',
#  'cif_mp-1100777_VTeO3.cif',
#  'cif_mp-1100778_ZnCuO3.cif',
#  'cif_mp-1100784_U3In.cif',
#  'cif_mp-1101333_SrNdO3.cif',
#  'cif_mp-1101336_TbCeO4.cif',
#  'cif_mp-1101666_NaFe5O8.cif',
#  'cif_mp-1101717_PrHfO4.cif',
#  'cif_mp-1101754_Ti4H7.cif',
#  'cif_mp-1101765_BiRhSe.cif',
#  'cif_mp-1101820_MgTi3H8.cif',
#  'cif_mp-1101823_Cd(N2O3)2.cif',
#  'cif_mp-1101846_Mg3TiH8.cif',
#  'cif_mp-1101868_AuN2.cif',
#  'cif_mp-1101912_BaSiPt.cif',
#  'cif_mp-1101930_MgO.cif',
#  'cif_mp-1101975_WN2.cif',
#  'cif_mp-1102002_FeTe2.cif',
#  'cif_mp-1102038_MgH2.cif',
#  'cif_mp-1102074_OsN2.cif',
#  'cif_mp-1102114_TaN2.cif',
#  'cif_mp-1102124_Na8BiO3.cif',
#  'cif_mp-1102140_NdSiIr.cif',
#  'cif_mp-1102163_Li8AsO3.cif',
#  'cif_mp-1102170_CrO2.cif',
#  'cif_mp-1102223_K8SbO3.cif',
#  'cif_mp-1102232_HCN.cif',
#  'cif_mp-1102235_IrN2.cif',
#  'cif_mp-1102261_IrS2.cif',
#  'cif_mp-1102284_SbPdS.cif',
#  'cif_mp-1102324_NiTe2.cif',
#  'cif_mp-1102366_SbRhSe.cif',
#  'cif_mp-1102429_HfN2.cif',
#  'cif_mp-1102430_SbTeIr.cif',
#  'cif_mp-1102443_CoSbS.cif',
#  'cif_mp-1102444_UC2.cif',
#  'cif_mp-1102515_ZnSe2.cif',
#  'cif_mp-1102531_PRhSe.cif',
#  'cif_mp-1102539_Na8SbO3.cif',
#  'cif_mp-1102584_Ca4Mg4Fe3.cif',
#  'cif_mp-1102591_TiO2.cif',
#  'cif_mp-1102609_BaSiPd.cif',
#  'cif_mp-1102647_NaC2.cif',
#  'cif_mp-1102668_CrSbPt.cif',
#  'cif_mp-11026_Rb3Hg20.cif',
#  'cif_mp-1102707_FeSbPt.cif',
#  'cif_mp-1102716_Li8SbO3.cif',
#  'cif_mp-1102743_ZnS2.cif',
#  'cif_mp-1102773_K8BiO3.cif',
#  'cif_mp-11027_Cs3Hg20.cif',
#  'cif_mp-1102811_SiC2.cif',
#  'cif_mp-1102836_BiIrS.cif',
#  'cif_mp-1102845_TiS2.cif',
#  'cif_mp-1102850_SbPtS.cif',
#  'cif_mp-1102865_Li8BiO3.cif',
#  'cif_mp-1102981_Rb8SbO3.cif',
#  'cif_mp-1102998_Na8AsO3.cif',
#  'cif_mp-1103017_NiBiSe.cif',
#  'cif_mp-1103058_Rb8AsO3.cif',
#  'cif_mp-1103098_BiRhS.cif',
#  'cif_mp-1103155_LaSiRh.cif',
#  'cif_mp-1103177_FeSe2.cif',
#  'cif_mp-1103210_EuMgNi.cif',
#  'cif_mp-1103228_BiIrSe.cif',
#  'cif_mp-1103235_CuTe2.cif',
#  'cif_mp-1103284_Rb8BiO3.cif',
#  'cif_mp-1103317_SbRhS.cif',
#  'cif_mp-1103420_ReN2.cif',
#  'cif_mp-1103427_PdN2.cif',
#  'cif_mp-1103513_Li3(Mg2Si)4.cif',
#  'cif_mp-1103521_Sr8Rh5.cif',
#  'cif_mp-1103590_MgSe2.cif',
#  'cif_mp-1103943_ErGa3Ru.cif',
#  'cif_mp-1104461_TbGa3Ru.cif',
#  'cif_mp-1104503_YGa3Ru.cif',
#  'cif_mp-1104547_HoGa3Ru.cif',
#  'cif_mp-1104791_Li(Mg2Si)4.cif',
#  'cif_mp-1104_LaMg.cif',
#  'cif_mp-1105018_Al2O3.cif',
#  'cif_mp-1105019_DyGa3Ru.cif',
#  'cif_mp-1105290_Co3Sb4(OF)6.cif',
#  'cif_mp-1105641_InHO2.cif',
#  'cif_mp-1105655_C3N2.cif',
#  'cif_mp-1105932_Li2MgSi.cif',
#  'cif_mp-1106349_SmPd3S4.cif',
#  'cif_mp-1110791_RbAuCl3.cif',
#  'cif_mp-1110854_KAuCl3.cif',
#  'cif_mp-1110999_RbAuBr3.cif',
#  'cif_mp-1111644_RbAuF3.cif',
#  'cif_mp-1111868_KAuF3.cif',
#  'cif_mp-1112174_KAuBr3.cif',
#  'cif_mp-1112985_CsAuF3.cif',
#  'cif_mp-1112987_CsAuBr3.cif',
#  'cif_mp-1120716_CdHg3Te4.cif',
#  'cif_mp-1120717_V3Bi.cif',
#  'cif_mp-1120718_MgZn3S4.cif',
#  'cif_mp-1120722_CuO.cif',
#  'cif_mp-1120765_BaNiO3.cif',
#  'cif_mp-1120777_NaTiF3.cif',
#  'cif_mp-1120_Mo3Ir.cif',
#  'cif_mp-1121_GaCo.cif',
#  'cif_mp-11221_SmAl.cif',
#  'cif_mp-11222_Sm3Al.cif',
#  'cif_mp-11224_Sr8Al7.cif',
#  'cif_mp-11229_YAl.cif',
#  'cif_mp-11231_YAl3.cif',
#  'cif_mp-11237_ScAg.cif',
#  'cif_mp-11240_DyAu.cif',
#  'cif_mp-11245_HoAu.cif',
#  'cif_mp-11248_LiAu3.cif',
#  'cif_mp-11249_LuAu.cif',
#  'cif_mp-11254_NdAu.cif',
#  'cif_mp-11255_PrAu.cif',
#  'cif_mp-11256_ScAu.cif',
#  'cif_mp-11257_SmAu.cif',
#  'cif_mp-11258_TbAu.cif',
#  'cif_mp-11259_TiAu.cif',
#  'cif_mp-11260_Ti3Au.cif',
#  'cif_mp-11261_YAu.cif',
#  'cif_mp-11271_BeMo3.cif',
#  'cif_mp-11274_BePd.cif',
#  'cif_mp-11276_BeRh.cif',
#  'cif_mp-11279_TiBe.cif',
#  'cif_mp-11286_CaHg.cif',
#  'cif_mp-11290_CaSn3.cif',
#  'cif_mp-1129_ScIr.cif',
#  'cif_mp-11309_NbCd3.cif',
#  'cif_mp-11312_V3Cd.cif',
#  'cif_mp-11334_W.cif',
#  'cif_mp-11364_TiCu.cif',
#  'cif_mp-11365_Ti3Cu.cif',
#  'cif_mp-11370_ErIn.cif',
#  'cif_mp-11372_ErSn3.cif',
#  'cif_mp-11374_DyTl.cif',
#  'cif_mp-11375_EuHg.cif',
#  'cif_mp-11388_GaIr.cif',
#  'cif_mp-1139958_LiY(TlCl3)2.cif',
#  'cif_mp-11407_GaPt3.cif',
#  'cif_mp-11418_TbGa3.cif',
#  'cif_mp-11422_GdHg.cif',
#  'cif_mp-11447_UTe.cif',
#  'cif_mp-11452_HfOs.cif',
#  'cif_mp-11455_HfPt.cif',
#  'cif_mp-11457_HfRh.cif',
#  'cif_mp-11460_HfTc.cif',
#  'cif_mp-11467_NdHg.cif',
#  'cif_mp-11469_PrHg.cif',
#  'cif_mp-11471_ScHg.cif',
#  'cif_mp-11473_TlHg.cif',
#  'cif_mp-11474_TlHg3.cif',
#  'cif_mp-1147577_GdCrO3.cif',
#  'cif_mp-11475_TmHg.cif',
#  'cif_mp-1147612_Mg(CuN)3.cif',
#  'cif_mp-1147638_CsVC6.cif',
#  'cif_mp-1147651_SnAu.cif',
#  'cif_mp-1147653_CaCu3O4.cif',
#  'cif_mp-1147655_Ba4Cu3SnO9.cif',
#  'cif_mp-1147674_Li(CuN)3.cif',
#  'cif_mp-1147675_Rh3Cl4.cif',
#  'cif_mp-1147682_CsNbC6.cif',
#  'cif_mp-1147699_Ba4Ti(CuO3)3.cif',
#  'cif_mp-11476_HoIr.cif',
#  'cif_mp-1147701_Cu3NF3.cif',
#  'cif_mp-1147702_Li(CuO)3.cif',
#  'cif_mp-1147710_CsPdCl3.cif',
#  'cif_mp-1147716_CsMoC6.cif',
#  'cif_mp-1147731_In(CuN)3.cif',
#  'cif_mp-1147740_Pt3Cl3F.cif',
#  'cif_mp-1147742_CsCrC6.cif',
#  'cif_mp-1147771_Al(CuN)3.cif',
#  'cif_mp-11477_HoSn3.cif',
#  'cif_mp-11478_GaAg.cif',
#  'cif_mp-11483_TmIr.cif',
#  'cif_mp-11484_ZrIr.cif',
#  'cif_mp-11487_LaPt3.cif',
#  'cif_mp-11488_LaTl.cif',
#  'cif_mp-11495_LuRu.cif',
#  'cif_mp-11496_LuZn.cif',
#  'cif_mp-11498_MgTl.cif',
#  'cif_mp-11503_MnZn.cif',
#  'cif_mp-1150_URh3.cif',
#  'cif_mp-11516_NbRu.cif',
#  'cif_mp-11521_ScNi.cif',
#  'cif_mp-1152_TiRh3.cif',
#  'cif_mp-11536_NpRh3.cif',
#  'cif_mp-11541_ZrOs.cif',
#  'cif_mp-11546_TiPd.cif',
#  'cif_mp-11552_TiPt.cif',
#  'cif_mp-11554_ZrPt.cif',
#  'cif_mp-11555_PuRu.cif',
#  'cif_mp-11561_TbRh.cif',
#  'cif_mp-11563_TiRh.cif',
#  'cif_mp-11564_TmRh.cif',
#  'cif_mp-11566_ScZn.cif',
#  'cif_mp-11568_SmTl.cif',
#  'cif_mp-11569_SmTl3.cif',
#  'cif_mp-11570_TbSn3.cif',
#  'cif_mp-11571_YSn3.cif',
#  'cif_mp-11572_TaTc.cif',
#  'cif_mp-11573_TiTc.cif',
#  'cif_mp-11575_YTl.cif',
#  'cif_mp-1158_LuPd3.cif',
#  'cif_mp-1169_ScCu.cif',
#  'cif_mp-1172909_BeCl2.cif',
#  'cif_mp-1172_MgRh.cif',
#  'cif_mp-11733_Lu3InN.cif',
#  'cif_mp-1174_MgSc.cif',
#  'cif_mp-1176363_Na2Sb3O8.cif',
#  'cif_mp-1176709_LiFeF3.cif',
#  'cif_mp-1177863_Li2Ti3FeO8.cif',
#  'cif_mp-1177906_Li2Ti3CoO8.cif',
#  'cif_mp-1177935_Li2Mn3CoO8.cif',
#  'cif_mp-1177962_Li2Fe3SnO8.cif',
#  'cif_mp-1177997_Li2Fe3BiO8.cif',
#  'cif_mp-1178248_HfZrO4.cif',
#  'cif_mp-1178268_GdAlO3.cif',
#  'cif_mp-1178354_EuZrO3.cif',
#  'cif_mp-1178500_CeHfO4.cif',
#  'cif_mp-1178510_BaPdO3.cif',
#  'cif_mp-1178641_ZnCu3NiSe4.cif',
#  'cif_mp-1178642_ZnCoCu3Se4.cif',
#  'cif_mp-1178643_ZnCrCu3Se4.cif',
#  'cif_mp-1178644_ZnGaCu3Se4.cif',
#  'cif_mp-1178645_ZnInCu3Se4.cif',
#  'cif_mp-1178697_YCu3PbSe4.cif',
#  'cif_mp-1178705_YMgCu3Se4.cif',
#  'cif_mp-1178710_YCu3HgSe4.cif',
#  'cif_mp-1178729_YCdCu3Se4.cif',
#  'cif_mp-1178753_VZnCu3Se4.cif',
#  'cif_mp-1178804_VCu3HgSe4.cif',
#  'cif_mp-1178806_VCdCu3Se4.cif',
#  'cif_mp-1178824_VCu3PbSe4.cif',
#  'cif_mp-1178984_TlZnCu3Se4.cif',
#  'cif_mp-1178991_Ti4(SiO8)3.cif',
#  'cif_mp-1179003_SrYCu3Se4.cif',
#  'cif_mp-1179014_SrVCu3Se4.cif',
#  'cif_mp-1179021_TlCdCu3Se4.cif',
#  'cif_mp-1179028_TlCu3PbSe4.cif',
#  'cif_mp-1179060_SrTlCu3Se4.cif',
#  'cif_mp-1179075_SrScCu3Se4.cif',
#  'cif_mp-1179109_TeC6(I3N)2.cif',
#  'cif_mp-1179118_SrGaCu3Se4.cif',
#  'cif_mp-1179119_SrInCu3Se4.cif',
#  'cif_mp-1179135_ScZnCu3Se4.cif',
#  'cif_mp-1179138_SrCu3NiSe4.cif',
#  'cif_mp-1179142_SrCoCu3Se4.cif',
#  'cif_mp-1179174_SrAlCu3Se4.cif',
#  'cif_mp-1179510_ScCdCu3Se4.cif',
#  'cif_mp-1179516_ScCu3HgSe4.cif',
#  'cif_mp-1179525_ScCu3PbSe4.cif',
#  'cif_mp-1179676_RbZrCu3Se4.cif',
#  'cif_mp-1179694_RbVCu3Se4.cif',
#  'cif_mp-1179697_RbTiCu3Se4.cif',
#  'cif_mp-1179714_RbMnCu3Se4.cif',
#  'cif_mp-1179715_RbHfCu3Se4.cif',
#  'cif_mp-1179749_RbCu3GeSe4.cif',
#  'cif_mp-1179750_RbCoCu3Se4.cif',
#  'cif_mp-1179752_RbCu3SnSe4.cif',
#  'cif_mp-1179753_RbCu3SiSe4.cif',
#  'cif_mp-1179805_RbCr(SO10)2.cif',
#  'cif_mp-1179860_NaCu3SnSe4.cif',
#  'cif_mp-1179864_NaMnCu3Se4.cif',
#  'cif_mp-1179880_NaCu3GeSe4.cif',
#  'cif_mp-1179888_NaCu3PbSe4.cif',
#  'cif_mp-1179889_NaCoCu3Se4.cif',
#  'cif_mp-1179901_NaCu3NiSe4.cif',
#  'cif_mp-1180005_NaCr(SO10)2.cif',
#  'cif_mp-1180089_NaZrCu3Se4.cif',
#  'cif_mp-1180113_NaVCu3Se4.cif',
#  'cif_mp-1180119_NaTiCu3Se4.cif',
#  'cif_mp-1180276_MgVCu3Se4.cif',
#  'cif_mp-1180283_MgGaCu3Se4.cif',
#  'cif_mp-1180284_MgCu3NiSe4.cif',
#  'cif_mp-1180289_MgCrCu3Se4.cif',
#  'cif_mp-1180309_Mn2Al3.cif',
#  'cif_mp-1180322_MgCoCu3Se4.cif',
#  'cif_mp-1180325_MgTlCu3Se4.cif',
#  'cif_mp-1180332_MgAlCu3Se4.cif',
#  'cif_mp-1180537_NiH12(ClO6)2.cif',
#  'cif_mp-1180545_NaAl(SO10)2.cif',
#  'cif_mp-1180619_Li2O2.cif',
#  'cif_mp-1180674_KZrCu3Se4.cif',
#  'cif_mp-1180688_KTiCu3Se4.cif',
#  'cif_mp-1180689_KVCu3Se4.cif',
#  'cif_mp-1180796_KCu3SnSe4.cif',
#  'cif_mp-1180804_KCoCu3Se4.cif',
#  'cif_mp-1180817_KCu3NiSe4.cif',
#  'cif_mp-1180832_KMnCu3Se4.cif',
#  'cif_mp-1180842_KCu3GeSe4.cif',
#  'cif_mp-1180844_KCu3SiSe4.cif',
#  'cif_mp-1180884_KHfCu3Se4.cif',
#  'cif_mp-1180900_KCu3PbSe4.cif',
#  'cif_mp-1180995_InCu3HgSe4.cif',
#  'cif_mp-1181191_KAl(SO10)2.cif',
#  'cif_mp-1181291_Ge7O23.cif',
#  'cif_mp-1181331_GaCu3HgSe4.cif',
#  'cif_mp-1181468_Cu3NiHgSe4.cif',
#  'cif_mp-1181478_Ni2Mo3N.cif',
#  'cif_mp-1181558_CsZrCu3Se4.cif',
#  'cif_mp-1181577_CsTiCu3Se4.cif',
#  'cif_mp-1181585_CsHfCu3Se4.cif',
#  'cif_mp-1181597_CsCu3GeSe4.cif',
#  'cif_mp-1181613_Cu3NiPbSe4.cif',
#  'cif_mp-1181644_NaCo(N2O3)4.cif',
#  'cif_mp-1181705_Cu3SnAu.cif',
#  'cif_mp-1181713_CrCdCu3Se4.cif',
#  'cif_mp-1181716_CrCu3HgSe4.cif',
#  'cif_mp-1181720_CrCu3PbSe4.cif',
#  'cif_mp-1181785_CoCu3HgSe4.cif',
#  'cif_mp-1181852_CaTlCu3Se4.cif',
#  'cif_mp-1181874_CdGaCu3Se4.cif',
#  'cif_mp-1181876_LaAl(NO4)6.cif',
#  'cif_mp-1181879_CdCu3NiSe4.cif',
#  'cif_mp-1181881_CdCoCu3Se4.cif',
#  'cif_mp-1181925_CaScCu3Se4.cif',
#  'cif_mp-1181927_CaYCu3Se4.cif',
#  'cif_mp-1181943_CaVCu3Se4.cif',
#  'cif_mp-1181967_CaCu3NiSe4.cif',
#  'cif_mp-1181975_CaCoCu3Se4.cif',
#  'cif_mp-1181990_CdInCu3Se4.cif',
#  'cif_mp-1182006_CaCrCu3Se4.cif',
#  'cif_mp-1182175_BaInCu3Se4.cif',
#  'cif_mp-1182176_BaAlCu3Se4.cif',
#  'cif_mp-1182182_BaScCu3Se4.cif',
#  'cif_mp-1182227_BaGaCu3Se4.cif',
#  'cif_mp-1182239_BaCu3NiSe4.cif',
#  'cif_mp-1182240_BaTlCu3Se4.cif',
#  'cif_mp-1182242_BaYCu3Se4.cif',
#  'cif_mp-11824_Ca3PN.cif',
#  'cif_mp-1182688_CsTiH24(SO10)2.cif',
#  'cif_mp-1182706_Nb3Al2N.cif',
#  'cif_mp-1182859_AlZnCu3Se4.cif',
#  'cif_mp-1182878_AlCdCu3Se4.cif',
#  'cif_mp-1182880_AlCu3HgSe4.cif',
#  'cif_mp-1182885_AlCu4.cif',
#  'cif_mp-1182890_AlCu3PbSe4.cif',
#  'cif_mp-1182920_AlS2NO20.cif',
#  'cif_mp-1183043_ZrSiO3.cif',
#  'cif_mp-1183044_ZrTlO3.cif',
#  'cif_mp-1183045_ZrTiO3.cif',
#  'cif_mp-1183052_AcBO3.cif',
#  'cif_mp-1183053_AcGaO3.cif',
#  'cif_mp-1183056_Ac3Cl.cif',
#  'cif_mp-1183058_Ac3Zr.cif',
#  'cif_mp-1183064_Ac3Au.cif',
#  'cif_mp-1183075_Ac3Cr.cif',
#  'cif_mp-1183105_Ac3Ce.cif',
#  ...]

# %%
len(files)
# Out:
# 4575

# %%
path = '../input/material_projects_api_cif/'
files = os.listdir(path)
len(files)
# Out:
# 153235

# %%
# cubic_filesに含まれないものを/workdir/practical-mi-guide/chapter3/input/material_projects_api_cif_cubicからランダムに5425個抽出して、/workdir/practical-mi-guide/chapter3/input/material_projects_api_cif_not_cubicにコピーする

not_cubic_files = np.random.choice([file for file in files if file not in cubic_files], 5425, replace=False)

for file in tqdm(not_cubic_files):
    shutil.copy(f"{path}/{file}", f"../input/material_projects_api_cif_not_cubic/{file}")
    
path = '../input/material_projects_api_cif_not_cubic/'

files = os.listdir(path)

len(files)
# Out:
#   0%|          | 0/5425 [00:00<?, ?it/s]
# 5425

# %%
files
# Out:
# ['cif_mp-1001835_LiB.cif',
#  'cif_mp-1002181_TcN.cif',
#  'cif_mp-1002182_TcN.cif',
#  'cif_mp-1003320_CaMn4O8.cif',
#  'cif_mp-1004532_CCl4.cif',
#  'cif_mp-10051_TeAs.cif',
#  'cif_mp-10059_ZrCo3B2.cif',
#  'cif_mp-1006056_PaNi2Ge.cif',
#  'cif_mp-1006399_CeZnIn.cif',
#  'cif_mp-1006588_Zn3In2O6.cif',
#  'cif_mp-1006617_ZnP2NO9.cif',
#  'cif_mp-1007910_NaEuS2.cif',
#  'cif_mp-1007_DySb.cif',
#  'cif_mp-1008226_CrFe2Sn.cif',
#  'cif_mp-1008511_BaGaCu2.cif',
#  'cif_mp-1008527_B2CN.cif',
#  'cif_mp-1008881_MgNiH.cif',
#  'cif_mp-1009078_CoN.cif',
#  'cif_mp-1009088_BeGeAs2.cif',
#  'cif_mp-1009218_MoC.cif',
#  'cif_mp-1009491_RbTe.cif',
#  'cif_mp-1009496_OsN.cif',
#  'cif_mp-1009547_CsRbAs.cif',
#  'cif_mp-1009601_PdN.cif',
#  'cif_mp-1009735_ReC.cif',
#  'cif_mp-1009787_RuC.cif',
#  'cif_mp-1009817_TaC.cif',
#  'cif_mp-1009827_BaSi2.cif',
#  'cif_mp-1009_SrSi6.cif',
#  'cif_mp-100_Hf.cif',
#  'cif_mp-10115_ThB2Ir3.cif',
#  'cif_mp-10117_Mg3(Ni10B3)2.cif',
#  'cif_mp-1011834_Na2CoP2O7.cif',
#  'cif_mp-1012835_SmCu(WO4)2.cif',
#  'cif_mp-1014307_ZrC.cif',
#  'cif_mp-1014509_Cr3N2.cif',
#  'cif_mp-1014910_CrN2.cif',
#  'cif_mp-10152_La(SiIr)2.cif',
#  'cif_mp-1015814_LiMg2Al.cif',
#  'cif_mp-1016223_Mg3Mo.cif',
#  'cif_mp-1016252_Mg7Ga.cif',
#  'cif_mp-10164_NaGaTe2.cif',
#  'cif_mp-1016580_Mg6NbW.cif',
#  'cif_mp-1016582_BaMg6Cd.cif',
#  'cif_mp-1016596_Mg6NbGa.cif',
#  'cif_mp-1016630_Mg6NbC.cif',
#  'cif_mp-1016652_BaHfMg6.cif',
#  'cif_mp-1016655_HfMg6Mo.cif',
#  'cif_mp-1017072_CsMg6Nb.cif',
#  'cif_mp-1017110_HfMg6Ga.cif',
#  'cif_mp-1017305_NaMg6Sb.cif',
#  'cif_mp-1017487_BaLaMg6.cif',
#  'cif_mp-1017508_LuTlTe2.cif',
#  'cif_mp-1017511_Cr3Fe.cif',
#  'cif_mp-1017533_YN.cif',
#  'cif_mp-1017565_In2Se3.cif',
#  'cif_mp-1017579_In2Au3.cif',
#  'cif_mp-1018015_Ti2MnGe.cif',
#  'cif_mp-1018025_LuAgO2.cif',
#  'cif_mp-1018088_C.cif',
#  'cif_mp-1018117_CeRh.cif',
#  'cif_mp-1018134_Li.cif',
#  'cif_mp-1018658_CaCoSi.cif',
#  'cif_mp-1018671_CeZnGa.cif',
#  'cif_mp-1018691_Eu2H3Br.cif',
#  'cif_mp-1018699_EuZnGe.cif',
#  'cif_mp-1018802_MnGaGe.cif',
#  'cif_mp-1018804_MnS2.cif',
#  'cif_mp-1019055_ReN2.cif',
#  'cif_mp-1019099_SmCoP.cif',
#  'cif_mp-1019239_PdN2.cif',
#  'cif_mp-1019549_BaMg2Si2O7.cif',
#  'cif_mp-1019573_CaAl2SiO6.cif',
#  'cif_mp-1019718_CsBe4(BO3)3.cif',
#  'cif_mp-1019730_EuZn(BO2)5.cif',
#  'cif_mp-1019733_Eu(NO3)3.cif',
#  'cif_mp-1019785_K2Si(S2O7)3.cif',
#  'cif_mp-1020018_Li5B(SO4)4.cif',
#  'cif_mp-1020019_Li2PNO2.cif',
#  'cif_mp-1020056_LiCa3Si2N5.cif',
#  'cif_mp-1020110_Mg2SiO4.cif',
#  'cif_mp-1020145_Na2Ge(S2O7)3.cif',
#  'cif_mp-1020598_Y4Si2S3O7.cif',
#  'cif_mp-1020896_Rb4Ge3B6O17.cif',
#  'cif_mp-1021256_LaMg6Si.cif',
#  'cif_mp-1021292_KMg6Cd.cif',
#  'cif_mp-10212_ScGe2.cif',
#  'cif_mp-1021300_KMg6Ga.cif',
#  'cif_mp-1021383_RbMg6Ti.cif',
#  'cif_mp-1021417_BaMg6Sn.cif',
#  'cif_mp-1021462_BaMg6Ti.cif',
#  'cif_mp-1021507_Ba2Y(CuO2)3.cif',
#  'cif_mp-1021521_LiCeMg6.cif',
#  'cif_mp-1021658_Mg6VSb.cif',
#  'cif_mp-1021660_NbInRu.cif',
#  'cif_mp-1021685_Mg6VGa.cif',
#  'cif_mp-1021694_Mg6VSi.cif',
#  'cif_mp-1021710_Mg6VMo.cif',
#  'cif_mp-1021726_Mg6VC.cif',
#  'cif_mp-1021950_BaNb2(FeO3)4.cif',
#  'cif_mp-1022063_Mg6CuSb.cif',
#  'cif_mp-1022079_Mg6CdCu.cif',
#  'cif_mp-1022184_Mg6FeBi.cif',
#  'cif_mp-1022199_Mg6GaFe.cif',
#  'cif_mp-1022576_Mg6ZnC.cif',
#  'cif_mp-1022609_Mg6VZn.cif',
#  'cif_mp-1022658_SrMg6Zn.cif',
#  'cif_mp-1022683_YMg6Mo.cif',
#  'cif_mp-1022812_LiYMg6.cif',
#  'cif_mp-1022813_LiYMg6.cif',
#  'cif_mp-1022814_YMg6V.cif',
#  'cif_mp-1022889_Mg6MnB.cif',
#  'cif_mp-1022939_Mg6MnCd.cif',
#  'cif_mp-1023142_CaMg6Nb.cif',
#  'cif_mp-1023300_RbMg6Al.cif',
#  'cif_mp-1023306_Mg6AlCd.cif',
#  'cif_mp-1023499_NaMg15.cif',
#  'cif_mp-1024951_LaScSi.cif',
#  'cif_mp-1025044_AlNi2.cif',
#  'cif_mp-1025059_LaAg2.cif',
#  'cif_mp-1025181_Tm2Cr2C3.cif',
#  'cif_mp-1025205_Y2Re2Si2C.cif',
#  'cif_mp-1025223_Hf4Al3.cif',
#  'cif_mp-1025241_ScGa5Fe.cif',
#  'cif_mp-1025245_La2Re2Si2C.cif',
#  'cif_mp-1025264_U2W2C3.cif',
#  'cif_mp-1025329_TlSiPt5.cif',
#  'cif_mp-1025337_Tl2CdTe4.cif',
#  'cif_mp-1025355_ZrGa5Co.cif',
#  'cif_mp-1025362_Er2Re2Si2C.cif',
#  'cif_mp-1025365_Sc(VGa2)2.cif',
#  'cif_mp-1025382_Th2Fe2Si2C.cif',
#  'cif_mp-1025450_CeFeSi2.cif',
#  'cif_mp-1025472_NpTe3.cif',
#  'cif_mp-1025483_ErO3.cif',
#  'cif_mp-1025504_TmGa2Ni.cif',
#  'cif_mp-1025682_Te4Mo(WSe)2.cif',
#  'cif_mp-1025856_Te2MoW2(SeS)2.cif',
#  'cif_mp-1025924_Te4Mo(WS)2.cif',
#  'cif_mp-1025946_Mo2W(Se2S)2.cif',
#  'cif_mp-1025988_Mo3(SeS2)2.cif',
#  'cif_mp-10260_Ni3Sb.cif',
#  'cif_mp-1026395_Mg14TiW.cif',
#  'cif_mp-1026399_Mg14CrSn.cif',
#  'cif_mp-1026447_Mg14CdGa.cif',
#  'cif_mp-1026494_Mg14CdMo.cif',
#  'cif_mp-1026571_SrMg14Nb.cif',
#  'cif_mp-1026573_BaMg14Nb.cif',
#  'cif_mp-1026593_CsMg14W.cif',
#  'cif_mp-1026625_Mg14SnBi.cif',
#  'cif_mp-1026647_Mg14CdC.cif',
#  'cif_mp-1026660_NaMg14Bi.cif',
#  'cif_mp-1026758_NaCeMg14.cif',
#  'cif_mp-1026766_BaLaMg14.cif',
#  'cif_mp-1026776_LiMg14Ga.cif',
#  'cif_mp-1026793_LiMg14Cr.cif',
#  'cif_mp-1026796_LiMg14Mo.cif',
#  'cif_mp-1026808_CeMg14W.cif',
#  'cif_mp-1026810_CeMg14B.cif',
#  'cif_mp-1026902_Mg14CuB.cif',
#  'cif_mp-1027112_MoW3(SeS)4.cif',
#  'cif_mp-1027483_Mo2Se3S.cif',
#  'cif_mp-1027567_Te2Mo3WS6.cif',
#  'cif_mp-1027671_MoW(SeS)2.cif',
#  'cif_mp-1027740_TeMoWSeS2.cif',
#  'cif_mp-1027759_TeMoWSeS2.cif',
#  'cif_mp-1027818_TeMo2Se3.cif',
#  'cif_mp-1027859_BaMg14Fe.cif',
#  'cif_mp-1027959_Mg14TiZn.cif',
#  'cif_mp-1028010_Mg14ZrFe.cif',
#  'cif_mp-1028176_CaMg14Sn.cif',
#  'cif_mp-10281_ZnS.cif',
#  'cif_mp-1028218_NaMg14Al.cif',
#  'cif_mp-1028262_RbMg14Al.cif',
#  'cif_mp-1028301_Mg14VMo.cif',
#  'cif_mp-1028341_Mg14NiW.cif',
#  'cif_mp-1028420_Mo3WSe8.cif',
#  'cif_mp-1028433_Te6MoW3Se2.cif',
#  'cif_mp-1028456_TeWSe.cif',
#  'cif_mp-1028463_Te2MoW3(Se2S)2.cif',
#  'cif_mp-1028505_Te2Mo3WSe6.cif',
#  'cif_mp-1028729_TeW2Se2S.cif',
#  'cif_mp-1028910_Te4MoW3(SeS)2.cif',
#  'cif_mp-1028918_CeMg14V.cif',
#  'cif_mp-1028951_Te2MoW3(Se2S)2.cif',
#  'cif_mp-1029077_MoW(SeS)2.cif',
#  'cif_mp-1029166_Te4MoW3S4.cif',
#  'cif_mp-1029190_Te2MoW3(Se2S)2.cif',
#  'cif_mp-1029234_MoW3(SeS3)2.cif',
#  'cif_mp-1029274_TeMoWSeS2.cif',
#  'cif_mp-1029297_LiZr2N3.cif',
#  'cif_mp-1029378_Mg2SbN3.cif',
#  'cif_mp-1029418_KSi2N3.cif',
#  'cif_mp-1029625_LiTaN2.cif',
#  'cif_mp-1029852_RbMoN2.cif',
#  'cif_mp-1029978_KRuN2.cif',
#  'cif_mp-1030101_Te4MoW3Se4.cif',
#  'cif_mp-1030128_Te4MoW3(SeS)2.cif',
#  'cif_mp-1030196_Te2MoWS2.cif',
#  'cif_mp-1030235_Te3MoWSe.cif',
#  'cif_mp-1030269_Te4Mo3WS4.cif',
#  'cif_mp-1030409_Te2Mo3W(Se2S)2.cif',
#  'cif_mp-1030507_Te2Mo3W(SeS2)2.cif',
#  'cif_mp-1030509_TeMoWSe3.cif',
#  'cif_mp-1030512_TeMoWSeS2.cif',
#  'cif_mp-1030525_Te2MoW3(SeS2)2.cif',
#  'cif_mp-1030677_NaMg6SbO8.cif',
#  'cif_mp-1030910_NaLiMg6O7.cif',
#  'cif_mp-1030980_RbNaMg6O7.cif',
#  'cif_mp-1031026_RbLiMg6O7.cif',
#  'cif_mp-1031131_LiMg6SbO8.cif',
#  'cif_mp-1031136_CeHfMg6O8.cif',
#  'cif_mp-1031185_LiMg6BO7.cif',
#  'cif_mp-1031233_CsMg6SiO8.cif',
#  'cif_mp-1031273_KMg6BO7.cif',
#  'cif_mp-1031460_Mg6SiSnO8.cif',
#  'cif_mp-1031470_Mg6VBiO8.cif',
#  'cif_mp-1031540_Mg6AlSiO8.cif',
#  'cif_mp-1031550_Mg6SnCO8.cif',
#  'cif_mp-1031564_Mg6CdSnO8.cif',
#  'cif_mp-1031751_Mg6SnCO8.cif',
#  'cif_mp-1031885_KMg6MnO8.cif',
#  'cif_mp-1031907_YMg6NbO8.cif',
#  'cif_mp-1031979_Mg6CrCoO8.cif',
#  'cif_mp-1031988_Mg6CoCO8.cif',
#  'cif_mp-1032012_Mg6TiZnO8.cif',
#  'cif_mp-1032096_Mg6CoCuO8.cif',
#  'cif_mp-1032467_LiMg6FeO8.cif',
#  'cif_mp-1032744_YMg6CuO8.cif',
#  'cif_mp-1032771_YMg6CuO8.cif',
#  'cif_mp-1032929_CaMg6FeO8.cif',
#  'cif_mp-1033028_SrMg6AlO8.cif',
#  'cif_mp-1033065_CsMg6AlO8.cif',
#  'cif_mp-1033259_Mg6CdBiO8.cif',
#  'cif_mp-1033359_Mg6NbBiO8.cif',
#  'cif_mp-1033410_SrMg6BiO8.cif',
#  'cif_mp-1033459_Mg6NbCO8.cif',
#  'cif_mp-1033488_SrMg6CO8.cif',
#  'cif_mp-1033518_CsMg6SbO8.cif',
#  'cif_mp-1033686_HfMg14BO16.cif',
#  'cif_mp-1033715_CsHfMg6O7.cif',
#  'cif_mp-1033747_Mg14BiBO16.cif',
#  'cif_mp-1033748_Mg14CdCO16.cif',
#  'cif_mp-1033978_KRbMg14O15.cif',
#  'cif_mp-1034033_Mg14TiCO16.cif',
#  'cif_mp-1034035_Mg14TiCdO16.cif',
#  'cif_mp-1034041_KLiMg14O15.cif',
#  'cif_mp-1034246_RbMg14CrO16.cif',
#  'cif_mp-1034380_NaHfMg14O15.cif',
#  'cif_mp-1034473_BaMg14VO16.cif',
#  'cif_mp-1034517_Mg14NbVO16.cif',
#  'cif_mp-1034765_Mg14NbSiO16.cif',
#  'cif_mp-1034805_Mg14NbNiO16.cif',
#  'cif_mp-1034899_Mg14TiZnO16.cif',
#  'cif_mp-1034906_NaCeMg14O16.cif',
#  'cif_mp-1035303_Mg14CoSiO16.cif',
#  'cif_mp-1035444_RbMg14CoO16.cif',
#  'cif_mp-1035626_Mg14NbFeO16.cif',
#  'cif_mp-1035680_KMg14BO15.cif',
#  'cif_mp-1036120_HfMg14MnO16.cif',
#  'cif_mp-1036211_BaMg14MnO16.cif',
#  'cif_mp-1036325_CaMg14NbO16.cif',
#  'cif_mp-1036525_Mg14NbAlO16.cif',
#  'cif_mp-10365_MnCoSi.cif',
#  'cif_mp-1036646_Mg14AlSnO16.cif',
#  'cif_mp-1036672_SrMg30SnO32.cif',
#  'cif_mp-1036755_Mg30VBiO32.cif',
#  'cif_mp-1036757_Mg30VSiO32.cif',
#  'cif_mp-1036758_SrMg30VO32.cif',
#  'cif_mp-1036804_Mg30TiVO32.cif',
#  'cif_mp-1036923_Mg30CoBiO32.cif',
#  'cif_mp-1037288_Mg30CrCuO32.cif',
#  'cif_mp-1037450_Mg30ZnCdO32.cif',
#  'cif_mp-1037462_Mg30NbZnO32.cif',
#  'cif_mp-1037608_SrMg30ZnO32.cif',
#  'cif_mp-1037924_Mg30MnZnO32.cif',
#  'cif_mp-1038038_LiMg30MnO32.cif',
#  'cif_mp-1038048_BaMg30MnO32.cif',
#  'cif_mp-1038167_Mg30MnVO32.cif',
#  'cif_mp-1038202_Mg30AlBiO32.cif',
#  'cif_mp-1038204_LiMg30AlO32.cif',
#  'cif_mp-1038339_Mg30AlVO32.cif',
#  'cif_mp-1038446_HfMg30GaO32.cif',
#  'cif_mp-1038544_HfMg30WO32.cif',
#  'cif_mp-1038595_Mg30CrCdO32.cif',
#  'cif_mp-1038689_CsHfMg30O31.cif',
#  'cif_mp-1038744_SrMg30CrO32.cif',
#  'cif_mp-1038788_CeMg.cif',
#  'cif_mp-1038789_Mg2Bi.cif',
#  'cif_mp-1038834_Mg2Bi.cif',
#  'cif_mp-1038862_CaMg.cif',
#  'cif_mp-1039170_MgBi.cif',
#  'cif_mp-1039186_MgCd.cif',
#  'cif_mp-1039634_RbMg30BiO32.cif',
#  'cif_mp-1039659_CeMg2.cif',
#  'cif_mp-1039694_RbMg30WO32.cif',
#  'cif_mp-1039724_RbMg30CrO32.cif',
#  'cif_mp-1039831_Mg30CdSiO32.cif',
#  'cif_mp-1039932_NaLaMg30O32.cif',
#  'cif_mp-1039957_LiHfMg30O31.cif',
#  'cif_mp-1039970_RbNaMg30O31.cif',
#  'cif_mp-1040157_LiMg30SiO32.cif',
#  'cif_mp-1040232_RbLiMg30O31.cif',
#  'cif_mp-1040283_KNaMg30O31.cif',
#  'cif_mp-1040783_Ho(SbO3)2.cif',
#  'cif_mp-1040834_WO2.cif',
#  'cif_mp-1040851_ZnSn2P2O9.cif',
#  'cif_mp-1040914_CaNi2(PO4)2.cif',
#  'cif_mp-1040986_Mg(FeO2)2.cif',
#  'cif_mp-1041288_BaCr4O8.cif',
#  'cif_mp-1041341_BaSbF7.cif',
#  'cif_mp-1041374_MgCr4O9.cif',
#  'cif_mp-1041467_CaFe2(CuO4)2.cif',
#  'cif_mp-1041479_MgCu(SiO3)2.cif',
#  'cif_mp-1041494_Mg(CuO2)2.cif',
#  'cif_mp-1041564_CaTi(SiO3)2.cif',
#  'cif_mp-1041629_Mg(CoO2)2.cif',
#  'cif_mp-1041642_Mg(SbO2)2.cif',
#  'cif_mp-1041768_MgCr2CuO7.cif',
#  'cif_mp-1041823_Ca(AgO2)2.cif',
#  'cif_mp-1042060_MgNiP2O7.cif',
#  'cif_mp-1042127_BiS2.cif',
#  'cif_mp-1042234_Ca(SnO2)2.cif',
#  'cif_mp-1042328_YMo(WO4)2.cif',
#  'cif_mp-1042444_Mg2Sb3O8.cif',
#  'cif_mp-1042475_BaYCrCuO5.cif',
#  'cif_mp-1042519_BaAlCuWO5.cif',
#  'cif_mp-1042689_CaBiWO5.cif',
#  'cif_mp-1042711_CaFeBiO5.cif',
#  'cif_mp-1042729_ZnCu3(BiO3)4.cif',
#  'cif_mp-1042856_Ca2V3O8.cif',
#  'cif_mp-1042909_Ca2Nb2SnO8.cif',
#  'cif_mp-1043070_ZnAs2WO7.cif',
#  'cif_mp-1043136_Cr4(CuO4)3.cif',
#  'cif_mp-1043149_MgCo(GeO3)2.cif',
#  'cif_mp-1043184_V4Zn(CuO4)3.cif',
#  'cif_mp-1043219_MgMo2O5.cif',
#  'cif_mp-1043253_Mg(Fe2O3)2.cif',
#  'cif_mp-1043255_CaCo2O5.cif',
#  'cif_mp-1043551_CaNiSbP2O9.cif',
#  'cif_mp-10435_Y(AlSi)2.cif',
#  'cif_mp-1043611_Zn(Fe2O3)2.cif',
#  'cif_mp-1043624_Mg(SbO2)4.cif',
#  'cif_mp-1043839_LaMg(FeO3)2.cif',
#  'cif_mp-1043864_CaLaFeSbO6.cif',
#  'cif_mp-1043885_Sr2AlCu2MoO7.cif',
#  'cif_mp-1043973_ZnW4O9.cif',
#  'cif_mp-1044127_ZnNi2(PO5)2.cif',
#  'cif_mp-1044162_PWO5.cif',
#  'cif_mp-1044267_TiV(PO4)3.cif',
#  'cif_mp-1044282_MgTiFe(PO4)3.cif',
#  'cif_mp-1044358_CaCrBiO5.cif',
#  'cif_mp-1044499_PrZn(SnO3)2.cif',
#  'cif_mp-1044577_BaZn(NiO2)4.cif',
#  'cif_mp-1044787_PrZn(NiO3)2.cif',
#  'cif_mp-1044853_TiO2.cif',
#  'cif_mp-1045326_Zn(BiO3)2.cif',
#  'cif_mp-1045435_Li(MnS2)2.cif',
#  'cif_mp-1045744_Mn4Al(CuO4)3.cif',
#  'cif_mp-1045813_CaNi(PO3)4.cif',
#  'cif_mp-1045862_Ba2ZnCr2CuF14.cif',
#  'cif_mp-1045961_TiZnO2.cif',
#  'cif_mp-1046045_Sr2YTlNi2O7.cif',
#  'cif_mp-1046096_SrMgTi(PO4)2.cif',
#  'cif_mp-1046176_Sr2Cu2SbO7.cif',
#  'cif_mp-1046252_Zn(BiO2)4.cif',
#  'cif_mp-1046352_Ta2MoO8.cif',
#  'cif_mp-1046426_SrVZn(PO4)2.cif',
#  'cif_mp-1046496_SrCaFe(PO4)2.cif',
#  'cif_mp-1046522_Ba2Mg2Tl2Ni3O10.cif',
#  'cif_mp-1046567_Ba2Tl2Mo3O10.cif',
#  'cif_mp-1046644_MgMo3O8.cif',
#  'cif_mp-1046647_ZnCoPO5.cif',
#  'cif_mp-1046709_ZnCrSF5.cif',
#  'cif_mp-1046740_MgNiPO5.cif',
#  'cif_mp-1046839_Mg2Nb2CrO8.cif',
#  'cif_mp-1046867_Mg(SnO2)2.cif',
#  'cif_mp-1046961_BaMg(AgO2)4.cif',
#  'cif_mp-1046983_Nb2CrO8.cif',
#  'cif_mp-1046998_BaCa(AgO2)4.cif',
#  'cif_mp-1047047_Ti3(P2O7)2.cif',
#  'cif_mp-1047238_Sr2Y2W2O7.cif',
#  'cif_mp-1047292_MgMn2O4.cif',
#  'cif_mp-1047345_Sr2YMn2O7.cif',
#  'cif_mp-1047356_TaF5.cif',
#  'cif_mp-1047421_BaTi4O8.cif',
#  'cif_mp-1047527_Ca2YFeO5.cif',
#  'cif_mp-1047530_YTi3F15.cif',
#  'cif_mp-1047653_TaAl(WO4)2.cif',
#  'cif_mp-1047752_Sb(WO4)2.cif',
#  'cif_mp-1047775_Mg3Co3(AsO4)4.cif',
#  'cif_mp-1047811_Be3Si3(MoO6)2.cif',
#  'cif_mp-1047872_MgTi2Be3(SiO4)3.cif',
#  'cif_mp-1047986_MgTi4O8.cif',
#  'cif_mp-1047992_ZnSnP2O7.cif',
#  'cif_mp-1048015_CaFe4O9.cif',
#  'cif_mp-1048029_Ni3P3O13.cif',
#  'cif_mp-1048068_Sr2YTi2AlO7.cif',
#  'cif_mp-1048115_BaYCu4O7.cif',
#  'cif_mp-1048143_Ba2AlW3O8.cif',
#  'cif_mp-1048266_MgCrP2O7.cif',
#  'cif_mp-1048301_CaTi2Be3(SiO4)3.cif',
#  'cif_mp-1048371_BaCr4O7.cif',
#  'cif_mp-1048496_Ba2Co3O7.cif',
#  'cif_mp-1048511_Ba2Mn3O7.cif',
#  'cif_mp-1048546_V3Se2ClO8.cif',
#  'cif_mp-1048549_Ba2Ca3Mn4Tl2O12.cif',
#  'cif_mp-1048568_Sr2YSn2O7.cif',
#  'cif_mp-1048637_Sr3CaCo2S2O5.cif',
#  'cif_mp-1048666_Ca3(TiS2)8.cif',
#  'cif_mp-1048893_Ca(CuO2)2.cif',
#  'cif_mp-1054_ErTl.cif',
#  'cif_mp-1057758_BaN.cif',
#  'cif_mp-1057979_IN.cif',
#  'cif_mp-1058119_KS.cif',
#  'cif_mp-1058586_SrN.cif',
#  'cif_mp-1058689_KN.cif',
#  'cif_mp-1061635_MgNb2.cif',
#  'cif_mp-1063239_DyPd2.cif',
#  'cif_mp-1063522_CePd2.cif',
#  'cif_mp-1063988_S.cif',
#  'cif_mp-1064554_BiRh.cif',
#  'cif_mp-10645_TbSe.cif',
#  'cif_mp-1065609_GdTlTe2.cif',
#  'cif_mp-1066006_VFeCoAs.cif',
#  'cif_mp-1066274_PtPb.cif',
#  'cif_mp-10679_Ba.cif',
#  'cif_mp-1068325_Sr(InHg)2.cif',
#  'cif_mp-10687_LiCdP.cif',
#  'cif_mp-1069079_FeBiO3.cif',
#  'cif_mp-1069193_Pd(NCl)2.cif',
#  'cif_mp-1069723_U(CuAs)2.cif',
#  'cif_mp-1069726_Pd(NCl)2.cif',
#  'cif_mp-1069811_Hf2H2Pd.cif',
#  'cif_mp-1072086_TaS2.cif',
#  'cif_mp-1072087_LaAu2.cif',
#  'cif_mp-1072167_EuN2.cif',
#  'cif_mp-1072737_NdAg2.cif',
#  'cif_mp-1073254_MgSi2.cif',
#  'cif_mp-1073358_MgSi2.cif',
#  'cif_mp-1073387_MgSi2.cif',
#  'cif_mp-1073416_MgSi2.cif',
#  'cif_mp-1073477_MgSi2.cif',
#  'cif_mp-1074149_Mg4Si7.cif',
#  'cif_mp-1074199_Mg4Si7.cif',
#  'cif_mp-1074272_Mg4Si3.cif',
#  'cif_mp-1074331_Mg4Si3.cif',
#  'cif_mp-1074803_Mg7Si4.cif',
#  'cif_mp-1074923_Mg7Si4.cif',
#  'cif_mp-10749_SrCuSb.cif',
#  'cif_mp-1075131_Mg3Si4.cif',
#  'cif_mp-1075253_Mg3Si4.cif',
#  'cif_mp-1075368_Mg5Si6.cif',
#  'cif_mp-1075405_Mg5Si6.cif',
#  'cif_mp-1075421_Mg5Si6.cif',
#  'cif_mp-1075616_Mg5Si9.cif',
#  'cif_mp-1075638_Mg5Si9.cif',
#  'cif_mp-1075674_Mg5Si9.cif',
#  'cif_mp-1075761_Mg5Si9.cif',
#  'cif_mp-1076014_Ca2Mn2O5.cif',
#  'cif_mp-1076055_Sm2V2O5.cif',
#  'cif_mp-1076080_Sr5Ca3Mn7FeO24.cif',
#  'cif_mp-1076134_Sr3Ca5Ti3Mn5O20.cif',
#  'cif_mp-1076204_La7SmCr2(Fe3O10)2.cif',
#  'cif_mp-1076289_Sm2Mn2O5.cif',
#  'cif_mp-1076335_K5Na3Nb8O24.cif',
#  'cif_mp-1076505_Sr3CaTiMn3O10.cif',
#  'cif_mp-1076581_La7SmTi3V5O24.cif',
#  'cif_mp-1076671_La7SmMn4(FeO6)4.cif',
#  'cif_mp-1076685_K4Na4MoW7O24.cif',
#  'cif_mp-1076884_Sr6Ca2Fe7CoO20.cif',
#  'cif_mp-1077088_PrCdNi4.cif',
#  'cif_mp-1077095_LuCdNi4.cif',
#  'cif_mp-1077147_HoSi2.cif',
#  'cif_mp-1077267_ErSi2.cif',
#  'cif_mp-1077457_Eu.cif',
#  'cif_mp-1077485_HoSnGe.cif',
#  'cif_mp-1077708_Cr2Fe.cif',
#  'cif_mp-1077776_ScB2Ir3.cif',
#  'cif_mp-1077831_EuScGe.cif',
#  'cif_mp-1078085_Cs2PdCl4.cif',
#  'cif_mp-1078108_Mn2B4Mo.cif',
#  'cif_mp-1078110_Mn(GaS2)2.cif',
#  'cif_mp-1078140_Mn(InSe2)2.cif',
#  'cif_mp-1078184_Eu4Bi2O.cif',
#  'cif_mp-1078200_V2CoSe4.cif',
#  'cif_mp-1078335_Pr2BiN.cif',
#  'cif_mp-1078409_Ba2LaBiO6.cif',
#  'cif_mp-1078431_LaBiSe2O.cif',
#  'cif_mp-1078435_BaCd2Pt.cif',
#  'cif_mp-1078505_DySn3.cif',
#  'cif_mp-1078533_Th(AlAu)2.cif',
#  'cif_mp-1078539_Sr2MgMoO6.cif',
#  'cif_mp-1078684_ErCdGa.cif',
#  'cif_mp-1078698_ZrCuGeAs.cif',
#  'cif_mp-1078716_SrMoO3.cif',
#  'cif_mp-1078726_CsHoS2.cif',
#  'cif_mp-1078729_Zr6CuBi2.cif',
#  'cif_mp-1078740_Ho3(CoGe2)2.cif',
#  'cif_mp-1078751_Na2PdSe2.cif',
#  'cif_mp-1078775_Nd(CrB3)2.cif',
#  'cif_mp-1078857_DyAlCu.cif',
#  'cif_mp-1078896_Mn2Ga2S5.cif',
#  'cif_mp-1078992_Th3Pt5.cif',
#  'cif_mp-1079017_CeCdCu.cif',
#  'cif_mp-1079065_Zr3Co.cif',
#  'cif_mp-1079072_Mg3In.cif',
#  'cif_mp-1079107_Co(N3Cl)2.cif',
#  'cif_mp-1079174_PuPd.cif',
#  'cif_mp-1079250_SmNiSb2.cif',
#  'cif_mp-1079269_SiPt3.cif',
#  'cif_mp-1079295_ErSi.cif',
#  'cif_mp-1079393_Co3Si.cif',
#  'cif_mp-1079489_Zr2InAu2.cif',
#  'cif_mp-1079582_VIr.cif',
#  'cif_mp-1079596_Er2NiSn6.cif',
#  'cif_mp-1079670_TmSb(PbO3)2.cif',
#  'cif_mp-1079671_Tb2CuGe6.cif',
#  'cif_mp-1079704_Tb3Sn7.cif',
#  'cif_mp-1079782_Cu(N3Cl)2.cif',
#  'cif_mp-1079818_CrTe.cif',
#  'cif_mp-1079829_Ti2CdO6.cif',
#  'cif_mp-1079855_LiPd7.cif',
#  'cif_mp-1079860_HfGaNi.cif',
#  'cif_mp-1079925_Sr2YCrO6.cif',
#  'cif_mp-1079999_Zr2NiP2.cif',
#  'cif_mp-1080000_CdNCl3.cif',
#  'cif_mp-1080031_Co(ClO3)2.cif',
#  'cif_mp-1080110_Ti(NF2)3.cif',
#  'cif_mp-1080142_Co(N2Cl)3.cif',
#  'cif_mp-1080199_V3N4.cif',
#  'cif_mp-1080205_KMnO2.cif',
#  'cif_mp-1080213_CaMn4O8.cif',
#  'cif_mp-1080237_Te4MoW3(SeS)2.cif',
#  'cif_mp-1080241_Li2Ge(S2O7)3.cif',
#  'cif_mp-1080259_CeSe2.cif',
#  'cif_mp-1080272_CeSe2.cif',
#  'cif_mp-1080273_CeSe2.cif',
#  'cif_mp-1080303_CeSe2.cif',
#  'cif_mp-1080363_CeSe2.cif',
#  'cif_mp-1080381_SmB2Ir3.cif',
#  'cif_mp-1080424_ScAgGe.cif',
#  'cif_mp-1080452_KCd4As3.cif',
#  'cif_mp-1080515_Nd(BOs)2.cif',
#  'cif_mp-1080528_U3Al3NiRu2.cif',
#  'cif_mp-1080567_Sm(NiSb)2.cif',
#  'cif_mp-1080572_NdCoGe2.cif',
#  'cif_mp-1080625_Sr2LiReO6.cif',
#  'cif_mp-1080661_Gd2SnAu2.cif',
#  'cif_mp-1080749_CsFeO2.cif',
#  'cif_mp-1080834_Na5As4.cif',
#  'cif_mp-1080842_Ba2UPbO6.cif',
#  'cif_mp-1084775_ScSnPt.cif',
#  'cif_mp-1084847_TbTe3.cif',
#  'cif_mp-1086660_Nb2FeB2.cif',
#  'cif_mp-1086_TaC.cif',
#  'cif_mp-1087509_P4Os.cif',
#  'cif_mp-1087511_UFeAs2.cif',
#  'cif_mp-1087524_LiH2N.cif',
#  'cif_mp-1092251_Nd2CuGe6.cif',
#  'cif_mp-1093567_Y2CdPd.cif',
#  'cif_mp-1093580_Li2YIn.cif',
#  'cif_mp-1093581_ZrCuAu2.cif',
#  'cif_mp-1093623_LiHg2Pt.cif',
#  'cif_mp-1093627_Ta2NbRe.cif',
#  'cif_mp-1093634_BaSrMg2.cif',
#  'cif_mp-1093652_In2GaSn.cif',
#  'cif_mp-1093672_Ba2CdIn.cif',
#  'cif_mp-1093688_CaCdAg2.cif',
#  'cif_mp-1093693_HfTlAu2.cif',
#  'cif_mp-1093827_LiZr2Ru.cif',
#  'cif_mp-1093848_SrLaAu2.cif',
#  'cif_mp-1093849_Nb2ReW.cif',
#  'cif_mp-1093889_Li2ZnAg.cif',
#  'cif_mp-1093891_AlZnNi2.cif',
#  'cif_mp-1093918_Al2CuPd.cif',
#  'cif_mp-1093941_Ta2TiRe.cif',
#  'cif_mp-1093974_CrTcGe2.cif',
#  'cif_mp-1094022_Zn(GaS2)2.cif',
#  'cif_mp-1094065_Sr2Co2O5.cif',
#  'cif_mp-1094069_Sr2Cd2Cu(SO)2.cif',
#  'cif_mp-1094075_P.cif',
#  'cif_mp-1094105_Na4ZnSe3.cif',
#  'cif_mp-1094122_Mg.cif',
#  'cif_mp-1094135_LiO2.cif',
#  'cif_mp-1094168_LaMg2.cif',
#  'cif_mp-1094194_MgZn5.cif',
#  'cif_mp-1094216_LaMg.cif',
#  'cif_mp-1094227_Mg5Sn.cif',
#  'cif_mp-1094238_MgSn.cif',
#  'cif_mp-1094251_MgSn.cif',
#  'cif_mp-1094275_MgTi2.cif',
#  'cif_mp-1094286_SrMg.cif',
#  'cif_mp-1094313_Sr2Mg.cif',
#  'cif_mp-1094320_SrMg3.cif',
#  'cif_mp-1094346_MgTi.cif',
#  'cif_mp-1094434_Mg5Zn.cif',
#  'cif_mp-1094455_Mg2Zn.cif',
#  'cif_mp-1094532_Mg2Sb.cif',
#  'cif_mp-1094589_LiMg.cif',
#  'cif_mp-1094595_Mg2Sb.cif',
#  'cif_mp-1094620_MgGa.cif',
#  'cif_mp-1094621_MgGa.cif',
#  'cif_mp-1094635_Mg2Ga.cif',
#  'cif_mp-1094637_MgGa.cif',
#  'cif_mp-1094646_MgGa2.cif',
#  'cif_mp-1094688_Sr3Mg.cif',
#  'cif_mp-1094697_Mg2Cd.cif',
#  'cif_mp-1094746_SrMg3.cif',
#  'cif_mp-1094804_MgCd2.cif',
#  'cif_mp-1094870_YMg.cif',
#  'cif_mp-1094878_MgBi2.cif',
#  'cif_mp-1094956_MgZn.cif',
#  'cif_mp-1095039_Sr2HfCrO6.cif',
#  'cif_mp-1095201_ZrCuGe2.cif',
#  'cif_mp-1095223_OF2.cif',
#  'cif_mp-1095382_Fe5O7.cif',
#  'cif_mp-1095479_GdS2.cif',
#  'cif_mp-1095527_GdGeRh.cif',
#  'cif_mp-1095533_KAsO4.cif',
#  'cif_mp-1095536_VNiGe.cif',
#  'cif_mp-1095622_Zr(MoO4)2.cif',
#  'cif_mp-1095641_Tb5S7.cif',
#  'cif_mp-1095711_MgScAu2.cif',
#  'cif_mp-1095762_MgRu2W.cif',
#  'cif_mp-1095776_LiCd2Hg.cif',
#  'cif_mp-1095784_LiAlZn2.cif',
#  'cif_mp-1095853_Y2CdAg.cif',
#  'cif_mp-1095956_YAgAu2.cif',
#  'cif_mp-1095963_Hf2MnZn.cif',
#  'cif_mp-1095964_Zn2AgPd.cif',
#  'cif_mp-1095977_Ba2LiCd.cif',
#  'cif_mp-1095990_Ba2NaLi.cif',
#  'cif_mp-1095991_Zr2CdTc.cif',
#  'cif_mp-1096026_Ca2ZnSn.cif',
#  'cif_mp-1096069_Ba2NaIn.cif',
#  'cif_mp-1096090_NaTl2Hg.cif',
#  'cif_mp-1096104_NbV2Os.cif',
#  'cif_mp-1096131_HfScZn2.cif',
#  'cif_mp-1096228_Ti2FeRu.cif',
#  'cif_mp-1096244_TiTc2Ge.cif',
#  'cif_mp-1096277_CdPd2Pb.cif',
#  'cif_mp-1096295_VCr2Mo.cif',
#  'cif_mp-1096320_Y2MgIr.cif',
#  'cif_mp-1096362_Sr2HgBi.cif',
#  'cif_mp-1096458_NaTlCd2.cif',
#  'cif_mp-1096492_Be2CrPt.cif',
#  'cif_mp-1096526_CsRbI2.cif',
#  'cif_mp-1096528_Y2InRu.cif',
#  'cif_mp-1096555_Ba2CdGa.cif',
#  'cif_mp-1096603_Ba2LiHg.cif',
#  'cif_mp-1096633_K2NaHg.cif',
#  'cif_mp-1096686_TlBiPb2.cif',
#  'cif_mp-1096688_Ba2LiTl.cif',
#  'cif_mp-1096696_Y2PtRh.cif',
#  'cif_mp-1096708_NaAgPd2.cif',
#  'cif_mp-1096726_BaNa2Sn.cif',
#  'cif_mp-1096761_KRb2Na.cif',
#  'cif_mp-1096769_Ni3Cl4.cif',
#  'cif_mp-1096798_ScAgO2.cif',
#  'cif_mp-1096811_Al(BiO2)2.cif',
#  'cif_mp-1096842_Ba3SnS5.cif',
#  'cif_mp-1096889_CrN2.cif',
#  'cif_mp-1096945_DyMn2O4.cif',
#  'cif_mp-1096957_CrN2.cif',
#  'cif_mp-1096995_HfSO.cif',
#  'cif_mp-1097065_Li2HfN2.cif',
#  'cif_mp-1097153_LiAl2Co.cif',
#  'cif_mp-1097167_Ti2IrOs.cif',
#  'cif_mp-1097216_CaPd2Pb.cif',
#  'cif_mp-1097236_Li2SnPb.cif',
#  'cif_mp-1097309_Ba2InHg.cif',
#  'cif_mp-1097321_MgCuPd2.cif',
#  'cif_mp-1097383_SrSnHg2.cif',
#  'cif_mp-1097411_GaSnRu2.cif',
#  'cif_mp-1097497_CaSbRh2.cif',
#  'cif_mp-1097506_LiCdIn2.cif',
#  'cif_mp-1097512_LiZnCd2.cif',
#  'cif_mp-1097515_K2AgAu.cif',
#  'cif_mp-1097623_Ca2PdRh.cif',
#  'cif_mp-1097628_Be2IrAu.cif',
#  'cif_mp-1097632_NbMo2W.cif',
#  'cif_mp-1097635_NaSr2Ca.cif',
#  'cif_mp-1097654_Mn2CoTc.cif',
#  'cif_mp-1097889_NiBrO.cif',
#  'cif_mp-1097905_Li3Mn4O8.cif',
#  'cif_mp-1098064_CsHfMg14O15.cif',
#  'cif_mp-1098122_KMg6Nb.cif',
#  'cif_mp-1098346_Mg30SnCO32.cif',
#  'cif_mp-1098422_LiMg30BO31.cif',
#  'cif_mp-1099092_SrMg14Fe.cif',
#  'cif_mp-1099115_CsCeMg14.cif',
#  'cif_mp-1099222_CsMg14CrO16.cif',
#  'cif_mp-1099265_YMg6Cu.cif',
#  'cif_mp-1099266_YMg6Ni.cif',
#  'cif_mp-1099287_Mg6FeC.cif',
#  'cif_mp-1099288_RbMg6Co.cif',
#  'cif_mp-1099315_RbMg6Ti.cif',
#  'cif_mp-1099572_MnInF3.cif',
#  'cif_mp-1099653_Sr2Ca6FeCo7O20.cif',
#  'cif_mp-1099703_Sr3CaTi3MnO12.cif',
#  'cif_mp-1099945_KNaW2O5.cif',
#  'cif_mp-1100085_Ba3SrCoCu3O10.cif',
#  'cif_mp-1100163_RbMg6Mo.cif',
#  'cif_mp-1100395_BaBrCl.cif',
#  'cif_mp-1100417_VSbRh.cif',
#  'cif_mp-1100438_LiScSn.cif',
#  'cif_mp-1100486_Li9Mn7O16.cif',
#  'cif_mp-1100526_Li9Mn7O16.cif',
#  'cif_mp-1100536_Li9Mn7O16.cif',
#  'cif_mp-1100556_Li9Mn7O16.cif',
#  'cif_mp-1100570_Li9Mn2Co5O16.cif',
#  'cif_mp-1100595_Li9Mn2Co5O16.cif',
#  'cif_mp-1100597_Li9Mn2Co5O16.cif',
#  'cif_mp-1100602_Li9Mn2Co5O16.cif',
#  'cif_mp-1100616_Li9Mn2Co5O16.cif',
#  'cif_mp-1100655_Li9Mn2Co5O16.cif',
#  'cif_mp-1100657_Li9Mn2Co5O16.cif',
#  'cif_mp-11006_BaPS3.cif',
#  'cif_mp-1100701_Li9Mn2Co5O16.cif',
#  'cif_mp-1100714_Li9Mn2Co5O16.cif',
#  'cif_mp-1100720_Li9Mn2Co5O16.cif',
#  'cif_mp-1100727_Li9Mn2Co5O16.cif',
#  'cif_mp-1100751_Li9Mn2Co5O16.cif',
#  'cif_mp-1100753_Li9Mn2Co5O16.cif',
#  'cif_mp-1100785_SrEuIn2.cif',
#  'cif_mp-1100895_Y5O4F7.cif',
#  'cif_mp-1100928_VMoO5.cif',
#  'cif_mp-1100997_TlCr5Te8.cif',
#  'cif_mp-1101073_TiZn(BiO3)2.cif',
#  'cif_mp-1101184_V3O5F.cif',
#  'cif_mp-1101221_V4O5F7.cif',
#  'cif_mp-1101295_Ti2O3.cif',
#  'cif_mp-1101300_TiMn3Fe2(PO4)6.cif',
#  'cif_mp-1101345_SrCaI4.cif',
#  'cif_mp-1101509_LiMo(PO4)2.cif',
#  'cif_mp-1101524_LiFe2(PO4)3.cif',
#  'cif_mp-1101525_LiSn(PO3)4.cif',
#  'cif_mp-1101562_Cr(PO3)5.cif',
#  'cif_mp-1101785_YCoGe.cif',
#  'cif_mp-1101790_CrNiP.cif',
#  'cif_mp-1101818_BaLaAgSe3.cif',
#  'cif_mp-1101900_LuCo3.cif',
#  'cif_mp-1101972_CdF2.cif',
#  'cif_mp-1102029_CsUTe3Au.cif',
#  'cif_mp-1102101_ScCoSn.cif',
#  'cif_mp-1102449_SmAlAu.cif',
#  'cif_mp-1102477_Eu2Si.cif',
#  'cif_mp-1102532_NbGeRh.cif',
#  'cif_mp-1102554_CuClO.cif',
#  'cif_mp-1102589_SrNiGe.cif',
#  'cif_mp-1102641_PdC2(NO)4.cif',
#  'cif_mp-1102760_DyGaNi.cif',
#  'cif_mp-1102778_Dy2In8Co.cif',
#  'cif_mp-1102948_GdNi4B.cif',
#  'cif_mp-1102968_Tm2(NiB2)3.cif',
#  'cif_mp-1102977_GaAsO4.cif',
#  'cif_mp-1102997_VBiO4.cif',
#  'cif_mp-1103144_CBrN3O.cif',
#  'cif_mp-1103172_CaCdPd.cif',
#  'cif_mp-1103229_Li4Sm3Ge4.cif',
#  'cif_mp-1103369_CuWO4.cif',
#  'cif_mp-1103431_Ga2Au.cif',
#  'cif_mp-1103475_TeO2.cif',
#  'cif_mp-1103493_Tm(Mo3S4)2.cif',
#  'cif_mp-1103573_Sm3Zn11.cif',
#  'cif_mp-1103663_Sr3TaHO6.cif',
#  'cif_mp-1103679_CuWO4.cif',
#  'cif_mp-1103792_Nb2O2F3.cif',
#  'cif_mp-1103827_Cu(NF2)2.cif',
#  'cif_mp-1103844_Ho(MnAl2)4.cif',
#  'cif_mp-11038_Zr6Al2Fe.cif',
#  'cif_mp-1103954_Tb3Ga8Ir3.cif',
#  'cif_mp-1103959_Ho4(CoB2)3.cif',
#  'cif_mp-1104015_CsMoO2F3.cif',
#  'cif_mp-1104028_HgC2(NO)2.cif',
#  'cif_mp-1104047_Al4Tc.cif',
#  'cif_mp-1104221_Ho(Ni2P)2.cif',
#  'cif_mp-1104253_Lu3Ga8Cu3.cif',
#  'cif_mp-1104261_LiFePO4.cif',
#  'cif_mp-1104279_Tb3GaCo3.cif',
#  'cif_mp-1104405_Na(SO2)2.cif',
#  'cif_mp-1104451_SmGa6.cif',
#  'cif_mp-1104471_Mo(Br2N)2.cif',
#  'cif_mp-1104676_Os(SeBr6)2.cif',
#  'cif_mp-1104693_LiCa2HC3.cif',
#  'cif_mp-1104717_Na2AgF4.cif',
#  'cif_mp-1104730_Sm(Ni2Sn)2.cif',
#  'cif_mp-1104744_Hg(CO2)2.cif',
#  'cif_mp-1104854_Ni3(PbS)2.cif',
#  'cif_mp-1105102_Sm3GaCo3.cif',
#  'cif_mp-1105118_As2O3.cif',
#  'cif_mp-1105139_Zr3Sb.cif',
#  'cif_mp-1105167_VCuO3.cif',
#  'cif_mp-11051_NaSn.cif',
#  'cif_mp-1105280_LiTaO3.cif',
#  'cif_mp-1105365_KNO3.cif',
#  'cif_mp-1105402_Sr2DyMoO6.cif',
#  'cif_mp-1105463_Cu5(AsO5)2.cif',
#  'cif_mp-1105594_La3Cu3Sb4.cif',
#  'cif_mp-1105648_Zn2BrN.cif',
#  'cif_mp-1105718_NiBiO3.cif',
#  'cif_mp-1105724_Ba2ErGaTe5.cif',
#  'cif_mp-1105730_CaU(PbO3)2.cif',
#  'cif_mp-1105734_Ho2Co7.cif',
#  'cif_mp-1105779_ZnHg3(SCl2)2.cif',
#  'cif_mp-1105877_Si2Ni3H4O9.cif',
#  'cif_mp-1105910_Pu2Zn17.cif',
#  'cif_mp-1105914_KCaH3.cif',
#  'cif_mp-1105938_K2Dy4Cu4S9.cif',
#  'cif_mp-1105942_Sm5Ga3.cif',
#  'cif_mp-1105949_Eu5Sb3.cif',
#  'cif_mp-1105959_Re5Si3.cif',
#  'cif_mp-1106075_KAuC2N2Cl2O.cif',
#  'cif_mp-1106096_Ba2YInTe5.cif',
#  'cif_mp-1106113_HfSO7.cif',
#  'cif_mp-1106183_LiAlS2.cif',
#  'cif_mp-1106184_MnB4.cif',
#  'cif_mp-1106249_Ba4Co(ReO6)2.cif',
#  'cif_mp-1106290_Er2S3.cif',
#  'cif_mp-1106297_Ho4Ga12Fe.cif',
#  'cif_mp-1106357_Tb5Sn3.cif',
#  'cif_mp-1106363_Ho3Sb4Au3.cif',
#  'cif_mp-1110591_Rb2GaAuF6.cif',
#  'cif_mp-1110627_RbNa2AlF6.cif',
#  'cif_mp-1110630_Rb2LiNbF6.cif',
#  'cif_mp-1110675_K2RbBiF6.cif',
#  'cif_mp-1110708_Rb2LiSbBr6.cif',
#  'cif_mp-1110736_Rb3AlBr6.cif',
#  'cif_mp-1110824_Rb2NdAgI6.cif',
#  'cif_mp-1110869_K2LiBiCl6.cif',
#  'cif_mp-1110873_K2AgSbCl6.cif',
#  'cif_mp-11108_SrP3.cif',
#  'cif_mp-1110902_K2LiBiBr6.cif',
#  'cif_mp-1110993_Na2TlCuBr6.cif',
#  'cif_mp-1111019_KNa2AlF6.cif',
#  'cif_mp-1111089_Na2AsAuF6.cif',
#  'cif_mp-1111180_Na2FeHgF6.cif',
#  'cif_mp-1111185_K3AlBr6.cif',
#  'cif_mp-1111189_Na2CoHgF6.cif',
#  'cif_mp-1111289_Na2CuAsF6.cif',
#  'cif_mp-1111290_Li3CoF6.cif',
#  'cif_mp-1111310_Cs2TaCuF6.cif',
#  'cif_mp-1111315_Na2TiAgF6.cif',
#  'cif_mp-1111318_K3TlI6.cif',
#  'cif_mp-1111479_Cs2RbTmCl6.cif',
#  'cif_mp-1111508_Na2ErCuCl6.cif',
#  'cif_mp-1111538_Na2AgSbCl6.cif',
#  'cif_mp-1111541_Na2AgAuCl6.cif',
#  'cif_mp-1111586_Na2AlAgBr6.cif',
#  'cif_mp-1111667_Na2AlHgCl6.cif',
#  'cif_mp-1111671_K2LiInF6.cif',
#  'cif_mp-1111675_K2LiCeCl6.cif',
#  'cif_mp-1111722_Rb2AlAuBr6.cif',
#  'cif_mp-1111779_CsRb2InBr6.cif',
#  'cif_mp-1111785_CsRb2AlBr6.cif',
#  'cif_mp-1111873_Cs2KSbCl6.cif',
#  'cif_mp-1111937_K2HgAuF6.cif',
#  'cif_mp-1111966_Cs2RbNbF6.cif',
#  'cif_mp-1111979_Cs2NaRhF6.cif',
#  'cif_mp-1112025_K2YHgBr6.cif',
#  'cif_mp-1112029_K2ScHgI6.cif',
#  'cif_mp-1112032_K2HgAsI6.cif',
#  'cif_mp-1112058_K2YAuBr6.cif',
#  'cif_mp-1112098_K2DyAgCl6.cif',
#  'cif_mp-1112118_Cs2RbSmCl6.cif',
#  'cif_mp-1112191_K2AlInBr6.cif',
#  'cif_mp-1112195_K2HgSbF6.cif',
#  'cif_mp-1112321_CsK2GaCl6.cif',
#  'cif_mp-1112376_Cs3AsBr6.cif',
#  'cif_mp-1112408_Rb2HgAsF6.cif',
#  'cif_mp-1112413_Rb2YCuBr6.cif',
#  'cif_mp-1112551_Cs2TlSbF6.cif',
#  'cif_mp-1112710_Cs2KScI6.cif',
#  'cif_mp-1112904_Cs2InHgCl6.cif',
#  'cif_mp-1112911_Cs2HgAsBr6.cif',
#  'cif_mp-1112921_Cs2TbAuCl6.cif',
#  'cif_mp-1112929_Cs2AsAuI6.cif',
#  'cif_mp-1112932_Cs2AlAuI6.cif',
#  'cif_mp-1113091_Cs2InSbF6.cif',
#  'cif_mp-1113222_Cs2TaAgCl6.cif',
#  'cif_mp-1113284_Na2LiTmCl6.cif',
#  'cif_mp-1113311_Na3AuCl6.cif',
#  'cif_mp-1113416_Cs2GaAuBr6.cif',
#  'cif_mp-1113487_Rb2FeCuF6.cif',
#  'cif_mp-1113506_Na3SmCl6.cif',
#  'cif_mp-1113542_Cs2LuAgCl6.cif',
#  'cif_mp-1113543_Cs2AgAsCl6.cif',
#  'cif_mp-1113739_Na2LiNdCl6.cif',
#  'cif_mp-1113748_Rb2LiAsF6.cif',
#  'cif_mp-1113839_Na2LiDyCl6.cif',
#  'cif_mp-1113854_Rb2TlRuF6.cif',
#  'cif_mp-1113863_Rb2TlMoF6.cif',
#  'cif_mp-1113919_Na2LiGdCl6.cif',
#  'cif_mp-1114004_Rb2TlGaCl6.cif',
#  'cif_mp-11140_Ho2Sb5.cif',
#  'cif_mp-1114122_KRb2InBr6.cif',
#  'cif_mp-1114131_Rb2InSbBr6.cif',
#  'cif_mp-11144_SrCu9Ge4.cif',
#  'cif_mp-11145_BaCu9Ge4.cif',
#  'cif_mp-11183_Pr(BO2)3.cif',
#  'cif_mp-1118832_Ca2WN2.cif',
#  'cif_mp-11206_LiTi(SiO3)2.cif',
#  'cif_mp-1120745_NaTiF4.cif',
#  'cif_mp-1120808_Ti2ZnSn2O7.cif',
#  'cif_mp-11220_Sc2Al.cif',
#  'cif_mp-11225_TbAl.cif',
#  'cif_mp-11285_Ca3(GaNi)4.cif',
#  'cif_mp-11293_ZrCdCu2.cif',
#  'cif_mp-11345_ZrP.cif',
#  'cif_mp-11369_ErHg2.cif',
#  'cif_mp-11387_HfGa3.cif',
#  'cif_mp-11392_TmGa2Pd.cif',
#  'cif_mp-11470_Hg2Pt.cif',
#  'cif_mp-1147533_BiBOF4.cif',
#  'cif_mp-1147554_LiLaSO.cif',
#  'cif_mp-1147563_Sr4Fe3ClO8.cif',
#  'cif_mp-1147610_Li6Zn3(PS4)4.cif',
#  'cif_mp-1147615_Nb(Cu3O4)2.cif',
#  'cif_mp-1147639_Cd(Cu3O4)2.cif',
#  'cif_mp-1147648_Sr2CoSeO2.cif',
#  'cif_mp-1147661_MgVS3.cif',
#  'cif_mp-1147677_Ca(Cu3O4)2.cif',
#  'cif_mp-1147713_La2CuS4.cif',
#  'cif_mp-1147743_Th2Cu(NO)2.cif',
#  'cif_mp-11508_MoP4.cif',
#  'cif_mp-11519_NiSnRh2.cif',
#  'cif_mp-1157313_Y2Cr3(SiO4)3.cif',
#  'cif_mp-11582_LiGaSe2.cif',
#  'cif_mp-11583_Zr2SN2.cif',
#  'cif_mp-11641_Ag2SeO4.cif',
#  'cif_mp-1172875_Mn2O3.cif',
#  'cif_mp-1173121_TbCuSe2.cif',
#  'cif_mp-1173246_Sr2Y4Fe2Cu2O13.cif',
#  'cif_mp-1173260_Sr2Li4MnS3O2.cif',
#  'cif_mp-1173333_Re3O10.cif',
#  'cif_mp-1173361_Rb4Sb2O5.cif',
#  'cif_mp-1173506_Nb9IrS20.cif',
#  'cif_mp-1173567_NaLaMgWO6.cif',
#  'cif_mp-1173635_Sr18La2MgRu9O40.cif',
#  'cif_mp-1173642_NaMnFe(PO4)2.cif',
#  'cif_mp-1173656_Na2PrO3.cif',
#  'cif_mp-1173715_NaCo2H3(SO5)2.cif',
#  'cif_mp-1173728_Na2MnCdFe(PO4)3.cif',
#  'cif_mp-1173750_NaCaAlFe(SiO3)4.cif',
#  'cif_mp-1173812_Na3Mg4ScSi8(O11F)2.cif',
#  'cif_mp-1173853_Na3Ca2Mg10Si16(O11F)4.cif',
#  'cif_mp-1173859_Na9Fe2P4HO18.cif',
#  'cif_mp-1173891_Li2CoO3.cif',
#  'cif_mp-1173910_Li2MnCoO4.cif',
#  'cif_mp-1173952_Li3Mn2O5.cif',
#  'cif_mp-1173959_Li3Mn2CoO6.cif',
#  'cif_mp-1174120_Li5Mn(CoO4)2.cif',
#  'cif_mp-1174195_Li3MnCoO5.cif',
#  'cif_mp-1174197_Li4Co3O7.cif',
#  'cif_mp-1174236_Li5Mn(CoO4)2.cif',
#  'cif_mp-1174277_Li3MnCoO5.cif',
#  'cif_mp-1174280_Li6Mn3CoO10.cif',
#  'cif_mp-1174316_Li4Mn3O7.cif',
#  'cif_mp-1174320_Li4Mn3O7.cif',
#  'cif_mp-1174339_Li4Co3O7.cif',
#  'cif_mp-1174347_Li4MnCo2O7.cif',
#  'cif_mp-1174390_Li4Co3O7.cif',
#  'cif_mp-1174406_Li5Mn2CoO8.cif',
#  'cif_mp-1174494_Li7Co5O12.cif',
#  'cif_mp-1174564_Li4MnCo2O7.cif',
#  'cif_mp-1174580_Li4MnCo2O7.cif',
#  'cif_mp-1174598_Li4MnCo2O7.cif',
#  'cif_mp-1174628_Li4MnCo2O7.cif',
#  'cif_mp-1174700_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1174758_Li5Mn3O8.cif',
#  'cif_mp-1174803_Li4MnCo2O7.cif',
#  'cif_mp-1174829_Li6Mn3CoO10.cif',
#  'cif_mp-1174830_Li6Mn3CoO10.cif',
#  'cif_mp-1174862_Li4MnCo2O7.cif',
#  'cif_mp-1174868_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1174953_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175061_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175064_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175101_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175307_Li7Mn4CoO12.cif',
#  'cif_mp-1175357_Li7Mn5O12.cif',
#  'cif_mp-1175358_Li7Mn5O12.cif',
#  'cif_mp-1175392_Li9Co7O16.cif',
#  'cif_mp-1175428_Li9Co7O16.cif',
#  'cif_mp-1175482_Li9Co7O16.cif',
#  'cif_mp-1175489_Li9Mn2Co5O16.cif',
#  'cif_mp-1175526_Li9Mn2Co5O16.cif',
#  'cif_mp-1175595_Li9Mn2Co5O16.cif',
#  'cif_mp-1175603_Li9Mn2Co5O16.cif',
#  'cif_mp-1175764_Li9Mn2Co5O16.cif',
#  'cif_mp-1175838_Li9Mn2Co5O16.cif',
#  'cif_mp-1175861_Li9Mn2Co5O16.cif',
#  'cif_mp-1175933_Li9Mn2Co5O16.cif',
#  'cif_mp-1175947_Li9Mn2Co5O16.cif',
#  'cif_mp-1176053_Li9Mn2Co5O16.cif',
#  'cif_mp-1176183_Li9Mn2Co5O16.cif',
#  'cif_mp-1176218_Li9Mn2Co5O16.cif',
#  'cif_mp-1176240_Li9Mn2Co5O16.cif',
#  'cif_mp-1176262_Li9Mn2Co5O16.cif',
#  ...]

# %%
x = np.arange(5,100,0.01)

# Set to use 'Agg' backend which does not display to the screen
plt.switch_backend('Agg')

for file in tqdm(files):
    struct = Structure.from_file(f"{path}/{file}")
    xrd_cond = XRDCalculator()
    xrd_calcd = xrd_cond.get_pattern(struct)
    
    calcd_x = xrd_calcd.x
    calcd_y = xrd_calcd.y
    calcd_hkls = xrd_calcd.hkls
    calcd_d = xrd_calcd.d_hkls
    
    calcd_pattern = np.zeros(len(x))
    
    N = len(calcd_x)
    for i in range(N):
        norm = calcd_y[i]
        center = calcd_x[i]
        lw = 0.05
        gw = 0.05
        params = [norm, center, lw, gw]
        calcd_pattern += voigt(x, params)
    
    figure = plt.figure(figsize=(5,3))
    ax = figure.add_subplot(111)
    
    ax.plot(x, calcd_pattern,color='red')
    
    ax.set_xlim(5, 100)
    ax.set_ylim(0, 500)
    
    ax.set_xlabel(r'2$\theta$ (deg)')
    ax.set_ylabel('Intensity (a.u.)')
    
    # 上記のfigureを保存
    plt.tight_layout()
    plt.savefig(f'../input/material_projects_maked_xrd_pattern_not_cubic/{file}_xrd_pattern.png',bbox_inches='tight')
    
    # x, calcd_patternをcsvで保存、xは2theta、calcd_patternはIntensity
    df = pd.DataFrame({'2theta':x, 'Intensity':calcd_pattern})
    df.to_csv(f'../input/material_projects_maked_xrd_pattern_not_cubic/{file}_xrd_pattern.csv', index=False)
    
    del struct, xrd_cond, xrd_calcd, calcd_x, calcd_y, calcd_hkls, calcd_d, calcd_pattern, df
    gc.collect()
# Out:
#   0%|          | 0/5425 [00:00<?, ?it/s]

# %%
with open('not_cubic_files_list.pkl', 'wb') as f:
    pickle.dump(files, f)

# %%
with open('not_cubic_files_list.pkl', 'rb') as f:
    files_ = pickle.load(f)
    
files_
# Out:
# ['cif_mp-1001835_LiB.cif',
#  'cif_mp-1002181_TcN.cif',
#  'cif_mp-1002182_TcN.cif',
#  'cif_mp-1003320_CaMn4O8.cif',
#  'cif_mp-1004532_CCl4.cif',
#  'cif_mp-10051_TeAs.cif',
#  'cif_mp-10059_ZrCo3B2.cif',
#  'cif_mp-1006056_PaNi2Ge.cif',
#  'cif_mp-1006399_CeZnIn.cif',
#  'cif_mp-1006588_Zn3In2O6.cif',
#  'cif_mp-1006617_ZnP2NO9.cif',
#  'cif_mp-1007910_NaEuS2.cif',
#  'cif_mp-1007_DySb.cif',
#  'cif_mp-1008226_CrFe2Sn.cif',
#  'cif_mp-1008511_BaGaCu2.cif',
#  'cif_mp-1008527_B2CN.cif',
#  'cif_mp-1008881_MgNiH.cif',
#  'cif_mp-1009078_CoN.cif',
#  'cif_mp-1009088_BeGeAs2.cif',
#  'cif_mp-1009218_MoC.cif',
#  'cif_mp-1009491_RbTe.cif',
#  'cif_mp-1009496_OsN.cif',
#  'cif_mp-1009547_CsRbAs.cif',
#  'cif_mp-1009601_PdN.cif',
#  'cif_mp-1009735_ReC.cif',
#  'cif_mp-1009787_RuC.cif',
#  'cif_mp-1009817_TaC.cif',
#  'cif_mp-1009827_BaSi2.cif',
#  'cif_mp-1009_SrSi6.cif',
#  'cif_mp-100_Hf.cif',
#  'cif_mp-10115_ThB2Ir3.cif',
#  'cif_mp-10117_Mg3(Ni10B3)2.cif',
#  'cif_mp-1011834_Na2CoP2O7.cif',
#  'cif_mp-1012835_SmCu(WO4)2.cif',
#  'cif_mp-1014307_ZrC.cif',
#  'cif_mp-1014509_Cr3N2.cif',
#  'cif_mp-1014910_CrN2.cif',
#  'cif_mp-10152_La(SiIr)2.cif',
#  'cif_mp-1015814_LiMg2Al.cif',
#  'cif_mp-1016223_Mg3Mo.cif',
#  'cif_mp-1016252_Mg7Ga.cif',
#  'cif_mp-10164_NaGaTe2.cif',
#  'cif_mp-1016580_Mg6NbW.cif',
#  'cif_mp-1016582_BaMg6Cd.cif',
#  'cif_mp-1016596_Mg6NbGa.cif',
#  'cif_mp-1016630_Mg6NbC.cif',
#  'cif_mp-1016652_BaHfMg6.cif',
#  'cif_mp-1016655_HfMg6Mo.cif',
#  'cif_mp-1017072_CsMg6Nb.cif',
#  'cif_mp-1017110_HfMg6Ga.cif',
#  'cif_mp-1017305_NaMg6Sb.cif',
#  'cif_mp-1017487_BaLaMg6.cif',
#  'cif_mp-1017508_LuTlTe2.cif',
#  'cif_mp-1017511_Cr3Fe.cif',
#  'cif_mp-1017533_YN.cif',
#  'cif_mp-1017565_In2Se3.cif',
#  'cif_mp-1017579_In2Au3.cif',
#  'cif_mp-1018015_Ti2MnGe.cif',
#  'cif_mp-1018025_LuAgO2.cif',
#  'cif_mp-1018088_C.cif',
#  'cif_mp-1018117_CeRh.cif',
#  'cif_mp-1018134_Li.cif',
#  'cif_mp-1018658_CaCoSi.cif',
#  'cif_mp-1018671_CeZnGa.cif',
#  'cif_mp-1018691_Eu2H3Br.cif',
#  'cif_mp-1018699_EuZnGe.cif',
#  'cif_mp-1018802_MnGaGe.cif',
#  'cif_mp-1018804_MnS2.cif',
#  'cif_mp-1019055_ReN2.cif',
#  'cif_mp-1019099_SmCoP.cif',
#  'cif_mp-1019239_PdN2.cif',
#  'cif_mp-1019549_BaMg2Si2O7.cif',
#  'cif_mp-1019573_CaAl2SiO6.cif',
#  'cif_mp-1019718_CsBe4(BO3)3.cif',
#  'cif_mp-1019730_EuZn(BO2)5.cif',
#  'cif_mp-1019733_Eu(NO3)3.cif',
#  'cif_mp-1019785_K2Si(S2O7)3.cif',
#  'cif_mp-1020018_Li5B(SO4)4.cif',
#  'cif_mp-1020019_Li2PNO2.cif',
#  'cif_mp-1020056_LiCa3Si2N5.cif',
#  'cif_mp-1020110_Mg2SiO4.cif',
#  'cif_mp-1020145_Na2Ge(S2O7)3.cif',
#  'cif_mp-1020598_Y4Si2S3O7.cif',
#  'cif_mp-1020896_Rb4Ge3B6O17.cif',
#  'cif_mp-1021256_LaMg6Si.cif',
#  'cif_mp-1021292_KMg6Cd.cif',
#  'cif_mp-10212_ScGe2.cif',
#  'cif_mp-1021300_KMg6Ga.cif',
#  'cif_mp-1021383_RbMg6Ti.cif',
#  'cif_mp-1021417_BaMg6Sn.cif',
#  'cif_mp-1021462_BaMg6Ti.cif',
#  'cif_mp-1021507_Ba2Y(CuO2)3.cif',
#  'cif_mp-1021521_LiCeMg6.cif',
#  'cif_mp-1021658_Mg6VSb.cif',
#  'cif_mp-1021660_NbInRu.cif',
#  'cif_mp-1021685_Mg6VGa.cif',
#  'cif_mp-1021694_Mg6VSi.cif',
#  'cif_mp-1021710_Mg6VMo.cif',
#  'cif_mp-1021726_Mg6VC.cif',
#  'cif_mp-1021950_BaNb2(FeO3)4.cif',
#  'cif_mp-1022063_Mg6CuSb.cif',
#  'cif_mp-1022079_Mg6CdCu.cif',
#  'cif_mp-1022184_Mg6FeBi.cif',
#  'cif_mp-1022199_Mg6GaFe.cif',
#  'cif_mp-1022576_Mg6ZnC.cif',
#  'cif_mp-1022609_Mg6VZn.cif',
#  'cif_mp-1022658_SrMg6Zn.cif',
#  'cif_mp-1022683_YMg6Mo.cif',
#  'cif_mp-1022812_LiYMg6.cif',
#  'cif_mp-1022813_LiYMg6.cif',
#  'cif_mp-1022814_YMg6V.cif',
#  'cif_mp-1022889_Mg6MnB.cif',
#  'cif_mp-1022939_Mg6MnCd.cif',
#  'cif_mp-1023142_CaMg6Nb.cif',
#  'cif_mp-1023300_RbMg6Al.cif',
#  'cif_mp-1023306_Mg6AlCd.cif',
#  'cif_mp-1023499_NaMg15.cif',
#  'cif_mp-1024951_LaScSi.cif',
#  'cif_mp-1025044_AlNi2.cif',
#  'cif_mp-1025059_LaAg2.cif',
#  'cif_mp-1025181_Tm2Cr2C3.cif',
#  'cif_mp-1025205_Y2Re2Si2C.cif',
#  'cif_mp-1025223_Hf4Al3.cif',
#  'cif_mp-1025241_ScGa5Fe.cif',
#  'cif_mp-1025245_La2Re2Si2C.cif',
#  'cif_mp-1025264_U2W2C3.cif',
#  'cif_mp-1025329_TlSiPt5.cif',
#  'cif_mp-1025337_Tl2CdTe4.cif',
#  'cif_mp-1025355_ZrGa5Co.cif',
#  'cif_mp-1025362_Er2Re2Si2C.cif',
#  'cif_mp-1025365_Sc(VGa2)2.cif',
#  'cif_mp-1025382_Th2Fe2Si2C.cif',
#  'cif_mp-1025450_CeFeSi2.cif',
#  'cif_mp-1025472_NpTe3.cif',
#  'cif_mp-1025483_ErO3.cif',
#  'cif_mp-1025504_TmGa2Ni.cif',
#  'cif_mp-1025682_Te4Mo(WSe)2.cif',
#  'cif_mp-1025856_Te2MoW2(SeS)2.cif',
#  'cif_mp-1025924_Te4Mo(WS)2.cif',
#  'cif_mp-1025946_Mo2W(Se2S)2.cif',
#  'cif_mp-1025988_Mo3(SeS2)2.cif',
#  'cif_mp-10260_Ni3Sb.cif',
#  'cif_mp-1026395_Mg14TiW.cif',
#  'cif_mp-1026399_Mg14CrSn.cif',
#  'cif_mp-1026447_Mg14CdGa.cif',
#  'cif_mp-1026494_Mg14CdMo.cif',
#  'cif_mp-1026571_SrMg14Nb.cif',
#  'cif_mp-1026573_BaMg14Nb.cif',
#  'cif_mp-1026593_CsMg14W.cif',
#  'cif_mp-1026625_Mg14SnBi.cif',
#  'cif_mp-1026647_Mg14CdC.cif',
#  'cif_mp-1026660_NaMg14Bi.cif',
#  'cif_mp-1026758_NaCeMg14.cif',
#  'cif_mp-1026766_BaLaMg14.cif',
#  'cif_mp-1026776_LiMg14Ga.cif',
#  'cif_mp-1026793_LiMg14Cr.cif',
#  'cif_mp-1026796_LiMg14Mo.cif',
#  'cif_mp-1026808_CeMg14W.cif',
#  'cif_mp-1026810_CeMg14B.cif',
#  'cif_mp-1026902_Mg14CuB.cif',
#  'cif_mp-1027112_MoW3(SeS)4.cif',
#  'cif_mp-1027483_Mo2Se3S.cif',
#  'cif_mp-1027567_Te2Mo3WS6.cif',
#  'cif_mp-1027671_MoW(SeS)2.cif',
#  'cif_mp-1027740_TeMoWSeS2.cif',
#  'cif_mp-1027759_TeMoWSeS2.cif',
#  'cif_mp-1027818_TeMo2Se3.cif',
#  'cif_mp-1027859_BaMg14Fe.cif',
#  'cif_mp-1027959_Mg14TiZn.cif',
#  'cif_mp-1028010_Mg14ZrFe.cif',
#  'cif_mp-1028176_CaMg14Sn.cif',
#  'cif_mp-10281_ZnS.cif',
#  'cif_mp-1028218_NaMg14Al.cif',
#  'cif_mp-1028262_RbMg14Al.cif',
#  'cif_mp-1028301_Mg14VMo.cif',
#  'cif_mp-1028341_Mg14NiW.cif',
#  'cif_mp-1028420_Mo3WSe8.cif',
#  'cif_mp-1028433_Te6MoW3Se2.cif',
#  'cif_mp-1028456_TeWSe.cif',
#  'cif_mp-1028463_Te2MoW3(Se2S)2.cif',
#  'cif_mp-1028505_Te2Mo3WSe6.cif',
#  'cif_mp-1028729_TeW2Se2S.cif',
#  'cif_mp-1028910_Te4MoW3(SeS)2.cif',
#  'cif_mp-1028918_CeMg14V.cif',
#  'cif_mp-1028951_Te2MoW3(Se2S)2.cif',
#  'cif_mp-1029077_MoW(SeS)2.cif',
#  'cif_mp-1029166_Te4MoW3S4.cif',
#  'cif_mp-1029190_Te2MoW3(Se2S)2.cif',
#  'cif_mp-1029234_MoW3(SeS3)2.cif',
#  'cif_mp-1029274_TeMoWSeS2.cif',
#  'cif_mp-1029297_LiZr2N3.cif',
#  'cif_mp-1029378_Mg2SbN3.cif',
#  'cif_mp-1029418_KSi2N3.cif',
#  'cif_mp-1029625_LiTaN2.cif',
#  'cif_mp-1029852_RbMoN2.cif',
#  'cif_mp-1029978_KRuN2.cif',
#  'cif_mp-1030101_Te4MoW3Se4.cif',
#  'cif_mp-1030128_Te4MoW3(SeS)2.cif',
#  'cif_mp-1030196_Te2MoWS2.cif',
#  'cif_mp-1030235_Te3MoWSe.cif',
#  'cif_mp-1030269_Te4Mo3WS4.cif',
#  'cif_mp-1030409_Te2Mo3W(Se2S)2.cif',
#  'cif_mp-1030507_Te2Mo3W(SeS2)2.cif',
#  'cif_mp-1030509_TeMoWSe3.cif',
#  'cif_mp-1030512_TeMoWSeS2.cif',
#  'cif_mp-1030525_Te2MoW3(SeS2)2.cif',
#  'cif_mp-1030677_NaMg6SbO8.cif',
#  'cif_mp-1030910_NaLiMg6O7.cif',
#  'cif_mp-1030980_RbNaMg6O7.cif',
#  'cif_mp-1031026_RbLiMg6O7.cif',
#  'cif_mp-1031131_LiMg6SbO8.cif',
#  'cif_mp-1031136_CeHfMg6O8.cif',
#  'cif_mp-1031185_LiMg6BO7.cif',
#  'cif_mp-1031233_CsMg6SiO8.cif',
#  'cif_mp-1031273_KMg6BO7.cif',
#  'cif_mp-1031460_Mg6SiSnO8.cif',
#  'cif_mp-1031470_Mg6VBiO8.cif',
#  'cif_mp-1031540_Mg6AlSiO8.cif',
#  'cif_mp-1031550_Mg6SnCO8.cif',
#  'cif_mp-1031564_Mg6CdSnO8.cif',
#  'cif_mp-1031751_Mg6SnCO8.cif',
#  'cif_mp-1031885_KMg6MnO8.cif',
#  'cif_mp-1031907_YMg6NbO8.cif',
#  'cif_mp-1031979_Mg6CrCoO8.cif',
#  'cif_mp-1031988_Mg6CoCO8.cif',
#  'cif_mp-1032012_Mg6TiZnO8.cif',
#  'cif_mp-1032096_Mg6CoCuO8.cif',
#  'cif_mp-1032467_LiMg6FeO8.cif',
#  'cif_mp-1032744_YMg6CuO8.cif',
#  'cif_mp-1032771_YMg6CuO8.cif',
#  'cif_mp-1032929_CaMg6FeO8.cif',
#  'cif_mp-1033028_SrMg6AlO8.cif',
#  'cif_mp-1033065_CsMg6AlO8.cif',
#  'cif_mp-1033259_Mg6CdBiO8.cif',
#  'cif_mp-1033359_Mg6NbBiO8.cif',
#  'cif_mp-1033410_SrMg6BiO8.cif',
#  'cif_mp-1033459_Mg6NbCO8.cif',
#  'cif_mp-1033488_SrMg6CO8.cif',
#  'cif_mp-1033518_CsMg6SbO8.cif',
#  'cif_mp-1033686_HfMg14BO16.cif',
#  'cif_mp-1033715_CsHfMg6O7.cif',
#  'cif_mp-1033747_Mg14BiBO16.cif',
#  'cif_mp-1033748_Mg14CdCO16.cif',
#  'cif_mp-1033978_KRbMg14O15.cif',
#  'cif_mp-1034033_Mg14TiCO16.cif',
#  'cif_mp-1034035_Mg14TiCdO16.cif',
#  'cif_mp-1034041_KLiMg14O15.cif',
#  'cif_mp-1034246_RbMg14CrO16.cif',
#  'cif_mp-1034380_NaHfMg14O15.cif',
#  'cif_mp-1034473_BaMg14VO16.cif',
#  'cif_mp-1034517_Mg14NbVO16.cif',
#  'cif_mp-1034765_Mg14NbSiO16.cif',
#  'cif_mp-1034805_Mg14NbNiO16.cif',
#  'cif_mp-1034899_Mg14TiZnO16.cif',
#  'cif_mp-1034906_NaCeMg14O16.cif',
#  'cif_mp-1035303_Mg14CoSiO16.cif',
#  'cif_mp-1035444_RbMg14CoO16.cif',
#  'cif_mp-1035626_Mg14NbFeO16.cif',
#  'cif_mp-1035680_KMg14BO15.cif',
#  'cif_mp-1036120_HfMg14MnO16.cif',
#  'cif_mp-1036211_BaMg14MnO16.cif',
#  'cif_mp-1036325_CaMg14NbO16.cif',
#  'cif_mp-1036525_Mg14NbAlO16.cif',
#  'cif_mp-10365_MnCoSi.cif',
#  'cif_mp-1036646_Mg14AlSnO16.cif',
#  'cif_mp-1036672_SrMg30SnO32.cif',
#  'cif_mp-1036755_Mg30VBiO32.cif',
#  'cif_mp-1036757_Mg30VSiO32.cif',
#  'cif_mp-1036758_SrMg30VO32.cif',
#  'cif_mp-1036804_Mg30TiVO32.cif',
#  'cif_mp-1036923_Mg30CoBiO32.cif',
#  'cif_mp-1037288_Mg30CrCuO32.cif',
#  'cif_mp-1037450_Mg30ZnCdO32.cif',
#  'cif_mp-1037462_Mg30NbZnO32.cif',
#  'cif_mp-1037608_SrMg30ZnO32.cif',
#  'cif_mp-1037924_Mg30MnZnO32.cif',
#  'cif_mp-1038038_LiMg30MnO32.cif',
#  'cif_mp-1038048_BaMg30MnO32.cif',
#  'cif_mp-1038167_Mg30MnVO32.cif',
#  'cif_mp-1038202_Mg30AlBiO32.cif',
#  'cif_mp-1038204_LiMg30AlO32.cif',
#  'cif_mp-1038339_Mg30AlVO32.cif',
#  'cif_mp-1038446_HfMg30GaO32.cif',
#  'cif_mp-1038544_HfMg30WO32.cif',
#  'cif_mp-1038595_Mg30CrCdO32.cif',
#  'cif_mp-1038689_CsHfMg30O31.cif',
#  'cif_mp-1038744_SrMg30CrO32.cif',
#  'cif_mp-1038788_CeMg.cif',
#  'cif_mp-1038789_Mg2Bi.cif',
#  'cif_mp-1038834_Mg2Bi.cif',
#  'cif_mp-1038862_CaMg.cif',
#  'cif_mp-1039170_MgBi.cif',
#  'cif_mp-1039186_MgCd.cif',
#  'cif_mp-1039634_RbMg30BiO32.cif',
#  'cif_mp-1039659_CeMg2.cif',
#  'cif_mp-1039694_RbMg30WO32.cif',
#  'cif_mp-1039724_RbMg30CrO32.cif',
#  'cif_mp-1039831_Mg30CdSiO32.cif',
#  'cif_mp-1039932_NaLaMg30O32.cif',
#  'cif_mp-1039957_LiHfMg30O31.cif',
#  'cif_mp-1039970_RbNaMg30O31.cif',
#  'cif_mp-1040157_LiMg30SiO32.cif',
#  'cif_mp-1040232_RbLiMg30O31.cif',
#  'cif_mp-1040283_KNaMg30O31.cif',
#  'cif_mp-1040783_Ho(SbO3)2.cif',
#  'cif_mp-1040834_WO2.cif',
#  'cif_mp-1040851_ZnSn2P2O9.cif',
#  'cif_mp-1040914_CaNi2(PO4)2.cif',
#  'cif_mp-1040986_Mg(FeO2)2.cif',
#  'cif_mp-1041288_BaCr4O8.cif',
#  'cif_mp-1041341_BaSbF7.cif',
#  'cif_mp-1041374_MgCr4O9.cif',
#  'cif_mp-1041467_CaFe2(CuO4)2.cif',
#  'cif_mp-1041479_MgCu(SiO3)2.cif',
#  'cif_mp-1041494_Mg(CuO2)2.cif',
#  'cif_mp-1041564_CaTi(SiO3)2.cif',
#  'cif_mp-1041629_Mg(CoO2)2.cif',
#  'cif_mp-1041642_Mg(SbO2)2.cif',
#  'cif_mp-1041768_MgCr2CuO7.cif',
#  'cif_mp-1041823_Ca(AgO2)2.cif',
#  'cif_mp-1042060_MgNiP2O7.cif',
#  'cif_mp-1042127_BiS2.cif',
#  'cif_mp-1042234_Ca(SnO2)2.cif',
#  'cif_mp-1042328_YMo(WO4)2.cif',
#  'cif_mp-1042444_Mg2Sb3O8.cif',
#  'cif_mp-1042475_BaYCrCuO5.cif',
#  'cif_mp-1042519_BaAlCuWO5.cif',
#  'cif_mp-1042689_CaBiWO5.cif',
#  'cif_mp-1042711_CaFeBiO5.cif',
#  'cif_mp-1042729_ZnCu3(BiO3)4.cif',
#  'cif_mp-1042856_Ca2V3O8.cif',
#  'cif_mp-1042909_Ca2Nb2SnO8.cif',
#  'cif_mp-1043070_ZnAs2WO7.cif',
#  'cif_mp-1043136_Cr4(CuO4)3.cif',
#  'cif_mp-1043149_MgCo(GeO3)2.cif',
#  'cif_mp-1043184_V4Zn(CuO4)3.cif',
#  'cif_mp-1043219_MgMo2O5.cif',
#  'cif_mp-1043253_Mg(Fe2O3)2.cif',
#  'cif_mp-1043255_CaCo2O5.cif',
#  'cif_mp-1043551_CaNiSbP2O9.cif',
#  'cif_mp-10435_Y(AlSi)2.cif',
#  'cif_mp-1043611_Zn(Fe2O3)2.cif',
#  'cif_mp-1043624_Mg(SbO2)4.cif',
#  'cif_mp-1043839_LaMg(FeO3)2.cif',
#  'cif_mp-1043864_CaLaFeSbO6.cif',
#  'cif_mp-1043885_Sr2AlCu2MoO7.cif',
#  'cif_mp-1043973_ZnW4O9.cif',
#  'cif_mp-1044127_ZnNi2(PO5)2.cif',
#  'cif_mp-1044162_PWO5.cif',
#  'cif_mp-1044267_TiV(PO4)3.cif',
#  'cif_mp-1044282_MgTiFe(PO4)3.cif',
#  'cif_mp-1044358_CaCrBiO5.cif',
#  'cif_mp-1044499_PrZn(SnO3)2.cif',
#  'cif_mp-1044577_BaZn(NiO2)4.cif',
#  'cif_mp-1044787_PrZn(NiO3)2.cif',
#  'cif_mp-1044853_TiO2.cif',
#  'cif_mp-1045326_Zn(BiO3)2.cif',
#  'cif_mp-1045435_Li(MnS2)2.cif',
#  'cif_mp-1045744_Mn4Al(CuO4)3.cif',
#  'cif_mp-1045813_CaNi(PO3)4.cif',
#  'cif_mp-1045862_Ba2ZnCr2CuF14.cif',
#  'cif_mp-1045961_TiZnO2.cif',
#  'cif_mp-1046045_Sr2YTlNi2O7.cif',
#  'cif_mp-1046096_SrMgTi(PO4)2.cif',
#  'cif_mp-1046176_Sr2Cu2SbO7.cif',
#  'cif_mp-1046252_Zn(BiO2)4.cif',
#  'cif_mp-1046352_Ta2MoO8.cif',
#  'cif_mp-1046426_SrVZn(PO4)2.cif',
#  'cif_mp-1046496_SrCaFe(PO4)2.cif',
#  'cif_mp-1046522_Ba2Mg2Tl2Ni3O10.cif',
#  'cif_mp-1046567_Ba2Tl2Mo3O10.cif',
#  'cif_mp-1046644_MgMo3O8.cif',
#  'cif_mp-1046647_ZnCoPO5.cif',
#  'cif_mp-1046709_ZnCrSF5.cif',
#  'cif_mp-1046740_MgNiPO5.cif',
#  'cif_mp-1046839_Mg2Nb2CrO8.cif',
#  'cif_mp-1046867_Mg(SnO2)2.cif',
#  'cif_mp-1046961_BaMg(AgO2)4.cif',
#  'cif_mp-1046983_Nb2CrO8.cif',
#  'cif_mp-1046998_BaCa(AgO2)4.cif',
#  'cif_mp-1047047_Ti3(P2O7)2.cif',
#  'cif_mp-1047238_Sr2Y2W2O7.cif',
#  'cif_mp-1047292_MgMn2O4.cif',
#  'cif_mp-1047345_Sr2YMn2O7.cif',
#  'cif_mp-1047356_TaF5.cif',
#  'cif_mp-1047421_BaTi4O8.cif',
#  'cif_mp-1047527_Ca2YFeO5.cif',
#  'cif_mp-1047530_YTi3F15.cif',
#  'cif_mp-1047653_TaAl(WO4)2.cif',
#  'cif_mp-1047752_Sb(WO4)2.cif',
#  'cif_mp-1047775_Mg3Co3(AsO4)4.cif',
#  'cif_mp-1047811_Be3Si3(MoO6)2.cif',
#  'cif_mp-1047872_MgTi2Be3(SiO4)3.cif',
#  'cif_mp-1047986_MgTi4O8.cif',
#  'cif_mp-1047992_ZnSnP2O7.cif',
#  'cif_mp-1048015_CaFe4O9.cif',
#  'cif_mp-1048029_Ni3P3O13.cif',
#  'cif_mp-1048068_Sr2YTi2AlO7.cif',
#  'cif_mp-1048115_BaYCu4O7.cif',
#  'cif_mp-1048143_Ba2AlW3O8.cif',
#  'cif_mp-1048266_MgCrP2O7.cif',
#  'cif_mp-1048301_CaTi2Be3(SiO4)3.cif',
#  'cif_mp-1048371_BaCr4O7.cif',
#  'cif_mp-1048496_Ba2Co3O7.cif',
#  'cif_mp-1048511_Ba2Mn3O7.cif',
#  'cif_mp-1048546_V3Se2ClO8.cif',
#  'cif_mp-1048549_Ba2Ca3Mn4Tl2O12.cif',
#  'cif_mp-1048568_Sr2YSn2O7.cif',
#  'cif_mp-1048637_Sr3CaCo2S2O5.cif',
#  'cif_mp-1048666_Ca3(TiS2)8.cif',
#  'cif_mp-1048893_Ca(CuO2)2.cif',
#  'cif_mp-1054_ErTl.cif',
#  'cif_mp-1057758_BaN.cif',
#  'cif_mp-1057979_IN.cif',
#  'cif_mp-1058119_KS.cif',
#  'cif_mp-1058586_SrN.cif',
#  'cif_mp-1058689_KN.cif',
#  'cif_mp-1061635_MgNb2.cif',
#  'cif_mp-1063239_DyPd2.cif',
#  'cif_mp-1063522_CePd2.cif',
#  'cif_mp-1063988_S.cif',
#  'cif_mp-1064554_BiRh.cif',
#  'cif_mp-10645_TbSe.cif',
#  'cif_mp-1065609_GdTlTe2.cif',
#  'cif_mp-1066006_VFeCoAs.cif',
#  'cif_mp-1066274_PtPb.cif',
#  'cif_mp-10679_Ba.cif',
#  'cif_mp-1068325_Sr(InHg)2.cif',
#  'cif_mp-10687_LiCdP.cif',
#  'cif_mp-1069079_FeBiO3.cif',
#  'cif_mp-1069193_Pd(NCl)2.cif',
#  'cif_mp-1069723_U(CuAs)2.cif',
#  'cif_mp-1069726_Pd(NCl)2.cif',
#  'cif_mp-1069811_Hf2H2Pd.cif',
#  'cif_mp-1072086_TaS2.cif',
#  'cif_mp-1072087_LaAu2.cif',
#  'cif_mp-1072167_EuN2.cif',
#  'cif_mp-1072737_NdAg2.cif',
#  'cif_mp-1073254_MgSi2.cif',
#  'cif_mp-1073358_MgSi2.cif',
#  'cif_mp-1073387_MgSi2.cif',
#  'cif_mp-1073416_MgSi2.cif',
#  'cif_mp-1073477_MgSi2.cif',
#  'cif_mp-1074149_Mg4Si7.cif',
#  'cif_mp-1074199_Mg4Si7.cif',
#  'cif_mp-1074272_Mg4Si3.cif',
#  'cif_mp-1074331_Mg4Si3.cif',
#  'cif_mp-1074803_Mg7Si4.cif',
#  'cif_mp-1074923_Mg7Si4.cif',
#  'cif_mp-10749_SrCuSb.cif',
#  'cif_mp-1075131_Mg3Si4.cif',
#  'cif_mp-1075253_Mg3Si4.cif',
#  'cif_mp-1075368_Mg5Si6.cif',
#  'cif_mp-1075405_Mg5Si6.cif',
#  'cif_mp-1075421_Mg5Si6.cif',
#  'cif_mp-1075616_Mg5Si9.cif',
#  'cif_mp-1075638_Mg5Si9.cif',
#  'cif_mp-1075674_Mg5Si9.cif',
#  'cif_mp-1075761_Mg5Si9.cif',
#  'cif_mp-1076014_Ca2Mn2O5.cif',
#  'cif_mp-1076055_Sm2V2O5.cif',
#  'cif_mp-1076080_Sr5Ca3Mn7FeO24.cif',
#  'cif_mp-1076134_Sr3Ca5Ti3Mn5O20.cif',
#  'cif_mp-1076204_La7SmCr2(Fe3O10)2.cif',
#  'cif_mp-1076289_Sm2Mn2O5.cif',
#  'cif_mp-1076335_K5Na3Nb8O24.cif',
#  'cif_mp-1076505_Sr3CaTiMn3O10.cif',
#  'cif_mp-1076581_La7SmTi3V5O24.cif',
#  'cif_mp-1076671_La7SmMn4(FeO6)4.cif',
#  'cif_mp-1076685_K4Na4MoW7O24.cif',
#  'cif_mp-1076884_Sr6Ca2Fe7CoO20.cif',
#  'cif_mp-1077088_PrCdNi4.cif',
#  'cif_mp-1077095_LuCdNi4.cif',
#  'cif_mp-1077147_HoSi2.cif',
#  'cif_mp-1077267_ErSi2.cif',
#  'cif_mp-1077457_Eu.cif',
#  'cif_mp-1077485_HoSnGe.cif',
#  'cif_mp-1077708_Cr2Fe.cif',
#  'cif_mp-1077776_ScB2Ir3.cif',
#  'cif_mp-1077831_EuScGe.cif',
#  'cif_mp-1078085_Cs2PdCl4.cif',
#  'cif_mp-1078108_Mn2B4Mo.cif',
#  'cif_mp-1078110_Mn(GaS2)2.cif',
#  'cif_mp-1078140_Mn(InSe2)2.cif',
#  'cif_mp-1078184_Eu4Bi2O.cif',
#  'cif_mp-1078200_V2CoSe4.cif',
#  'cif_mp-1078335_Pr2BiN.cif',
#  'cif_mp-1078409_Ba2LaBiO6.cif',
#  'cif_mp-1078431_LaBiSe2O.cif',
#  'cif_mp-1078435_BaCd2Pt.cif',
#  'cif_mp-1078505_DySn3.cif',
#  'cif_mp-1078533_Th(AlAu)2.cif',
#  'cif_mp-1078539_Sr2MgMoO6.cif',
#  'cif_mp-1078684_ErCdGa.cif',
#  'cif_mp-1078698_ZrCuGeAs.cif',
#  'cif_mp-1078716_SrMoO3.cif',
#  'cif_mp-1078726_CsHoS2.cif',
#  'cif_mp-1078729_Zr6CuBi2.cif',
#  'cif_mp-1078740_Ho3(CoGe2)2.cif',
#  'cif_mp-1078751_Na2PdSe2.cif',
#  'cif_mp-1078775_Nd(CrB3)2.cif',
#  'cif_mp-1078857_DyAlCu.cif',
#  'cif_mp-1078896_Mn2Ga2S5.cif',
#  'cif_mp-1078992_Th3Pt5.cif',
#  'cif_mp-1079017_CeCdCu.cif',
#  'cif_mp-1079065_Zr3Co.cif',
#  'cif_mp-1079072_Mg3In.cif',
#  'cif_mp-1079107_Co(N3Cl)2.cif',
#  'cif_mp-1079174_PuPd.cif',
#  'cif_mp-1079250_SmNiSb2.cif',
#  'cif_mp-1079269_SiPt3.cif',
#  'cif_mp-1079295_ErSi.cif',
#  'cif_mp-1079393_Co3Si.cif',
#  'cif_mp-1079489_Zr2InAu2.cif',
#  'cif_mp-1079582_VIr.cif',
#  'cif_mp-1079596_Er2NiSn6.cif',
#  'cif_mp-1079670_TmSb(PbO3)2.cif',
#  'cif_mp-1079671_Tb2CuGe6.cif',
#  'cif_mp-1079704_Tb3Sn7.cif',
#  'cif_mp-1079782_Cu(N3Cl)2.cif',
#  'cif_mp-1079818_CrTe.cif',
#  'cif_mp-1079829_Ti2CdO6.cif',
#  'cif_mp-1079855_LiPd7.cif',
#  'cif_mp-1079860_HfGaNi.cif',
#  'cif_mp-1079925_Sr2YCrO6.cif',
#  'cif_mp-1079999_Zr2NiP2.cif',
#  'cif_mp-1080000_CdNCl3.cif',
#  'cif_mp-1080031_Co(ClO3)2.cif',
#  'cif_mp-1080110_Ti(NF2)3.cif',
#  'cif_mp-1080142_Co(N2Cl)3.cif',
#  'cif_mp-1080199_V3N4.cif',
#  'cif_mp-1080205_KMnO2.cif',
#  'cif_mp-1080213_CaMn4O8.cif',
#  'cif_mp-1080237_Te4MoW3(SeS)2.cif',
#  'cif_mp-1080241_Li2Ge(S2O7)3.cif',
#  'cif_mp-1080259_CeSe2.cif',
#  'cif_mp-1080272_CeSe2.cif',
#  'cif_mp-1080273_CeSe2.cif',
#  'cif_mp-1080303_CeSe2.cif',
#  'cif_mp-1080363_CeSe2.cif',
#  'cif_mp-1080381_SmB2Ir3.cif',
#  'cif_mp-1080424_ScAgGe.cif',
#  'cif_mp-1080452_KCd4As3.cif',
#  'cif_mp-1080515_Nd(BOs)2.cif',
#  'cif_mp-1080528_U3Al3NiRu2.cif',
#  'cif_mp-1080567_Sm(NiSb)2.cif',
#  'cif_mp-1080572_NdCoGe2.cif',
#  'cif_mp-1080625_Sr2LiReO6.cif',
#  'cif_mp-1080661_Gd2SnAu2.cif',
#  'cif_mp-1080749_CsFeO2.cif',
#  'cif_mp-1080834_Na5As4.cif',
#  'cif_mp-1080842_Ba2UPbO6.cif',
#  'cif_mp-1084775_ScSnPt.cif',
#  'cif_mp-1084847_TbTe3.cif',
#  'cif_mp-1086660_Nb2FeB2.cif',
#  'cif_mp-1086_TaC.cif',
#  'cif_mp-1087509_P4Os.cif',
#  'cif_mp-1087511_UFeAs2.cif',
#  'cif_mp-1087524_LiH2N.cif',
#  'cif_mp-1092251_Nd2CuGe6.cif',
#  'cif_mp-1093567_Y2CdPd.cif',
#  'cif_mp-1093580_Li2YIn.cif',
#  'cif_mp-1093581_ZrCuAu2.cif',
#  'cif_mp-1093623_LiHg2Pt.cif',
#  'cif_mp-1093627_Ta2NbRe.cif',
#  'cif_mp-1093634_BaSrMg2.cif',
#  'cif_mp-1093652_In2GaSn.cif',
#  'cif_mp-1093672_Ba2CdIn.cif',
#  'cif_mp-1093688_CaCdAg2.cif',
#  'cif_mp-1093693_HfTlAu2.cif',
#  'cif_mp-1093827_LiZr2Ru.cif',
#  'cif_mp-1093848_SrLaAu2.cif',
#  'cif_mp-1093849_Nb2ReW.cif',
#  'cif_mp-1093889_Li2ZnAg.cif',
#  'cif_mp-1093891_AlZnNi2.cif',
#  'cif_mp-1093918_Al2CuPd.cif',
#  'cif_mp-1093941_Ta2TiRe.cif',
#  'cif_mp-1093974_CrTcGe2.cif',
#  'cif_mp-1094022_Zn(GaS2)2.cif',
#  'cif_mp-1094065_Sr2Co2O5.cif',
#  'cif_mp-1094069_Sr2Cd2Cu(SO)2.cif',
#  'cif_mp-1094075_P.cif',
#  'cif_mp-1094105_Na4ZnSe3.cif',
#  'cif_mp-1094122_Mg.cif',
#  'cif_mp-1094135_LiO2.cif',
#  'cif_mp-1094168_LaMg2.cif',
#  'cif_mp-1094194_MgZn5.cif',
#  'cif_mp-1094216_LaMg.cif',
#  'cif_mp-1094227_Mg5Sn.cif',
#  'cif_mp-1094238_MgSn.cif',
#  'cif_mp-1094251_MgSn.cif',
#  'cif_mp-1094275_MgTi2.cif',
#  'cif_mp-1094286_SrMg.cif',
#  'cif_mp-1094313_Sr2Mg.cif',
#  'cif_mp-1094320_SrMg3.cif',
#  'cif_mp-1094346_MgTi.cif',
#  'cif_mp-1094434_Mg5Zn.cif',
#  'cif_mp-1094455_Mg2Zn.cif',
#  'cif_mp-1094532_Mg2Sb.cif',
#  'cif_mp-1094589_LiMg.cif',
#  'cif_mp-1094595_Mg2Sb.cif',
#  'cif_mp-1094620_MgGa.cif',
#  'cif_mp-1094621_MgGa.cif',
#  'cif_mp-1094635_Mg2Ga.cif',
#  'cif_mp-1094637_MgGa.cif',
#  'cif_mp-1094646_MgGa2.cif',
#  'cif_mp-1094688_Sr3Mg.cif',
#  'cif_mp-1094697_Mg2Cd.cif',
#  'cif_mp-1094746_SrMg3.cif',
#  'cif_mp-1094804_MgCd2.cif',
#  'cif_mp-1094870_YMg.cif',
#  'cif_mp-1094878_MgBi2.cif',
#  'cif_mp-1094956_MgZn.cif',
#  'cif_mp-1095039_Sr2HfCrO6.cif',
#  'cif_mp-1095201_ZrCuGe2.cif',
#  'cif_mp-1095223_OF2.cif',
#  'cif_mp-1095382_Fe5O7.cif',
#  'cif_mp-1095479_GdS2.cif',
#  'cif_mp-1095527_GdGeRh.cif',
#  'cif_mp-1095533_KAsO4.cif',
#  'cif_mp-1095536_VNiGe.cif',
#  'cif_mp-1095622_Zr(MoO4)2.cif',
#  'cif_mp-1095641_Tb5S7.cif',
#  'cif_mp-1095711_MgScAu2.cif',
#  'cif_mp-1095762_MgRu2W.cif',
#  'cif_mp-1095776_LiCd2Hg.cif',
#  'cif_mp-1095784_LiAlZn2.cif',
#  'cif_mp-1095853_Y2CdAg.cif',
#  'cif_mp-1095956_YAgAu2.cif',
#  'cif_mp-1095963_Hf2MnZn.cif',
#  'cif_mp-1095964_Zn2AgPd.cif',
#  'cif_mp-1095977_Ba2LiCd.cif',
#  'cif_mp-1095990_Ba2NaLi.cif',
#  'cif_mp-1095991_Zr2CdTc.cif',
#  'cif_mp-1096026_Ca2ZnSn.cif',
#  'cif_mp-1096069_Ba2NaIn.cif',
#  'cif_mp-1096090_NaTl2Hg.cif',
#  'cif_mp-1096104_NbV2Os.cif',
#  'cif_mp-1096131_HfScZn2.cif',
#  'cif_mp-1096228_Ti2FeRu.cif',
#  'cif_mp-1096244_TiTc2Ge.cif',
#  'cif_mp-1096277_CdPd2Pb.cif',
#  'cif_mp-1096295_VCr2Mo.cif',
#  'cif_mp-1096320_Y2MgIr.cif',
#  'cif_mp-1096362_Sr2HgBi.cif',
#  'cif_mp-1096458_NaTlCd2.cif',
#  'cif_mp-1096492_Be2CrPt.cif',
#  'cif_mp-1096526_CsRbI2.cif',
#  'cif_mp-1096528_Y2InRu.cif',
#  'cif_mp-1096555_Ba2CdGa.cif',
#  'cif_mp-1096603_Ba2LiHg.cif',
#  'cif_mp-1096633_K2NaHg.cif',
#  'cif_mp-1096686_TlBiPb2.cif',
#  'cif_mp-1096688_Ba2LiTl.cif',
#  'cif_mp-1096696_Y2PtRh.cif',
#  'cif_mp-1096708_NaAgPd2.cif',
#  'cif_mp-1096726_BaNa2Sn.cif',
#  'cif_mp-1096761_KRb2Na.cif',
#  'cif_mp-1096769_Ni3Cl4.cif',
#  'cif_mp-1096798_ScAgO2.cif',
#  'cif_mp-1096811_Al(BiO2)2.cif',
#  'cif_mp-1096842_Ba3SnS5.cif',
#  'cif_mp-1096889_CrN2.cif',
#  'cif_mp-1096945_DyMn2O4.cif',
#  'cif_mp-1096957_CrN2.cif',
#  'cif_mp-1096995_HfSO.cif',
#  'cif_mp-1097065_Li2HfN2.cif',
#  'cif_mp-1097153_LiAl2Co.cif',
#  'cif_mp-1097167_Ti2IrOs.cif',
#  'cif_mp-1097216_CaPd2Pb.cif',
#  'cif_mp-1097236_Li2SnPb.cif',
#  'cif_mp-1097309_Ba2InHg.cif',
#  'cif_mp-1097321_MgCuPd2.cif',
#  'cif_mp-1097383_SrSnHg2.cif',
#  'cif_mp-1097411_GaSnRu2.cif',
#  'cif_mp-1097497_CaSbRh2.cif',
#  'cif_mp-1097506_LiCdIn2.cif',
#  'cif_mp-1097512_LiZnCd2.cif',
#  'cif_mp-1097515_K2AgAu.cif',
#  'cif_mp-1097623_Ca2PdRh.cif',
#  'cif_mp-1097628_Be2IrAu.cif',
#  'cif_mp-1097632_NbMo2W.cif',
#  'cif_mp-1097635_NaSr2Ca.cif',
#  'cif_mp-1097654_Mn2CoTc.cif',
#  'cif_mp-1097889_NiBrO.cif',
#  'cif_mp-1097905_Li3Mn4O8.cif',
#  'cif_mp-1098064_CsHfMg14O15.cif',
#  'cif_mp-1098122_KMg6Nb.cif',
#  'cif_mp-1098346_Mg30SnCO32.cif',
#  'cif_mp-1098422_LiMg30BO31.cif',
#  'cif_mp-1099092_SrMg14Fe.cif',
#  'cif_mp-1099115_CsCeMg14.cif',
#  'cif_mp-1099222_CsMg14CrO16.cif',
#  'cif_mp-1099265_YMg6Cu.cif',
#  'cif_mp-1099266_YMg6Ni.cif',
#  'cif_mp-1099287_Mg6FeC.cif',
#  'cif_mp-1099288_RbMg6Co.cif',
#  'cif_mp-1099315_RbMg6Ti.cif',
#  'cif_mp-1099572_MnInF3.cif',
#  'cif_mp-1099653_Sr2Ca6FeCo7O20.cif',
#  'cif_mp-1099703_Sr3CaTi3MnO12.cif',
#  'cif_mp-1099945_KNaW2O5.cif',
#  'cif_mp-1100085_Ba3SrCoCu3O10.cif',
#  'cif_mp-1100163_RbMg6Mo.cif',
#  'cif_mp-1100395_BaBrCl.cif',
#  'cif_mp-1100417_VSbRh.cif',
#  'cif_mp-1100438_LiScSn.cif',
#  'cif_mp-1100486_Li9Mn7O16.cif',
#  'cif_mp-1100526_Li9Mn7O16.cif',
#  'cif_mp-1100536_Li9Mn7O16.cif',
#  'cif_mp-1100556_Li9Mn7O16.cif',
#  'cif_mp-1100570_Li9Mn2Co5O16.cif',
#  'cif_mp-1100595_Li9Mn2Co5O16.cif',
#  'cif_mp-1100597_Li9Mn2Co5O16.cif',
#  'cif_mp-1100602_Li9Mn2Co5O16.cif',
#  'cif_mp-1100616_Li9Mn2Co5O16.cif',
#  'cif_mp-1100655_Li9Mn2Co5O16.cif',
#  'cif_mp-1100657_Li9Mn2Co5O16.cif',
#  'cif_mp-11006_BaPS3.cif',
#  'cif_mp-1100701_Li9Mn2Co5O16.cif',
#  'cif_mp-1100714_Li9Mn2Co5O16.cif',
#  'cif_mp-1100720_Li9Mn2Co5O16.cif',
#  'cif_mp-1100727_Li9Mn2Co5O16.cif',
#  'cif_mp-1100751_Li9Mn2Co5O16.cif',
#  'cif_mp-1100753_Li9Mn2Co5O16.cif',
#  'cif_mp-1100785_SrEuIn2.cif',
#  'cif_mp-1100895_Y5O4F7.cif',
#  'cif_mp-1100928_VMoO5.cif',
#  'cif_mp-1100997_TlCr5Te8.cif',
#  'cif_mp-1101073_TiZn(BiO3)2.cif',
#  'cif_mp-1101184_V3O5F.cif',
#  'cif_mp-1101221_V4O5F7.cif',
#  'cif_mp-1101295_Ti2O3.cif',
#  'cif_mp-1101300_TiMn3Fe2(PO4)6.cif',
#  'cif_mp-1101345_SrCaI4.cif',
#  'cif_mp-1101509_LiMo(PO4)2.cif',
#  'cif_mp-1101524_LiFe2(PO4)3.cif',
#  'cif_mp-1101525_LiSn(PO3)4.cif',
#  'cif_mp-1101562_Cr(PO3)5.cif',
#  'cif_mp-1101785_YCoGe.cif',
#  'cif_mp-1101790_CrNiP.cif',
#  'cif_mp-1101818_BaLaAgSe3.cif',
#  'cif_mp-1101900_LuCo3.cif',
#  'cif_mp-1101972_CdF2.cif',
#  'cif_mp-1102029_CsUTe3Au.cif',
#  'cif_mp-1102101_ScCoSn.cif',
#  'cif_mp-1102449_SmAlAu.cif',
#  'cif_mp-1102477_Eu2Si.cif',
#  'cif_mp-1102532_NbGeRh.cif',
#  'cif_mp-1102554_CuClO.cif',
#  'cif_mp-1102589_SrNiGe.cif',
#  'cif_mp-1102641_PdC2(NO)4.cif',
#  'cif_mp-1102760_DyGaNi.cif',
#  'cif_mp-1102778_Dy2In8Co.cif',
#  'cif_mp-1102948_GdNi4B.cif',
#  'cif_mp-1102968_Tm2(NiB2)3.cif',
#  'cif_mp-1102977_GaAsO4.cif',
#  'cif_mp-1102997_VBiO4.cif',
#  'cif_mp-1103144_CBrN3O.cif',
#  'cif_mp-1103172_CaCdPd.cif',
#  'cif_mp-1103229_Li4Sm3Ge4.cif',
#  'cif_mp-1103369_CuWO4.cif',
#  'cif_mp-1103431_Ga2Au.cif',
#  'cif_mp-1103475_TeO2.cif',
#  'cif_mp-1103493_Tm(Mo3S4)2.cif',
#  'cif_mp-1103573_Sm3Zn11.cif',
#  'cif_mp-1103663_Sr3TaHO6.cif',
#  'cif_mp-1103679_CuWO4.cif',
#  'cif_mp-1103792_Nb2O2F3.cif',
#  'cif_mp-1103827_Cu(NF2)2.cif',
#  'cif_mp-1103844_Ho(MnAl2)4.cif',
#  'cif_mp-11038_Zr6Al2Fe.cif',
#  'cif_mp-1103954_Tb3Ga8Ir3.cif',
#  'cif_mp-1103959_Ho4(CoB2)3.cif',
#  'cif_mp-1104015_CsMoO2F3.cif',
#  'cif_mp-1104028_HgC2(NO)2.cif',
#  'cif_mp-1104047_Al4Tc.cif',
#  'cif_mp-1104221_Ho(Ni2P)2.cif',
#  'cif_mp-1104253_Lu3Ga8Cu3.cif',
#  'cif_mp-1104261_LiFePO4.cif',
#  'cif_mp-1104279_Tb3GaCo3.cif',
#  'cif_mp-1104405_Na(SO2)2.cif',
#  'cif_mp-1104451_SmGa6.cif',
#  'cif_mp-1104471_Mo(Br2N)2.cif',
#  'cif_mp-1104676_Os(SeBr6)2.cif',
#  'cif_mp-1104693_LiCa2HC3.cif',
#  'cif_mp-1104717_Na2AgF4.cif',
#  'cif_mp-1104730_Sm(Ni2Sn)2.cif',
#  'cif_mp-1104744_Hg(CO2)2.cif',
#  'cif_mp-1104854_Ni3(PbS)2.cif',
#  'cif_mp-1105102_Sm3GaCo3.cif',
#  'cif_mp-1105118_As2O3.cif',
#  'cif_mp-1105139_Zr3Sb.cif',
#  'cif_mp-1105167_VCuO3.cif',
#  'cif_mp-11051_NaSn.cif',
#  'cif_mp-1105280_LiTaO3.cif',
#  'cif_mp-1105365_KNO3.cif',
#  'cif_mp-1105402_Sr2DyMoO6.cif',
#  'cif_mp-1105463_Cu5(AsO5)2.cif',
#  'cif_mp-1105594_La3Cu3Sb4.cif',
#  'cif_mp-1105648_Zn2BrN.cif',
#  'cif_mp-1105718_NiBiO3.cif',
#  'cif_mp-1105724_Ba2ErGaTe5.cif',
#  'cif_mp-1105730_CaU(PbO3)2.cif',
#  'cif_mp-1105734_Ho2Co7.cif',
#  'cif_mp-1105779_ZnHg3(SCl2)2.cif',
#  'cif_mp-1105877_Si2Ni3H4O9.cif',
#  'cif_mp-1105910_Pu2Zn17.cif',
#  'cif_mp-1105914_KCaH3.cif',
#  'cif_mp-1105938_K2Dy4Cu4S9.cif',
#  'cif_mp-1105942_Sm5Ga3.cif',
#  'cif_mp-1105949_Eu5Sb3.cif',
#  'cif_mp-1105959_Re5Si3.cif',
#  'cif_mp-1106075_KAuC2N2Cl2O.cif',
#  'cif_mp-1106096_Ba2YInTe5.cif',
#  'cif_mp-1106113_HfSO7.cif',
#  'cif_mp-1106183_LiAlS2.cif',
#  'cif_mp-1106184_MnB4.cif',
#  'cif_mp-1106249_Ba4Co(ReO6)2.cif',
#  'cif_mp-1106290_Er2S3.cif',
#  'cif_mp-1106297_Ho4Ga12Fe.cif',
#  'cif_mp-1106357_Tb5Sn3.cif',
#  'cif_mp-1106363_Ho3Sb4Au3.cif',
#  'cif_mp-1110591_Rb2GaAuF6.cif',
#  'cif_mp-1110627_RbNa2AlF6.cif',
#  'cif_mp-1110630_Rb2LiNbF6.cif',
#  'cif_mp-1110675_K2RbBiF6.cif',
#  'cif_mp-1110708_Rb2LiSbBr6.cif',
#  'cif_mp-1110736_Rb3AlBr6.cif',
#  'cif_mp-1110824_Rb2NdAgI6.cif',
#  'cif_mp-1110869_K2LiBiCl6.cif',
#  'cif_mp-1110873_K2AgSbCl6.cif',
#  'cif_mp-11108_SrP3.cif',
#  'cif_mp-1110902_K2LiBiBr6.cif',
#  'cif_mp-1110993_Na2TlCuBr6.cif',
#  'cif_mp-1111019_KNa2AlF6.cif',
#  'cif_mp-1111089_Na2AsAuF6.cif',
#  'cif_mp-1111180_Na2FeHgF6.cif',
#  'cif_mp-1111185_K3AlBr6.cif',
#  'cif_mp-1111189_Na2CoHgF6.cif',
#  'cif_mp-1111289_Na2CuAsF6.cif',
#  'cif_mp-1111290_Li3CoF6.cif',
#  'cif_mp-1111310_Cs2TaCuF6.cif',
#  'cif_mp-1111315_Na2TiAgF6.cif',
#  'cif_mp-1111318_K3TlI6.cif',
#  'cif_mp-1111479_Cs2RbTmCl6.cif',
#  'cif_mp-1111508_Na2ErCuCl6.cif',
#  'cif_mp-1111538_Na2AgSbCl6.cif',
#  'cif_mp-1111541_Na2AgAuCl6.cif',
#  'cif_mp-1111586_Na2AlAgBr6.cif',
#  'cif_mp-1111667_Na2AlHgCl6.cif',
#  'cif_mp-1111671_K2LiInF6.cif',
#  'cif_mp-1111675_K2LiCeCl6.cif',
#  'cif_mp-1111722_Rb2AlAuBr6.cif',
#  'cif_mp-1111779_CsRb2InBr6.cif',
#  'cif_mp-1111785_CsRb2AlBr6.cif',
#  'cif_mp-1111873_Cs2KSbCl6.cif',
#  'cif_mp-1111937_K2HgAuF6.cif',
#  'cif_mp-1111966_Cs2RbNbF6.cif',
#  'cif_mp-1111979_Cs2NaRhF6.cif',
#  'cif_mp-1112025_K2YHgBr6.cif',
#  'cif_mp-1112029_K2ScHgI6.cif',
#  'cif_mp-1112032_K2HgAsI6.cif',
#  'cif_mp-1112058_K2YAuBr6.cif',
#  'cif_mp-1112098_K2DyAgCl6.cif',
#  'cif_mp-1112118_Cs2RbSmCl6.cif',
#  'cif_mp-1112191_K2AlInBr6.cif',
#  'cif_mp-1112195_K2HgSbF6.cif',
#  'cif_mp-1112321_CsK2GaCl6.cif',
#  'cif_mp-1112376_Cs3AsBr6.cif',
#  'cif_mp-1112408_Rb2HgAsF6.cif',
#  'cif_mp-1112413_Rb2YCuBr6.cif',
#  'cif_mp-1112551_Cs2TlSbF6.cif',
#  'cif_mp-1112710_Cs2KScI6.cif',
#  'cif_mp-1112904_Cs2InHgCl6.cif',
#  'cif_mp-1112911_Cs2HgAsBr6.cif',
#  'cif_mp-1112921_Cs2TbAuCl6.cif',
#  'cif_mp-1112929_Cs2AsAuI6.cif',
#  'cif_mp-1112932_Cs2AlAuI6.cif',
#  'cif_mp-1113091_Cs2InSbF6.cif',
#  'cif_mp-1113222_Cs2TaAgCl6.cif',
#  'cif_mp-1113284_Na2LiTmCl6.cif',
#  'cif_mp-1113311_Na3AuCl6.cif',
#  'cif_mp-1113416_Cs2GaAuBr6.cif',
#  'cif_mp-1113487_Rb2FeCuF6.cif',
#  'cif_mp-1113506_Na3SmCl6.cif',
#  'cif_mp-1113542_Cs2LuAgCl6.cif',
#  'cif_mp-1113543_Cs2AgAsCl6.cif',
#  'cif_mp-1113739_Na2LiNdCl6.cif',
#  'cif_mp-1113748_Rb2LiAsF6.cif',
#  'cif_mp-1113839_Na2LiDyCl6.cif',
#  'cif_mp-1113854_Rb2TlRuF6.cif',
#  'cif_mp-1113863_Rb2TlMoF6.cif',
#  'cif_mp-1113919_Na2LiGdCl6.cif',
#  'cif_mp-1114004_Rb2TlGaCl6.cif',
#  'cif_mp-11140_Ho2Sb5.cif',
#  'cif_mp-1114122_KRb2InBr6.cif',
#  'cif_mp-1114131_Rb2InSbBr6.cif',
#  'cif_mp-11144_SrCu9Ge4.cif',
#  'cif_mp-11145_BaCu9Ge4.cif',
#  'cif_mp-11183_Pr(BO2)3.cif',
#  'cif_mp-1118832_Ca2WN2.cif',
#  'cif_mp-11206_LiTi(SiO3)2.cif',
#  'cif_mp-1120745_NaTiF4.cif',
#  'cif_mp-1120808_Ti2ZnSn2O7.cif',
#  'cif_mp-11220_Sc2Al.cif',
#  'cif_mp-11225_TbAl.cif',
#  'cif_mp-11285_Ca3(GaNi)4.cif',
#  'cif_mp-11293_ZrCdCu2.cif',
#  'cif_mp-11345_ZrP.cif',
#  'cif_mp-11369_ErHg2.cif',
#  'cif_mp-11387_HfGa3.cif',
#  'cif_mp-11392_TmGa2Pd.cif',
#  'cif_mp-11470_Hg2Pt.cif',
#  'cif_mp-1147533_BiBOF4.cif',
#  'cif_mp-1147554_LiLaSO.cif',
#  'cif_mp-1147563_Sr4Fe3ClO8.cif',
#  'cif_mp-1147610_Li6Zn3(PS4)4.cif',
#  'cif_mp-1147615_Nb(Cu3O4)2.cif',
#  'cif_mp-1147639_Cd(Cu3O4)2.cif',
#  'cif_mp-1147648_Sr2CoSeO2.cif',
#  'cif_mp-1147661_MgVS3.cif',
#  'cif_mp-1147677_Ca(Cu3O4)2.cif',
#  'cif_mp-1147713_La2CuS4.cif',
#  'cif_mp-1147743_Th2Cu(NO)2.cif',
#  'cif_mp-11508_MoP4.cif',
#  'cif_mp-11519_NiSnRh2.cif',
#  'cif_mp-1157313_Y2Cr3(SiO4)3.cif',
#  'cif_mp-11582_LiGaSe2.cif',
#  'cif_mp-11583_Zr2SN2.cif',
#  'cif_mp-11641_Ag2SeO4.cif',
#  'cif_mp-1172875_Mn2O3.cif',
#  'cif_mp-1173121_TbCuSe2.cif',
#  'cif_mp-1173246_Sr2Y4Fe2Cu2O13.cif',
#  'cif_mp-1173260_Sr2Li4MnS3O2.cif',
#  'cif_mp-1173333_Re3O10.cif',
#  'cif_mp-1173361_Rb4Sb2O5.cif',
#  'cif_mp-1173506_Nb9IrS20.cif',
#  'cif_mp-1173567_NaLaMgWO6.cif',
#  'cif_mp-1173635_Sr18La2MgRu9O40.cif',
#  'cif_mp-1173642_NaMnFe(PO4)2.cif',
#  'cif_mp-1173656_Na2PrO3.cif',
#  'cif_mp-1173715_NaCo2H3(SO5)2.cif',
#  'cif_mp-1173728_Na2MnCdFe(PO4)3.cif',
#  'cif_mp-1173750_NaCaAlFe(SiO3)4.cif',
#  'cif_mp-1173812_Na3Mg4ScSi8(O11F)2.cif',
#  'cif_mp-1173853_Na3Ca2Mg10Si16(O11F)4.cif',
#  'cif_mp-1173859_Na9Fe2P4HO18.cif',
#  'cif_mp-1173891_Li2CoO3.cif',
#  'cif_mp-1173910_Li2MnCoO4.cif',
#  'cif_mp-1173952_Li3Mn2O5.cif',
#  'cif_mp-1173959_Li3Mn2CoO6.cif',
#  'cif_mp-1174120_Li5Mn(CoO4)2.cif',
#  'cif_mp-1174195_Li3MnCoO5.cif',
#  'cif_mp-1174197_Li4Co3O7.cif',
#  'cif_mp-1174236_Li5Mn(CoO4)2.cif',
#  'cif_mp-1174277_Li3MnCoO5.cif',
#  'cif_mp-1174280_Li6Mn3CoO10.cif',
#  'cif_mp-1174316_Li4Mn3O7.cif',
#  'cif_mp-1174320_Li4Mn3O7.cif',
#  'cif_mp-1174339_Li4Co3O7.cif',
#  'cif_mp-1174347_Li4MnCo2O7.cif',
#  'cif_mp-1174390_Li4Co3O7.cif',
#  'cif_mp-1174406_Li5Mn2CoO8.cif',
#  'cif_mp-1174494_Li7Co5O12.cif',
#  'cif_mp-1174564_Li4MnCo2O7.cif',
#  'cif_mp-1174580_Li4MnCo2O7.cif',
#  'cif_mp-1174598_Li4MnCo2O7.cif',
#  'cif_mp-1174628_Li4MnCo2O7.cif',
#  'cif_mp-1174700_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1174758_Li5Mn3O8.cif',
#  'cif_mp-1174803_Li4MnCo2O7.cif',
#  'cif_mp-1174829_Li6Mn3CoO10.cif',
#  'cif_mp-1174830_Li6Mn3CoO10.cif',
#  'cif_mp-1174862_Li4MnCo2O7.cif',
#  'cif_mp-1174868_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1174953_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175061_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175064_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175101_Li7Mn2(CoO4)3.cif',
#  'cif_mp-1175307_Li7Mn4CoO12.cif',
#  'cif_mp-1175357_Li7Mn5O12.cif',
#  'cif_mp-1175358_Li7Mn5O12.cif',
#  'cif_mp-1175392_Li9Co7O16.cif',
#  'cif_mp-1175428_Li9Co7O16.cif',
#  'cif_mp-1175482_Li9Co7O16.cif',
#  'cif_mp-1175489_Li9Mn2Co5O16.cif',
#  'cif_mp-1175526_Li9Mn2Co5O16.cif',
#  'cif_mp-1175595_Li9Mn2Co5O16.cif',
#  'cif_mp-1175603_Li9Mn2Co5O16.cif',
#  'cif_mp-1175764_Li9Mn2Co5O16.cif',
#  'cif_mp-1175838_Li9Mn2Co5O16.cif',
#  'cif_mp-1175861_Li9Mn2Co5O16.cif',
#  'cif_mp-1175933_Li9Mn2Co5O16.cif',
#  'cif_mp-1175947_Li9Mn2Co5O16.cif',
#  'cif_mp-1176053_Li9Mn2Co5O16.cif',
#  'cif_mp-1176183_Li9Mn2Co5O16.cif',
#  'cif_mp-1176218_Li9Mn2Co5O16.cif',
#  'cif_mp-1176240_Li9Mn2Co5O16.cif',
#  'cif_mp-1176262_Li9Mn2Co5O16.cif',
#  ...]

# %%
len(files_)
# Out:
# 5425
